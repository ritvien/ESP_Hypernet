# %%
import os
import time
import math
import itertools
import yaml
import numpy as np
import torch
import torch.optim as optim
import matplotlib.pyplot as plt
from scipy.optimize import minimize, Bounds
from hypernet_MLP import Hypernet_MLP
from hypernet_trans import Hypernet_trans

# %%
def set_seed(seed=702):
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)

set_seed(702)

# %%
case = case = "_Ex_7_1"

# %% [markdown]
# # Const

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device = torch.device("cpu")
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
GROUND_TRUTH_FILE = f"../4_Pareto_front/test/{case}/pf_dynamic_true.npy" 

if os.path.exists(GROUND_TRUTH_FILE):
    pf_true = np.load(GROUND_TRUTH_FILE)
    print(f"✅ Đã tải ground truth Pareto front từ: {GROUND_TRUTH_FILE}, Shape: {pf_true.shape}")
else:
    print(f"❌ KHÔNG tìm thấy file ground truth tại: {GROUND_TRUTH_FILE}")
# Out:
# ✅ Đã tải ground truth Pareto front từ: ../4_Pareto_front/test/_Ex_7_1/pf_dynamic_true.npy, Shape: (20, 2)

# %% [markdown]
# # Def

# %%
import autograd.numpy as np
from scipy.optimize import minimize            
        
class Projection:
    def __init__(self, cons, bounds, dim, proj_type='euclid'):
        self.cons = cons
        self.bounds = bounds
        self.dim = dim
        self.proj_type = proj_type
        
        if self.proj_type == 'qplus':
            self.objective_func = self._obj_positive_diff
        elif self.proj_type == 'euclid':
            self.objective_func = self._obj_l2_norm
        else:
            print(f"Phép chiếu {self.objective_func} không cài đặt, chọn 'qplus' hoặc 'euclid'")

    def _obj_l2_norm(self, x, y):
        return np.sqrt(np.sum((x - y)**2))
    
    def _obj_positive_diff(self, x, y):
        v = np.maximum(y - x, 0) 
        return np.sum(v**2)

    def project(self, target_point):
        init_point = np.random.rand(1, self.dim).tolist()[0]
        
        res = minimize(
            self.objective_func,
            init_point,
            args=(target_point, ),
            constraints=self.cons,
            bounds=self.bounds,
            options={'disp': False}
        )
        
        optim_point = res.x
        
        if self.proj_type == 'qplus':
            return target_point - np.maximum(target_point - optim_point, 0)
        else:
            return optim_point

class Problem():
    def __init__(self, f, dim_x, dim_y, proj_C, proj_Qplus):
        self.f = f
        self.dim_x = dim_x
        self.dim_y = dim_y
        self.proj_C = proj_C
        self.proj_Qplus = proj_Qplus
    
    def objective_func(self, x):
        vals = [func(x) for func in self.f]
        return np.concatenate(vals)

# %%
def f1(x):    return x[0]
def f2(x):    return (x[0] - 1)**2
#--------------- C --------------------#
def c1(x):    return x[0]
def c2(x):    return -x[0] + 1
#--------------- Q --------------------#
def q1(y):    return 0.2**2 - (y[0] - 0.4)**2 - (y[1] - 0.4)**2

def q_plus(y):
    center = .4
    radius_sq = 0.2**2  
    dx = np.maximum(0, y[0] - center)
    dy = np.maximum(0, y[1] - center)
    return radius_sq - (dx**2 + dy**2)
# Hàm dùng cho Projection 
cons_C = ({'type': 'ineq', 'fun' : c1,},
          {'type': 'ineq', 'fun' : c2,})
dim_x = 1
bounds_x = None
cons_Q = ({'type': 'ineq', 'fun' : q1,},)
cons_Qplus = ({'type': 'ineq', 'fun': q_plus},)
dim_y = 2

# Setup Projections
proj_C_handler = Projection(cons=cons_C, bounds=bounds_x, dim=dim_x, proj_type='euclid')
proj_Q_handler = Projection(cons=cons_Q, bounds=None, dim=dim_y, proj_type='qplus')
# Setup Problem
prob = Problem(
    f=[f1, f2], 
    dim_x=dim_x, dim_y=dim_y,
    proj_C=proj_C_handler.project,
    proj_Qplus=proj_Q_handler.project
)
z_star = np.array([0.0, 0.0])

# %%
def evaluate_objectives_single(functions, x_tensor):
    vals = []
    for func in functions:
        val = func(x_tensor)
        if not torch.is_tensor(val): val = torch.tensor(val, dtype=torch.float32, device=x_tensor.device)
        vals.append(val)
    return torch.stack(vals).reshape(-1)

def calculate_mse_igd(pf_pred, pf_true):
    if len(pf_pred) == 0: return np.inf
    total_dist_sq = 0
    # Với mỗi điểm ground truth, tìm điểm dự đoán gần nhất
    for p_true in pf_true:
        dists_sq = np.sum((pf_pred - p_true)**2, axis=1)
        total_dist_sq += np.min(dists_sq)
    return total_dist_sq / len(pf_true)

def calculate_mse(pf_pred, pf_true):
    pf_pred_ = np.array(pf_pred)
    pf_true_ = np.array(pf_true)
    
    if pf_pred_.shape != pf_true_.shape:
        print(f"⚠️ Warning: Shape mismatch {pf_pred_.shape} vs {pf_true_.shape}. MSE có thể không chính xác.")
        return np.inf

    return np.mean((pf_pred_ - pf_true_)**2)

# %%
def train_hypernet(hypernet, prob, z_star, 
                   num_epochs=1000, lr=1e-3, num_partitions=50, 
                   lr_step_size=300, lr_gamma=0.5,
                   init_pen_C=1.0, max_pen_C=1000.0, pen_C_growth=1.01,
                   init_pen_Q=50.0, min_pen_Q=1.0, pen_Q_decay=0.995,
                   verbose=False):
    
    hypernet = hypernet.to(device)
    optimizer = optim.Adam(hypernet.parameters(), lr=lr)
    scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=lr_step_size, gamma=lr_gamma)
    z_star_tensor = torch.tensor(z_star, dtype=torch.float32, device=device).view(1, -1)
    
    current_pen_C = init_pen_C
    current_pen_Q = init_pen_Q
    angle_step = (math.pi / 2) / num_partitions
    
    for epoch in range(num_epochs):
        hypernet.train()
        optimizer.zero_grad()
        
        # 1. Stratified Sampling
        starts = torch.arange(num_partitions) * angle_step
        noise = torch.rand(num_partitions) * angle_step
        thetas = starts + noise
        r_batch_np = np.stack([np.cos(thetas.numpy()), np.sin(thetas.numpy())], axis=1)
        r_tensor_batch = torch.tensor(r_batch_np, dtype=torch.float32, device=device)
        
        # 2. Forward & Loss Calculation (Loop safe logic)
        loss_C_list = []
        loss_Q_list = []
        y_pred_list = []
        
        # Forward pass batch (Nhanh hơn gọi từng cái)
        x_vec_batch = hypernet(r_tensor_batch) # (Batch, 2)
        x_np_batch = x_vec_batch.detach().cpu().numpy()
        
        for i in range(num_partitions):
            x_i_tensor = x_vec_batch[i]
            x_i_np = x_np_batch[i]
            
            # Loss C
            x_proj_i_np = prob.proj_C(x_i_np)
            x_proj_i_tensor = torch.tensor(x_proj_i_np, dtype=torch.float32, device=device)
            loss_C_list.append(torch.sum((x_i_tensor - x_proj_i_tensor)**2))
            
            # F(x)
            y_pred_i = evaluate_objectives_single(prob.f, x_i_tensor)
            y_pred_list.append(y_pred_i)
            
            # Loss Q
            y_i_np = y_pred_i.detach().cpu().numpy()
            y_proj_i_np = prob.proj_Qplus(y_i_np)
            y_proj_i_tensor = torch.tensor(y_proj_i_np, dtype=torch.float32, device=device)
            loss_Q_list.append(torch.sum((y_pred_i - y_proj_i_tensor)**2))
            
        y_pred_batch = torch.stack(y_pred_list)
        loss_C = torch.mean(torch.stack(loss_C_list))
        loss_Q = torch.mean(torch.stack(loss_Q_list))
        
        # Chebyshev Loss
        diff = y_pred_batch - z_star_tensor
        weighted_diff = r_tensor_batch * diff
        max_vals, _ = torch.max(weighted_diff, dim=1)
        loss_obj = torch.mean(max_vals)
        
        total_loss = loss_obj + (current_pen_C * loss_C) + (current_pen_Q * loss_Q)
        
        total_loss.backward()
        optimizer.step()
        scheduler.step()
        
        # Update Penalties
        current_pen_C = min(max_pen_C, current_pen_C * pen_C_growth)
        current_pen_Q = max(min_pen_Q, current_pen_Q * pen_Q_decay)
        
        if verbose and epoch % (num_epochs // 5) == 0:
            print(f"  Ep {epoch}: Loss={total_loss.item():.2f} (Obj={loss_obj.item():.2f}, C={loss_C.item():.4f}, Q={loss_C.item():.4f})")
            
    return hypernet

# %%
def evaluate_model(hypernet, prob, test_rays, pf_true, calculate_metric):
    hypernet.eval()
    pf_pred = []
    
    # Chuyển test_rays sang tensor batch để infer nhanh
    rays_tensor = torch.tensor(test_rays, dtype=torch.float32, device=device)
    
    with torch.no_grad():
        x_raw = hypernet(rays_tensor) # (N, 2)
        x_raw_np = x_raw.cpu().numpy()
        
        # Loop project and eval
        for i in range(len(x_raw_np)):
            # Chiếu lên C (Quan trọng để feasible)
            x_proj = prob.proj_C(x_raw_np[i])
            # Tính f
            val = [func(x_proj) for func in prob.f]
            pf_pred.append(val)
            
    pf_pred = np.array(pf_pred)
    igd_score = calculate_metric(pf_pred, pf_true)
    return igd_score, pf_pred

# %% [markdown]
# # Config

# %%
param_grid = {
    'lr': [1e-3, 1e-4],
    'num_epochs': [500, 800],
    'pen_C_growth': [1.01],      # Tăng phạt C nhanh hay chậm
    'pen_Q_decay': [0.99, 0.995, 0.999],      
    'init_pen_C': [10.0],
    'init_pen_Q': [20.0, 50.0, 100.0],
    'max_pen_C': [500.0],
    'min_pen_Q': [10.0, 20.0, 50.0]
}

config_path='../4_Pareto_front/config.yaml'
with open(config_path, 'r') as f:
    cfg = yaml.safe_load(f)
test_rays = np.array(cfg['data']['test_ray'])

# %% [markdown]
# # Run

# %%
models = ["trans", "MLP"]
mode_tests = ["MSE", "MSE_IGD"]

# %%
results = []
best_scores_tracker = {}
save_dir = f"model/{case}"

# %%
for mode_test in mode_tests:
    if mode_test == "MSE":
        calculate_metric = calculate_mse
        metric_label = "MSE"
    else:
        calculate_metric = calculate_mse_igd
        metric_label = "IGD"
        
    print(f"\n{'='*40}")
    print(f"🚀 BẮT ĐẦU TEST VỚI METRIC: {mode_test}")
    print(f"{'='*40}")

    for model_name in models:
        print(f"\n🔹 Đang train Model: {model_name} | Metric tối ưu: {metric_label}")
        
        # Reset tracker cho cặp (model, metric) này
        current_best_score = float('inf')
        current_best_config = None
        
        # Tạo lưới tham số
        keys, values = zip(*param_grid.items())
        param_combinations = [dict(zip(keys, v)) for v in itertools.product(*values)]
        
        for idx, params in enumerate(param_combinations):
            print(f"\n   >>> Config {idx+1}/{len(param_combinations)}: {params}")
            
            # 1. Init Model
            if model_name == "MLP":
                # Đảm bảo dim_x đã được định nghĩa từ trước
                model = Hypernet_MLP(ray_hidden_dim=32, out_dim=dim_x, n_tasks=2)
            else:
                model = Hypernet_trans(ray_hidden_dim=32, out_dim=dim_x, n_tasks=2)
            
            # Đưa model lên device (nếu chưa xử lý trong init/train)
            # model = model.to(device) 

            # 2. Train
            start_time = time.time()
            # Lưu ý: Hàm train_hypernet cần được định nghĩa đúng các tham số truyền vào
            trained_model = train_hypernet(
                model, prob, z_star, 
                num_epochs=params['num_epochs'],
                lr=params['lr'],
                num_partitions=20, 
                init_pen_C=params['init_pen_C'],
                pen_C_growth=params['pen_C_growth'],
                init_pen_Q=params['init_pen_Q'],
                pen_Q_decay=params['pen_Q_decay'],
                min_pen_Q=params['min_pen_Q'],
                verbose=False # Tắt verbose chi tiết để log gọn hơn
            )
            train_time = time.time() - start_time

            # 3. Evaluate
            # Lưu ý: pf_true cần được định nghĩa từ trước
            score, pf_pred = evaluate_model(trained_model, prob, test_rays, pf_true, calculate_metric)

            print(f"      ⏱️ Time: {train_time:.2f}s | 📉 {metric_label}: {score:.4f}")

            # 4. Save result to List
            res = {
                'model_type': model_name,
                'metric_type': mode_test,
                'config_id': idx,
                'params': params,
                'score': score,
                'time': train_time
            }
            results.append(res)

            # 5. Update Best Model cho Cặp (Model, Metric) hiện tại
            if score < current_best_score:
                current_best_score = score
                current_best_config = params
                
                save_path = f"{save_dir}/best_hnet_{model_name}_{mode_test}.pth"
                torch.save(trained_model.state_dict(), save_path)
                print(f"      🏆 New Best Found! Saved to: {save_path}")

        print(f"\n✅ Hoàn thành {model_name} - {mode_test}. Best Score: {current_best_score:.4f}")
        print(f"   Best Config: {current_best_config}")
# Out:
# ========================================
# 🚀 BẮT ĐẦU TEST VỚI METRIC: MSE
# ========================================
#
# 🔹 Đang train Model: trans | Metric tối ưu: MSE
#
#    >>> Config 1/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 28.54s | 📉 MSE: 0.0051
#       🏆 New Best Found! Saved to: model/_Ex_7_1/best_hnet_trans_MSE.pth
#
#    >>> Config 2/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 27.44s | 📉 MSE: 0.0042
#       🏆 New Best Found! Saved to: model/_Ex_7_1/best_hnet_trans_MSE.pth
#
#    >>> Config 3/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 26.40s | 📉 MSE: 0.0019
#       🏆 New Best Found! Saved to: model/_Ex_7_1/best_hnet_trans_MSE.pth
#
#    >>> Config 4/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 27.86s | 📉 MSE: 0.0050
#
#    >>> Config 5/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 27.74s | 📉 MSE: 0.0044
#
#    >>> Config 6/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 28.12s | 📉 MSE: 0.0043
#
#    >>> Config 7/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 27.79s | 📉 MSE: 0.0051
#
#    >>> Config 8/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 28.00s | 📉 MSE: 0.0042
#
#    >>> Config 9/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 27.33s | 📉 MSE: 0.0040
#
#    >>> Config 10/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 27.75s | 📉 MSE: 0.0049
#
#    >>> Config 11/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 26.13s | 📉 MSE: 0.0017
#       🏆 New Best Found! Saved to: model/_Ex_7_1/best_hnet_trans_MSE.pth
#
#    >>> Config 12/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 27.98s | 📉 MSE: 0.0038
#
#    >>> Config 13/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 27.98s | 📉 MSE: 0.0052
#
#    >>> Config 14/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 27.65s | 📉 MSE: 0.0043
#
#    >>> Config 15/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 27.12s | 📉 MSE: 0.0034
#
#    >>> Config 16/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 25.81s | 📉 MSE: 0.0025
#
#    >>> Config 17/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 27.51s | 📉 MSE: 0.0040
#
#    >>> Config 18/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 28.15s | 📉 MSE: 0.0044
#
#    >>> Config 19/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 27.74s | 📉 MSE: 0.0047
#
#    >>> Config 20/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 28.05s | 📉 MSE: 0.0041
#
#    >>> Config 21/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 27.19s | 📉 MSE: 0.0036
#
#    >>> Config 22/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 27.35s | 📉 MSE: 0.0037
#
#    >>> Config 23/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 27.28s | 📉 MSE: 0.0040
#
#    >>> Config 24/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 25.88s | 📉 MSE: 0.0010
#       🏆 New Best Found! Saved to: model/_Ex_7_1/best_hnet_trans_MSE.pth
#
#    >>> Config 25/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 26.29s | 📉 MSE: 0.0012
#
#    >>> Config 26/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 25.90s | 📉 MSE: 0.0026
#
#    >>> Config 27/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 28.16s | 📉 MSE: 0.0042
#
#    >>> Config 28/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 44.74s | 📉 MSE: 0.0050
#
#    >>> Config 29/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 44.85s | 📉 MSE: 0.0045
#
#    >>> Config 30/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 44.35s | 📉 MSE: 0.0039
#
#    >>> Config 31/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 44.86s | 📉 MSE: 0.0053
#
#    >>> Config 32/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 44.07s | 📉 MSE: 0.0040
#
#    >>> Config 33/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 45.56s | 📉 MSE: 0.0040
#
#    >>> Config 34/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 45.12s | 📉 MSE: 0.0052
#
#    >>> Config 35/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 44.87s | 📉 MSE: 0.0045
#
#    >>> Config 36/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 44.64s | 📉 MSE: 0.0039
#
#    >>> Config 37/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 44.99s | 📉 MSE: 0.0051
#
#    >>> Config 38/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 44.99s | 📉 MSE: 0.0044
#
#    >>> Config 39/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 44.77s | 📉 MSE: 0.0039
#
#    >>> Config 40/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 43.80s | 📉 MSE: 0.0048
#
#    >>> Config 41/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 44.20s | 📉 MSE: 0.0039
#
#    >>> Config 42/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 44.31s | 📉 MSE: 0.0035
#
#    >>> Config 43/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 44.61s | 📉 MSE: 0.0047
#
#    >>> Config 44/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 45.05s | 📉 MSE: 0.0044
#
#    >>> Config 45/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 44.40s | 📉 MSE: 0.0039
#
#    >>> Config 46/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 44.00s | 📉 MSE: 0.0047
#
#    >>> Config 47/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 44.33s | 📉 MSE: 0.0036
#
#    >>> Config 48/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 44.75s | 📉 MSE: 0.0041
#
#    >>> Config 49/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 44.42s | 📉 MSE: 0.0045
#
#    >>> Config 50/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 45.10s | 📉 MSE: 0.0045
#
#    >>> Config 51/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 45.43s | 📉 MSE: 0.0041
#
#    >>> Config 52/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 44.65s | 📉 MSE: 0.0040
#
#    >>> Config 53/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 43.15s | 📉 MSE: 0.0036
#
#    >>> Config 54/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 45.26s | 📉 MSE: 0.0041
#
#    >>> Config 55/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 28.03s | 📉 MSE: 0.0289
#
#    >>> Config 56/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 27.08s | 📉 MSE: 0.0037
#
#    >>> Config 57/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 27.85s | 📉 MSE: 0.0431
#
#    >>> Config 58/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 26.60s | 📉 MSE: 0.0046
#
#    >>> Config 59/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 26.36s | 📉 MSE: 0.0021
#
#    >>> Config 60/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 27.89s | 📉 MSE: 0.0493
#
#    >>> Config 61/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 26.37s | 📉 MSE: 0.0042
#
#    >>> Config 62/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 27.49s | 📉 MSE: 0.0041
#
#    >>> Config 63/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 28.40s | 📉 MSE: 0.0285
#
#    >>> Config 64/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 27.23s | 📉 MSE: 0.0072
#
#    >>> Config 65/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 27.22s | 📉 MSE: 0.0044
#
#    >>> Config 66/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 27.72s | 📉 MSE: 0.0036
#
#    >>> Config 67/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 27.57s | 📉 MSE: 0.0052
#
#    >>> Config 68/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 27.20s | 📉 MSE: 0.0097
#
#    >>> Config 69/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 27.89s | 📉 MSE: 0.0169
#
#    >>> Config 70/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 27.38s | 📉 MSE: 0.0049
#
#    >>> Config 71/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 29.86s | 📉 MSE: 0.0499
#
#    >>> Config 72/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 29.07s | 📉 MSE: 0.0419
#
#    >>> Config 73/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 27.29s | 📉 MSE: 0.0033
#
#    >>> Config 74/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 26.24s | 📉 MSE: 0.0011
#
#    >>> Config 75/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 27.53s | 📉 MSE: 0.0038
#
#    >>> Config 76/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 27.82s | 📉 MSE: 0.0031
#
#    >>> Config 77/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 26.98s | 📉 MSE: 0.0032
#
#    >>> Config 78/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 27.47s | 📉 MSE: 0.0035
#
#    >>> Config 79/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 26.42s | 📉 MSE: 0.0032
#
#    >>> Config 80/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 27.10s | 📉 MSE: 0.0071
#
#    >>> Config 81/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 27.06s | 📉 MSE: 0.0018
#
#    >>> Config 82/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 42.81s | 📉 MSE: 0.0045
#
#    >>> Config 83/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 44.25s | 📉 MSE: 0.0037
#
#    >>> Config 84/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 42.50s | 📉 MSE: 0.0015
#
#    >>> Config 85/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 45.22s | 📉 MSE: 0.0150
#
#    >>> Config 86/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 44.43s | 📉 MSE: 0.0042
#
#    >>> Config 87/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 42.31s | 📉 MSE: 0.0038
#
#    >>> Config 88/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 42.18s | 📉 MSE: 0.0017
#
#    >>> Config 89/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 47.62s | 📉 MSE: 0.0397
#
#    >>> Config 90/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 43.80s | 📉 MSE: 0.0040
#
#    >>> Config 91/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 44.62s | 📉 MSE: 0.0048
#
#    >>> Config 92/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 42.81s | 📉 MSE: 0.0040
#
#    >>> Config 93/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 42.08s | 📉 MSE: 0.0024
#
#    >>> Config 94/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 42.83s | 📉 MSE: 0.0044
#
#    >>> Config 95/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 43.34s | 📉 MSE: 0.0033
#
#    >>> Config 96/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 43.82s | 📉 MSE: 0.0072
#
#    >>> Config 97/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 43.04s | 📉 MSE: 0.0196
#
#    >>> Config 98/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 45.95s | 📉 MSE: 0.0429
#
#    >>> Config 99/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 44.99s | 📉 MSE: 0.0389
#
#    >>> Config 100/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 44.75s | 📉 MSE: 0.0049
#
#    >>> Config 101/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 43.25s | 📉 MSE: 0.0049
#
#    >>> Config 102/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 44.99s | 📉 MSE: 0.0041
#
#    >>> Config 103/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 44.05s | 📉 MSE: 0.0188
#
#    >>> Config 104/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 42.84s | 📉 MSE: 0.0049
#
#    >>> Config 105/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 41.57s | 📉 MSE: 0.0010
#       🏆 New Best Found! Saved to: model/_Ex_7_1/best_hnet_trans_MSE.pth
#
#    >>> Config 106/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 43.78s | 📉 MSE: 0.0427
#
#    >>> Config 107/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 41.94s | 📉 MSE: 0.0013
#
#    >>> Config 108/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 42.11s | 📉 MSE: 0.0014
#
# ✅ Hoàn thành trans - MSE. Best Score: 0.0010
#    Best Config: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#
# 🔹 Đang train Model: MLP | Metric tối ưu: MSE
#
#    >>> Config 1/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 27.52s | 📉 MSE: 0.0051
#       🏆 New Best Found! Saved to: model/_Ex_7_1/best_hnet_MLP_MSE.pth
#
#    >>> Config 2/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 27.34s | 📉 MSE: 0.0044
#       🏆 New Best Found! Saved to: model/_Ex_7_1/best_hnet_MLP_MSE.pth
#
#    >>> Config 3/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 27.35s | 📉 MSE: 0.0042
#       🏆 New Best Found! Saved to: model/_Ex_7_1/best_hnet_MLP_MSE.pth
#
#    >>> Config 4/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 27.31s | 📉 MSE: 0.0051
#
#    >>> Config 5/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 27.15s | 📉 MSE: 0.0045
#
#    >>> Config 6/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 27.53s | 📉 MSE: 0.0042
#       🏆 New Best Found! Saved to: model/_Ex_7_1/best_hnet_MLP_MSE.pth
#
#    >>> Config 7/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 24.91s | 📉 MSE: 0.0088
#
#    >>> Config 8/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 27.20s | 📉 MSE: 0.0044
#
#    >>> Config 9/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 26.43s | 📉 MSE: 0.0106
#
#    >>> Config 10/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 27.04s | 📉 MSE: 0.0051
#
#    >>> Config 11/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 27.32s | 📉 MSE: 0.0042
#
#    >>> Config 12/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 26.13s | 📉 MSE: 0.0042
#
#    >>> Config 13/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 25.89s | 📉 MSE: 0.0048
#
#    >>> Config 14/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 26.59s | 📉 MSE: 0.0045
#
#    >>> Config 15/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 25.48s | 📉 MSE: 0.0037
#       🏆 New Best Found! Saved to: model/_Ex_7_1/best_hnet_MLP_MSE.pth
#
#    >>> Config 16/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 26.53s | 📉 MSE: 0.0051
#
#    >>> Config 17/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 25.31s | 📉 MSE: 0.0041
#
#    >>> Config 18/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 26.13s | 📉 MSE: 0.0037
#       🏆 New Best Found! Saved to: model/_Ex_7_1/best_hnet_MLP_MSE.pth
#
#    >>> Config 19/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 26.58s | 📉 MSE: 0.0047
#
#    >>> Config 20/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 26.92s | 📉 MSE: 0.0046
#
#    >>> Config 21/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 26.12s | 📉 MSE: 0.0038
#
#    >>> Config 22/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 24.96s | 📉 MSE: 0.0010
#       🏆 New Best Found! Saved to: model/_Ex_7_1/best_hnet_MLP_MSE.pth
#
#    >>> Config 23/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 26.65s | 📉 MSE: 0.0042
#
#    >>> Config 24/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 26.56s | 📉 MSE: 0.0037
#
#    >>> Config 25/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 26.12s | 📉 MSE: 0.0041
#
#    >>> Config 26/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 25.02s | 📉 MSE: 0.0115
#
#    >>> Config 27/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 26.21s | 📉 MSE: 0.0025
#
#    >>> Config 28/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 44.52s | 📉 MSE: 0.0051
#
#    >>> Config 29/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 43.92s | 📉 MSE: 0.0044
#
#    >>> Config 30/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 44.50s | 📉 MSE: 0.0041
#
#    >>> Config 31/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 43.72s | 📉 MSE: 0.0051
#
#    >>> Config 32/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 42.67s | 📉 MSE: 0.0041
#
#    >>> Config 33/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 43.65s | 📉 MSE: 0.0039
#
#    >>> Config 34/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 43.44s | 📉 MSE: 0.0051
#
#    >>> Config 35/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 41.08s | 📉 MSE: 0.0039
#
#    >>> Config 36/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 43.98s | 📉 MSE: 0.0041
#
#    >>> Config 37/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 43.95s | 📉 MSE: 0.0051
#
#    >>> Config 38/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 43.76s | 📉 MSE: 0.0042
#
#    >>> Config 39/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 44.31s | 📉 MSE: 0.0041
#
#    >>> Config 40/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 44.22s | 📉 MSE: 0.0051
#
#    >>> Config 41/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 45.48s | 📉 MSE: 0.0046
#
#    >>> Config 42/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 44.51s | 📉 MSE: 0.0038
#
#    >>> Config 43/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 43.62s | 📉 MSE: 0.0050
#
#    >>> Config 44/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 43.28s | 📉 MSE: 0.0044
#
#    >>> Config 45/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 42.66s | 📉 MSE: 0.0038
#
#    >>> Config 46/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 43.45s | 📉 MSE: 0.0051
#
#    >>> Config 47/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 43.69s | 📉 MSE: 0.0044
#
#    >>> Config 48/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 42.03s | 📉 MSE: 0.0036
#
#    >>> Config 49/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 44.37s | 📉 MSE: 0.0045
#
#    >>> Config 50/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 41.70s | 📉 MSE: 0.0042
#
#    >>> Config 51/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 42.51s | 📉 MSE: 0.0039
#
#    >>> Config 52/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 41.30s | 📉 MSE: 0.0033
#
#    >>> Config 53/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 42.93s | 📉 MSE: 0.0041
#
#    >>> Config 54/108: {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 42.34s | 📉 MSE: 0.0040
#
#    >>> Config 55/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 28.93s | 📉 MSE: 0.0614
#
#    >>> Config 56/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 25.85s | 📉 MSE: 0.0042
#
#    >>> Config 57/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 28.70s | 📉 MSE: 0.0463
#
#    >>> Config 58/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 30.00s | 📉 MSE: 0.0519
#
#    >>> Config 59/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 28.04s | 📉 MSE: 0.0335
#
#    >>> Config 60/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 27.05s | 📉 MSE: 0.1386
#
#    >>> Config 61/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 27.50s | 📉 MSE: 0.1023
#
#    >>> Config 62/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 30.19s | 📉 MSE: 0.0506
#
#    >>> Config 63/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 27.43s | 📉 MSE: 0.1257
#
#    >>> Config 64/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 29.73s | 📉 MSE: 0.0605
#
#    >>> Config 65/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 27.23s | 📉 MSE: 0.0040
#
#    >>> Config 66/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 27.22s | 📉 MSE: 0.0032
#
#    >>> Config 67/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 29.25s | 📉 MSE: 0.0567
#
#    >>> Config 68/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 30.14s | 📉 MSE: 0.0765
#
#    >>> Config 69/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 29.29s | 📉 MSE: 0.0587
#
#    >>> Config 70/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 30.49s | 📉 MSE: 0.0514
#
#    >>> Config 71/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 29.63s | 📉 MSE: 0.0610
#
#    >>> Config 72/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 27.20s | 📉 MSE: 0.0063
#
#    >>> Config 73/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 27.45s | 📉 MSE: 0.0102
#
#    >>> Config 74/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 28.22s | 📉 MSE: 0.0336
#
#    >>> Config 75/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 26.76s | 📉 MSE: 0.0146
#
#    >>> Config 76/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 30.26s | 📉 MSE: 0.0608
#
#    >>> Config 77/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 28.94s | 📉 MSE: 0.0555
#
#    >>> Config 78/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 28.89s | 📉 MSE: 0.0396
#
#    >>> Config 79/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 28.52s | 📉 MSE: 0.1185
#
#    >>> Config 80/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 30.98s | 📉 MSE: 0.0582
#
#    >>> Config 81/108: {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 30.38s | 📉 MSE: 0.0535
#
#    >>> Config 82/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 42.42s | 📉 MSE: 0.0046
#
#    >>> Config 83/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 43.14s | 📉 MSE: 0.0111
#
#    >>> Config 84/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 45.47s | 📉 MSE: 0.0558
#
#    >>> Config 85/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 45.66s | 📉 MSE: 0.0258
#
#    >>> Config 86/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 45.84s | 📉 MSE: 0.0344
#
#    >>> Config 87/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 47.24s | 📉 MSE: 0.0482
#
#    >>> Config 88/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 48.11s | 📉 MSE: 0.0503
#
#    >>> Config 89/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 49.41s | 📉 MSE: 0.0568
#
#    >>> Config 90/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 46.38s | 📉 MSE: 0.0688
#
#    >>> Config 91/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 45.64s | 📉 MSE: 0.0340
#
#    >>> Config 92/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 45.07s | 📉 MSE: 0.0417
#
#    >>> Config 93/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 47.35s | 📉 MSE: 0.0512
#
#    >>> Config 94/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 48.94s | 📉 MSE: 0.0787
#
#    >>> Config 95/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 47.49s | 📉 MSE: 0.0456
#
#    >>> Config 96/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 45.85s | 📉 MSE: 0.0504
#
#    >>> Config 97/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 47.54s | 📉 MSE: 0.0783
#
#    >>> Config 98/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 44.16s | 📉 MSE: 0.0318
#
#    >>> Config 99/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 45.43s | 📉 MSE: 0.0244
#
#    >>> Config 100/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 46.10s | 📉 MSE: 0.0462
#
#    >>> Config 101/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 44.24s | 📉 MSE: 0.0238
#
#    >>> Config 102/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 42.70s | 📉 MSE: 0.0093
#
#    >>> Config 103/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 41.80s | 📉 MSE: 0.0038
#
#    >>> Config 104/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 44.54s | 📉 MSE: 0.0307
#
#    >>> Config 105/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 44.83s | 📉 MSE: 0.0478
#
#    >>> Config 106/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 47.36s | 📉 MSE: 0.0527
#
#    >>> Config 107/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 45.71s | 📉 MSE: 0.0632
#
#    >>> Config 108/108: {'lr': 0.0001, 'num_epochs': 800, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 44.97s | 📉 MSE: 0.0487
#
# ✅ Hoàn thành MLP - MSE. Best Score: 0.0010
#    Best Config: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.999, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#
# ========================================
# 🚀 BẮT ĐẦU TEST VỚI METRIC: MSE_IGD
# ========================================
#
# 🔹 Đang train Model: trans | Metric tối ưu: IGD
#
#    >>> Config 1/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 27.46s | 📉 IGD: 0.0002
#       🏆 New Best Found! Saved to: model/_Ex_7_1/best_hnet_trans_MSE_IGD.pth
#
#    >>> Config 2/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 28.06s | 📉 IGD: 0.0002
#       🏆 New Best Found! Saved to: model/_Ex_7_1/best_hnet_trans_MSE_IGD.pth
#
#    >>> Config 3/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 28.27s | 📉 IGD: 0.0001
#       🏆 New Best Found! Saved to: model/_Ex_7_1/best_hnet_trans_MSE_IGD.pth
#
#    >>> Config 4/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 28.85s | 📉 IGD: 0.0002
#
#    >>> Config 5/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 28.21s | 📉 IGD: 0.0002
#
#    >>> Config 6/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
#       ⏱️ Time: 28.26s | 📉 IGD: 0.0002
#
#    >>> Config 7/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 10.0}
#       ⏱️ Time: 26.03s | 📉 IGD: 0.0015
#
#    >>> Config 8/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 20.0}
#       ⏱️ Time: 26.34s | 📉 IGD: 0.0073
#
#    >>> Config 9/108: {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.99, 'init_pen_C': 10.0, 'init_pen_Q': 100.0, 'max_pen_C': 500.0, 'min_pen_Q': 50.0}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 40
#      38 start_time = time.time()
#      39 # Lưu ý: Hàm train_hypernet cần được định nghĩa đúng các tham số truyền vào
# ---> 40 trained_model = train_hypernet(
#      41     model, prob, z_star,
#      42     num_epochs=params['num_epochs'],
#      43     lr=params['lr'],
#      44     num_partitions=20,
#      45     init_pen_C=params['init_pen_C'],
#      46     pen_C_growth=params['pen_C_growth'],
#      47     init_pen_Q=params['init_pen_Q'],
#      48     pen_Q_decay=params['pen_Q_decay'],
#      49     min_pen_Q=params['min_pen_Q'],
#      50     verbose=False # Tắt verbose chi tiết để log gọn hơn
#      51 )
#      52 train_time = time.time() - start_time
#      54 # 3. Evaluate
#      55 # Lưu ý: pf_true cần được định nghĩa từ trước
#
# Cell In[19], line 43, in train_hypernet(hypernet, prob, z_star, num_epochs, lr, num_partitions, lr_step_size, lr_gamma, init_pen_C, max_pen_C, pen_C_growth, init_pen_Q, min_pen_Q, pen_Q_decay, verbose)
#      41 # Loss C
#      42 x_proj_i_np = prob.proj_C(x_i_np)
# ---> 43 x_proj_i_tensor = torch.tensor(x_proj_i_np, dtype=torch.float32, device=device)
#      44 loss_C_list.append(torch.sum((x_i_tensor - x_proj_i_tensor)**2))
#      46 # F(x)
#
# KeyboardInterrupt:

# %%
df_results = pd.DataFrame(results)
print("\n=== TỔNG HỢP KẾT QUẢ ===")
df_results.sort_values(by=['metric_type', 'model_type', 'score'])
# Out:
# === TỔNG HỢP KẾT QUẢ ===
#     model_type metric_type  config_id  \
# 129        MLP         MSE         21
# 134        MLP         MSE         26
# 173        MLP         MSE         65
# 159        MLP         MSE         51
# 155        MLP         MSE         47
# ..         ...         ...        ...
# 216      trans     MSE_IGD          0
# 219      trans     MSE_IGD          3
# 220      trans     MSE_IGD          4
# 222      trans     MSE_IGD          6
# 223      trans     MSE_IGD          7
#
#                                                 params     score       time
# 129  {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth...  0.000978  24.960053
# 134  {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth...  0.002487  26.212012
# 173  {'lr': 0.0001, 'num_epochs': 500, 'pen_C_growt...  0.003188  27.223085
# 159  {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth...  0.003311  41.300932
# 155  {'lr': 0.001, 'num_epochs': 800, 'pen_C_growth...  0.003603  42.033796
# ..                                                 ...       ...        ...
# 216  {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth...  0.000162  27.464283
# 219  {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth...  0.000169  28.853848
# 220  {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth...  0.000193  28.213165
# 222  {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth...  0.001464  26.028553
# 223  {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth...  0.007340  26.336787
#
# [224 rows x 6 columns]

# %%
df_results.head()
# Out:
#   model_type metric_type  config_id  \
# 0      trans         MSE          0
# 1      trans         MSE          1
# 2      trans         MSE          2
# 3      trans         MSE          3
# 4      trans         MSE          4
#
#                                               params     score       time
# 0  {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth...  0.005100  28.535853
# 1  {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth...  0.004191  27.435437
# 2  {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth...  0.001877  26.398983
# 3  {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth...  0.005004  27.859559
# 4  {'lr': 0.001, 'num_epochs': 500, 'pen_C_growth...  0.004380  27.736486

# %% [markdown]
# # Viz

# %%
import pandas as pd
import ast

# %%
if isinstance(df_results['params'].iloc[0], str):
    df_results['params'] = df_results['params'].apply(ast.literal_eval)

# Tách cột params thành các cột riêng biệt (lr, num_epochs, ...)
params_df = pd.json_normalize(df_results['params'])

# Ghép lại với cột score để vẽ
df_plot = pd.concat([df_results[['score']], params_df], axis=1)

param_cols = params_df.columns

# Thiết lập kích thước khung hình
plt.figure(figsize=(20, 5))

# Vẽ vòng lặp
for i, col in enumerate(param_cols):
    plt.subplot(1, len(param_cols), i + 1)
    
    # Vẽ scatter plot (biểu đồ chấm)
    sns.scatterplot(data=df_plot, x=col, y='score', s=100, color='blue')
    
    # Vẽ đường xu hướng (tùy chọn, giúp dễ nhìn trend)
    # sns.regplot(data=df_plot, x=col, y='score', scatter=False, color='red')
    
    plt.title(f'Score vs {col}')
    plt.xlabel(col)
    plt.ylabel('Score (MSE)')
    plt.grid(True, linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()
