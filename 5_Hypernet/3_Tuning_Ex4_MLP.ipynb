# %%
import os
import time
import math
import itertools
import yaml
import numpy as np
import torch
import torch.optim as optim
import matplotlib.pyplot as plt
from scipy.optimize import minimize, Bounds
from hypernet_MLP import Hypernet_MLP

# %%
def set_seed(seed=702):
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)

set_seed(702)

# %% [markdown]
# # Const

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
GROUND_TRUTH_FILE = "../4_Pareto_front/test/ex4/pf_dynamic_true.npy" 

if os.path.exists(GROUND_TRUTH_FILE):
    pf_true = np.load(GROUND_TRUTH_FILE)
    print(f"✅ Đã tải ground truth Pareto front từ: {GROUND_TRUTH_FILE}, Shape: {pf_true.shape}")
else:
    print(f"❌ KHÔNG tìm thấy file ground truth tại: {GROUND_TRUTH_FILE}")
# Out:
# ✅ Đã tải ground truth Pareto front từ: ../4_Pareto_front/test/ex4/pf_dynamic_true.npy, Shape: (20, 2)

# %% [markdown]
# # Def

# %%
import autograd.numpy as np
from scipy.optimize import minimize            
        
class Projection:
    def __init__(self, cons, bounds, dim, proj_type='euclid'):
        self.cons = cons
        self.bounds = bounds
        self.dim = dim
        self.proj_type = proj_type
        
        if self.proj_type == 'qplus':
            self.objective_func = self._obj_positive_diff
        elif self.proj_type == 'euclid':
            self.objective_func = self._obj_l2_norm
        else:
            print(f"Phép chiếu {self.objective_func} không cài đặt, chọn 'qplus' hoặc 'euclid'")

    def _obj_l2_norm(self, x, y):
        return np.sqrt(np.sum((x - y)**2))
    
    def _obj_positive_diff(self, x, y):
        v = np.maximum(y - x, 0) 
        return np.sum(v**2)

    def project(self, target_point):
        init_point = np.random.rand(1, self.dim).tolist()[0]
        
        res = minimize(
            self.objective_func,
            init_point,
            args=(target_point, ),
            constraints=self.cons,
            bounds=self.bounds,
            options={'disp': False}
        )
        
        optim_point = res.x
        
        if self.proj_type == 'qplus':
            return target_point - np.maximum(target_point - optim_point, 0)
        else:
            return optim_point

class Problem():
    def __init__(self, f, dim_x, dim_y, proj_C, proj_Qplus):
        self.f = f
        self.dim_x = dim_x
        self.dim_y = dim_y
        self.proj_C = proj_C
        self.proj_Qplus = proj_Qplus
    
    def objective_func(self, x):
        vals = [func(x) for func in self.f]
        return np.concatenate(vals)

# %%
def f1(x): return 4*x[0]**2 + 4*x[1]**2
def f2(x): return (x[0] - 5)**2 + (x[1] - 5)**2

def c1(x): return -(x[0] - 5)**2 - x[1]**2 + 25
def c2(x): return -(x[0] - 8)**2 - (x[1] + 3)**2 + 17.7

def q1(y): return 50**2 - (y[0] - 50)**2 - (y[1] - 50)**2
def q_plus(y):
    center = 50.0; radius_sq = 50**2
    dx = np.maximum(0, y[0] - center)
    dy = np.maximum(0, y[1] - center)
    return radius_sq - (dx**2 + dy**2)

cons_C = ({'type': 'ineq', 'fun': c1}, {'type': 'ineq', 'fun': c2})
cons_Q = ({'type': 'ineq', 'fun': q1},)
cons_Qplus = ({'type': 'ineq', 'fun': q_plus},)
bounds_x = Bounds([-15,-15],[30, 30])
dim_x = 2; dim_y = 2

# Setup
proj_C_handler = Projection(cons_C, bounds_x, dim_x, 'euclid')
proj_Q_handler = Projection(cons_Q, None, dim_y, 'qplus')
prob = Problem([f1, f2], dim_x, dim_y, proj_C_handler.project, proj_Q_handler.project)
z_star = np.array([75.23366646094793, 25.502227623508944])

# %%
def evaluate_objectives_single(functions, x_tensor):
    vals = []
    for func in functions:
        val = func(x_tensor)
        if not torch.is_tensor(val): val = torch.tensor(val, dtype=torch.float32, device=x_tensor.device)
        vals.append(val)
    return torch.stack(vals).reshape(-1)

def calculate_mse_igd(pf_pred, pf_true):
    if len(pf_pred) == 0: return np.inf
    total_dist_sq = 0
    # Với mỗi điểm ground truth, tìm điểm dự đoán gần nhất
    for p_true in pf_true:
        dists_sq = np.sum((pf_pred - p_true)**2, axis=1)
        total_dist_sq += np.min(dists_sq)
    return total_dist_sq / len(pf_true)

# %%
def train_hypernet(hypernet, prob, z_star, 
                   num_epochs=1000, lr=1e-3, num_partitions=50, 
                   lr_step_size=300, lr_gamma=0.5,
                   init_pen_C=1.0, max_pen_C=1000.0, pen_C_growth=1.01,
                   init_pen_Q=50.0, min_pen_Q=1.0, pen_Q_decay=0.995,
                   verbose=False):
    
    hypernet = hypernet.to(device)
    optimizer = optim.Adam(hypernet.parameters(), lr=lr)
    scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=lr_step_size, gamma=lr_gamma)
    z_star_tensor = torch.tensor(z_star, dtype=torch.float32, device=device).view(1, -1)
    
    current_pen_C = init_pen_C
    current_pen_Q = init_pen_Q
    angle_step = (math.pi / 2) / num_partitions
    
    for epoch in range(num_epochs):
        hypernet.train()
        optimizer.zero_grad()
        
        # 1. Stratified Sampling
        starts = torch.arange(num_partitions) * angle_step
        noise = torch.rand(num_partitions) * angle_step
        thetas = starts + noise
        r_batch_np = np.stack([np.cos(thetas.numpy()), np.sin(thetas.numpy())], axis=1)
        r_tensor_batch = torch.tensor(r_batch_np, dtype=torch.float32, device=device)
        
        # 2. Forward & Loss Calculation (Loop safe logic)
        loss_C_list = []
        loss_Q_list = []
        y_pred_list = []
        
        # Forward pass batch (Nhanh hơn gọi từng cái)
        x_vec_batch = hypernet(r_tensor_batch) # (Batch, 2)
        x_np_batch = x_vec_batch.detach().cpu().numpy()
        
        for i in range(num_partitions):
            x_i_tensor = x_vec_batch[i]
            x_i_np = x_np_batch[i]
            
            # Loss C
            x_proj_i_np = prob.proj_C(x_i_np)
            x_proj_i_tensor = torch.tensor(x_proj_i_np, dtype=torch.float32, device=device)
            loss_C_list.append(torch.sum((x_i_tensor - x_proj_i_tensor)**2))
            
            # F(x)
            y_pred_i = evaluate_objectives_single(prob.f, x_i_tensor)
            y_pred_list.append(y_pred_i)
            
            # Loss Q
            y_i_np = y_pred_i.detach().cpu().numpy()
            y_proj_i_np = prob.proj_Qplus(y_i_np)
            y_proj_i_tensor = torch.tensor(y_proj_i_np, dtype=torch.float32, device=device)
            loss_Q_list.append(torch.sum((y_pred_i - y_proj_i_tensor)**2))
            
        y_pred_batch = torch.stack(y_pred_list)
        loss_C = torch.mean(torch.stack(loss_C_list))
        loss_Q = torch.mean(torch.stack(loss_Q_list))
        
        # Chebyshev Loss
        diff = y_pred_batch - z_star_tensor
        weighted_diff = r_tensor_batch * diff
        max_vals, _ = torch.max(weighted_diff, dim=1)
        loss_obj = torch.mean(max_vals)
        
        total_loss = loss_obj + (current_pen_C * loss_C) + (current_pen_Q * loss_Q)
        
        total_loss.backward()
        optimizer.step()
        scheduler.step()
        
        # Update Penalties
        current_pen_C = min(max_pen_C, current_pen_C * pen_C_growth)
        current_pen_Q = max(min_pen_Q, current_pen_Q * pen_Q_decay)
        
        if verbose and epoch % (num_epochs // 5) == 0:
            print(f"  Ep {epoch}: Loss={total_loss.item():.2f} (Obj={loss_obj.item():.2f}, C={loss_C.item():.4f})")
            
    return hypernet

# %%
def evaluate_model(hypernet, prob, test_rays, pf_true):
    hypernet.eval()
    pf_pred = []
    
    # Chuyển test_rays sang tensor batch để infer nhanh
    rays_tensor = torch.tensor(test_rays, dtype=torch.float32, device=device)
    
    with torch.no_grad():
        x_raw = hypernet(rays_tensor) # (N, 2)
        x_raw_np = x_raw.cpu().numpy()
        
        # Loop project and eval
        for i in range(len(x_raw_np)):
            # Chiếu lên C (Quan trọng để feasible)
            x_proj = prob.proj_C(x_raw_np[i])
            # Tính f
            val = [func(x_proj) for func in prob.f]
            pf_pred.append(val)
            
    pf_pred = np.array(pf_pred)
    igd_score = calculate_mse_igd(pf_pred, pf_true)
    return igd_score, pf_pred

# %% [markdown]
# # Config

# %%
param_grid = {
    'lr': [1e-3],
    'num_epochs': [1000],
    'pen_C_growth': [1.005, 1.01, 1.05],      # Tăng phạt C nhanh hay chậm
    'pen_Q_decay': [0.995],      
    'init_pen_C': [10.0, 50.0, 100.0],
    'init_pen_Q': [20.0, 50.0],
    'max_pen_C': [500.0, 1000.0, 2000.0]
}

config_path='../4_Pareto_front/config.yaml'
with open(config_path, 'r') as f:
    cfg = yaml.safe_load(f)
test_rays = np.array(cfg['data']['test_ray'])

# %% [markdown]
# # Run

# %%
keys, values = zip(*param_grid.items())
param_combinations = [dict(zip(keys, v)) for v in itertools.product(*values)]

print(f"🔍 Bắt đầu Grid Search với {len(param_combinations)} cấu hình...")

results = []
best_igd = float('inf')
best_config = None
best_pf_pred = None

# --- Main Tuning Loop ---
for idx, params in enumerate(param_combinations):
    print(f"\n--- Running Config {idx+1}/{len(param_combinations)} ---")
    print(params)
    
    # 1. Init Model
    model = Hypernet_MLP(ray_hidden_dim=32, out_dim=dim_x, n_tasks=2)
    
    # 2. Train
    start_time = time.time()
    trained_model = train_hypernet(
        model, prob, z_star, 
        num_epochs=params['num_epochs'],
        lr=params['lr'],
        num_partitions=20, 
        init_pen_C=params['init_pen_C'],
        pen_C_growth=params['pen_C_growth'],
        init_pen_Q=params['init_pen_Q'],
        pen_Q_decay=params['pen_Q_decay'],
        verbose=True
    )
    train_time = time.time() - start_time
    
    # 3. Evaluate
    igd, pf_pred = evaluate_model(trained_model, prob, test_rays, pf_true)
    
    print(f"⏱️ Time: {train_time:.2f}s | 📉 IGD Score: {igd:.4f}")
    
    # Save result
    res = {
        'config_id': idx,
        'params': params,
        'igd': igd,
        'time': train_time
    }
    results.append(res)
    
    # Update Best
    if igd < best_igd:
        best_igd = igd
        best_config = params
        best_pf_pred = pf_pred
        # Lưu model tốt nhất (optional)
        torch.save(trained_model.state_dict(), "best_hypernet_tuned.pth")
# Out:
# 🔍 Bắt đầu Grid Search với 54 cấu hình...
#
# --- Running Config 1/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.005, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0}
#   Ep 0: Loss=210.01 (Obj=16.26, C=19.3750)
#   Ep 200: Loss=3.86 (Obj=2.81, C=0.0388)
#   Ep 400: Loss=3.62 (Obj=3.16, C=0.0062)
#   Ep 600: Loss=3.77 (Obj=3.48, C=0.0014)
#   Ep 800: Loss=3.80 (Obj=3.67, C=0.0002)
# ⏱️ Time: 93.45s | 📉 IGD Score: 2.9408
#
# --- Running Config 2/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.005, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 1000.0}
#   Ep 0: Loss=200.32 (Obj=15.20, C=18.5126)
#   Ep 200: Loss=5.81 (Obj=4.68, C=0.0419)
#   Ep 400: Loss=4.62 (Obj=3.58, C=0.0142)
#   Ep 600: Loss=4.65 (Obj=4.08, C=0.0029)
#   Ep 800: Loss=4.10 (Obj=3.86, C=0.0005)
# ⏱️ Time: 106.42s | 📉 IGD Score: 8.6996
#
# --- Running Config 3/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.005, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 2000.0}
#   Ep 0: Loss=187.31 (Obj=14.75, C=17.2561)
#   Ep 200: Loss=3.75 (Obj=2.71, C=0.0383)
#   Ep 400: Loss=4.39 (Obj=3.46, C=0.0127)
#   Ep 600: Loss=3.78 (Obj=3.58, C=0.0010)
#   Ep 800: Loss=3.83 (Obj=3.72, C=0.0002)
# ⏱️ Time: 98.19s | 📉 IGD Score: 4.3304
#
# --- Running Config 4/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.005, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0}
#   Ep 0: Loss=209.70 (Obj=16.25, C=19.3453)
#   Ep 200: Loss=6.97 (Obj=6.89, C=0.0029)
#   Ep 400: Loss=4.90 (Obj=3.85, C=0.0144)
#   Ep 600: Loss=5.50 (Obj=4.87, C=0.0032)
#   Ep 800: Loss=5.45 (Obj=5.18, C=0.0005)
# ⏱️ Time: 112.30s | 📉 IGD Score: 27.3329
#
# --- Running Config 5/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.005, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 1000.0}
#   Ep 0: Loss=201.00 (Obj=15.33, C=18.5677)
#   Ep 200: Loss=4.04 (Obj=2.92, C=0.0413)
#   Ep 400: Loss=4.29 (Obj=3.39, C=0.0122)
#   Ep 600: Loss=3.76 (Obj=3.63, C=0.0006)
#   Ep 800: Loss=3.81 (Obj=3.71, C=0.0002)
# ⏱️ Time: 100.70s | 📉 IGD Score: 4.5493
#
# --- Running Config 6/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.005, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 2000.0}
#   Ep 0: Loss=203.58 (Obj=14.73, C=18.8854)
#   Ep 200: Loss=3.84 (Obj=2.88, C=0.0356)
#   Ep 400: Loss=4.02 (Obj=3.35, C=0.0092)
#   Ep 600: Loss=3.77 (Obj=3.58, C=0.0010)
#   Ep 800: Loss=3.89 (Obj=3.73, C=0.0003)
# ⏱️ Time: 96.58s | 📉 IGD Score: 4.4644
#
# --- Running Config 7/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.005, 'pen_Q_decay': 0.995, 'init_pen_C': 50.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0}
#   Ep 0: Loss=1055.88 (Obj=17.09, C=20.7759)
#   Ep 200: Loss=11.40 (Obj=11.27, C=0.0010)
#   Ep 400: Loss=6.08 (Obj=5.64, C=0.0012)
#   Ep 600: Loss=6.17 (Obj=6.02, C=0.0001)
#   Ep 800: Loss=6.06 (Obj=5.91, C=0.0001)
# ⏱️ Time: 122.46s | 📉 IGD Score: 37.9995
#
# --- Running Config 8/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.005, 'pen_Q_decay': 0.995, 'init_pen_C': 50.0, 'init_pen_Q': 20.0, 'max_pen_C': 1000.0}
#   Ep 0: Loss=908.35 (Obj=14.27, C=17.8815)
#   Ep 200: Loss=12.14 (Obj=12.01, C=0.0009)
#   Ep 400: Loss=6.29 (Obj=5.72, C=0.0016)
#   Ep 600: Loss=6.02 (Obj=5.91, C=0.0001)
#   Ep 800: Loss=5.85 (Obj=5.69, C=0.0002)
# ⏱️ Time: 129.65s | 📉 IGD Score: 33.2112
#
# --- Running Config 9/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.005, 'pen_Q_decay': 0.995, 'init_pen_C': 50.0, 'init_pen_Q': 20.0, 'max_pen_C': 2000.0}
#   Ep 0: Loss=879.06 (Obj=13.94, C=17.3025)
#   Ep 200: Loss=9.17 (Obj=7.47, C=0.0125)
#   Ep 400: Loss=8.05 (Obj=6.83, C=0.0033)
#   Ep 600: Loss=7.06 (Obj=6.73, C=0.0003)
#   Ep 800: Loss=6.63 (Obj=6.29, C=0.0003)
# ⏱️ Time: 130.16s | 📉 IGD Score: 35.9473
#
# --- Running Config 10/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.005, 'pen_Q_decay': 0.995, 'init_pen_C': 50.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0}
#   Ep 0: Loss=916.01 (Obj=14.18, C=18.0365)
#   Ep 200: Loss=12.51 (Obj=12.40, C=0.0008)
#   Ep 400: Loss=7.66 (Obj=7.63, C=0.0001)
#   Ep 600: Loss=5.94 (Obj=5.79, C=0.0001)
#   Ep 800: Loss=5.80 (Obj=5.67, C=0.0001)
# ⏱️ Time: 145.40s | 📉 IGD Score: 39.6612
#
# --- Running Config 11/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.005, 'pen_Q_decay': 0.995, 'init_pen_C': 50.0, 'init_pen_Q': 50.0, 'max_pen_C': 1000.0}
#   Ep 0: Loss=1014.73 (Obj=16.79, C=19.9588)
#   Ep 200: Loss=24.10 (Obj=23.73, C=0.0027)
#   Ep 400: Loss=17.92 (Obj=17.78, C=0.0004)
#   Ep 600: Loss=13.74 (Obj=13.74, C=0.0000)
#   Ep 800: Loss=11.64 (Obj=11.62, C=0.0000)
# ⏱️ Time: 149.74s | 📉 IGD Score: 138.5472
#
# --- Running Config 12/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.005, 'pen_Q_decay': 0.995, 'init_pen_C': 50.0, 'init_pen_Q': 50.0, 'max_pen_C': 2000.0}
#   Ep 0: Loss=964.10 (Obj=16.31, C=18.9558)
#   Ep 200: Loss=15.41 (Obj=15.38, C=0.0002)
#   Ep 400: Loss=6.31 (Obj=5.84, C=0.0013)
#   Ep 600: Loss=5.97 (Obj=5.79, C=0.0002)
#   Ep 800: Loss=5.76 (Obj=5.61, C=0.0001)
# ⏱️ Time: 133.53s | 📉 IGD Score: 38.2426
#
# --- Running Config 13/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.005, 'pen_Q_decay': 0.995, 'init_pen_C': 100.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0}
#   Ep 0: Loss=1818.27 (Obj=14.28, C=18.0399)
#   Ep 200: Loss=19.16 (Obj=18.64, C=0.0019)
#   Ep 400: Loss=7.11 (Obj=6.55, C=0.0008)
#   Ep 600: Loss=6.46 (Obj=6.05, C=0.0004)
#   Ep 800: Loss=6.01 (Obj=5.82, C=0.0002)
# ⏱️ Time: 155.51s | 📉 IGD Score: 26.7877
#
# --- Running Config 14/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.005, 'pen_Q_decay': 0.995, 'init_pen_C': 100.0, 'init_pen_Q': 20.0, 'max_pen_C': 1000.0}
#   Ep 0: Loss=2028.35 (Obj=16.35, C=20.1200)
#   Ep 200: Loss=17.50 (Obj=17.25, C=0.0009)
#   Ep 400: Loss=12.68 (Obj=12.50, C=0.0002)
#   Ep 600: Loss=9.01 (Obj=8.94, C=0.0001)
#   Ep 800: Loss=7.65 (Obj=7.35, C=0.0003)
# ⏱️ Time: 160.50s | 📉 IGD Score: 42.4123
#
# --- Running Config 15/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.005, 'pen_Q_decay': 0.995, 'init_pen_C': 100.0, 'init_pen_Q': 20.0, 'max_pen_C': 2000.0}
#   Ep 0: Loss=1872.28 (Obj=15.89, C=18.5639)
#   Ep 200: Loss=8.78 (Obj=8.76, C=0.0001)
#   Ep 400: Loss=6.55 (Obj=5.96, C=0.0008)
#   Ep 600: Loss=6.28 (Obj=6.00, C=0.0003)
#   Ep 800: Loss=6.21 (Obj=5.88, C=0.0003)
# ⏱️ Time: 133.82s | 📉 IGD Score: 38.0860
#
# --- Running Config 16/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.005, 'pen_Q_decay': 0.995, 'init_pen_C': 100.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0}
#   Ep 0: Loss=1915.72 (Obj=16.28, C=18.9944)
#   Ep 200: Loss=12.27 (Obj=12.24, C=0.0001)
#   Ep 400: Loss=6.97 (Obj=6.59, C=0.0005)
#   Ep 600: Loss=5.60 (Obj=5.24, C=0.0004)
#   Ep 800: Loss=4.97 (Obj=4.69, C=0.0003)
# ⏱️ Time: 153.81s | 📉 IGD Score: 19.1391
#
# --- Running Config 17/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.005, 'pen_Q_decay': 0.995, 'init_pen_C': 100.0, 'init_pen_Q': 50.0, 'max_pen_C': 1000.0}
#   Ep 0: Loss=2012.91 (Obj=17.14, C=19.9577)
#   Ep 200: Loss=17.40 (Obj=17.19, C=0.0008)
#   Ep 400: Loss=12.93 (Obj=12.92, C=0.0000)
#   Ep 600: Loss=7.09 (Obj=6.73, C=0.0004)
#   Ep 800: Loss=6.05 (Obj=5.74, C=0.0003)
# ⏱️ Time: 151.89s | 📉 IGD Score: 17.3016
#
# --- Running Config 18/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.005, 'pen_Q_decay': 0.995, 'init_pen_C': 100.0, 'init_pen_Q': 50.0, 'max_pen_C': 2000.0}
#   Ep 0: Loss=2043.90 (Obj=16.92, C=20.2698)
#   Ep 200: Loss=6.44 (Obj=6.31, C=0.0005)
#   Ep 400: Loss=6.05 (Obj=5.86, C=0.0003)
#   Ep 600: Loss=6.07 (Obj=5.95, C=0.0001)
#   Ep 800: Loss=6.07 (Obj=5.94, C=0.0001)
# ⏱️ Time: 117.76s | 📉 IGD Score: 52.6095
#
# --- Running Config 19/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0}
#   Ep 0: Loss=200.90 (Obj=16.90, C=18.3999)
#   Ep 200: Loss=5.00 (Obj=4.08, C=0.0126)
#   Ep 400: Loss=5.28 (Obj=5.02, C=0.0005)
#   Ep 600: Loss=4.11 (Obj=3.96, C=0.0001)
#   Ep 800: Loss=3.94 (Obj=3.86, C=0.0001)
# ⏱️ Time: 119.58s | 📉 IGD Score: 5.4820
#
# --- Running Config 20/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 1000.0}
#   Ep 0: Loss=204.11 (Obj=15.10, C=18.9010)
#   Ep 200: Loss=11.51 (Obj=11.20, C=0.0042)
#   Ep 400: Loss=7.00 (Obj=6.13, C=0.0016)
#   Ep 600: Loss=5.60 (Obj=5.44, C=0.0002)
#   Ep 800: Loss=5.36 (Obj=5.21, C=0.0001)
# ⏱️ Time: 132.72s | 📉 IGD Score: 17.7347
#
# --- Running Config 21/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 2000.0}
#   Ep 0: Loss=183.48 (Obj=15.53, C=16.7951)
#   Ep 200: Loss=4.67 (Obj=3.74, C=0.0126)
#   Ep 400: Loss=3.92 (Obj=3.78, C=0.0003)
#   Ep 600: Loss=3.90 (Obj=3.86, C=0.0000)
#   Ep 800: Loss=3.79 (Obj=3.75, C=0.0000)
# ⏱️ Time: 107.71s | 📉 IGD Score: 3.5679
#
# --- Running Config 22/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0}
#   Ep 0: Loss=222.49 (Obj=17.11, C=20.5380)
#   Ep 200: Loss=14.00 (Obj=13.85, C=0.0021)
#   Ep 400: Loss=8.68 (Obj=8.64, C=0.0001)
#   Ep 600: Loss=6.88 (Obj=6.65, C=0.0002)
#   Ep 800: Loss=6.70 (Obj=6.50, C=0.0002)
# ⏱️ Time: 133.38s | 📉 IGD Score: 44.8991
#
# --- Running Config 23/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 1000.0}
#   Ep 0: Loss=214.95 (Obj=17.93, C=19.7021)
#   Ep 200: Loss=10.67 (Obj=10.37, C=0.0040)
#   Ep 400: Loss=6.77 (Obj=6.17, C=0.0011)
#   Ep 600: Loss=6.09 (Obj=5.89, C=0.0002)
#   Ep 800: Loss=5.96 (Obj=5.75, C=0.0002)
# ⏱️ Time: 132.72s | 📉 IGD Score: 30.8828
#
# --- Running Config 24/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 2000.0}
#   Ep 0: Loss=209.62 (Obj=15.84, C=19.3786)
#   Ep 200: Loss=12.59 (Obj=12.48, C=0.0015)
#   Ep 400: Loss=6.51 (Obj=5.99, C=0.0010)
#   Ep 600: Loss=6.01 (Obj=5.83, C=0.0002)
#   Ep 800: Loss=5.80 (Obj=5.65, C=0.0002)
# ⏱️ Time: 125.06s | 📉 IGD Score: 36.7326
#
# --- Running Config 25/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 50.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0}
#   Ep 0: Loss=1023.24 (Obj=15.86, C=20.1478)
#   Ep 200: Loss=14.55 (Obj=14.47, C=0.0002)
#   Ep 400: Loss=8.42 (Obj=8.37, C=0.0000)
#   Ep 600: Loss=6.38 (Obj=6.11, C=0.0003)
#   Ep 800: Loss=6.29 (Obj=6.00, C=0.0003)
# ⏱️ Time: 137.41s | 📉 IGD Score: 40.0656
#
# --- Running Config 26/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 50.0, 'init_pen_Q': 20.0, 'max_pen_C': 1000.0}
#   Ep 0: Loss=936.97 (Obj=14.94, C=18.4406)
#   Ep 200: Loss=11.19 (Obj=11.18, C=0.0000)
#   Ep 400: Loss=6.48 (Obj=6.33, C=0.0001)
#   Ep 600: Loss=5.15 (Obj=5.06, C=0.0001)
#   Ep 800: Loss=4.34 (Obj=4.28, C=0.0001)
# ⏱️ Time: 132.62s | 📉 IGD Score: 13.5468
#
# --- Running Config 27/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 50.0, 'init_pen_Q': 20.0, 'max_pen_C': 2000.0}
#   Ep 0: Loss=920.96 (Obj=16.08, C=18.0976)
#   Ep 200: Loss=22.67 (Obj=22.01, C=0.0018)
#   Ep 400: Loss=17.50 (Obj=17.47, C=0.0000)
#   Ep 600: Loss=14.51 (Obj=14.50, C=0.0000)
#   Ep 800: Loss=12.85 (Obj=12.85, C=0.0000)
# ⏱️ Time: 159.84s | 📉 IGD Score: 154.1902
#
# --- Running Config 28/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 50.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0}
#   Ep 0: Loss=1015.39 (Obj=17.42, C=19.9594)
#   Ep 200: Loss=10.89 (Obj=10.74, C=0.0004)
#   Ep 400: Loss=7.30 (Obj=6.82, C=0.0005)
#   Ep 600: Loss=6.54 (Obj=6.14, C=0.0004)
#   Ep 800: Loss=6.22 (Obj=5.96, C=0.0003)
# ⏱️ Time: 148.46s | 📉 IGD Score: 32.5965
#
# --- Running Config 29/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 50.0, 'init_pen_Q': 50.0, 'max_pen_C': 1000.0}
#   Ep 0: Loss=1064.55 (Obj=16.13, C=20.9684)
#   Ep 200: Loss=6.89 (Obj=6.79, C=0.0003)
#   Ep 400: Loss=6.28 (Obj=6.17, C=0.0001)
#   Ep 600: Loss=6.17 (Obj=5.99, C=0.0002)
#   Ep 800: Loss=6.16 (Obj=6.02, C=0.0001)
# ⏱️ Time: 122.26s | 📉 IGD Score: 43.0119
#
# --- Running Config 30/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 50.0, 'init_pen_Q': 50.0, 'max_pen_C': 2000.0}
#   Ep 0: Loss=957.59 (Obj=15.14, C=18.8490)
#   Ep 200: Loss=21.32 (Obj=20.95, C=0.0010)
#   Ep 400: Loss=16.94 (Obj=16.78, C=0.0002)
#   Ep 600: Loss=13.68 (Obj=13.68, C=0.0000)
#   Ep 800: Loss=11.95 (Obj=11.93, C=0.0000)
# ⏱️ Time: 160.54s | 📉 IGD Score: 139.1323
#
# --- Running Config 31/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 100.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0}
#   Ep 0: Loss=2040.19 (Obj=15.81, C=20.2438)
#   Ep 200: Loss=14.02 (Obj=13.47, C=0.0008)
#   Ep 400: Loss=10.86 (Obj=10.06, C=0.0008)
#   Ep 600: Loss=9.43 (Obj=8.76, C=0.0007)
#   Ep 800: Loss=8.72 (Obj=7.95, C=0.0008)
# ⏱️ Time: 149.93s | 📉 IGD Score: 43.3812
#
# --- Running Config 32/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 100.0, 'init_pen_Q': 20.0, 'max_pen_C': 1000.0}
#   Ep 0: Loss=1966.93 (Obj=16.94, C=19.4999)
#   Ep 200: Loss=11.16 (Obj=11.11, C=0.0001)
#   Ep 400: Loss=5.97 (Obj=5.78, C=0.0002)
#   Ep 600: Loss=4.88 (Obj=4.68, C=0.0002)
#   Ep 800: Loss=4.54 (Obj=4.38, C=0.0002)
# ⏱️ Time: 133.57s | 📉 IGD Score: 14.1999
#
# --- Running Config 33/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 100.0, 'init_pen_Q': 20.0, 'max_pen_C': 2000.0}
#   Ep 0: Loss=2033.59 (Obj=14.69, C=20.1889)
#   Ep 200: Loss=12.43 (Obj=12.37, C=0.0001)
#   Ep 400: Loss=6.11 (Obj=5.92, C=0.0002)
#   Ep 600: Loss=5.40 (Obj=5.17, C=0.0002)
#   Ep 800: Loss=5.09 (Obj=4.95, C=0.0001)
# ⏱️ Time: 138.97s | 📉 IGD Score: 18.3479
#
# --- Running Config 34/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 100.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0}
#   Ep 0: Loss=1861.35 (Obj=16.15, C=18.4520)
#   Ep 200: Loss=16.04 (Obj=15.22, C=0.0011)
#   Ep 400: Loss=9.60 (Obj=9.53, C=0.0001)
#   Ep 600: Loss=7.09 (Obj=7.02, C=0.0001)
#   Ep 800: Loss=6.33 (Obj=6.22, C=0.0001)
# ⏱️ Time: 139.04s | 📉 IGD Score: 32.8454
#
# --- Running Config 35/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 100.0, 'init_pen_Q': 50.0, 'max_pen_C': 1000.0}
#   Ep 0: Loss=1764.90 (Obj=13.96, C=17.5094)
#   Ep 200: Loss=14.02 (Obj=12.48, C=0.0021)
#   Ep 400: Loss=8.82 (Obj=7.96, C=0.0009)
#   Ep 600: Loss=7.48 (Obj=6.94, C=0.0005)
#   Ep 800: Loss=7.17 (Obj=6.65, C=0.0005)
# ⏱️ Time: 154.61s | 📉 IGD Score: 32.6839
#
# --- Running Config 36/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 100.0, 'init_pen_Q': 50.0, 'max_pen_C': 2000.0}
#   Ep 0: Loss=1899.96 (Obj=14.37, C=18.8560)
#   Ep 200: Loss=11.98 (Obj=11.98, C=0.0000)
#   Ep 400: Loss=7.47 (Obj=7.30, C=0.0002)
#   Ep 600: Loss=6.32 (Obj=6.11, C=0.0002)
#   Ep 800: Loss=6.15 (Obj=5.97, C=0.0002)
# ⏱️ Time: 138.70s | 📉 IGD Score: 42.1927
#
# --- Running Config 37/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.05, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0}
#   Ep 0: Loss=212.41 (Obj=16.22, C=19.6193)
#   Ep 200: Loss=17.23 (Obj=17.11, C=0.0001)
#   Ep 400: Loss=14.18 (Obj=14.16, C=0.0000)
#   Ep 600: Loss=11.28 (Obj=11.27, C=0.0000)
#   Ep 800: Loss=9.65 (Obj=9.65, C=0.0000)
# ⏱️ Time: 158.56s | 📉 IGD Score: 66.2592
#
# --- Running Config 38/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.05, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 1000.0}
#   Ep 0: Loss=202.78 (Obj=15.51, C=18.7267)
#   Ep 200: Loss=16.76 (Obj=16.60, C=0.0002)
#   Ep 400: Loss=12.66 (Obj=12.24, C=0.0004)
#   Ep 600: Loss=9.43 (Obj=9.23, C=0.0002)
#   Ep 800: Loss=8.88 (Obj=8.32, C=0.0006)
# ⏱️ Time: 156.42s | 📉 IGD Score: 47.4322
#
# --- Running Config 39/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.05, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 2000.0}
#   Ep 0: Loss=180.48 (Obj=14.88, C=16.5598)
#   Ep 200: Loss=11.22 (Obj=11.20, C=0.0000)
#   Ep 400: Loss=6.43 (Obj=6.34, C=0.0001)
#   Ep 600: Loss=6.14 (Obj=5.98, C=0.0002)
#   Ep 800: Loss=6.10 (Obj=5.94, C=0.0002)
# ⏱️ Time: 135.31s | 📉 IGD Score: 39.2138
#
# --- Running Config 40/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.05, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0}
#   Ep 0: Loss=189.83 (Obj=15.96, C=17.3862)
#   Ep 200: Loss=21.73 (Obj=21.34, C=0.0004)
#   Ep 400: Loss=18.71 (Obj=18.66, C=0.0000)
#   Ep 600: Loss=16.79 (Obj=16.74, C=0.0000)
#   Ep 800: Loss=16.19 (Obj=16.17, C=0.0000)
# ⏱️ Time: 160.13s | 📉 IGD Score: 315.6867
#
# --- Running Config 41/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.05, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 1000.0}
#   Ep 0: Loss=218.29 (Obj=15.75, C=20.2545)
#   Ep 200: Loss=17.73 (Obj=17.51, C=0.0002)
#   Ep 400: Loss=15.47 (Obj=15.33, C=0.0001)
#   Ep 600: Loss=13.66 (Obj=13.45, C=0.0002)
#   Ep 800: Loss=12.57 (Obj=12.56, C=0.0000)
# ⏱️ Time: 158.74s | 📉 IGD Score: 161.1044
#
# --- Running Config 42/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.05, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 2000.0}
#   Ep 0: Loss=212.85 (Obj=15.37, C=19.7483)
#   Ep 200: Loss=18.95 (Obj=18.82, C=0.0001)
#   Ep 400: Loss=15.89 (Obj=15.86, C=0.0000)
#   Ep 600: Loss=13.93 (Obj=13.93, C=0.0000)
#   Ep 800: Loss=12.87 (Obj=12.86, C=0.0000)
# ⏱️ Time: 152.23s | 📉 IGD Score: 218.6102
#
# --- Running Config 43/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.05, 'pen_Q_decay': 0.995, 'init_pen_C': 50.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0}
#   Ep 0: Loss=998.43 (Obj=16.29, C=19.6429)
#   Ep 200: Loss=19.30 (Obj=19.00, C=0.0003)
#   Ep 400: Loss=17.05 (Obj=17.00, C=0.0000)
#   Ep 600: Loss=15.26 (Obj=15.25, C=0.0000)
#   Ep 800: Loss=14.17 (Obj=14.13, C=0.0000)
# ⏱️ Time: 160.82s | 📉 IGD Score: 274.8056
#
# --- Running Config 44/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.05, 'pen_Q_decay': 0.995, 'init_pen_C': 50.0, 'init_pen_Q': 20.0, 'max_pen_C': 1000.0}
#   Ep 0: Loss=1047.36 (Obj=16.97, C=20.6078)
#   Ep 200: Loss=21.74 (Obj=20.96, C=0.0008)
#   Ep 400: Loss=18.67 (Obj=18.17, C=0.0005)
#   Ep 600: Loss=16.70 (Obj=16.66, C=0.0000)
#   Ep 800: Loss=16.00 (Obj=15.97, C=0.0000)
# ⏱️ Time: 160.93s | 📉 IGD Score: 310.5482
#
# --- Running Config 45/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.05, 'pen_Q_decay': 0.995, 'init_pen_C': 50.0, 'init_pen_Q': 20.0, 'max_pen_C': 2000.0}
#   Ep 0: Loss=899.18 (Obj=14.91, C=17.6855)
#   Ep 200: Loss=14.58 (Obj=14.56, C=0.0000)
#   Ep 400: Loss=4.75 (Obj=4.49, C=0.0003)
#   Ep 600: Loss=4.41 (Obj=4.27, C=0.0001)
#   Ep 800: Loss=4.40 (Obj=4.22, C=0.0002)
# ⏱️ Time: 135.37s | 📉 IGD Score: 9.2146
#
# --- Running Config 46/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.05, 'pen_Q_decay': 0.995, 'init_pen_C': 50.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0}
#   Ep 0: Loss=909.56 (Obj=15.05, C=17.8902)
#   Ep 200: Loss=15.39 (Obj=15.03, C=0.0004)
#   Ep 400: Loss=12.50 (Obj=12.36, C=0.0001)
#   Ep 600: Loss=11.19 (Obj=10.99, C=0.0002)
#   Ep 800: Loss=10.40 (Obj=10.39, C=0.0000)
# ⏱️ Time: 158.20s | 📉 IGD Score: 106.7784
#
# --- Running Config 47/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.05, 'pen_Q_decay': 0.995, 'init_pen_C': 50.0, 'init_pen_Q': 50.0, 'max_pen_C': 1000.0}
#   Ep 0: Loss=954.75 (Obj=15.09, C=18.7933)
#   Ep 200: Loss=13.77 (Obj=13.66, C=0.0001)
#   Ep 400: Loss=12.62 (Obj=12.61, C=0.0000)
#   Ep 600: Loss=11.74 (Obj=11.72, C=0.0000)
#   Ep 800: Loss=11.03 (Obj=11.01, C=0.0000)
# ⏱️ Time: 150.76s | 📉 IGD Score: 166.1021
#
# --- Running Config 48/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.05, 'pen_Q_decay': 0.995, 'init_pen_C': 50.0, 'init_pen_Q': 50.0, 'max_pen_C': 2000.0}
#   Ep 0: Loss=943.06 (Obj=14.50, C=18.5711)
#   Ep 200: Loss=14.40 (Obj=14.05, C=0.0003)
#   Ep 400: Loss=11.58 (Obj=11.35, C=0.0002)
#   Ep 600: Loss=10.59 (Obj=10.07, C=0.0005)
#   Ep 800: Loss=10.25 (Obj=9.60, C=0.0006)
# ⏱️ Time: 150.98s | 📉 IGD Score: 65.1571
#
# --- Running Config 49/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.05, 'pen_Q_decay': 0.995, 'init_pen_C': 100.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0}
#   Ep 0: Loss=1888.37 (Obj=14.93, C=18.7344)
#   Ep 200: Loss=10.91 (Obj=10.89, C=0.0000)
#   Ep 400: Loss=9.95 (Obj=9.95, C=0.0000)
#   Ep 600: Loss=9.17 (Obj=9.15, C=0.0000)
#   Ep 800: Loss=8.80 (Obj=8.72, C=0.0001)
# ⏱️ Time: 157.03s | 📉 IGD Score: 80.1398
#
# --- Running Config 50/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.05, 'pen_Q_decay': 0.995, 'init_pen_C': 100.0, 'init_pen_Q': 20.0, 'max_pen_C': 1000.0}
#   Ep 0: Loss=1955.37 (Obj=15.53, C=19.3983)
#   Ep 200: Loss=20.34 (Obj=20.06, C=0.0003)
#   Ep 400: Loss=18.50 (Obj=18.39, C=0.0001)
#   Ep 600: Loss=17.43 (Obj=17.35, C=0.0001)
#   Ep 800: Loss=16.70 (Obj=16.61, C=0.0001)
# ⏱️ Time: 163.21s | 📉 IGD Score: 318.8553
#
# --- Running Config 51/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.05, 'pen_Q_decay': 0.995, 'init_pen_C': 100.0, 'init_pen_Q': 20.0, 'max_pen_C': 2000.0}
#   Ep 0: Loss=1892.43 (Obj=16.48, C=18.7595)
#   Ep 200: Loss=21.31 (Obj=20.93, C=0.0004)
#   Ep 400: Loss=20.10 (Obj=19.68, C=0.0004)
#   Ep 600: Loss=18.46 (Obj=18.34, C=0.0001)
#   Ep 800: Loss=17.70 (Obj=17.60, C=0.0001)
# ⏱️ Time: 159.58s | 📉 IGD Score: 403.0031
#
# --- Running Config 52/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.05, 'pen_Q_decay': 0.995, 'init_pen_C': 100.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0}
#   Ep 0: Loss=1749.59 (Obj=16.44, C=17.3315)
#   Ep 200: Loss=17.75 (Obj=17.29, C=0.0005)
#   Ep 400: Loss=14.04 (Obj=13.81, C=0.0002)
#   Ep 600: Loss=12.69 (Obj=12.68, C=0.0000)
#   Ep 800: Loss=12.27 (Obj=12.01, C=0.0003)
# ⏱️ Time: 158.03s | 📉 IGD Score: 156.4892
#
# --- Running Config 53/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.05, 'pen_Q_decay': 0.995, 'init_pen_C': 100.0, 'init_pen_Q': 50.0, 'max_pen_C': 1000.0}
#   Ep 0: Loss=1698.19 (Obj=15.73, C=16.8246)
#   Ep 200: Loss=14.21 (Obj=14.16, C=0.0001)
#   Ep 400: Loss=13.13 (Obj=13.09, C=0.0000)
#   Ep 600: Loss=12.06 (Obj=12.05, C=0.0000)
#   Ep 800: Loss=11.47 (Obj=11.45, C=0.0000)
# ⏱️ Time: 155.83s | 📉 IGD Score: 110.7919
#
# --- Running Config 54/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.05, 'pen_Q_decay': 0.995, 'init_pen_C': 100.0, 'init_pen_Q': 50.0, 'max_pen_C': 2000.0}
#   Ep 0: Loss=1900.31 (Obj=16.44, C=18.8387)
#   Ep 200: Loss=20.82 (Obj=19.72, C=0.0011)
#   Ep 400: Loss=18.50 (Obj=18.42, C=0.0001)
#   Ep 600: Loss=17.55 (Obj=17.21, C=0.0003)
#   Ep 800: Loss=16.79 (Obj=16.44, C=0.0004)
# ⏱️ Time: 162.66s | 📉 IGD Score: 310.2950

# %% [markdown]
# # Viz

# %%
print("\n" + "="*40)
print(f"🏆 BEST CONFIGURATION FOUND (IGD={best_igd:.4f})")
print("="*40)
for k, v in best_config.items():
    print(f"{k}: {v}")

# Sắp xếp kết quả theo IGD
sorted_results = sorted(results, key=lambda x: x['igd'])
print("\nTop 5 Configs:")
for i in range(min(5, len(sorted_results))):
    r = sorted_results[i]
    print(f"Rank {i+1}: IGD={r['igd']:.4f} | Params={r['params']}")

# --- Plotting ---
plt.figure(figsize=(10, 6))

# Plot Ground Truth
if pf_true is not None:
    plt.scatter(pf_true[:, 0], pf_true[:, 1], c='gray', alpha=0.5, label='Ground Truth', s=20)

# Plot Best Prediction
if best_pf_pred is not None:
    plt.scatter(best_pf_pred[:, 0], best_pf_pred[:, 1], c='red', marker='x', label='Best Prediction', s=40)

# Plot Ideal Point
plt.scatter(z_star[0], z_star[1], c='green', marker='*', s=150, label='Ideal Point (z*)')

plt.xlabel('f1')
plt.ylabel('f2')
plt.title(f'Pareto Front Approximation (Best IGD: {best_igd:.4f})')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()
# Out:
# ========================================
# 🏆 BEST CONFIGURATION FOUND (IGD=2.9408)
# ========================================
# lr: 0.001
# num_epochs: 1000
# pen_C_growth: 1.005
# pen_Q_decay: 0.995
# init_pen_C: 10.0
# init_pen_Q: 20.0
# max_pen_C: 500.0
#
# Top 5 Configs:
# Rank 1: IGD=2.9408 | Params={'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.005, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0}
# Rank 2: IGD=3.5679 | Params={'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 2000.0}
# Rank 3: IGD=4.3304 | Params={'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.005, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 2000.0}
# Rank 4: IGD=4.4644 | Params={'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.005, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 2000.0}
# Rank 5: IGD=4.5493 | Params={'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.005, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 1000.0}

# %%
import pandas as pd

pd.DataFrame(sorted_results)
# Out:
#     config_id                                             params         igd  \
# 0           0  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...    2.940787
# 1          20  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...    3.567915
# 2           2  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...    4.330421
# 3           5  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...    4.464400
# 4           4  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...    4.549287
# 5          18  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...    5.481994
# 6           1  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...    8.699601
# 7          44  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...    9.214555
# 8          25  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   13.546761
# 9          31  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   14.199908
# 10         16  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   17.301583
# 11         19  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   17.734657
# 12         32  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   18.347930
# 13         15  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   19.139098
# 14         12  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   26.787679
# 15          3  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   27.332904
# 16         22  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   30.882830
# 17         27  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   32.596550
# 18         34  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   32.683919
# 19         33  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   32.845359
# 20          7  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   33.211166
# 21          8  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   35.947344
# 22         23  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   36.732567
# 23          6  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   37.999529
# 24         14  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   38.085986
# 25         11  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   38.242555
# 26         38  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   39.213765
# 27          9  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   39.661227
# 28         24  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   40.065645
# 29         35  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   42.192669
# 30         13  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   42.412316
# 31         28  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   43.011947
# 32         30  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   43.381152
# 33         21  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   44.899114
# 34         37  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   47.432213
# 35         17  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   52.609461
# 36         47  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   65.157124
# 37         36  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   66.259152
# 38         48  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   80.139773
# 39         45  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...  106.778359
# 40         52  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...  110.791896
# 41         10  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...  138.547176
# 42         29  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...  139.132335
# 43         26  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...  154.190191
# 44         51  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...  156.489249
# 45         40  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...  161.104442
# 46         46  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...  166.102057
# 47         41  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...  218.610226
# 48         42  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...  274.805553
# 49         53  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...  310.294954
# 50         43  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...  310.548241
# 51         39  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...  315.686709
# 52         49  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...  318.855262
# 53         50  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...  403.003133
#
#           time
# 0    93.445961
# 1   107.713984
# 2    98.187716
# 3    96.579152
# 4   100.698933
# 5   119.584781
# 6   106.421500
# 7   135.374696
# 8   132.623991
# 9   133.573009
# 10  151.892879
# 11  132.717288
# 12  138.966720
# 13  153.807389
# 14  155.512950
# 15  112.297101
# 16  132.721345
# 17  148.458704
# 18  154.611679
# 19  139.041243
# 20  129.645662
# 21  130.159938
# 22  125.064764
# 23  122.457710
# 24  133.822949
# 25  133.527489
# 26  135.307257
# 27  145.397743
# 28  137.409911
# 29  138.704684
# 30  160.502674
# 31  122.263008
# 32  149.933409
# 33  133.382343
# 34  156.415477
# 35  117.762857
# 36  150.983611
# 37  158.562869
# 38  157.032150
# 39  158.199682
# 40  155.825988
# 41  149.735588
# 42  160.537247
# 43  159.843478
# 44  158.031534
# 45  158.735729
# 46  150.763125
# 47  152.227650
# 48  160.824646
# 49  162.660301
# 50  160.930132
# 51  160.127950
# 52  163.214318
# 53  159.584861
