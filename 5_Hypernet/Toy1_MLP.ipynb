# %%
import time
import numpy as np
import yaml
import autograd.numpy as np1
from scipy.optimize import Bounds
import torch
from torch import Tensor, optim
import torch.optim.lr_scheduler as lr_scheduler
from utils import circle_points, plot_trajectories

# %%
from tqdm import tqdm
from hypernet_MLP import Hypernet_MLP
import math

# %%
import autograd.numpy as np
from scipy.optimize import minimize            
from scipy.optimize import BFGS
        
class Projection:
    def __init__(self, cons, bounds, dim, proj_type='euclid'):
        """
        cons: Ràng buộc (constraints)
        bounds: Giới hạn biên (bounds)
        n: Số chiều
        proj_type: Loại phép chiếu ('euclid' cho miền C hoặc 'qplus' cho miền Q+)
        """
        self.cons = cons
        self.bounds = bounds
        self.dim = dim
        self.proj_type = proj_type
        
        # Cấu hình hàm mục tiêu dựa trên loại phép chiếu
        if self.proj_type == 'qplus':
            self.objective_func = self._obj_positive_diff
        elif self.proj_type == 'euclid':
            self.objective_func = self._obj_l2_norm
        else:
            print(f"Phép chiếu {self.objective_func} không cài đặt, chọn 'qplus' hoặc 'euclid'")

    def _obj_l2_norm(self, x, y):
        """Hàm mục tiêu khoảng cách Euclid chuẩn (Dùng cho C)"""
        return np.sqrt(np.sum((x - y)**2))
    
    def _obj_positive_diff(self, x, y):
        """Hàm mục tiêu (Dùng cho Qplus)"""
        v = np.maximum(y - x, 0) 
        return np.sum(v**2)

    def project(self, target_point):
        """
        init_point: Điểm khởi tạo
        target_point: Điểm cần chiếu 
        """
        
        init_point = np.random.rand(1, self.dim).tolist()[0]
        
        res = minimize(
            self.objective_func,
            init_point,
            args=(target_point, ),
#             jac="2-point",
#             hess=BFGS(),
            constraints=self.cons,
#             method="trust-constr",
            bounds=self.bounds,
            options={'disp': False}
        )
        
        optim_point = res.x
        
        if self.proj_type == 'qplus':
            return target_point - np.maximum(target_point - optim_point, 0)
        else:
            return optim_point

# %%
class Problem():
    def __init__(self, f, dim_x, dim_y, proj_C, proj_Qplus):
        self.f = f
        self.dim_x = dim_x
        self.dim_y = dim_y
        self.proj_C = proj_C
        self.proj_Qplus = proj_Qplus
    
    def objective_func(self, x):
        vals = [func(x) for func in self.f]
        return np.concatenate(vals)

# %% [markdown]
# # Define

# %%
def f(x):
    return np.array([
        x[0]**2,
       (x[0]-1)**2
    ])

def f1(x):
    return x**2
def f2(x):
    return (x-1)**2

#--------------- C --------------------#


#--------------- Q --------------------#


# Hàm dùng cho Projection 
cons_C = (

)

dim_x = 1

cons_Q = (
 
)

cons_Qplus = (
)
dim_y = 2

# %%
# Setup Projections
proj_C_handler = Projection(cons=cons_C, bounds=None, dim=dim_x, proj_type='euclid')
proj_Q_handler = Projection(cons=cons_Q, bounds=None, dim=dim_y, proj_type='qplus')

prob = Problem(
    f=[f1, f2],
    dim_x=1, dim_y=2,
    proj_C=proj_C_handler.project,
    proj_Qplus=proj_Q_handler.project
)

# %%
config_path='../4_Pareto_front/config.yaml'
with open(config_path, 'r') as f:
    cfg = yaml.safe_load(f)
test_rays = np.array(cfg['data']['test_ray'])
z_star = np.array([0., 0.])

# %%
def evaluate_objectives_single(functions, x_tensor):
    """
    Tính f1, f2 cho 1 mẫu x duy nhất.
    Args:
        x_tensor: Shape (Dim_x,) -> VD: (2,)
    Returns:
        Tensor Shape (Num_Obj,) -> VD: (2,)
    """
    vals = []
    for func in functions:
        val = func(x_tensor)
        if not torch.is_tensor(val):
            val = torch.tensor(val, dtype=torch.float32)
        vals.append(val)
    
    return torch.stack(vals).reshape(-1)

def train_hypernet(hypernet, prob, z_star, 
                   num_epochs=1000, 
                   lr=1e-3, 
                   num_partitions=100, 
                   lr_step_size=300, 
                   lr_gamma=0.5,
                   init_penalty_weight=10.0,
                   penalty_decay=0.999):
    
    optimizer = optim.Adam(hypernet.parameters(), lr=lr)
    scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=lr_step_size, gamma=lr_gamma)
    
    # Đảm bảo z_star chuẩn shape (1, 2)
    z_star_tensor = torch.tensor(z_star, dtype=torch.float32).view(1, -1)
    
    current_penalty = init_penalty_weight
    angle_step = (math.pi / 2) / num_partitions
    
    print(f"=== TRAIN HYPERNET (Penalty Method for both C & Q) ===")
    
    for epoch in range(num_epochs):
        hypernet.train()
        optimizer.zero_grad()
        
        # 1. Stratified Sampling
        starts = torch.arange(num_partitions) * angle_step
        noise = torch.rand(num_partitions) * angle_step
        thetas = starts + noise 
        
        r_batch_np = np.stack([np.cos(thetas.numpy()), np.sin(thetas.numpy())], axis=1)
        r_tensor_batch = torch.tensor(r_batch_np, dtype=torch.float32) # Shape (100, 2)
        
        # 2. Sequential Forward
        x_pred_list = []
        for i in range(num_partitions):
            r_single = r_tensor_batch[i].unsqueeze(0)
            x_single = hypernet(r_single)
            x_pred_list.append(x_single)
            
        x_vec_batch = torch.cat(x_pred_list, dim=0) # Shape (100, 2)
        
        # 3. Tính toán Loss 
        x_np_batch = x_vec_batch.detach().cpu().numpy()
        
        loss_C_list = [] # Danh sách loss cho C
        loss_Q_list = []
        y_pred_list = []
        
        for i in range(num_partitions):
            # Lấy 1 mẫu: shape (2,)
            x_i_tensor = x_vec_batch[i]
            x_i_np = x_np_batch[i]
            
            # --- a. Tính Loss C (Khoảng cách từ x đến proj_C(x)) ---
            x_proj_i_np = prob.proj_C(x_i_np)
            x_proj_i_tensor = torch.tensor(x_proj_i_np, dtype=torch.float32)
            
            # Tính khoảng cách bình phương làm loss phạt cho C
            loss_C_list.append(torch.sum((x_i_tensor - x_proj_i_tensor)**2))
            
            # --- b. Tính F(x) dùng output GỐC của mạng (không qua STE) ---
            # Output shape bảo đảm là (2,)
            y_pred_i = evaluate_objectives_single(prob.f, x_i_tensor)
            y_pred_list.append(y_pred_i)
            
            # --- c. Tính Loss Q (Khoảng cách từ y đến proj_Q+(y)) ---
            y_i_np = y_pred_i.detach().cpu().numpy()
            y_proj_i_np = prob.proj_Qplus(y_i_np)
            y_proj_i_tensor = torch.tensor(y_proj_i_np, dtype=torch.float32)
            
            loss_Q_list.append(torch.sum((y_pred_i - y_proj_i_tensor)**2))
        
        # Stack lại: List 100 cái (2,) -> Tensor (100, 2)
        y_pred_batch = torch.stack(y_pred_list)
        
        # Tính trung bình loss phạt
        loss_C = torch.mean(torch.stack(loss_C_list))
        loss_Q = torch.mean(torch.stack(loss_Q_list))
        
        # 4. Chebyshev Loss
        # diff: (100, 2) - (1, 2) -> (100, 2)
        diff = y_pred_batch - z_star_tensor 
        
        # weighted_diff: (100, 2) * (100, 2) -> (100, 2)
        weighted_diff = r_tensor_batch * diff
        
        max_vals, _ = torch.max(weighted_diff, dim=1) # (100,)
        loss_obj = torch.mean(max_vals)
        
        # 5. Backward (Tổng hợp cả Loss C và Loss Q vào penalty)
        total_loss = loss_obj + current_penalty * (loss_C + loss_Q)
        
        total_loss.backward()
        optimizer.step()
        scheduler.step()
        
        current_penalty = max(0.1, current_penalty * penalty_decay)
        
        if epoch % 10 == 0:
            current_lr = scheduler.get_last_lr()[0]
            print(f"Epoch {epoch}: Total={total_loss.item():.4f} (Obj={loss_obj.item():.4f}, C={loss_C.item():.4f}, Q={loss_Q.item():.4f}) || Pen={current_penalty:.2f}")
            
    return hypernet

# %%
hypernet_c = Hypernet_MLP(ray_hidden_dim=32, out_dim=prob.dim_x, n_tasks=2)

# %%
trained_c = train_hypernet(hypernet_c, prob, z_star, num_epochs=1000, init_penalty_weight=20.0)
# Out:
# === TRAIN HYPERNET (Penalty Method for both C & Q) ===
# Epoch 0: Total=0.7903 (Obj=0.7903, C=0.0000, Q=0.0000) || Pen=19.98
# Epoch 10: Total=0.6156 (Obj=0.6156, C=0.0000, Q=0.0000) || Pen=19.78
# Epoch 20: Total=0.4624 (Obj=0.4624, C=0.0000, Q=0.0000) || Pen=19.58
# Epoch 30: Total=0.2929 (Obj=0.2929, C=0.0000, Q=0.0000) || Pen=19.39
# Epoch 40: Total=0.2361 (Obj=0.2361, C=0.0000, Q=0.0000) || Pen=19.20
# Epoch 50: Total=0.2166 (Obj=0.2166, C=0.0000, Q=0.0000) || Pen=19.01
# Epoch 60: Total=0.1958 (Obj=0.1958, C=0.0000, Q=0.0000) || Pen=18.82
# Epoch 70: Total=0.1738 (Obj=0.1738, C=0.0000, Q=0.0000) || Pen=18.63
# Epoch 80: Total=0.1534 (Obj=0.1534, C=0.0000, Q=0.0000) || Pen=18.44
# Epoch 90: Total=0.1417 (Obj=0.1417, C=0.0000, Q=0.0000) || Pen=18.26
# Epoch 100: Total=0.1411 (Obj=0.1411, C=0.0000, Q=0.0000) || Pen=18.08
# Epoch 110: Total=0.1401 (Obj=0.1401, C=0.0000, Q=0.0000) || Pen=17.90
# Epoch 120: Total=0.1383 (Obj=0.1383, C=0.0000, Q=0.0000) || Pen=17.72
# Epoch 130: Total=0.1366 (Obj=0.1366, C=0.0000, Q=0.0000) || Pen=17.54
# Epoch 140: Total=0.1356 (Obj=0.1356, C=0.0000, Q=0.0000) || Pen=17.37
# Epoch 150: Total=0.1347 (Obj=0.1347, C=0.0000, Q=0.0000) || Pen=17.20
# Epoch 160: Total=0.1339 (Obj=0.1339, C=0.0000, Q=0.0000) || Pen=17.02
# Epoch 170: Total=0.1328 (Obj=0.1328, C=0.0000, Q=0.0000) || Pen=16.85
# Epoch 180: Total=0.1323 (Obj=0.1323, C=0.0000, Q=0.0000) || Pen=16.69
# Epoch 190: Total=0.1315 (Obj=0.1315, C=0.0000, Q=0.0000) || Pen=16.52
# Epoch 200: Total=0.1311 (Obj=0.1311, C=0.0000, Q=0.0000) || Pen=16.36
# Epoch 210: Total=0.1309 (Obj=0.1309, C=0.0000, Q=0.0000) || Pen=16.19
# Epoch 220: Total=0.1303 (Obj=0.1303, C=0.0000, Q=0.0000) || Pen=16.03
# Epoch 230: Total=0.1299 (Obj=0.1299, C=0.0000, Q=0.0000) || Pen=15.87
# Epoch 240: Total=0.1299 (Obj=0.1299, C=0.0000, Q=0.0000) || Pen=15.71
# Epoch 250: Total=0.1295 (Obj=0.1295, C=0.0000, Q=0.0000) || Pen=15.56
# Epoch 260: Total=0.1294 (Obj=0.1294, C=0.0000, Q=0.0000) || Pen=15.40
# Epoch 270: Total=0.1293 (Obj=0.1293, C=0.0000, Q=0.0000) || Pen=15.25
# Epoch 280: Total=0.1290 (Obj=0.1290, C=0.0000, Q=0.0000) || Pen=15.10
# Epoch 290: Total=0.1289 (Obj=0.1289, C=0.0000, Q=0.0000) || Pen=14.95
# Epoch 300: Total=0.1287 (Obj=0.1287, C=0.0000, Q=0.0000) || Pen=14.80
# Epoch 310: Total=0.1286 (Obj=0.1286, C=0.0000, Q=0.0000) || Pen=14.65
# Epoch 320: Total=0.1286 (Obj=0.1286, C=0.0000, Q=0.0000) || Pen=14.51
# Epoch 330: Total=0.1288 (Obj=0.1288, C=0.0000, Q=0.0000) || Pen=14.36
# Epoch 340: Total=0.1287 (Obj=0.1287, C=0.0000, Q=0.0000) || Pen=14.22
# Epoch 350: Total=0.1285 (Obj=0.1285, C=0.0000, Q=0.0000) || Pen=14.08
# Epoch 360: Total=0.1287 (Obj=0.1287, C=0.0000, Q=0.0000) || Pen=13.94
# Epoch 370: Total=0.1285 (Obj=0.1285, C=0.0000, Q=0.0000) || Pen=13.80
# Epoch 380: Total=0.1285 (Obj=0.1285, C=0.0000, Q=0.0000) || Pen=13.66
# Epoch 390: Total=0.1284 (Obj=0.1284, C=0.0000, Q=0.0000) || Pen=13.52
# Epoch 400: Total=0.1284 (Obj=0.1284, C=0.0000, Q=0.0000) || Pen=13.39
# Epoch 410: Total=0.1284 (Obj=0.1284, C=0.0000, Q=0.0000) || Pen=13.26
# Epoch 420: Total=0.1280 (Obj=0.1280, C=0.0000, Q=0.0000) || Pen=13.13
# Epoch 430: Total=0.1283 (Obj=0.1283, C=0.0000, Q=0.0000) || Pen=12.99
# Epoch 440: Total=0.1280 (Obj=0.1280, C=0.0000, Q=0.0000) || Pen=12.87
# Epoch 450: Total=0.1282 (Obj=0.1282, C=0.0000, Q=0.0000) || Pen=12.74
# Epoch 460: Total=0.1280 (Obj=0.1280, C=0.0000, Q=0.0000) || Pen=12.61
# Epoch 470: Total=0.1281 (Obj=0.1281, C=0.0000, Q=0.0000) || Pen=12.48
# Epoch 480: Total=0.1281 (Obj=0.1281, C=0.0000, Q=0.0000) || Pen=12.36
# Epoch 490: Total=0.1280 (Obj=0.1280, C=0.0000, Q=0.0000) || Pen=12.24
# Epoch 500: Total=0.1280 (Obj=0.1280, C=0.0000, Q=0.0000) || Pen=12.12
# Epoch 510: Total=0.1282 (Obj=0.1282, C=0.0000, Q=0.0000) || Pen=11.99
# Epoch 520: Total=0.1280 (Obj=0.1280, C=0.0000, Q=0.0000) || Pen=11.88
# Epoch 530: Total=0.1278 (Obj=0.1278, C=0.0000, Q=0.0000) || Pen=11.76
# Epoch 540: Total=0.1280 (Obj=0.1280, C=0.0000, Q=0.0000) || Pen=11.64
# Epoch 550: Total=0.1279 (Obj=0.1279, C=0.0000, Q=0.0000) || Pen=11.52
# Epoch 560: Total=0.1277 (Obj=0.1277, C=0.0000, Q=0.0000) || Pen=11.41
# Epoch 570: Total=0.1277 (Obj=0.1277, C=0.0000, Q=0.0000) || Pen=11.30
# Epoch 580: Total=0.1277 (Obj=0.1277, C=0.0000, Q=0.0000) || Pen=11.18
# Epoch 590: Total=0.1278 (Obj=0.1278, C=0.0000, Q=0.0000) || Pen=11.07
# Epoch 600: Total=0.1278 (Obj=0.1278, C=0.0000, Q=0.0000) || Pen=10.96
# Epoch 610: Total=0.1276 (Obj=0.1276, C=0.0000, Q=0.0000) || Pen=10.85
# Epoch 620: Total=0.1276 (Obj=0.1276, C=0.0000, Q=0.0000) || Pen=10.74
# Epoch 630: Total=0.1278 (Obj=0.1278, C=0.0000, Q=0.0000) || Pen=10.64
# Epoch 640: Total=0.1278 (Obj=0.1278, C=0.0000, Q=0.0000) || Pen=10.53
# Epoch 650: Total=0.1276 (Obj=0.1276, C=0.0000, Q=0.0000) || Pen=10.43
# Epoch 660: Total=0.1276 (Obj=0.1276, C=0.0000, Q=0.0000) || Pen=10.32
# Epoch 670: Total=0.1276 (Obj=0.1276, C=0.0000, Q=0.0000) || Pen=10.22
# Epoch 680: Total=0.1277 (Obj=0.1277, C=0.0000, Q=0.0000) || Pen=10.12
# Epoch 690: Total=0.1274 (Obj=0.1274, C=0.0000, Q=0.0000) || Pen=10.02
# Epoch 700: Total=0.1276 (Obj=0.1276, C=0.0000, Q=0.0000) || Pen=9.92
# Epoch 710: Total=0.1274 (Obj=0.1274, C=0.0000, Q=0.0000) || Pen=9.82
# Epoch 720: Total=0.1276 (Obj=0.1276, C=0.0000, Q=0.0000) || Pen=9.72
# Epoch 730: Total=0.1275 (Obj=0.1275, C=0.0000, Q=0.0000) || Pen=9.63
# Epoch 740: Total=0.1274 (Obj=0.1274, C=0.0000, Q=0.0000) || Pen=9.53
# Epoch 750: Total=0.1274 (Obj=0.1274, C=0.0000, Q=0.0000) || Pen=9.43
# Epoch 760: Total=0.1274 (Obj=0.1274, C=0.0000, Q=0.0000) || Pen=9.34
# Epoch 770: Total=0.1274 (Obj=0.1274, C=0.0000, Q=0.0000) || Pen=9.25
# Epoch 780: Total=0.1273 (Obj=0.1273, C=0.0000, Q=0.0000) || Pen=9.16
# Epoch 790: Total=0.1276 (Obj=0.1276, C=0.0000, Q=0.0000) || Pen=9.06
# Epoch 800: Total=0.1276 (Obj=0.1276, C=0.0000, Q=0.0000) || Pen=8.97
# Epoch 810: Total=0.1274 (Obj=0.1274, C=0.0000, Q=0.0000) || Pen=8.88
# Epoch 820: Total=0.1276 (Obj=0.1276, C=0.0000, Q=0.0000) || Pen=8.80
# Epoch 830: Total=0.1274 (Obj=0.1274, C=0.0000, Q=0.0000) || Pen=8.71
# Epoch 840: Total=0.1277 (Obj=0.1277, C=0.0000, Q=0.0000) || Pen=8.62
# Epoch 850: Total=0.1273 (Obj=0.1273, C=0.0000, Q=0.0000) || Pen=8.54
# Epoch 860: Total=0.1273 (Obj=0.1273, C=0.0000, Q=0.0000) || Pen=8.45
# Epoch 870: Total=0.1273 (Obj=0.1273, C=0.0000, Q=0.0000) || Pen=8.37
# Epoch 880: Total=0.1273 (Obj=0.1273, C=0.0000, Q=0.0000) || Pen=8.28
# Epoch 890: Total=0.1274 (Obj=0.1274, C=0.0000, Q=0.0000) || Pen=8.20
# Epoch 900: Total=0.1274 (Obj=0.1274, C=0.0000, Q=0.0000) || Pen=8.12
# Epoch 910: Total=0.1272 (Obj=0.1272, C=0.0000, Q=0.0000) || Pen=8.04
# Epoch 920: Total=0.1272 (Obj=0.1272, C=0.0000, Q=0.0000) || Pen=7.96
# Epoch 930: Total=0.1272 (Obj=0.1272, C=0.0000, Q=0.0000) || Pen=7.88
# Epoch 940: Total=0.1274 (Obj=0.1274, C=0.0000, Q=0.0000) || Pen=7.80
# Epoch 950: Total=0.1273 (Obj=0.1273, C=0.0000, Q=0.0000) || Pen=7.72
# Epoch 960: Total=0.1272 (Obj=0.1272, C=0.0000, Q=0.0000) || Pen=7.65
# Epoch 970: Total=0.1272 (Obj=0.1272, C=0.0000, Q=0.0000) || Pen=7.57
# Epoch 980: Total=0.1275 (Obj=0.1275, C=0.0000, Q=0.0000) || Pen=7.50
# Epoch 990: Total=0.1272 (Obj=0.1272, C=0.0000, Q=0.0000) || Pen=7.42

# %% [markdown]
# # Test

# %%
pf_true = np.load("../4_Pareto_front/tmp/pf_true.npy")
target_space = np.load("../4_Pareto_front/tmp/target_space.npy")

# %% [markdown]
# ## Constraint

# %%
hypernet_c.eval()

pf_pred = [] 
tmp_err = [] 

t1 = time.time()


print(f"Evaluating on {len(test_rays)} rays...")

for r in test_rays:   
    # --- Dự đoán với Hypernetwork ---
    ray_t = torch.from_numpy(r).float().unsqueeze(0)
    
    with torch.no_grad(): 
        output_x = hypernet_c(ray_t).squeeze()
        vals = [func(output_x).item() for func in prob.f]
        obj_pred = np.array(vals)
    
    pf_pred.append(obj_pred)
    
#     err = np.sum(np.abs(obj_pred - y_test))
#     tmp_err.append(err)
    

t2 = time.time()

pf_pred = np.array(pf_pred)

print("-" * 30)
# print(f"Mean L1 Error: {np.mean(tmp_err):.6f}")
print(f"Inference Time: {t2-t1:.4f}s")
# Out:
# Evaluating on 100 rays...
# ------------------------------
# Inference Time: 0.0069s

# %%
plot_trajectories(obs_true=np.array(pf_true),obs_predict=np.array(pf_pred),obs_pareto_front=target_space , figsize=(16, 8))
