# %%
import os
import time
import math
import itertools
import yaml
import numpy as np
import torch
import torch.optim as optim
import matplotlib.pyplot as plt
from scipy.optimize import minimize, Bounds

# %%
def set_seed(seed=702):
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)

set_seed(702)

# %%
import torch
from torch import nn
import torch.nn.functional as F

class Hypernet_trans(nn.Module):
    def __init__(self, ray_hidden_dim=32, out_dim=2, target_hidden_dim=15, n_hidden=1, n_tasks=2):
        super().__init__()
        self.n_hidden = n_hidden
        self.n_tasks = n_tasks

        # Các layer giữ nguyên
        if self.n_tasks == 2:
            self.embedding_layer1 = nn.Sequential(nn.Linear(1, ray_hidden_dim), nn.ReLU(inplace=True))
            self.embedding_layer2 = nn.Sequential(nn.Linear(1, ray_hidden_dim), nn.ReLU(inplace=True))
        else:
            self.embedding_layer1 = nn.Sequential(nn.Linear(1, ray_hidden_dim), nn.ReLU(inplace=True))
            self.embedding_layer2 = nn.Sequential(nn.Linear(1, ray_hidden_dim), nn.ReLU(inplace=True))
            self.embedding_layer3 = nn.Sequential(nn.Linear(1, ray_hidden_dim), nn.ReLU(inplace=True))
            
        self.output_layer = nn.Linear(ray_hidden_dim, out_dim)
        self.attention = nn.MultiheadAttention(embed_dim=ray_hidden_dim, num_heads=2)
        self.ffn1 = nn.Linear(ray_hidden_dim, ray_hidden_dim)
        self.ffn2 = nn.Linear(ray_hidden_dim, ray_hidden_dim)

    def forward(self, ray):
        """
        Input ray: (Batch_Size, n_tasks) -> VD: (20, 2)
        Output x: (Batch_Size, out_dim) -> VD: (20, 2)
        """
        
        if self.n_tasks == 2: 
            emb1 = self.embedding_layer1(ray[:, 0].unsqueeze(1)) 
            emb2 = self.embedding_layer2(ray[:, 1].unsqueeze(1))
            
            x = torch.stack((emb1, emb2), dim=0) 
        else:
            x = torch.stack(
                (
                    self.embedding_layer1(ray[:, 0].unsqueeze(1)),
                    self.embedding_layer2(ray[:, 1].unsqueeze(1)),
                    self.embedding_layer3(ray[:, 2].unsqueeze(1))
                ), dim=0
            )
        
        # --- Transformer Block (Seq_len, Batch, Dim) ---
        x_res = x
        x, _ = self.attention(x, x, x)
        x = x + x_res
        
        x_res = x
        x = self.ffn1(x)
        x = F.relu(x)
        x = self.ffn2(x)
        x = x + x_res
        
        # --- Output Layer ---
        # x: (Seq_len, Batch, Hidden) -> (Seq_len, Batch, Out_dim)
        x = self.output_layer(x)
        
        # --- Aggregation ---
        # Kết quả: (Batch, Out_dim)
        x = torch.mean(x, dim=0) 
        
        
        return x

# %% [markdown]
# # Const

# %%
device = torch.device("cpu")
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
GROUND_TRUTH_FILE = "../4_Pareto_front/test/ex4/pf_dynamic_true.npy" 

if os.path.exists(GROUND_TRUTH_FILE):
    pf_true = np.load(GROUND_TRUTH_FILE)
    print(f"✅ Đã tải ground truth Pareto front từ: {GROUND_TRUTH_FILE}, Shape: {pf_true.shape}")
else:
    print(f"❌ KHÔNG tìm thấy file ground truth tại: {GROUND_TRUTH_FILE}")
# Out:
# ✅ Đã tải ground truth Pareto front từ: ../4_Pareto_front/test/ex4/pf_dynamic_true.npy, Shape: (20, 2)

# %% [markdown]
# # Def

# %%
import autograd.numpy as np
from scipy.optimize import minimize            
        
class Projection:
    def __init__(self, cons, bounds, dim, proj_type='euclid'):
        self.cons = cons
        self.bounds = bounds
        self.dim = dim
        self.proj_type = proj_type
        
        if self.proj_type == 'qplus':
            self.objective_func = self._obj_positive_diff
        elif self.proj_type == 'euclid':
            self.objective_func = self._obj_l2_norm
        else:
            print(f"Phép chiếu {self.objective_func} không cài đặt, chọn 'qplus' hoặc 'euclid'")

    def _obj_l2_norm(self, x, y):
        return np.sqrt(np.sum((x - y)**2))
    
    def _obj_positive_diff(self, x, y):
        v = np.maximum(y - x, 0) 
        return np.sum(v**2)

    def project(self, target_point):
        init_point = np.random.rand(1, self.dim).tolist()[0]
        
        res = minimize(
            self.objective_func,
            init_point,
            args=(target_point, ),
            constraints=self.cons,
            bounds=self.bounds,
            options={'disp': False}
        )
        
        optim_point = res.x
        
        if self.proj_type == 'qplus':
            return target_point - np.maximum(target_point - optim_point, 0)
        else:
            return optim_point

class Problem():
    def __init__(self, f, dim_x, dim_y, proj_C, proj_Qplus):
        self.f = f
        self.dim_x = dim_x
        self.dim_y = dim_y
        self.proj_C = proj_C
        self.proj_Qplus = proj_Qplus
    
    def objective_func(self, x):
        vals = [func(x) for func in self.f]
        return np.concatenate(vals)

# %%
def f1(x): return 4*x[0]**2 + 4*x[1]**2
def f2(x): return (x[0] - 5)**2 + (x[1] - 5)**2

def c1(x): return -(x[0] - 5)**2 - x[1]**2 + 25
def c2(x): return -(x[0] - 8)**2 - (x[1] + 3)**2 + 17.7

def q1(y): return 50**2 - (y[0] - 50)**2 - (y[1] - 50)**2
def q_plus(y):
    center = 50.0; radius_sq = 50**2
    dx = np.maximum(0, y[0] - center)
    dy = np.maximum(0, y[1] - center)
    return radius_sq - (dx**2 + dy**2)

cons_C = ({'type': 'ineq', 'fun': c1}, {'type': 'ineq', 'fun': c2})
cons_Q = ({'type': 'ineq', 'fun': q1},)
cons_Qplus = ({'type': 'ineq', 'fun': q_plus},)
bounds_x = Bounds([-15,-15],[30, 30])
dim_x = 2; dim_y = 2

# Setup
proj_C_handler = Projection(cons_C, bounds_x, dim_x, 'euclid')
proj_Q_handler = Projection(cons_Q, None, dim_y, 'qplus')
prob = Problem([f1, f2], dim_x, dim_y, proj_C_handler.project, proj_Q_handler.project)
z_star = np.array([75.23366646094793, 25.502227623508944])

# %%
def evaluate_objectives_single(functions, x_tensor):
    vals = []
    for func in functions:
        val = func(x_tensor)
        if not torch.is_tensor(val): val = torch.tensor(val, dtype=torch.float32, device=x_tensor.device)
        vals.append(val)
    return torch.stack(vals).reshape(-1)

def calculate_mse_igd(pf_pred, pf_true):
    if len(pf_pred) == 0: return np.inf
    total_dist_sq = 0
    # Với mỗi điểm ground truth, tìm điểm dự đoán gần nhất
    for p_true in pf_true:
        dists_sq = np.sum((pf_pred - p_true)**2, axis=1)
        total_dist_sq += np.min(dists_sq)
    return total_dist_sq / len(pf_true)

# %%
def train_hypernet(hypernet, prob, z_star, 
                   num_epochs=1000, lr=1e-3, num_partitions=50, 
                   lr_step_size=300, lr_gamma=0.5,
                   init_pen_C=1.0, max_pen_C=1000.0, pen_C_growth=1.01,
                   init_pen_Q=50.0, min_pen_Q=1.0, pen_Q_decay=0.995,
                   verbose=False):
    
    hypernet = hypernet.to(device)
    optimizer = optim.Adam(hypernet.parameters(), lr=lr)
    scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=lr_step_size, gamma=lr_gamma)
    z_star_tensor = torch.tensor(z_star, dtype=torch.float32, device=device).view(1, -1)
    
    current_pen_C = init_pen_C
    current_pen_Q = init_pen_Q
    angle_step = (math.pi / 2) / num_partitions
    
    for epoch in range(num_epochs):
        hypernet.train()
        optimizer.zero_grad()
        
        # 1. Stratified Sampling
        starts = torch.arange(num_partitions) * angle_step
        noise = torch.rand(num_partitions) * angle_step
        thetas = starts + noise
        r_batch_np = np.stack([np.cos(thetas.numpy()), np.sin(thetas.numpy())], axis=1)
        r_tensor_batch = torch.tensor(r_batch_np, dtype=torch.float32, device=device)
        
        # 2. Forward & Loss Calculation (Loop safe logic)
        loss_C_list = []
        loss_Q_list = []
        y_pred_list = []
        
        # Forward pass batch (Nhanh hơn gọi từng cái)
        x_vec_batch = hypernet(r_tensor_batch) # (Batch, 2)
        x_np_batch = x_vec_batch.detach().cpu().numpy()
        
        for i in range(num_partitions):
            x_i_tensor = x_vec_batch[i]
            x_i_np = x_np_batch[i]
            
            # Loss C
            x_proj_i_np = prob.proj_C(x_i_np)
            x_proj_i_tensor = torch.tensor(x_proj_i_np, dtype=torch.float32, device=device)
            loss_C_list.append(torch.sum((x_i_tensor - x_proj_i_tensor)**2))
            
            # F(x)
            y_pred_i = evaluate_objectives_single(prob.f, x_i_tensor)
            y_pred_list.append(y_pred_i)
            
            # Loss Q
            y_i_np = y_pred_i.detach().cpu().numpy()
            y_proj_i_np = prob.proj_Qplus(y_i_np)
            y_proj_i_tensor = torch.tensor(y_proj_i_np, dtype=torch.float32, device=device)
            loss_Q_list.append(torch.sum((y_pred_i - y_proj_i_tensor)**2))
            
        y_pred_batch = torch.stack(y_pred_list)
        loss_C = torch.mean(torch.stack(loss_C_list))
        loss_Q = torch.mean(torch.stack(loss_Q_list))
        
        # Chebyshev Loss
        diff = y_pred_batch - z_star_tensor
        weighted_diff = r_tensor_batch * diff
        max_vals, _ = torch.max(weighted_diff, dim=1)
        loss_obj = torch.mean(max_vals)
        
        total_loss = loss_obj + (current_pen_C * loss_C) + (current_pen_Q * loss_Q)
        
        total_loss.backward()
        optimizer.step()
        scheduler.step()
        
        # Update Penalties
        current_pen_C = min(max_pen_C, current_pen_C * pen_C_growth)
        current_pen_Q = max(min_pen_Q, current_pen_Q * pen_Q_decay)
        
        if verbose and epoch % (num_epochs // 5) == 0:
            print(f"  Ep {epoch}: Loss={total_loss.item():.2f} (Obj={loss_obj.item():.2f}, C={loss_C.item():.4f})")
            
    return hypernet

# %%
def evaluate_model(hypernet, prob, test_rays, pf_true):
    hypernet.eval()
    pf_pred = []
    
    # Chuyển test_rays sang tensor batch để infer nhanh
    rays_tensor = torch.tensor(test_rays, dtype=torch.float32, device=device)
    
    with torch.no_grad():
        x_raw = hypernet(rays_tensor) # (N, 2)
        x_raw_np = x_raw.cpu().numpy()
        
        # Loop project and eval
        for i in range(len(x_raw_np)):
            # Chiếu lên C (Quan trọng để feasible)
            x_proj = prob.proj_C(x_raw_np[i])
            # Tính f
            val = [func(x_proj) for func in prob.f]
            pf_pred.append(val)
            
    pf_pred = np.array(pf_pred)
    igd_score = calculate_mse_igd(pf_pred, pf_true)
    return igd_score, pf_pred

# %% [markdown]
# # Config

# %%
param_grid = {
    'lr': [1e-3],
    'num_epochs': [1000],
    'pen_C_growth': [1.005, 1.01, 1.05],      # Tăng phạt C nhanh hay chậm
    'pen_Q_decay': [0.995],      
    'init_pen_C': [10.0, 50.0, 100.0],
    'init_pen_Q': [20.0, 50.0],
    'max_pen_C': [500.0, 1000.0, 2000.0]
}

config_path='../4_Pareto_front/config.yaml'
with open(config_path, 'r') as f:
    cfg = yaml.safe_load(f)
test_rays = np.array(cfg['data']['test_ray'])

# %% [markdown]
# # Run

# %%
keys, values = zip(*param_grid.items())
param_combinations = [dict(zip(keys, v)) for v in itertools.product(*values)]

print(f"🔍 Bắt đầu Grid Search với {len(param_combinations)} cấu hình...")

results = []
best_igd = float('inf')
best_config = None
best_pf_pred = None

# --- Main Tuning Loop ---
for idx, params in enumerate(param_combinations):
    print(f"\n--- Running Config {idx+1}/{len(param_combinations)} ---")
    print(params)
    
    # 1. Init Model
    model = Hypernet_trans(ray_hidden_dim=32, out_dim=dim_x, n_tasks=2)
    
    # 2. Train
    start_time = time.time()
    trained_model = train_hypernet(
        model, prob, z_star, 
        num_epochs=params['num_epochs'],
        lr=params['lr'],
        num_partitions=20, 
        init_pen_C=params['init_pen_C'],
        pen_C_growth=params['pen_C_growth'],
        init_pen_Q=params['init_pen_Q'],
        pen_Q_decay=params['pen_Q_decay'],
        verbose=True
    )
    train_time = time.time() - start_time
    
    # 3. Evaluate
    igd, pf_pred = evaluate_model(trained_model, prob, test_rays, pf_true)
    
    print(f"⏱️ Time: {train_time:.2f}s | 📉 IGD Score: {igd:.4f}")
    
    # Save result
    res = {
        'config_id': idx,
        'params': params,
        'igd': igd,
        'time': train_time
    }
    results.append(res)
    
    # Update Best
    if igd < best_igd:
        best_igd = igd
        best_config = params
        best_pf_pred = pf_pred
        # Lưu model tốt nhất (optional)
        torch.save(trained_model.state_dict(), "best_hypernet_trans_tuned.pth")
# Out:
# 🔍 Bắt đầu Grid Search với 54 cấu hình...
#
# --- Running Config 1/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.005, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0}
#   Ep 0: Loss=186.18 (Obj=14.40, C=17.1778)
#   Ep 200: Loss=3.66 (Obj=2.59, C=0.0396)
#   Ep 400: Loss=4.06 (Obj=3.34, C=0.0097)
#   Ep 600: Loss=3.85 (Obj=3.53, C=0.0016)
#   Ep 800: Loss=3.86 (Obj=3.68, C=0.0003)
# ⏱️ Time: 81.14s | 📉 IGD Score: 4.3152
#
# --- Running Config 2/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.005, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 1000.0}
#   Ep 0: Loss=191.64 (Obj=17.98, C=17.3664)
#   Ep 200: Loss=3.19 (Obj=2.39, C=0.0297)
#   Ep 400: Loss=3.50 (Obj=3.15, C=0.0047)
#   Ep 600: Loss=3.64 (Obj=3.45, C=0.0010)
#   Ep 800: Loss=3.81 (Obj=3.65, C=0.0003)
# ⏱️ Time: 81.60s | 📉 IGD Score: 4.0215
#
# --- Running Config 3/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.005, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 2000.0}
#   Ep 0: Loss=254.10 (Obj=20.22, C=23.3880)
#   Ep 200: Loss=3.27 (Obj=2.34, C=0.0343)
#   Ep 400: Loss=3.47 (Obj=3.12, C=0.0048)
#   Ep 600: Loss=3.67 (Obj=3.48, C=0.0009)
#   Ep 800: Loss=3.74 (Obj=3.60, C=0.0003)
# ⏱️ Time: 81.79s | 📉 IGD Score: 4.4748
#
# --- Running Config 4/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.005, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0}
#   Ep 0: Loss=219.59 (Obj=18.71, C=20.0878)
#   Ep 200: Loss=5.65 (Obj=4.83, C=0.0302)
#   Ep 400: Loss=3.81 (Obj=3.29, C=0.0070)
#   Ep 600: Loss=3.81 (Obj=3.60, C=0.0010)
#   Ep 800: Loss=3.86 (Obj=3.74, C=0.0002)
# ⏱️ Time: 77.56s | 📉 IGD Score: 5.8981
#
# --- Running Config 5/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.005, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 1000.0}
#   Ep 0: Loss=233.39 (Obj=14.94, C=21.8450)
#   Ep 200: Loss=4.22 (Obj=3.08, C=0.0422)
#   Ep 400: Loss=4.28 (Obj=3.70, C=0.0079)
#   Ep 600: Loss=4.02 (Obj=3.89, C=0.0007)
#   Ep 800: Loss=4.04 (Obj=3.97, C=0.0001)
# ⏱️ Time: 84.21s | 📉 IGD Score: 11.3564
#
# --- Running Config 6/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.005, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 2000.0}
#   Ep 0: Loss=166.17 (Obj=17.16, C=14.9014)
#   Ep 200: Loss=3.21 (Obj=2.55, C=0.0242)
#   Ep 400: Loss=3.49 (Obj=3.19, C=0.0041)
#   Ep 600: Loss=3.64 (Obj=3.45, C=0.0009)
#   Ep 800: Loss=3.73 (Obj=3.65, C=0.0001)
# ⏱️ Time: 79.24s | 📉 IGD Score: 3.1932
#
# --- Running Config 7/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.005, 'pen_Q_decay': 0.995, 'init_pen_C': 50.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0}
#   Ep 0: Loss=793.60 (Obj=13.18, C=15.6084)
#   Ep 200: Loss=8.29 (Obj=8.24, C=0.0003)
#   Ep 400: Loss=5.00 (Obj=4.50, C=0.0014)
#   Ep 600: Loss=4.17 (Obj=4.01, C=0.0002)
#   Ep 800: Loss=3.93 (Obj=3.77, C=0.0002)
# ⏱️ Time: 95.21s | 📉 IGD Score: 5.1653
#
# --- Running Config 8/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.005, 'pen_Q_decay': 0.995, 'init_pen_C': 50.0, 'init_pen_Q': 20.0, 'max_pen_C': 1000.0}
#   Ep 0: Loss=931.09 (Obj=16.16, C=18.2988)
#   Ep 200: Loss=5.70 (Obj=5.02, C=0.0050)
#   Ep 400: Loss=4.77 (Obj=4.43, C=0.0009)
#   Ep 600: Loss=3.99 (Obj=3.94, C=0.0001)
#   Ep 800: Loss=3.89 (Obj=3.85, C=0.0000)
# ⏱️ Time: 92.08s | 📉 IGD Score: 5.2921
#
# --- Running Config 9/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.005, 'pen_Q_decay': 0.995, 'init_pen_C': 50.0, 'init_pen_Q': 20.0, 'max_pen_C': 2000.0}
#   Ep 0: Loss=1142.10 (Obj=17.39, C=22.4943)
#   Ep 200: Loss=6.10 (Obj=6.00, C=0.0007)
#   Ep 400: Loss=4.07 (Obj=3.87, C=0.0005)
#   Ep 600: Loss=3.90 (Obj=3.82, C=0.0001)
#   Ep 800: Loss=3.79 (Obj=3.74, C=0.0000)
# ⏱️ Time: 89.93s | 📉 IGD Score: 4.6156
#
# --- Running Config 10/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.005, 'pen_Q_decay': 0.995, 'init_pen_C': 50.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0}
#   Ep 0: Loss=991.02 (Obj=16.50, C=19.4904)
#   Ep 200: Loss=8.90 (Obj=8.85, C=0.0004)
#   Ep 400: Loss=6.56 (Obj=6.16, C=0.0011)
#   Ep 600: Loss=6.48 (Obj=6.35, C=0.0001)
#   Ep 800: Loss=6.35 (Obj=6.20, C=0.0001)
# ⏱️ Time: 97.92s | 📉 IGD Score: 46.6272
#
# --- Running Config 11/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.005, 'pen_Q_decay': 0.995, 'init_pen_C': 50.0, 'init_pen_Q': 50.0, 'max_pen_C': 1000.0}
#   Ep 0: Loss=881.66 (Obj=17.06, C=17.2919)
#   Ep 200: Loss=17.63 (Obj=17.54, C=0.0006)
#   Ep 400: Loss=12.54 (Obj=12.53, C=0.0000)
#   Ep 600: Loss=6.04 (Obj=5.62, C=0.0004)
#   Ep 800: Loss=5.47 (Obj=5.20, C=0.0003)
# ⏱️ Time: 111.03s | 📉 IGD Score: 25.6658
#
# --- Running Config 12/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.005, 'pen_Q_decay': 0.995, 'init_pen_C': 50.0, 'init_pen_Q': 50.0, 'max_pen_C': 2000.0}
#   Ep 0: Loss=970.74 (Obj=11.77, C=19.1794)
#   Ep 200: Loss=7.50 (Obj=7.28, C=0.0016)
#   Ep 400: Loss=5.95 (Obj=5.31, C=0.0017)
#   Ep 600: Loss=5.87 (Obj=5.50, C=0.0004)
#   Ep 800: Loss=5.46 (Obj=5.23, C=0.0002)
# ⏱️ Time: 105.00s | 📉 IGD Score: 26.6450
#
# --- Running Config 13/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.005, 'pen_Q_decay': 0.995, 'init_pen_C': 100.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0}
#   Ep 0: Loss=1794.17 (Obj=16.50, C=17.7766)
#   Ep 200: Loss=6.99 (Obj=6.30, C=0.0026)
#   Ep 400: Loss=5.97 (Obj=5.34, C=0.0009)
#   Ep 600: Loss=4.42 (Obj=4.28, C=0.0001)
#   Ep 800: Loss=4.02 (Obj=3.95, C=0.0001)
# ⏱️ Time: 108.39s | 📉 IGD Score: 4.1551
#
# --- Running Config 14/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.005, 'pen_Q_decay': 0.995, 'init_pen_C': 100.0, 'init_pen_Q': 20.0, 'max_pen_C': 1000.0}
#   Ep 0: Loss=1892.62 (Obj=13.18, C=18.7945)
#   Ep 200: Loss=5.73 (Obj=5.34, C=0.0015)
#   Ep 400: Loss=5.05 (Obj=4.87, C=0.0002)
#   Ep 600: Loss=3.90 (Obj=3.85, C=0.0001)
#   Ep 800: Loss=3.83 (Obj=3.77, C=0.0001)
# ⏱️ Time: 88.98s | 📉 IGD Score: 6.0405
#
# --- Running Config 15/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.005, 'pen_Q_decay': 0.995, 'init_pen_C': 100.0, 'init_pen_Q': 20.0, 'max_pen_C': 2000.0}
#   Ep 0: Loss=1785.51 (Obj=17.11, C=17.6839)
#   Ep 200: Loss=5.38 (Obj=4.66, C=0.0027)
#   Ep 400: Loss=4.41 (Obj=4.30, C=0.0002)
#   Ep 600: Loss=4.05 (Obj=3.93, C=0.0001)
#   Ep 800: Loss=3.90 (Obj=3.77, C=0.0001)
# ⏱️ Time: 98.36s | 📉 IGD Score: 5.9004
#
# --- Running Config 16/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.005, 'pen_Q_decay': 0.995, 'init_pen_C': 100.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0}
#   Ep 0: Loss=2144.05 (Obj=18.18, C=21.2588)
#   Ep 200: Loss=9.86 (Obj=9.74, C=0.0004)
#   Ep 400: Loss=6.47 (Obj=6.18, C=0.0004)
#   Ep 600: Loss=5.90 (Obj=5.64, C=0.0003)
#   Ep 800: Loss=5.48 (Obj=5.20, C=0.0003)
# ⏱️ Time: 108.04s | 📉 IGD Score: 11.4205
#
# --- Running Config 17/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.005, 'pen_Q_decay': 0.995, 'init_pen_C': 100.0, 'init_pen_Q': 50.0, 'max_pen_C': 1000.0}
#   Ep 0: Loss=2008.33 (Obj=17.52, C=19.9081)
#   Ep 200: Loss=6.59 (Obj=5.88, C=0.0026)
#   Ep 400: Loss=5.33 (Obj=4.90, C=0.0006)
#   Ep 600: Loss=4.00 (Obj=3.85, C=0.0001)
#   Ep 800: Loss=3.95 (Obj=3.84, C=0.0001)
# ⏱️ Time: 97.73s | 📉 IGD Score: 4.1352
#
# --- Running Config 18/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.005, 'pen_Q_decay': 0.995, 'init_pen_C': 100.0, 'init_pen_Q': 50.0, 'max_pen_C': 2000.0}
#   Ep 0: Loss=1494.33 (Obj=15.14, C=14.7919)
#   Ep 200: Loss=7.26 (Obj=7.14, C=0.0005)
#   Ep 400: Loss=6.23 (Obj=6.05, C=0.0002)
#   Ep 600: Loss=5.61 (Obj=5.48, C=0.0001)
#   Ep 800: Loss=5.16 (Obj=5.02, C=0.0001)
# ⏱️ Time: 101.85s | 📉 IGD Score: 25.5133
#
# --- Running Config 19/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0}
#   Ep 0: Loss=220.26 (Obj=15.54, C=20.4724)
#   Ep 200: Loss=5.06 (Obj=3.88, C=0.0160)
#   Ep 400: Loss=4.34 (Obj=4.17, C=0.0003)
#   Ep 600: Loss=3.89 (Obj=3.82, C=0.0001)
#   Ep 800: Loss=3.87 (Obj=3.82, C=0.0001)
# ⏱️ Time: 81.99s | 📉 IGD Score: 4.5204
#
# --- Running Config 20/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 1000.0}
#   Ep 0: Loss=210.78 (Obj=12.62, C=19.8160)
#   Ep 200: Loss=4.42 (Obj=3.47, C=0.0130)
#   Ep 400: Loss=4.38 (Obj=4.13, C=0.0005)
#   Ep 600: Loss=3.90 (Obj=3.83, C=0.0001)
#   Ep 800: Loss=3.87 (Obj=3.78, C=0.0001)
# ⏱️ Time: 86.69s | 📉 IGD Score: 3.5656
#
# --- Running Config 21/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 2000.0}
#   Ep 0: Loss=225.99 (Obj=15.39, C=21.0599)
#   Ep 200: Loss=3.52 (Obj=3.15, C=0.0050)
#   Ep 400: Loss=3.81 (Obj=3.63, C=0.0003)
#   Ep 600: Loss=3.76 (Obj=3.68, C=0.0001)
#   Ep 800: Loss=3.81 (Obj=3.74, C=0.0001)
# ⏱️ Time: 86.67s | 📉 IGD Score: 3.5650
#
# --- Running Config 22/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0}
#   Ep 0: Loss=156.43 (Obj=13.87, C=14.2558)
#   Ep 200: Loss=4.38 (Obj=3.58, C=0.0110)
#   Ep 400: Loss=3.87 (Obj=3.79, C=0.0002)
#   Ep 600: Loss=3.86 (Obj=3.77, C=0.0001)
#   Ep 800: Loss=3.83 (Obj=3.77, C=0.0001)
# ⏱️ Time: 88.30s | 📉 IGD Score: 5.2272
#
# --- Running Config 23/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 1000.0}
#   Ep 0: Loss=225.35 (Obj=14.81, C=21.0544)
#   Ep 200: Loss=5.66 (Obj=5.42, C=0.0033)
#   Ep 400: Loss=6.10 (Obj=5.63, C=0.0009)
#   Ep 600: Loss=5.62 (Obj=5.43, C=0.0002)
#   Ep 800: Loss=5.22 (Obj=5.06, C=0.0002)
# ⏱️ Time: 92.51s | 📉 IGD Score: 12.4944
#
# --- Running Config 24/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 2000.0}
#   Ep 0: Loss=243.92 (Obj=20.08, C=22.3843)
#   Ep 200: Loss=5.28 (Obj=4.03, C=0.0170)
#   Ep 400: Loss=4.98 (Obj=4.65, C=0.0006)
#   Ep 600: Loss=4.04 (Obj=3.97, C=0.0001)
#   Ep 800: Loss=4.01 (Obj=3.91, C=0.0001)
# ⏱️ Time: 94.38s | 📉 IGD Score: 8.2594
#
# --- Running Config 25/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 50.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0}
#   Ep 0: Loss=965.39 (Obj=14.61, C=19.0156)
#   Ep 200: Loss=6.45 (Obj=6.00, C=0.0012)
#   Ep 400: Loss=5.07 (Obj=4.89, C=0.0002)
#   Ep 600: Loss=3.98 (Obj=3.92, C=0.0001)
#   Ep 800: Loss=3.91 (Obj=3.87, C=0.0000)
# ⏱️ Time: 84.94s | 📉 IGD Score: 7.4434
#
# --- Running Config 26/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 50.0, 'init_pen_Q': 20.0, 'max_pen_C': 1000.0}
#   Ep 0: Loss=910.87 (Obj=15.60, C=17.9053)
#   Ep 200: Loss=4.49 (Obj=4.11, C=0.0010)
#   Ep 400: Loss=3.93 (Obj=3.85, C=0.0001)
#   Ep 600: Loss=3.92 (Obj=3.89, C=0.0000)
#   Ep 800: Loss=3.82 (Obj=3.75, C=0.0001)
# ⏱️ Time: 87.59s | 📉 IGD Score: 6.5890
#
# --- Running Config 27/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 50.0, 'init_pen_Q': 20.0, 'max_pen_C': 2000.0}
#   Ep 0: Loss=953.46 (Obj=16.65, C=18.7362)
#   Ep 200: Loss=5.49 (Obj=5.15, C=0.0009)
#   Ep 400: Loss=4.21 (Obj=4.08, C=0.0001)
#   Ep 600: Loss=3.95 (Obj=3.90, C=0.0001)
#   Ep 800: Loss=3.87 (Obj=3.81, C=0.0001)
# ⏱️ Time: 97.22s | 📉 IGD Score: 4.3141
#
# --- Running Config 28/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 50.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0}
#   Ep 0: Loss=866.95 (Obj=13.58, C=17.0673)
#   Ep 200: Loss=6.15 (Obj=6.10, C=0.0001)
#   Ep 400: Loss=4.33 (Obj=4.14, C=0.0002)
#   Ep 600: Loss=4.04 (Obj=3.89, C=0.0001)
#   Ep 800: Loss=3.94 (Obj=3.87, C=0.0001)
# ⏱️ Time: 99.43s | 📉 IGD Score: 7.7648
#
# --- Running Config 29/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 50.0, 'init_pen_Q': 50.0, 'max_pen_C': 1000.0}
#   Ep 0: Loss=1039.22 (Obj=11.95, C=20.5454)
#   Ep 200: Loss=7.43 (Obj=7.36, C=0.0002)
#   Ep 400: Loss=6.55 (Obj=6.40, C=0.0002)
#   Ep 600: Loss=6.26 (Obj=6.15, C=0.0001)
#   Ep 800: Loss=6.07 (Obj=5.93, C=0.0001)
# ⏱️ Time: 87.80s | 📉 IGD Score: 49.7488
#
# --- Running Config 30/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 50.0, 'init_pen_Q': 50.0, 'max_pen_C': 2000.0}
#   Ep 0: Loss=880.07 (Obj=15.30, C=17.2954)
#   Ep 200: Loss=6.23 (Obj=5.61, C=0.0017)
#   Ep 400: Loss=5.72 (Obj=5.58, C=0.0001)
#   Ep 600: Loss=3.91 (Obj=3.84, C=0.0001)
#   Ep 800: Loss=3.91 (Obj=3.82, C=0.0001)
# ⏱️ Time: 90.06s | 📉 IGD Score: 4.0087
#
# --- Running Config 31/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 100.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0}
#   Ep 0: Loss=1750.98 (Obj=13.43, C=17.3756)
#   Ep 200: Loss=7.52 (Obj=6.90, C=0.0008)
#   Ep 400: Loss=5.90 (Obj=5.38, C=0.0005)
#   Ep 600: Loss=4.74 (Obj=4.63, C=0.0001)
#   Ep 800: Loss=4.38 (Obj=4.23, C=0.0001)
# ⏱️ Time: 108.29s | 📉 IGD Score: 9.1538
#
# --- Running Config 32/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 100.0, 'init_pen_Q': 20.0, 'max_pen_C': 1000.0}
#   Ep 0: Loss=1718.87 (Obj=14.28, C=17.0460)
#   Ep 200: Loss=10.22 (Obj=10.22, C=0.0000)
#   Ep 400: Loss=6.28 (Obj=6.09, C=0.0002)
#   Ep 600: Loss=5.73 (Obj=5.62, C=0.0001)
#   Ep 800: Loss=5.53 (Obj=5.41, C=0.0001)
# ⏱️ Time: 95.09s | 📉 IGD Score: 30.5152
#
# --- Running Config 33/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 100.0, 'init_pen_Q': 20.0, 'max_pen_C': 2000.0}
#   Ep 0: Loss=1735.48 (Obj=15.08, C=17.2040)
#   Ep 200: Loss=5.08 (Obj=4.82, C=0.0004)
#   Ep 400: Loss=3.93 (Obj=3.81, C=0.0001)
#   Ep 600: Loss=3.84 (Obj=3.75, C=0.0001)
#   Ep 800: Loss=3.86 (Obj=3.77, C=0.0001)
# ⏱️ Time: 99.25s | 📉 IGD Score: 6.1224
#
# --- Running Config 34/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 100.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0}
#   Ep 0: Loss=1870.98 (Obj=14.18, C=18.5681)
#   Ep 200: Loss=12.16 (Obj=12.16, C=0.0000)
#   Ep 400: Loss=6.38 (Obj=6.29, C=0.0001)
#   Ep 600: Loss=5.76 (Obj=5.65, C=0.0001)
#   Ep 800: Loss=5.40 (Obj=5.28, C=0.0001)
# ⏱️ Time: 96.78s | 📉 IGD Score: 24.2744
#
# --- Running Config 35/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 100.0, 'init_pen_Q': 50.0, 'max_pen_C': 1000.0}
#   Ep 0: Loss=1927.95 (Obj=15.85, C=19.1210)
#   Ep 200: Loss=7.25 (Obj=6.63, C=0.0008)
#   Ep 400: Loss=5.70 (Obj=5.37, C=0.0003)
#   Ep 600: Loss=3.95 (Obj=3.86, C=0.0001)
#   Ep 800: Loss=3.85 (Obj=3.81, C=0.0000)
# ⏱️ Time: 103.62s | 📉 IGD Score: 3.8748
#
# --- Running Config 36/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 100.0, 'init_pen_Q': 50.0, 'max_pen_C': 2000.0}
#   Ep 0: Loss=2320.04 (Obj=16.47, C=23.0356)
#   Ep 200: Loss=6.08 (Obj=5.93, C=0.0002)
#   Ep 400: Loss=4.86 (Obj=4.70, C=0.0002)
#   Ep 600: Loss=4.15 (Obj=3.98, C=0.0002)
#   Ep 800: Loss=3.94 (Obj=3.83, C=0.0001)
# ⏱️ Time: 96.43s | 📉 IGD Score: 4.8909
#
# --- Running Config 37/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.05, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0}
#   Ep 0: Loss=215.67 (Obj=16.51, C=19.9155)
#   Ep 200: Loss=4.48 (Obj=4.23, C=0.0002)
#   Ep 400: Loss=3.93 (Obj=3.90, C=0.0000)
#   Ep 600: Loss=3.82 (Obj=3.77, C=0.0000)
#   Ep 800: Loss=3.76 (Obj=3.72, C=0.0000)
# ⏱️ Time: 93.76s | 📉 IGD Score: 4.0567
#
# --- Running Config 38/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.05, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 1000.0}
#   Ep 0: Loss=220.17 (Obj=16.46, C=20.3706)
#   Ep 200: Loss=5.18 (Obj=5.02, C=0.0002)
#   Ep 400: Loss=3.93 (Obj=3.86, C=0.0001)
#   Ep 600: Loss=3.86 (Obj=3.80, C=0.0001)
#   Ep 800: Loss=3.83 (Obj=3.75, C=0.0001)
# ⏱️ Time: 88.97s | 📉 IGD Score: 5.7274
#
# --- Running Config 39/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.05, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 2000.0}
#   Ep 0: Loss=211.82 (Obj=16.05, C=19.5767)
#   Ep 200: Loss=4.54 (Obj=4.45, C=0.0001)
#   Ep 400: Loss=3.91 (Obj=3.87, C=0.0000)
#   Ep 600: Loss=3.87 (Obj=3.83, C=0.0000)
#   Ep 800: Loss=3.81 (Obj=3.78, C=0.0000)
# ⏱️ Time: 89.86s | 📉 IGD Score: 4.3509
#
# --- Running Config 40/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.05, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0}
#   Ep 0: Loss=183.47 (Obj=15.77, C=16.7695)
#   Ep 200: Loss=6.68 (Obj=6.60, C=0.0001)
#   Ep 400: Loss=4.86 (Obj=4.73, C=0.0001)
#   Ep 600: Loss=4.57 (Obj=4.46, C=0.0001)
#   Ep 800: Loss=4.59 (Obj=4.37, C=0.0002)
# ⏱️ Time: 100.24s | 📉 IGD Score: 10.9955
#
# --- Running Config 41/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.05, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 1000.0}
#   Ep 0: Loss=239.73 (Obj=18.17, C=22.1560)
#   Ep 200: Loss=10.15 (Obj=10.13, C=0.0000)
#   Ep 400: Loss=7.08 (Obj=6.92, C=0.0002)
#   Ep 600: Loss=6.38 (Obj=6.24, C=0.0001)
#   Ep 800: Loss=6.14 (Obj=5.97, C=0.0002)
# ⏱️ Time: 108.34s | 📉 IGD Score: 37.2815
#
# --- Running Config 42/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.05, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 2000.0}
#   Ep 0: Loss=235.71 (Obj=17.45, C=21.8262)
#   Ep 200: Loss=15.69 (Obj=15.65, C=0.0000)
#   Ep 400: Loss=11.04 (Obj=11.03, C=0.0000)
#   Ep 600: Loss=4.99 (Obj=4.74, C=0.0002)
#   Ep 800: Loss=4.57 (Obj=4.38, C=0.0002)
# ⏱️ Time: 107.57s | 📉 IGD Score: 6.9656
#
# --- Running Config 43/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.05, 'pen_Q_decay': 0.995, 'init_pen_C': 50.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0}
#   Ep 0: Loss=957.05 (Obj=11.45, C=18.9118)
#   Ep 200: Loss=9.06 (Obj=8.96, C=0.0001)
#   Ep 400: Loss=6.88 (Obj=6.71, C=0.0002)
#   Ep 600: Loss=6.42 (Obj=6.28, C=0.0001)
#   Ep 800: Loss=6.26 (Obj=6.12, C=0.0001)
# ⏱️ Time: 106.61s | 📉 IGD Score: 42.6694
#
# --- Running Config 44/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.05, 'pen_Q_decay': 0.995, 'init_pen_C': 50.0, 'init_pen_Q': 20.0, 'max_pen_C': 1000.0}
#   Ep 0: Loss=829.79 (Obj=13.91, C=16.3176)
#   Ep 200: Loss=7.45 (Obj=7.42, C=0.0000)
#   Ep 400: Loss=4.94 (Obj=4.80, C=0.0001)
#   Ep 600: Loss=4.03 (Obj=3.94, C=0.0001)
#   Ep 800: Loss=3.88 (Obj=3.82, C=0.0001)
# ⏱️ Time: 98.31s | 📉 IGD Score: 3.9175
#
# --- Running Config 45/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.05, 'pen_Q_decay': 0.995, 'init_pen_C': 50.0, 'init_pen_Q': 20.0, 'max_pen_C': 2000.0}
#   Ep 0: Loss=941.70 (Obj=16.63, C=18.5012)
#   Ep 200: Loss=5.62 (Obj=5.42, C=0.0002)
#   Ep 400: Loss=4.96 (Obj=4.82, C=0.0001)
#   Ep 600: Loss=4.30 (Obj=4.19, C=0.0001)
#   Ep 800: Loss=4.07 (Obj=4.00, C=0.0001)
# ⏱️ Time: 98.34s | 📉 IGD Score: 11.1161
#
# --- Running Config 46/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.05, 'pen_Q_decay': 0.995, 'init_pen_C': 50.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0}
#   Ep 0: Loss=878.44 (Obj=11.98, C=17.3292)
#   Ep 200: Loss=6.30 (Obj=5.87, C=0.0004)
#   Ep 400: Loss=5.57 (Obj=5.42, C=0.0002)
#   Ep 600: Loss=5.22 (Obj=5.09, C=0.0001)
#   Ep 800: Loss=4.97 (Obj=4.82, C=0.0001)
# ⏱️ Time: 100.95s | 📉 IGD Score: 20.3304
#
# --- Running Config 47/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.05, 'pen_Q_decay': 0.995, 'init_pen_C': 50.0, 'init_pen_Q': 50.0, 'max_pen_C': 1000.0}
#   Ep 0: Loss=866.37 (Obj=11.90, C=17.0893)
#   Ep 200: Loss=14.07 (Obj=14.07, C=0.0000)
#   Ep 400: Loss=5.35 (Obj=5.19, C=0.0002)
#   Ep 600: Loss=4.71 (Obj=4.61, C=0.0001)
#   Ep 800: Loss=4.50 (Obj=4.41, C=0.0001)
# ⏱️ Time: 104.59s | 📉 IGD Score: 14.7127
#
# --- Running Config 48/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.05, 'pen_Q_decay': 0.995, 'init_pen_C': 50.0, 'init_pen_Q': 50.0, 'max_pen_C': 2000.0}
#   Ep 0: Loss=922.54 (Obj=15.20, C=18.1469)
#   Ep 200: Loss=13.71 (Obj=13.71, C=0.0000)
#   Ep 400: Loss=10.39 (Obj=10.38, C=0.0000)
#   Ep 600: Loss=7.23 (Obj=7.06, C=0.0002)
#   Ep 800: Loss=6.65 (Obj=6.11, C=0.0005)
# ⏱️ Time: 118.85s | 📉 IGD Score: 49.7391
#
# --- Running Config 49/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.05, 'pen_Q_decay': 0.995, 'init_pen_C': 100.0, 'init_pen_Q': 20.0, 'max_pen_C': 500.0}
#   Ep 0: Loss=1488.66 (Obj=12.43, C=14.7623)
#   Ep 200: Loss=7.72 (Obj=7.71, C=0.0000)
#   Ep 400: Loss=5.37 (Obj=5.11, C=0.0003)
#   Ep 600: Loss=4.88 (Obj=4.71, C=0.0002)
#   Ep 800: Loss=4.64 (Obj=4.50, C=0.0001)
# ⏱️ Time: 102.45s | 📉 IGD Score: 16.5184
#
# --- Running Config 50/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.05, 'pen_Q_decay': 0.995, 'init_pen_C': 100.0, 'init_pen_Q': 20.0, 'max_pen_C': 1000.0}
#   Ep 0: Loss=1885.05 (Obj=14.84, C=18.7021)
#   Ep 200: Loss=7.01 (Obj=6.81, C=0.0002)
#   Ep 400: Loss=6.01 (Obj=5.67, C=0.0003)
#   Ep 600: Loss=5.33 (Obj=5.16, C=0.0002)
#   Ep 800: Loss=4.98 (Obj=4.85, C=0.0001)
# ⏱️ Time: 101.29s | 📉 IGD Score: 21.5196
#
# --- Running Config 51/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.05, 'pen_Q_decay': 0.995, 'init_pen_C': 100.0, 'init_pen_Q': 20.0, 'max_pen_C': 2000.0}
#   Ep 0: Loss=1607.68 (Obj=14.82, C=15.9286)
#   Ep 200: Loss=10.00 (Obj=9.90, C=0.0001)
#   Ep 400: Loss=6.55 (Obj=6.27, C=0.0003)
#   Ep 600: Loss=5.83 (Obj=5.66, C=0.0002)
#   Ep 800: Loss=5.43 (Obj=5.29, C=0.0001)
# ⏱️ Time: 107.89s | 📉 IGD Score: 28.8134
#
# --- Running Config 52/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.05, 'pen_Q_decay': 0.995, 'init_pen_C': 100.0, 'init_pen_Q': 50.0, 'max_pen_C': 500.0}
#   Ep 0: Loss=1780.08 (Obj=12.84, C=17.6724)
#   Ep 200: Loss=9.70 (Obj=9.70, C=0.0000)
#   Ep 400: Loss=6.81 (Obj=6.76, C=0.0001)
#   Ep 600: Loss=5.71 (Obj=5.61, C=0.0001)
#   Ep 800: Loss=5.54 (Obj=5.43, C=0.0001)
# ⏱️ Time: 104.55s | 📉 IGD Score: 31.8627
#
# --- Running Config 53/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.05, 'pen_Q_decay': 0.995, 'init_pen_C': 100.0, 'init_pen_Q': 50.0, 'max_pen_C': 1000.0}
#   Ep 0: Loss=1627.88 (Obj=15.03, C=16.1285)
#   Ep 200: Loss=12.62 (Obj=12.60, C=0.0000)
#   Ep 400: Loss=7.54 (Obj=7.51, C=0.0000)
#   Ep 600: Loss=5.97 (Obj=5.87, C=0.0001)
#   Ep 800: Loss=5.82 (Obj=5.70, C=0.0001)
# ⏱️ Time: 102.09s | 📉 IGD Score: 31.9230
#
# --- Running Config 54/54 ---
# {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.05, 'pen_Q_decay': 0.995, 'init_pen_C': 100.0, 'init_pen_Q': 50.0, 'max_pen_C': 2000.0}
#   Ep 0: Loss=2051.32 (Obj=21.02, C=20.3030)
#   Ep 200: Loss=12.03 (Obj=12.02, C=0.0000)
#   Ep 400: Loss=8.50 (Obj=8.49, C=0.0000)
#   Ep 600: Loss=6.34 (Obj=6.19, C=0.0001)
#   Ep 800: Loss=5.98 (Obj=5.67, C=0.0003)
# ⏱️ Time: 111.48s | 📉 IGD Score: 37.8922

# %% [markdown]
# # Viz

# %%
print("\n" + "="*40)
print(f"🏆 BEST CONFIGURATION FOUND (IGD={best_igd:.4f})")
print("="*40)
for k, v in best_config.items():
    print(f"{k}: {v}")

# Sắp xếp kết quả theo IGD
sorted_results = sorted(results, key=lambda x: x['igd'])
print("\nTop 5 Configs:")
for i in range(min(5, len(sorted_results))):
    r = sorted_results[i]
    print(f"Rank {i+1}: IGD={r['igd']:.4f} | Params={r['params']}")

# --- Plotting ---
plt.figure(figsize=(10, 6))

# Plot Ground Truth
if pf_true is not None:
    plt.scatter(pf_true[:, 0], pf_true[:, 1], c='gray', alpha=0.5, label='Ground Truth', s=20)

# Plot Best Prediction
if best_pf_pred is not None:
    plt.scatter(best_pf_pred[:, 0], best_pf_pred[:, 1], c='red', marker='x', label='Best Prediction', s=40)

# Plot Ideal Point
plt.scatter(z_star[0], z_star[1], c='green', marker='*', s=150, label='Ideal Point (z*)')

plt.xlabel('f1')
plt.ylabel('f2')
plt.title(f'Pareto Front Approximation (Best IGD: {best_igd:.4f})')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()
# Out:
# ========================================
# 🏆 BEST CONFIGURATION FOUND (IGD=3.1932)
# ========================================
# lr: 0.001
# num_epochs: 1000
# pen_C_growth: 1.005
# pen_Q_decay: 0.995
# init_pen_C: 10.0
# init_pen_Q: 50.0
# max_pen_C: 2000.0
#
# Top 5 Configs:
# Rank 1: IGD=3.1932 | Params={'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.005, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 50.0, 'max_pen_C': 2000.0}
# Rank 2: IGD=3.5650 | Params={'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 2000.0}
# Rank 3: IGD=3.5656 | Params={'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 10.0, 'init_pen_Q': 20.0, 'max_pen_C': 1000.0}
# Rank 4: IGD=3.8748 | Params={'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.01, 'pen_Q_decay': 0.995, 'init_pen_C': 100.0, 'init_pen_Q': 50.0, 'max_pen_C': 1000.0}
# Rank 5: IGD=3.9175 | Params={'lr': 0.001, 'num_epochs': 1000, 'pen_C_growth': 1.05, 'pen_Q_decay': 0.995, 'init_pen_C': 50.0, 'init_pen_Q': 20.0, 'max_pen_C': 1000.0}

# %%
import pandas as pd

pd.DataFrame(sorted_results)
# Out:
#     config_id                                             params        igd  \
# 0           5  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   3.193151
# 1          20  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   3.565047
# 2          19  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   3.565648
# 3          34  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   3.874790
# 4          43  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   3.917462
# 5          29  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   4.008742
# 6           1  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   4.021538
# 7          36  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   4.056732
# 8          16  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   4.135219
# 9          12  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   4.155141
# 10         26  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   4.314103
# 11          0  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   4.315165
# 12         38  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   4.350914
# 13          2  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   4.474836
# 14         18  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   4.520387
# 15          8  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   4.615599
# 16         35  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   4.890870
# 17          6  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   5.165295
# 18         21  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   5.227219
# 19          7  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   5.292125
# 20         37  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   5.727384
# 21          3  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   5.898057
# 22         14  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   5.900404
# 23         13  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   6.040487
# 24         32  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   6.122425
# 25         25  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   6.589018
# 26         41  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   6.965550
# 27         24  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   7.443369
# 28         27  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   7.764849
# 29         23  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   8.259439
# 30         30  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...   9.153825
# 31         39  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...  10.995462
# 32         44  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...  11.116090
# 33          4  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...  11.356404
# 34         15  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...  11.420532
# 35         22  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...  12.494428
# 36         46  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...  14.712664
# 37         48  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...  16.518404
# 38         45  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...  20.330415
# 39         49  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...  21.519624
# 40         33  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...  24.274415
# 41         17  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...  25.513339
# 42         10  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...  25.665804
# 43         11  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...  26.645015
# 44         50  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...  28.813418
# 45         31  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...  30.515150
# 46         51  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...  31.862736
# 47         52  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...  31.923031
# 48         40  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...  37.281506
# 49         53  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...  37.892204
# 50         42  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...  42.669354
# 51          9  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...  46.627181
# 52         47  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...  49.739092
# 53         28  {'lr': 0.001, 'num_epochs': 1000, 'pen_C_growt...  49.748776
#
#           time
# 0    79.239307
# 1    86.667707
# 2    86.686694
# 3   103.620129
# 4    98.314711
# 5    90.061170
# 6    81.596900
# 7    93.763810
# 8    97.725530
# 9   108.391381
# 10   97.224790
# 11   81.140364
# 12   89.856259
# 13   81.789941
# 14   81.987863
# 15   89.927366
# 16   96.430345
# 17   95.207522
# 18   88.298048
# 19   92.081272
# 20   88.966025
# 21   77.558533
# 22   98.356295
# 23   88.982567
# 24   99.250074
# 25   87.588923
# 26  107.570889
# 27   84.942035
# 28   99.433757
# 29   94.381223
# 30  108.292295
# 31  100.244103
# 32   98.337473
# 33   84.207833
# 34  108.043935
# 35   92.511951
# 36  104.585141
# 37  102.454390
# 38  100.954303
# 39  101.292724
# 40   96.781903
# 41  101.854786
# 42  111.029864
# 43  104.995444
# 44  107.891573
# 45   95.094663
# 46  104.550220
# 47  102.092221
# 48  108.344599
# 49  111.484373
# 50  106.613970
# 51   97.919086
# 52  118.849908
# 53   87.802943
