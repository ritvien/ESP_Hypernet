# %%
from project import Projection
from Problem import Problem
from main import run_experiment, load_config
from Phase1 import solve_CQ_feasible
from Phase2_1_obj import optim_Universal
from utils import visualize_pareto_front

# %%
import autograd.numpy as np
from autograd import jacobian
from scipy.optimize import Bounds
import matplotlib.pyplot as plt
import pandas as pd
import math

# %%
case = "_Ex_7_2"

# %% [markdown]
# # Prob

# %%
def f1(x):    return (x[0]**2 + x[1]**2)/50
def f2(x):    return ((x[0] - 5)**2 + (x[1] - 5)**2)/50
def f(x):    return np.array([
    (x[0]**2 + x[1]**2)/50,
    ((x[0] - 5)**2 + (x[1] - 5)**2)/50])
#--------------- C --------------------#
bounds_x = Bounds([0,0],[5, 5])

#--------------- Q --------------------#
def q1(y):    return 0.2**2 - (y[0] - 0.4)**2 - (y[1] - 0.4)**2

def q_plus(y):
    center = 0.4
    radius_sq = 0.2**2  
    dx = np.maximum(0, y[0] - center)
    dy = np.maximum(0, y[1] - center)
    return radius_sq - (dx**2 + dy**2)
# Hàm dùng cho Projection 
cons_C = ()
dim_x = 2
cons_Q = ({'type': 'ineq', 'fun' : q1,},)
cons_Qplus = ({'type': 'ineq', 'fun': q_plus},)
dim_y = 2
# Setup Projections
proj_C_handler = Projection(cons=cons_C, bounds=bounds_x, dim=dim_x, proj_type='euclid')
proj_Q_handler = Projection(cons=cons_Q, bounds=None, dim=dim_y, proj_type='qplus')
# Setup Problem
prob = Problem(
    f=[f], jac_f=[jacobian(f)], C=[], Q=[],
    dim_x=dim_x, dim_y=dim_y,
    proj_C=proj_C_handler.project,
    proj_Qplus=proj_Q_handler.project
)
z_star = np.array([0.0, 0.0])
x_init = np.array([-10.0, -10.0])

# %%
def f(x):
    # Hỗ trợ tính toán broadcasting cho mảng 2D (N, 2) hoặc 1D (2,)
    if x.ndim == 1:
        val1 = (x[0]**2 + x[1]**2)/50
        val2 = ((x[0] - 5)**2 + (x[1] - 5)**2)/50
    else:
        val1 = (x[:,0]**2 + x[:,1]**2)/50
        val2 = ((x[:,0] - 5)**2 + (x[:,1] - 5)**2)/50
    
    if x.ndim == 1:
        return np.array([val1, val2])
    return np.column_stack([val1, val2])

def q1(y):
    # y là một điểm [y1, y2]
    return 0.2**2 - (y[0] - 0.4)**2 - (y[1] - 0.4)**2

def q_plus(y):
    center = 0.4
    radius_sq = 0.2**2  
    # Xử lý cho cả input là 1 điểm hoặc lưới điểm (meshgrid)
    dx = np.maximum(0, y[0] - center)
    dy = np.maximum(0, y[1] - center)
    return radius_sq - (dx**2 + dy**2)

# --- 2. CHUẨN BỊ DỮ LIỆU ---

# A. Tạo dữ liệu cho Image Space (Miền ảnh của C)
# C là hình vuông [0, 5] x [0, 5]
# Lấy mẫu ngẫu nhiên 50,000 điểm trong hình vuông này để vẽ "đám mây"
num_samples = 50000
x_samples = np.random.uniform(0, 5, size=(num_samples, 2))
y_cloud = f(x_samples)

# B. Tạo dữ liệu biên (Boundary) của Image Space để vẽ viền cho đẹp
# Biên của C gồm 4 cạnh của hình vuông
t = np.linspace(0, 5, 200)
# Cạnh 1: (t, 0)
edge1 = f(np.column_stack([t, np.zeros_like(t)]))
# Cạnh 2: (5, t)
edge2 = f(np.column_stack([np.full_like(t, 5), t]))
# Cạnh 3: (t, 5)
edge3 = f(np.column_stack([t, np.full_like(t, 5)]))
# Cạnh 4: (0, t)
edge4 = f(np.column_stack([np.zeros_like(t), t]))


# C. Tạo lưới để vẽ vùng Q và Q+ (Contour)
grid_res = 400
y_range = np.linspace(-0.2, 1.2, grid_res)
Y1, Y2 = np.meshgrid(y_range, y_range)

# Tính giá trị Z cho contour
Z_q1 = np.zeros_like(Y1)
Z_qplus = np.zeros_like(Y1)

# Tính toán ma trận (vector hóa để nhanh hơn vòng lặp)
# q1: 0.04 - (y1-0.4)^2 - (y2-0.4)^2
Z_q1 = 0.04 - (Y1 - 0.4)**2 - (Y2 - 0.4)**2

# q_plus
dx = np.maximum(0, Y1 - 0.4)
dy = np.maximum(0, Y2 - 0.4)
Z_qplus = 0.04 - (dx**2 + dy**2)


# --- 3. VẼ ĐỒ THỊ ---
plt.figure(figsize=(10, 10))

# 1. Vẽ vùng Q+ (Xanh lá) - Lớp dưới cùng
plt.contourf(Y1, Y2, Z_qplus, levels=[0, np.inf], colors=['#ccffcc'], alpha=0.5)
plt.contour(Y1, Y2, Z_qplus, levels=[0], colors='green', linestyles='--', linewidths=1)
plt.plot([], [], color='#ccffcc', marker='s', linestyle='None', label='Region $Q^+$')

# 2. Vẽ vùng Q (Đỏ)
plt.contourf(Y1, Y2, Z_q1, levels=[0, np.inf], colors=['#ffcccc'], alpha=0.6)
plt.contour(Y1, Y2, Z_q1, levels=[0], colors='red', linewidths=1)
plt.plot([], [], color='#ffcccc', marker='o', linestyle='None', label='Region $Q$')

# 3. Vẽ Image Space (Đám mây xám)
plt.scatter(y_cloud[:, 0], y_cloud[:, 1], s=1, color='gray', alpha=0.1, label='Feasible Image Space ($f(C)$)')

# 4. Vẽ biên của Image Space (Đường xanh đậm)
# Nối các cạnh lại để thấy rõ hình dạng
plt.plot(edge1[:,0], edge1[:,1], 'b-', linewidth=1.5)
plt.plot(edge2[:,0], edge2[:,1], 'b-', linewidth=1.5)
plt.plot(edge3[:,0], edge3[:,1], 'b-', linewidth=1.5)
plt.plot(edge4[:,0], edge4[:,1], 'b-', linewidth=1.5)
# Hack label cho biên
plt.plot([], [], 'b-', linewidth=1.5, label='Boundary of Image Space')


# --- 4. TRANG TRÍ ---
plt.title('Visualization of Objective Space $f(C)$ with $Q$ and $Q^+$', fontsize=14)
plt.xlabel('$f_1(x) = (x_1^2 + x_2^2)/50$', fontsize=12)
plt.ylabel('$f_2(x) = ((x_1-5)^2 + (x_2-5)^2)/50$', fontsize=12)

# Điểm Pareto lý tưởng (Utopia point) của Image Space này thường nằm ở góc dưới trái của đám mây xám
# Điểm Nadir nằm ở góc trên phải

plt.xlim(-0.1, 1.1)
plt.ylim(-0.1, 1.1)
plt.grid(True, linestyle=':', alpha=0.6)
plt.gca().set_aspect('equal', adjustable='box')
plt.legend(loc='upper right')

plt.show()

# %% [markdown]
# # Config

# %%
from ruamel.yaml import YAML
from ruamel.yaml.comments import CommentedSeq

def update_config(file_path, x_init_np):
    yaml = YAML()
    yaml.preserve_quotes = True
    yaml.indent(mapping=2, sequence=4, offset=2)

    with open(file_path, 'r', encoding='utf-8') as f_in:
        config = yaml.load(f_in)

    val_list = x_init_np.tolist() if hasattr(x_init_np, 'tolist') else x_init_np
    
    flow_list = CommentedSeq(val_list)
    flow_list.fa.set_flow_style() 

    config['initialization']['x_init'] = flow_list
    
    config['phase1']['gamma'] = 5
    config['phase1']['expo_gamma'] = 0.8
    config['phase1']['max_iter'] = 500
    
    config['phase2']['mu'] = 0.1
    config['phase2']['init_params'] = 1
    config['phase2']['expo_alpha'] = 0.35            
    config['phase2']['expo_lambda'] = 0.65
    config['phase2']['max_iter'] = 1000

    # 3. Ghi lại vào file
    with open(file_path, 'w', encoding='utf-8') as f_in:
        yaml.dump(config, f_in)
    
    print(f"✅ Đã cập nhật xong file: {file_path}")

# --- CHẠY THỬ ---
config_file = 'config.yaml'
update_config(config_file, x_init)

with open(config_file, 'r', encoding='utf-8') as f_in:
    print("\nNội dung file sau khi sửa:")
    print(f_in.read())
# Out:
# ✅ Đã cập nhật xong file: config.yaml
#
# Nội dung file sau khi sửa:
# data:
#   test_ray:
#     -   - 1.0
#         - 0.0
#     -   - 0.9965844930066698
#         - 0.08257934547233232
#     -   - 0.9863613034027223
#         - 0.1645945902807339
#     -   - 0.9694002659393304
#         - 0.24548548714079912
#     -   - 0.9458172417006346
#         - 0.32469946920468346
#     -   - 0.9157733266550574
#         - 0.4016954246529694
#     -   - 0.8794737512064891
#         - 0.4759473930370735
#     -   - 0.8371664782625285
#         - 0.5469481581224268
#     -   - 0.7891405093963936
#         - 0.6142127126896678
#     -   - 0.7357239106731316
#         - 0.677281571625741
#     -   - 0.6772815716257411
#         - 0.7357239106731316
#     -   - 0.6142127126896678
#         - 0.7891405093963936
#     -   - 0.5469481581224269
#         - 0.8371664782625285
#     -   - 0.4759473930370736
#         - 0.8794737512064891
#     -   - 0.40169542465296953
#         - 0.9157733266550574
#     -   - 0.32469946920468357
#         - 0.9458172417006346
#     -   - 0.24548548714079924
#         - 0.9694002659393304
#     -   - 0.16459459028073398
#         - 0.9863613034027223
#     -   - 0.0825793454723324
#         - 0.9965844930066698
#     -   - 0.0
#         - 1.0
# initialization:
#   x_init: [-10.0, -10.0]
# phase1:
#   gamma: 5
#   expo_gamma: 0.8
#   max_iter: 500
#   tol: 0.0001
#
# phase2:
#   expo_alpha: 0.35
#   expo_beta: 1.0
#   expo_lambda: 0.65
#   init_params: 1
#   max_iter: 1000
#   mu: 0.1
#   verbose: false

# %% [markdown]
# ## Cloud

# %%
def generate_pareto_grid(f_func, c_funcs, q_plus_func, resolution=400):
    """
    Sinh dữ liệu Pareto cho bài toán 2D bằng cách quét lưới tọa độ.
    f_func: Hàm mục tiêu f(x)
    c_funcs: Danh sách các hàm ràng buộc c(x) >= 0 (miền C)
    q_plus_func: Hàm ràng buộc q_plus(y) >= 0 (miền Q+)
    """
    print(f"--- Đang quét lưới {resolution}x{resolution} điểm ---")
    
    # 1. Xác định phạm vi quét dựa trên các ràng buộc hình tròn c1, c2

    x0_range = np.linspace(0, 5, resolution)
    x1_range = np.linspace(0, 5, resolution)
    X0, X1 = np.meshgrid(x0_range, x1_range)
    
    # Làm phẳng để tính toán vector
    points_X = np.vstack([X0.ravel(), X1.ravel()]).T
    
    # 2. Kiểm tra ràng buộc miền C: c1(x) >= 0 và c2(x) >= 0
    # (Sử dụng các hàm c1, c2 đã định nghĩa của bạn)
    mask_C = np.ones(len(points_X), dtype=bool)
    for c_func in c_funcs:
        mask_C &= (c_func(points_X.T) >= 0)
    
    feasible_X = points_X[mask_C]
    print(f"-> Tìm thấy {len(feasible_X)} điểm thỏa mãn miền C.")
    
    if len(feasible_X) == 0:
        return None, None

    # 3. Tính giá trị mục tiêu f(x) và kiểm tra miền Q+
    f_vals = np.array([f_func(x) for x in feasible_X])  # shape (N, 2)
    
    # Kiểm tra q_plus(f(x)) >= 0
    # Lưu ý: Hàm q_plus của bạn nhận 1 vector y, ta cần áp dụng cho toàn bộ f_vals
    mask_Qplus = np.array([q_plus_func(y) >= 0 for y in f_vals])
    
    pf_cloud_data = f_vals[mask_Qplus]
    print(f"-> Lọc còn {len(pf_cloud_data)} điểm thỏa mãn Q+ (Cloud).")

    if len(pf_cloud_data) == 0:
        return None, None

    # 4. Lọc Pareto Front từ Cloud (Tìm các điểm không bị trội)
    # Sắp xếp theo f1 tăng dần
    sorted_indices = np.argsort(pf_cloud_data[:, 0])
    y_sorted = pf_cloud_data[sorted_indices]
    
    pareto_list = []
    pareto_list.append(y_sorted[0])
    current_min_f2 = y_sorted[0][1]
    
    for i in range(1, len(y_sorted)):
        if y_sorted[i][1] < current_min_f2:
            pareto_list.append(y_sorted[i])
            current_min_f2 = y_sorted[i][1]
    
    pf_targets_data = np.array(pareto_list)
    print(f"-> Kết quả: {len(pf_targets_data)} điểm Pareto.")
    
    return pf_cloud_data, pf_targets_data

# %%
# def non_c(x):
#     return 1
# pf_cloud, pf_targets = generate_pareto_grid(
#     f_func=f, 
#     c_funcs=[non_c], 
#     q_plus_func=q_plus, 
#     resolution=500
# )

# %% [markdown]
# # Project

# %%
results = run_experiment(prob)
# Out:
# === BẮT ĐẦU PHASE 1: TÌM ĐIỂM KHẢ THI ===
# Khởi tạo: x0: [-10. -10.]
# Chiếu lên C được: x: [0. 0.]
# 100%|██████████| 500/500 [00:03<00:00, 158.81it/s]
# +-----+----------------------+---------+----------------------+----------------------+----------+----------+
# |  k  | x_new                | gamma_k | y                    | z_proj               |   e_x    |   e_f    |
# +-----+----------------------+---------+----------------------+----------------------+----------+----------+
# |  0  | [0., 0.]             | 5.0000  | [0., 1.]             | [0. , 0.6]           | 0.565685 | 0.400000 |
# |  10 | [0.796875, 0.796875] | 0.7343  | [0.0254 , 0.70665]   | [0.0254, 0.6   ]     | 0.018619 | 0.106650 |
# |  20 | [0.885176, 0.885176] | 0.4377  | [0.031341, 0.677271] | [0.031341, 0.6     ] | 0.007873 | 0.077271 |
# |  30 | [0.928898, 0.928898] | 0.3205  | [0.034514, 0.662955] | [0.034514, 0.600001] | 0.004647 | 0.062954 |
# |  40 | [0.956485, 0.956485] | 0.2563  | [0.036595, 0.654001] | [0.036595, 0.600001] | 0.003166 | 0.053999 |
# |  50 | [0.975988, 0.975988] | 0.2152  | [0.038102, 0.647707] | [0.038102, 0.600001] | 0.002337 | 0.047706 |
# |  60 | [0.990734, 0.990734] | 0.1865  | [0.039262, 0.642969] | [0.039262, 0.6     ] | 0.001818 | 0.042968 |
# |  70 | [1.002393, 1.002393] | 0.1652  | [0.040192, 0.639235] | [0.040192, 0.600002] | 0.001465 | 0.039233 |
# |  80 | [1.011909, 1.011909] | 0.1487  | [0.040958, 0.636195] | [0.040958, 0.600002] | 0.001214 | 0.036193 |
# |  90 | [1.019865, 1.019865] | 0.1354  | [0.041605, 0.633659] | [0.041605, 0.6     ] | 0.001026 | 0.033659 |
# | 100 | [1.026643, 1.026643] | 0.1246  | [0.04216 , 0.631503] | [0.04216, 0.6    ]   | 0.000882 | 0.031502 |
# | 110 | [1.032505, 1.032505] | 0.1155  | [0.042643, 0.629641] | [0.042643, 0.6     ] | 0.000769 | 0.029641 |
# | 120 | [1.037637, 1.037637] | 0.1078  | [0.043068, 0.628013] | [0.043068, 0.600001] | 0.000677 | 0.028012 |
# | 130 | [1.042178, 1.042178] | 0.1012  | [0.043445, 0.626574] | [0.043445, 0.599998] | 0.000602 | 0.026576 |
# | 140 | [1.04623, 1.04623]   | 0.0954  | [0.043784, 0.625292] | [0.043784, 0.6     ] | 0.000540 | 0.025292 |
# | 150 | [1.049874, 1.049874] | 0.0903  | [0.044089, 0.62414 ] | [0.044089, 0.6     ] | 0.000487 | 0.024140 |
# | 160 | [1.053173, 1.053173] | 0.0858  | [0.044367, 0.623098] | [0.044367, 0.6     ] | 0.000442 | 0.023098 |
# | 170 | [1.056176, 1.056176] | 0.0818  | [0.04462, 0.62215]   | [0.04462 , 0.600002] | 0.000404 | 0.022148 |
# | 180 | [1.058924, 1.058924] | 0.0781  | [0.044853, 0.621283] | [0.044853, 0.600002] | 0.000371 | 0.021281 |
# | 190 | [1.06145, 1.06145]   | 0.0748  | [0.045067, 0.620487] | [0.045067, 0.600002] | 0.000342 | 0.020485 |
# | 200 | [1.063783, 1.063783] | 0.0718  | [0.045265, 0.619752] | [0.045265, 0.6     ] | 0.000316 | 0.019752 |
# | 210 | [1.065943, 1.065943] | 0.0691  | [0.045449, 0.619072] | [0.045449, 0.6     ] | 0.000293 | 0.019072 |
# | 220 | [1.067952, 1.067952] | 0.0666  | [0.045621, 0.61844 ] | [0.045621, 0.600002] | 0.000273 | 0.018439 |
# | 230 | [1.069825, 1.069825] | 0.0643  | [0.045781, 0.617851] | [0.045781, 0.6     ] | 0.000255 | 0.017851 |
# | 240 | [1.071576, 1.071576] | 0.0621  | [0.045931, 0.617301] | [0.045931, 0.6     ] | 0.000239 | 0.017301 |
# | 250 | [1.073218, 1.073218] | 0.0601  | [0.046072, 0.616785] | [0.046072, 0.600002] | 0.000224 | 0.016783 |
# | 260 | [1.07476, 1.07476]   | 0.0583  | [0.046204, 0.6163  ] | [0.046204, 0.600001] | 0.000211 | 0.016300 |
# | 270 | [1.076213, 1.076213] | 0.0566  | [0.046329, 0.615844] | [0.046329, 0.6     ] | 0.000199 | 0.015844 |
# | 280 | [1.077585, 1.077585] | 0.0550  | [0.046448, 0.615414] | [0.046448, 0.6     ] | 0.000188 | 0.015414 |
# | 290 | [1.078881, 1.078881] | 0.0534  | [0.046559, 0.615007] | [0.046559, 0.6     ] | 0.000178 | 0.015007 |
# | 300 | [1.080109, 1.080109] | 0.0520  | [0.046665, 0.614622] | [0.046665, 0.6     ] | 0.000169 | 0.014622 |
# | 310 | [1.081274, 1.081274] | 0.0507  | [0.046766, 0.614257] | [0.046766, 0.600001] | 0.000160 | 0.014256 |
# | 320 | [1.082381, 1.082381] | 0.0494  | [0.046862, 0.61391 ] | [0.046862, 0.6     ] | 0.000152 | 0.013910 |
# | 330 | [1.083434, 1.083434] | 0.0482  | [0.046953, 0.613579] | [0.046953, 0.600001] | 0.000145 | 0.013578 |
# | 340 | [1.084438, 1.084438] | 0.0471  | [0.04704 , 0.613265] | [0.04704, 0.6    ]   | 0.000138 | 0.013265 |
# | 350 | [1.085396, 1.085396] | 0.0460  | [0.047123, 0.612965] | [0.047123, 0.600002] | 0.000132 | 0.012963 |
# | 360 | [1.086311, 1.086311] | 0.0450  | [0.047203, 0.612679] | [0.047203, 0.600001] | 0.000126 | 0.012678 |
# | 370 | [1.087186, 1.087186] | 0.0440  | [0.047279, 0.612405] | [0.047279, 0.6     ] | 0.000121 | 0.012405 |
# | 380 | [1.088024, 1.088024] | 0.0431  | [0.047352, 0.612142] | [0.047352, 0.6     ] | 0.000116 | 0.012142 |
# | 390 | [1.088827, 1.088827] | 0.0422  | [0.047422, 0.611891] | [0.047422, 0.6     ] | 0.000111 | 0.011891 |
# | 400 | [1.089597, 1.089597] | 0.0413  | [0.047489, 0.61165 ] | [0.047489, 0.6     ] | 0.000107 | 0.011650 |
# | 410 | [1.090337, 1.090337] | 0.0405  | [0.047553, 0.611418] | [0.047553, 0.6     ] | 0.000102 | 0.011418 |
# | 420 | [1.091049, 1.091049] | 0.0398  | [0.047615, 0.611196] | [0.047615, 0.6     ] | 0.000098 | 0.011196 |
# | 430 | [1.091733, 1.091733] | 0.0390  | [0.047675, 0.610982] | [0.047675, 0.600001] | 0.000095 | 0.010981 |
# | 440 | [1.092392, 1.092392] | 0.0383  | [0.047733, 0.610776] | [0.047733, 0.6     ] | 0.000091 | 0.010776 |
# | 450 | [1.093027, 1.093027] | 0.0376  | [0.047788, 0.610578] | [0.047788, 0.6     ] | 0.000088 | 0.010578 |
# | 460 | [1.093639, 1.093639] | 0.0370  | [0.047842, 0.610386] | [0.047842, 0.6     ] | 0.000085 | 0.010386 |
# | 470 | [1.094229, 1.094229] | 0.0364  | [0.047894, 0.610202] | [0.047894, 0.599982] | 0.000082 | 0.010220 |
# | 480 | [1.0948, 1.0948]     | 0.0357  | [0.047943, 0.610023] | [0.047943, 0.6     ] | 0.000079 | 0.010023 |
# | 490 | [1.095352, 1.095352] | 0.0352  | [0.047992, 0.609851] | [0.047992, 0.600002] | 0.000076 | 0.009849 |
# +-----+----------------------+---------+----------------------+----------------------+----------+----------+
# -> Điểm khả thi (Feasible Point): [1.0959 1.0959]
# === TÌM GIỚI HẠN PARETO: OPTIM 1 OBJ CỦA F ===
# Chiều 0: 0.0438333997437897
# Chiều 1: 0.04383351536861944
#
# === BẮT ĐẦU PHASE 2: SCALARIZATION (MULTI-RAY) ===
# Running Ray 1/20: [1. 0.]
# Chạy hết vòng lặp, còn cách Q: 0.02511285672740926
# Running Ray 2/20: [0.9966 0.0826]
# Chạy hết vòng lặp, còn cách Q: 0.0030266015965392246
# Running Ray 3/20: [0.9864 0.1646]
# Chạy hết vòng lặp, còn cách Q: 0.0
# Running Ray 4/20: [0.9694 0.2455]
# Chạy hết vòng lặp, còn cách Q: 0.0
# Running Ray 5/20: [0.9458 0.3247]
# Chạy hết vòng lặp, còn cách Q: 0.0
# Running Ray 6/20: [0.9158 0.4017]
# Chạy hết vòng lặp, còn cách Q: 0.0
# Running Ray 7/20: [0.8795 0.4759]
# Chạy hết vòng lặp, còn cách Q: 0.0
# Running Ray 8/20: [0.8372 0.5469]
# Chạy hết vòng lặp, còn cách Q: 0.0
# Running Ray 9/20: [0.7891 0.6142]
# Chạy hết vòng lặp, còn cách Q: 0.0
# Running Ray 10/20: [0.7357 0.6773]
# Chạy hết vòng lặp, còn cách Q: 0.0
# Running Ray 11/20: [0.6773 0.7357]
# Chạy hết vòng lặp, còn cách Q: 0.0
# Running Ray 12/20: [0.6142 0.7891]
# Chạy hết vòng lặp, còn cách Q: 0.0
# Running Ray 13/20: [0.5469 0.8372]
# Chạy hết vòng lặp, còn cách Q: 0.0
# Running Ray 14/20: [0.4759 0.8795]
# Chạy hết vòng lặp, còn cách Q: 0.0
# Running Ray 15/20: [0.4017 0.9158]
# Chạy hết vòng lặp, còn cách Q: 0.0
# Running Ray 16/20: [0.3247 0.9458]
# Chạy hết vòng lặp, còn cách Q: 0.0
# Running Ray 17/20: [0.2455 0.9694]
# Chạy hết vòng lặp, còn cách Q: 0.0
# Running Ray 18/20: [0.1646 0.9864]
# Chạy hết vòng lặp, còn cách Q: 0.0
# Running Ray 19/20: [0.0826 0.9966]
# Chạy hết vòng lặp, còn cách Q: 0.002899290012008171
# Running Ray 20/20: [0. 1.]
# Chạy hết vòng lặp, còn cách Q: 0.02511229256172054
#
# === HOÀN THÀNH ===
# Tìm thấy 20 điểm Pareto.
# [[0.0438 0.6251]
#  [0.0499 0.603 ]
#  [0.0841 0.504 ]
#  [0.112  0.4427]
#  [0.1365 0.3976]
#  [0.1587 0.3619]
#  [0.1796 0.332 ]
#  [0.1997 0.3059]
#  [0.2198 0.2821]
#  [0.2398 0.2604]
#  [0.2604 0.2399]
#  [0.2821 0.2198]
#  [0.3059 0.1998]
#  [0.3319 0.1797]
#  [0.3619 0.1588]
#  [0.3976 0.1365]
#  [0.4427 0.112 ]
#  [0.5042 0.0841]
#  [0.603  0.0499]
#  [0.6251 0.0438]]

# %%
visualize_pareto_front(
    pf_pred=results["pareto_f"], 
    pf_cloud=pf_cloud,   
    pf_targets=pf_targets,
    title="Objective Space Visualization",
    figsize=(12, 8)
)

# %%
np.save(f"test/{case}/pf_true.npy", results["pareto_f"])
np.save(f"test/{case}/target_space.npy", pf_cloud)

# %% [markdown]
# # Dynamic

# %%
from main_dynamic import run_experiment as run_experiment_dynamic

# %%
results_dynamic = run_experiment_dynamic(prob)
# Out:
# === BẮT ĐẦU PHASE 1: TÌM ĐIỂM KHẢ THI ===
# Khởi tạo: x0: [-10. -10.]
# Chiếu lên C được: x: [0. 0.]
# 100%|██████████| 500/500 [00:03<00:00, 156.71it/s]
# +-----+----------------------+---------+----------------------+----------------------+----------+----------+
# |  k  | x_new                | gamma_k | y                    | z_proj               |   e_x    |   e_f    |
# +-----+----------------------+---------+----------------------+----------------------+----------+----------+
# |  0  | [0., 0.]             | 5.0000  | [0., 1.]             | [0. , 0.6]           | 0.565685 | 0.400000 |
# |  10 | [0.796875, 0.796875] | 0.7343  | [0.0254 , 0.70665]   | [0.0254, 0.6   ]     | 0.018619 | 0.106650 |
# |  20 | [0.885176, 0.885176] | 0.4377  | [0.031341, 0.677271] | [0.031341, 0.600001] | 0.007873 | 0.077270 |
# |  30 | [0.928898, 0.928898] | 0.3205  | [0.034514, 0.662955] | [0.034514, 0.6     ] | 0.004647 | 0.062955 |
# |  40 | [0.956485, 0.956485] | 0.2563  | [0.036595, 0.654001] | [0.036595, 0.6     ] | 0.003166 | 0.054001 |
# |  50 | [0.975988, 0.975988] | 0.2152  | [0.038102, 0.647707] | [0.038102, 0.6     ] | 0.002337 | 0.047707 |
# |  60 | [0.990734, 0.990734] | 0.1865  | [0.039262, 0.642969] | [0.039262, 0.600001] | 0.001818 | 0.042968 |
# |  70 | [1.002393, 1.002393] | 0.1652  | [0.040192, 0.639235] | [0.040192, 0.6     ] | 0.001466 | 0.039234 |
# |  80 | [1.011909, 1.011909] | 0.1487  | [0.040958, 0.636195] | [0.040958, 0.6     ] | 0.001214 | 0.036195 |
# |  90 | [1.019865, 1.019865] | 0.1354  | [0.041605, 0.633659] | [0.041605, 0.600001] | 0.001026 | 0.033658 |
# | 100 | [1.026643, 1.026643] | 0.1246  | [0.04216 , 0.631503] | [0.04216, 0.6    ]   | 0.000882 | 0.031503 |
# | 110 | [1.032505, 1.032505] | 0.1155  | [0.042643, 0.629641] | [0.042643, 0.600001] | 0.000769 | 0.029640 |
# | 120 | [1.037637, 1.037637] | 0.1078  | [0.043068, 0.628013] | [0.043068, 0.600002] | 0.000677 | 0.028011 |
# | 130 | [1.042178, 1.042178] | 0.1012  | [0.043445, 0.626574] | [0.043445, 0.600002] | 0.000602 | 0.026573 |
# | 140 | [1.04623, 1.04623]   | 0.0954  | [0.043784, 0.625292] | [0.043784, 0.6     ] | 0.000540 | 0.025292 |
# | 150 | [1.049874, 1.049874] | 0.0903  | [0.044089, 0.62414 ] | [0.044089, 0.6     ] | 0.000487 | 0.024140 |
# | 160 | [1.053173, 1.053173] | 0.0858  | [0.044367, 0.623098] | [0.044367, 0.6     ] | 0.000442 | 0.023098 |
# | 170 | [1.056176, 1.056176] | 0.0818  | [0.04462, 0.62215]   | [0.04462, 0.6    ]   | 0.000404 | 0.022150 |
# | 180 | [1.058924, 1.058924] | 0.0781  | [0.044853, 0.621283] | [0.044853, 0.6     ] | 0.000371 | 0.021283 |
# | 190 | [1.061451, 1.061451] | 0.0748  | [0.045067, 0.620487] | [0.045067, 0.6     ] | 0.000342 | 0.020487 |
# | 200 | [1.063783, 1.063783] | 0.0718  | [0.045265, 0.619752] | [0.045265, 0.6     ] | 0.000316 | 0.019752 |
# | 210 | [1.065944, 1.065944] | 0.0691  | [0.045449, 0.619072] | [0.045449, 0.6     ] | 0.000293 | 0.019072 |
# | 220 | [1.067952, 1.067952] | 0.0666  | [0.045621, 0.61844 ] | [0.045621, 0.6     ] | 0.000273 | 0.018440 |
# | 230 | [1.069825, 1.069825] | 0.0643  | [0.045781, 0.617851] | [0.045781, 0.6     ] | 0.000255 | 0.017851 |
# | 240 | [1.071576, 1.071576] | 0.0621  | [0.045931, 0.617301] | [0.045931, 0.6     ] | 0.000239 | 0.017300 |
# | 250 | [1.073218, 1.073218] | 0.0601  | [0.046072, 0.616785] | [0.046072, 0.6     ] | 0.000224 | 0.016785 |
# | 260 | [1.074761, 1.074761] | 0.0583  | [0.046204, 0.6163  ] | [0.046204, 0.6     ] | 0.000211 | 0.016300 |
# | 270 | [1.076214, 1.076214] | 0.0566  | [0.046329, 0.615844] | [0.046329, 0.6     ] | 0.000199 | 0.015844 |
# | 280 | [1.077585, 1.077585] | 0.0550  | [0.046448, 0.615414] | [0.046448, 0.599998] | 0.000188 | 0.015415 |
# | 290 | [1.078881, 1.078881] | 0.0534  | [0.046559, 0.615007] | [0.046559, 0.6     ] | 0.000178 | 0.015007 |
# | 300 | [1.080109, 1.080109] | 0.0520  | [0.046665, 0.614622] | [0.046665, 0.6     ] | 0.000169 | 0.014621 |
# | 310 | [1.081274, 1.081274] | 0.0507  | [0.046766, 0.614256] | [0.046766, 0.6     ] | 0.000160 | 0.014256 |
# | 320 | [1.082381, 1.082381] | 0.0494  | [0.046862, 0.613909] | [0.046862, 0.6     ] | 0.000152 | 0.013909 |
# | 330 | [1.083435, 1.083435] | 0.0482  | [0.046953, 0.613579] | [0.046953, 0.600002] | 0.000145 | 0.013577 |
# | 340 | [1.084438, 1.084438] | 0.0471  | [0.04704 , 0.613265] | [0.04704, 0.6    ]   | 0.000138 | 0.013265 |
# | 350 | [1.085396, 1.085396] | 0.0460  | [0.047123, 0.612965] | [0.047123, 0.600001] | 0.000132 | 0.012964 |
# | 360 | [1.086311, 1.086311] | 0.0450  | [0.047203, 0.612678] | [0.047203, 0.6     ] | 0.000126 | 0.012678 |
# | 370 | [1.087186, 1.087186] | 0.0440  | [0.047279, 0.612404] | [0.047279, 0.600002] | 0.000121 | 0.012403 |
# | 380 | [1.088024, 1.088024] | 0.0431  | [0.047352, 0.612142] | [0.047352, 0.6     ] | 0.000116 | 0.012142 |
# | 390 | [1.088827, 1.088827] | 0.0422  | [0.047422, 0.611891] | [0.047422, 0.6     ] | 0.000111 | 0.011891 |
# | 400 | [1.089598, 1.089598] | 0.0413  | [0.047489, 0.61165 ] | [0.047489, 0.600002] | 0.000107 | 0.011647 |
# | 410 | [1.090338, 1.090338] | 0.0405  | [0.047553, 0.611418] | [0.047553, 0.600001] | 0.000102 | 0.011417 |
# | 420 | [1.091049, 1.091049] | 0.0398  | [0.047616, 0.611196] | [0.047616, 0.600002] | 0.000098 | 0.011194 |
# | 430 | [1.091733, 1.091733] | 0.0390  | [0.047675, 0.610982] | [0.047675, 0.6     ] | 0.000095 | 0.010982 |
# | 440 | [1.092392, 1.092392] | 0.0383  | [0.047733, 0.610776] | [0.047733, 0.6     ] | 0.000091 | 0.010776 |
# | 450 | [1.093027, 1.093027] | 0.0376  | [0.047788, 0.610578] | [0.047788, 0.6     ] | 0.000088 | 0.010578 |
# | 460 | [1.093639, 1.093639] | 0.0370  | [0.047842, 0.610386] | [0.047842, 0.6     ] | 0.000085 | 0.010386 |
# | 470 | [1.09423, 1.09423]   | 0.0364  | [0.047894, 0.610202] | [0.047894, 0.6     ] | 0.000082 | 0.010202 |
# | 480 | [1.0948, 1.0948]     | 0.0357  | [0.047943, 0.610023] | [0.047943, 0.6     ] | 0.000079 | 0.010023 |
# | 490 | [1.095351, 1.095351] | 0.0352  | [0.047992, 0.609851] | [0.047992, 0.6     ] | 0.000077 | 0.009851 |
# +-----+----------------------+---------+----------------------+----------------------+----------+----------+
# -> Điểm khả thi (Feasible Point): [1.0959 1.0959]
# === TÌM GIỚI HẠN PARETO: OPTIM 1 OBJ CỦA F ===
# Chiều 0: 0.04383341717061934
# Chiều 1: 0.04383353120531463
#
# === BẮT ĐẦU PHASE 2: SCALARIZATION (MULTI-RAY) ===
# Running Ray 1/20: [1. 0.]
# Reach max iter, C: 4.948720045322015e-09, Q: 0.025130757609043708
# Running Ray 2/20: [0.9966 0.0826]
# Reach max iter, C: 5.691286021034419e-09, Q: 0.00289374370874107
# Running Ray 3/20: [0.9864 0.1646]
# Reach max iter, C: 7.08464543523554e-09, Q: 0.0
# Running Ray 4/20: [0.9694 0.2455]
# Reach max iter, C: 5.25567239467249e-09, Q: 0.0
# Running Ray 5/20: [0.9458 0.3247]
# Reach max iter, C: 3.4398339828720245e-09, Q: 0.0
# Running Ray 6/20: [0.9158 0.4017]
# Reach max iter, C: 7.377985704094847e-09, Q: 0.0
# Running Ray 7/20: [0.8795 0.4759]
# Reach max iter, C: 4.823413763557158e-09, Q: 0.0
# Running Ray 8/20: [0.8372 0.5469]
# Reach max iter, C: 5.668730437334854e-09, Q: 0.0
# Running Ray 9/20: [0.7891 0.6142]
# Reach max iter, C: 6.458009273658281e-09, Q: 0.0
# Running Ray 10/20: [0.7357 0.6773]
# Reach max iter, C: 7.150136399552592e-09, Q: 0.0
# Running Ray 11/20: [0.6773 0.7357]
# Reach max iter, C: 7.04323093084743e-09, Q: 0.0
# Running Ray 12/20: [0.6142 0.7891]
# Reach max iter, C: 4.774076752895653e-09, Q: 0.0
# Running Ray 13/20: [0.5469 0.8372]
# Reach max iter, C: 7.2393365590239185e-09, Q: 0.0
# Running Ray 14/20: [0.4759 0.8795]
# Reach max iter, C: 3.63344563592023e-09, Q: 0.0
# Running Ray 15/20: [0.4017 0.9158]
# Reach max iter, C: 6.5977298417319365e-09, Q: 0.0
# Running Ray 16/20: [0.3247 0.9458]
# Reach max iter, C: 5.854392261647171e-09, Q: 0.0
# Running Ray 17/20: [0.2455 0.9694]
# Reach max iter, C: 6.393829398286343e-09, Q: 0.0
# Running Ray 18/20: [0.1646 0.9864]
# Reach max iter, C: 5.128306435486452e-09, Q: 0.0
# Running Ray 19/20: [0.0826 0.9966]
# Reach max iter, C: 6.596768392917519e-09, Q: 0.0030102797545320525
# Running Ray 20/20: [0. 1.]
# Reach max iter, C: 5.4896257743516774e-09, Q: 0.02509419038705807
#
# === HOÀN THÀNH ===
# Tìm thấy 20 điểm Pareto.
# [[0.0438 0.6251]
#  [0.0499 0.603 ]
#  [0.0841 0.5041]
#  [0.1121 0.4425]
#  [0.1365 0.3976]
#  [0.1587 0.3619]
#  [0.1796 0.3321]
#  [0.1997 0.306 ]
#  [0.2198 0.2822]
#  [0.2398 0.2604]
#  [0.2603 0.2399]
#  [0.2824 0.2196]
#  [0.3058 0.1998]
#  [0.3319 0.1797]
#  [0.3618 0.1588]
#  [0.3976 0.1365]
#  [0.4426 0.112 ]
#  [0.5042 0.0841]
#  [0.603  0.05  ]
#  [0.6251 0.0438]]

# %%
visualize_pareto_front(
    pf_pred=results_dynamic["pareto_f"], 
    pf_cloud=pf_cloud,   
    pf_targets=results["pareto_f"],
    title="Objective Space Visualization",
    figsize=(12, 8)
)

# %%
np.save(f"test/{case}/pf_dynamic_true.npy", results_dynamic["pareto_f"])
