# %%
from project import Projection
from Problem import Problem
from Phase1 import solve_CQ_feasible
from Phase2_1_obj import optim_Universal
from Phase2_dynamic import optim_Scalarization
from main_dynamic import load_config
from utils import visualize_pareto_front, generate_pareto_grid

# %%
import autograd.numpy as np
from autograd import jacobian
from scipy.optimize import Bounds
import matplotlib.pyplot as plt
import pandas as pd
import math
import itertools

# %%
case = "_Ex_7_2"

# %% [markdown]
# # Prob

# %%
def f1(x):    return (x[0]**2 + x[1]**2)/50
def f2(x):    return ((x[0] - 5)**2 + (x[1] - 5)**2)/50
def f(x):    return np.array([
    (x[0]**2 + x[1]**2)/50,
    ((x[0] - 5)**2 + (x[1] - 5)**2)/50])
#--------------- C --------------------#
bounds_x = Bounds([0,0],[5, 5])

#--------------- Q --------------------#
def q1(y):    return 0.2**2 - (y[0] - 0.4)**2 - (y[1] - 0.4)**2

def q_plus(y):
    center = 0.4
    radius_sq = 0.2**2  
    dx = np.maximum(0, y[0] - center)
    dy = np.maximum(0, y[1] - center)
    return radius_sq - (dx**2 + dy**2)
# Hàm dùng cho Projection 
cons_C = ()
dim_x = 2
cons_Q = ({'type': 'ineq', 'fun' : q1,},)
cons_Qplus = ({'type': 'ineq', 'fun': q_plus},)
dim_y = 2
# Setup Projections
proj_C_handler = Projection(cons=cons_C, bounds=bounds_x, dim=dim_x, proj_type='euclid')
proj_Q_handler = Projection(cons=cons_Q, bounds=None, dim=dim_y, proj_type='qplus')
# Setup Problem
prob = Problem(
    f=[f], jac_f=[jacobian(f)], C=[], Q=[],
    dim_x=dim_x, dim_y=dim_y,
    proj_C=proj_C_handler.project,
    proj_Qplus=proj_Q_handler.project
)
z_star = np.array([0.0, 0.0])
x_init = np.array([-10.0, -10.0])

# %%
def f(x):
    # Hỗ trợ tính toán broadcasting cho mảng 2D (N, 2) hoặc 1D (2,)
    if x.ndim == 1:
        val1 = (x[0]**2 + x[1]**2)/50
        val2 = ((x[0] - 5)**2 + (x[1] - 5)**2)/50
    else:
        val1 = (x[:,0]**2 + x[:,1]**2)/50
        val2 = ((x[:,0] - 5)**2 + (x[:,1] - 5)**2)/50
    
    if x.ndim == 1:
        return np.array([val1, val2])
    return np.column_stack([val1, val2])

def q1(y):
    # y là một điểm [y1, y2]
    return 0.2**2 - (y[0] - 0.4)**2 - (y[1] - 0.4)**2

def q_plus(y):
    center = 0.4
    radius_sq = 0.2**2  
    # Xử lý cho cả input là 1 điểm hoặc lưới điểm (meshgrid)
    dx = np.maximum(0, y[0] - center)
    dy = np.maximum(0, y[1] - center)
    return radius_sq - (dx**2 + dy**2)

# --- 2. CHUẨN BỊ DỮ LIỆU ---

# A. Tạo dữ liệu cho Image Space (Miền ảnh của C)
# C là hình vuông [0, 5] x [0, 5]
# Lấy mẫu ngẫu nhiên 50,000 điểm trong hình vuông này để vẽ "đám mây"
num_samples = 50000
x_samples = np.random.uniform(0, 5, size=(num_samples, 2))
y_cloud = f(x_samples)

# B. Tạo dữ liệu biên (Boundary) của Image Space để vẽ viền cho đẹp
# Biên của C gồm 4 cạnh của hình vuông
t = np.linspace(0, 5, 200)
# Cạnh 1: (t, 0)
edge1 = f(np.column_stack([t, np.zeros_like(t)]))
# Cạnh 2: (5, t)
edge2 = f(np.column_stack([np.full_like(t, 5), t]))
# Cạnh 3: (t, 5)
edge3 = f(np.column_stack([t, np.full_like(t, 5)]))
# Cạnh 4: (0, t)
edge4 = f(np.column_stack([np.zeros_like(t), t]))


# C. Tạo lưới để vẽ vùng Q và Q+ (Contour)
grid_res = 400
y_range = np.linspace(-0.2, 1.2, grid_res)
Y1, Y2 = np.meshgrid(y_range, y_range)

# Tính giá trị Z cho contour
Z_q1 = np.zeros_like(Y1)
Z_qplus = np.zeros_like(Y1)

# Tính toán ma trận (vector hóa để nhanh hơn vòng lặp)
# q1: 0.04 - (y1-0.4)^2 - (y2-0.4)^2
Z_q1 = 0.04 - (Y1 - 0.4)**2 - (Y2 - 0.4)**2

# q_plus
dx = np.maximum(0, Y1 - 0.4)
dy = np.maximum(0, Y2 - 0.4)
Z_qplus = 0.04 - (dx**2 + dy**2)


# --- 3. VẼ ĐỒ THỊ ---
plt.figure(figsize=(10, 10))

# 1. Vẽ vùng Q+ (Xanh lá) - Lớp dưới cùng
plt.contourf(Y1, Y2, Z_qplus, levels=[0, np.inf], colors=['#ccffcc'], alpha=0.5)
plt.contour(Y1, Y2, Z_qplus, levels=[0], colors='green', linestyles='--', linewidths=1)
plt.plot([], [], color='#ccffcc', marker='s', linestyle='None', label='Region $Q^+$')

# 2. Vẽ vùng Q (Đỏ)
plt.contourf(Y1, Y2, Z_q1, levels=[0, np.inf], colors=['#ffcccc'], alpha=0.6)
plt.contour(Y1, Y2, Z_q1, levels=[0], colors='red', linewidths=1)
plt.plot([], [], color='#ffcccc', marker='o', linestyle='None', label='Region $Q$')

# 3. Vẽ Image Space (Đám mây xám)
plt.scatter(y_cloud[:, 0], y_cloud[:, 1], s=1, color='gray', alpha=0.1, label='Feasible Image Space ($f(C)$)')

# 4. Vẽ biên của Image Space (Đường xanh đậm)
# Nối các cạnh lại để thấy rõ hình dạng
plt.plot(edge1[:,0], edge1[:,1], 'b-', linewidth=1.5)
plt.plot(edge2[:,0], edge2[:,1], 'b-', linewidth=1.5)
plt.plot(edge3[:,0], edge3[:,1], 'b-', linewidth=1.5)
plt.plot(edge4[:,0], edge4[:,1], 'b-', linewidth=1.5)
# Hack label cho biên
plt.plot([], [], 'b-', linewidth=1.5, label='Boundary of Image Space')


# --- 4. TRANG TRÍ ---
plt.title('Visualization of Objective Space $f(C)$ with $Q$ and $Q^+$', fontsize=14)
plt.xlabel('$f_1(x) = (x_1^2 + x_2^2)/50$', fontsize=12)
plt.ylabel('$f_2(x) = ((x_1-5)^2 + (x_2-5)^2)/50$', fontsize=12)

# Điểm Pareto lý tưởng (Utopia point) của Image Space này thường nằm ở góc dưới trái của đám mây xám
# Điểm Nadir nằm ở góc trên phải

plt.xlim(-0.1, 1.1)
plt.ylim(-0.1, 1.1)
plt.grid(True, linestyle=':', alpha=0.6)
plt.gca().set_aspect('equal', adjustable='box')
plt.legend(loc='upper right')

plt.show()

# %% [markdown]
# # Config

# %%
from ruamel.yaml import YAML
from ruamel.yaml.comments import CommentedSeq


def update_config(file_path, x_init_np):
    yaml = YAML()
    yaml.preserve_quotes = True
    yaml.indent(mapping=2, sequence=4, offset=2)

    with open(file_path, 'r', encoding='utf-8') as f_in:
        config = yaml.load(f_in)

    # Xử lý numpy array thành flow-style list cho đẹp
    val_list = x_init_np.tolist() if hasattr(x_init_np, 'tolist') else x_init_np
    flow_list = CommentedSeq(val_list)
    flow_list.fa.set_flow_style() 

    config['initialization']['x_init'] = flow_list
    
    # --- Cập nhật Phase 1 ---
    config['phase1']['gamma'] = 0.5
    config['phase1']['expo_gamma'] = 0.35 
    config['phase1']['max_iter'] = 500
    
    # --- Cập nhật Phase 2 (Algorithm 1-A Parameters) ---
    config['phase2']['mu'] = 0.0001
    config['phase2']['init_params'] = 1.0
    config['phase2']['max_iter'] = 2000
    
    # Các tham số số mũ hội tụ 
    config['phase2']['expo_lambda'] = 0.55    # Giảm: Bước nhảy (Điều kiện: 0.5 < l <= 1)
    config['phase2']['expo_alpha'] = 0.45     # Giảm: Trọng số mục tiêu (Điều kiện: l + a <= 1 => a < 0.5)

    
    # [MỚI] Thêm expo_beta và expo_gamma
    config['phase2']['expo_beta'] = 0.4      # Tăng: Phạt tập C (b_C < 0)
    config['phase2']['expo_gamma'] = 0.5    # Tăng: Phạt tập Q+ (b_Q < 0)

    # Ghi lại vào file
    with open(file_path, 'w', encoding='utf-8') as f_out:
        yaml.dump(config, f_out)
    
    print(f"✅ Đã cập nhật xong file: {file_path}")

config_file = 'config.yaml'
update_config(config_file, x_init)
print("\n" + "="*30)
print("NỘI DUNG FILE CONFIG SAU KHI SỬA:")
print("="*30)
with open(config_file, 'r', encoding='utf-8') as f_in:
    print(f_in.read())
# Out:
# ✅ Đã cập nhật xong file: config.yaml
#
# ==============================
# NỘI DUNG FILE CONFIG SAU KHI SỬA:
# ==============================
# data:
#   test_ray:
#     -   - 1.0
#         - 0.0
#     -   - 0.9965844930066698
#         - 0.08257934547233232
#     -   - 0.9863613034027223
#         - 0.1645945902807339
#     -   - 0.9694002659393304
#         - 0.24548548714079912
#     -   - 0.9458172417006346
#         - 0.32469946920468346
#     -   - 0.9157733266550574
#         - 0.4016954246529694
#     -   - 0.8794737512064891
#         - 0.4759473930370735
#     -   - 0.8371664782625285
#         - 0.5469481581224268
#     -   - 0.7891405093963936
#         - 0.6142127126896678
#     -   - 0.7357239106731316
#         - 0.677281571625741
#     -   - 0.6772815716257411
#         - 0.7357239106731316
#     -   - 0.6142127126896678
#         - 0.7891405093963936
#     -   - 0.5469481581224269
#         - 0.8371664782625285
#     -   - 0.4759473930370736
#         - 0.8794737512064891
#     -   - 0.40169542465296953
#         - 0.9157733266550574
#     -   - 0.32469946920468357
#         - 0.9458172417006346
#     -   - 0.24548548714079924
#         - 0.9694002659393304
#     -   - 0.16459459028073398
#         - 0.9863613034027223
#     -   - 0.0825793454723324
#         - 0.9965844930066698
#     -   - 0.0
#         - 1.0
# initialization:
#   x_init: [-10.0, -10.0]
# phase1:
#   gamma: 0.5
#   expo_gamma: 0.35
#   max_iter: 500
#   tol: 0.0001
#
# phase2:
#   expo_alpha: 0.45
#   expo_beta: 0.4
#   expo_lambda: 0.55
#   init_params: 1.0
#   max_iter: 2000
#   mu: 0.0001
#   verbose: false
#   expo_gamma: 0.5

# %% [markdown]
# ## Cloud

# %%
def generate_pareto_grid(f_func, c_funcs, q_plus_func, resolution=400):
    """
    Sinh dữ liệu Pareto cho bài toán 2D bằng cách quét lưới tọa độ.
    f_func: Hàm mục tiêu f(x)
    c_funcs: Danh sách các hàm ràng buộc c(x) >= 0 (miền C)
    q_plus_func: Hàm ràng buộc q_plus(y) >= 0 (miền Q+)
    """
    print(f"--- Đang quét lưới {resolution}x{resolution} điểm ---")
    
    # 1. Xác định phạm vi quét dựa trên các ràng buộc hình tròn c1, c2

    x0_range = np.linspace(0, 5, resolution)
    x1_range = np.linspace(0, 5, resolution)
    X0, X1 = np.meshgrid(x0_range, x1_range)
    
    # Làm phẳng để tính toán vector
    points_X = np.vstack([X0.ravel(), X1.ravel()]).T
    
    # 2. Kiểm tra ràng buộc miền C: c1(x) >= 0 và c2(x) >= 0
    # (Sử dụng các hàm c1, c2 đã định nghĩa của bạn)
    mask_C = np.ones(len(points_X), dtype=bool)
    for c_func in c_funcs:
        mask_C &= (c_func(points_X.T) >= 0)
    
    feasible_X = points_X[mask_C]
    print(f"-> Tìm thấy {len(feasible_X)} điểm thỏa mãn miền C.")
    
    if len(feasible_X) == 0:
        return None, None

    # 3. Tính giá trị mục tiêu f(x) và kiểm tra miền Q+
    f_vals = np.array([f_func(x) for x in feasible_X])  # shape (N, 2)
    
    # Kiểm tra q_plus(f(x)) >= 0
    # Lưu ý: Hàm q_plus của bạn nhận 1 vector y, ta cần áp dụng cho toàn bộ f_vals
    mask_Qplus = np.array([q_plus_func(y) >= 0 for y in f_vals])
    
    pf_cloud_data = f_vals[mask_Qplus]
    print(f"-> Lọc còn {len(pf_cloud_data)} điểm thỏa mãn Q+ (Cloud).")

    if len(pf_cloud_data) == 0:
        return None, None

    # 4. Lọc Pareto Front từ Cloud (Tìm các điểm không bị trội)
    # Sắp xếp theo f1 tăng dần
    sorted_indices = np.argsort(pf_cloud_data[:, 0])
    y_sorted = pf_cloud_data[sorted_indices]
    
    pareto_list = []
    pareto_list.append(y_sorted[0])
    current_min_f2 = y_sorted[0][1]
    
    for i in range(1, len(y_sorted)):
        if y_sorted[i][1] < current_min_f2:
            pareto_list.append(y_sorted[i])
            current_min_f2 = y_sorted[i][1]
    
    pf_targets_data = np.array(pareto_list)
    print(f"-> Kết quả: {len(pf_targets_data)} điểm Pareto.")
    
    return pf_cloud_data, pf_targets_data

# %%
def non_c(x):
    return 1
pf_cloud, pf_targets = generate_pareto_grid(
    f_func=f, 
    c_funcs=[non_c], 
    q_plus_func=q_plus, 
    resolution=500
)
# Out:
# --- Đang quét lưới 500x500 điểm ---
# -> Tìm thấy 250000 điểm thỏa mãn miền C.
# -> Lọc còn 192206 điểm thỏa mãn Q+ (Cloud).
# -> Kết quả: 549 điểm Pareto.

# %%
np.save(f"test/{case}/pf_true.npy", results["pareto_f"])
np.save(f"test/{case}/target_space.npy", pf_cloud)

# %% [markdown]
# # Dynamic

# %%
from main_dynamic import run_experiment as run_experiment_dynamic

# %%
results_dynamic = run_experiment_dynamic(prob)
# Out:
# === BẮT ĐẦU PHASE 1: TÌM ĐIỂM KHẢ THI ===
# Khởi tạo: x0: [-10. -10.]
# Chiếu lên C được: x: [0. 0.]
# 100%|██████████| 500/500 [00:03<00:00, 160.04it/s]
# +-----+----------------------+---------+----------------------+----------------------+----------+----------+
# |  k  | x_new                | gamma_k | y                    | z_proj               |   e_x    |   e_f    |
# +-----+----------------------+---------+----------------------+----------------------+----------+----------+
# |  0  | [0., 0.]             | 0.5000  | [0., 1.]             | [0. , 0.6]           | 0.056569 | 0.400000 |
# |  10 | [0.214928, 0.214928] | 0.2160  | [0.001848, 0.915877] | [0.001848, 0.6     ] | 0.018470 | 0.315877 |
# |  20 | [0.323543, 0.323543] | 0.1723  | [0.004187, 0.87477 ] | [0.004187, 0.6     ] | 0.012521 | 0.274770 |
# |  30 | [0.401868, 0.401868] | 0.1503  | [0.00646 , 0.845713] | [0.00646 , 0.600001] | 0.009607 | 0.245712 |
# |  40 | [0.463633, 0.463633] | 0.1363  | [0.008598, 0.823145] | [0.008598, 0.6     ] | 0.007805 | 0.223145 |
# |  50 | [0.514621, 0.514621] | 0.1263  | [0.010593, 0.804745] | [0.010593, 0.6     ] | 0.006560 | 0.204745 |
# |  60 | [0.557935, 0.557935] | 0.1186  | [0.012452, 0.789278] | [0.012452, 0.6     ] | 0.005641 | 0.189278 |
# |  70 | [0.595467, 0.595467] | 0.1125  | [0.014183, 0.775996] | [0.014183, 0.6     ] | 0.004932 | 0.175996 |
# |  80 | [0.628471, 0.628471] | 0.1074  | [0.015799, 0.76441 ] | [0.015799, 0.6     ] | 0.004367 | 0.164410 |
# |  90 | [0.657827, 0.657827] | 0.1031  | [0.017309, 0.754179] | [0.017309, 0.6     ] | 0.003905 | 0.154179 |
# | 100 | [0.684177, 0.684177] | 0.0994  | [0.018724, 0.745053] | [0.018724, 0.6     ] | 0.003521 | 0.145053 |
# | 110 | [0.708007, 0.708007] | 0.0962  | [0.020051, 0.736848] | [0.020051, 0.6     ] | 0.003196 | 0.136848 |
# | 120 | [0.729696, 0.729696] | 0.0933  | [0.021298, 0.72942 ] | [0.021298, 0.6     ] | 0.002918 | 0.129420 |
# | 130 | [0.749541, 0.749541] | 0.0908  | [0.022472, 0.722656] | [0.022472, 0.6     ] | 0.002677 | 0.122656 |
# | 140 | [0.767783, 0.767783] | 0.0885  | [0.02358 , 0.716466] | [0.02358, 0.6    ]   | 0.002467 | 0.116466 |
# | 150 | [0.784622, 0.784622] | 0.0864  | [0.024625, 0.710777] | [0.024625, 0.6     ] | 0.002281 | 0.110777 |
# | 160 | [0.800219, 0.800219] | 0.0844  | [0.025614, 0.705526] | [0.025614, 0.600001] | 0.002117 | 0.105526 |
# | 170 | [0.814714, 0.814714] | 0.0827  | [0.02655 , 0.700665] | [0.02655, 0.6    ]   | 0.001971 | 0.100665 |
# | 180 | [0.828222, 0.828222] | 0.0811  | [0.027438, 0.696149] | [0.027438, 0.6     ] | 0.001839 | 0.096149 |
# | 190 | [0.840842, 0.840843] | 0.0795  | [0.028281, 0.691944] | [0.028281, 0.600001] | 0.001721 | 0.091943 |
# | 200 | [0.852662, 0.852662] | 0.0781  | [0.029081, 0.688016] | [0.029081, 0.6     ] | 0.001613 | 0.088016 |
# | 210 | [0.863756, 0.863756] | 0.0768  | [0.029843, 0.684341] | [0.029843, 0.6     ] | 0.001516 | 0.084340 |
# | 220 | [0.874187, 0.874187] | 0.0756  | [0.030568, 0.680893] | [0.030568, 0.600001] | 0.001427 | 0.080893 |
# | 230 | [0.884015, 0.884015] | 0.0744  | [0.031259, 0.677653] | [0.031259, 0.6     ] | 0.001346 | 0.077653 |
# | 240 | [0.893288, 0.893288] | 0.0733  | [0.031919, 0.674603] | [0.031919, 0.6     ] | 0.001271 | 0.074603 |
# | 250 | [0.902052, 0.902052] | 0.0723  | [0.032548, 0.671727] | [0.032548, 0.6     ] | 0.001202 | 0.071727 |
# | 260 | [0.910346, 0.910346] | 0.0713  | [0.033149, 0.669011] | [0.033149, 0.6     ] | 0.001138 | 0.069011 |
# | 270 | [0.918206, 0.918206] | 0.0704  | [0.033724, 0.666442] | [0.033724, 0.600002] | 0.001080 | 0.066440 |
# | 280 | [0.925665, 0.925665] | 0.0695  | [0.034274, 0.664008] | [0.034274, 0.600002] | 0.001025 | 0.064007 |
# | 290 | [0.93275, 0.93275]   | 0.0686  | [0.034801, 0.661701] | [0.034801, 0.6     ] | 0.000974 | 0.061700 |
# | 300 | [0.939489, 0.939489] | 0.0678  | [0.035306, 0.65951 ] | [0.035306, 0.600002] | 0.000927 | 0.059508 |
# | 310 | [0.945904, 0.945904] | 0.0671  | [0.035789, 0.657428] | [0.035789, 0.6     ] | 0.000883 | 0.057427 |
# | 320 | [0.952017, 0.952017] | 0.0663  | [0.036253, 0.655447] | [0.036253, 0.6     ] | 0.000842 | 0.055447 |
# | 330 | [0.957848, 0.957848] | 0.0656  | [0.036699, 0.65356 ] | [0.036699, 0.600001] | 0.000804 | 0.053559 |
# | 340 | [0.963414, 0.963414] | 0.0649  | [0.037127, 0.651761] | [0.037127, 0.6     ] | 0.000768 | 0.051761 |
# | 350 | [0.968732, 0.968732] | 0.0643  | [0.037538, 0.650045] | [0.037538, 0.6     ] | 0.000734 | 0.050045 |
# | 360 | [0.973817, 0.973817] | 0.0637  | [0.037933, 0.648406] | [0.037933, 0.6     ] | 0.000702 | 0.048406 |
# | 370 | [0.978683, 0.978683] | 0.0631  | [0.038313, 0.64684 ] | [0.038313, 0.6     ] | 0.000672 | 0.046839 |
# | 380 | [0.983343, 0.983343] | 0.0625  | [0.038679, 0.645341] | [0.038679, 0.6     ] | 0.000644 | 0.045341 |
# | 390 | [0.987807, 0.987807] | 0.0619  | [0.039031, 0.643908] | [0.039031, 0.6     ] | 0.000617 | 0.043907 |
# | 400 | [0.992088, 0.992088] | 0.0614  | [0.03937 , 0.642534] | [0.03937, 0.6    ]   | 0.000592 | 0.042534 |
# | 410 | [0.996196, 0.996196] | 0.0608  | [0.039696, 0.641218] | [0.039696, 0.6     ] | 0.000568 | 0.041218 |
# | 420 | [1.000139, 1.000139] | 0.0603  | [0.040011, 0.639956] | [0.040011, 0.600002] | 0.000545 | 0.039953 |
# | 430 | [1.003926, 1.003926] | 0.0598  | [0.040315, 0.638744] | [0.040315, 0.6     ] | 0.000524 | 0.038744 |
# | 440 | [1.007566, 1.007566] | 0.0593  | [0.040608, 0.637581] | [0.040608, 0.6     ] | 0.000504 | 0.037581 |
# | 450 | [1.011066, 1.011066] | 0.0589  | [0.04089 , 0.636464] | [0.04089, 0.6    ]   | 0.000484 | 0.036464 |
# | 460 | [1.014434, 1.014434] | 0.0584  | [0.041163, 0.63539 ] | [0.041163, 0.6     ] | 0.000466 | 0.035389 |
# | 470 | [1.017675, 1.017675] | 0.0580  | [0.041426, 0.634357] | [0.041426, 0.6     ] | 0.000449 | 0.034357 |
# | 480 | [1.020796, 1.020796] | 0.0576  | [0.041681, 0.633363] | [0.041681, 0.600001] | 0.000432 | 0.033362 |
# | 490 | [1.023802, 1.023802] | 0.0572  | [0.041927, 0.632406] | [0.041927, 0.600001] | 0.000417 | 0.032405 |
# +-----+----------------------+---------+----------------------+----------------------+----------+----------+
# -> Điểm khả thi (Feasible Point): [1.0267 1.0267]
#
# === TÌM GIỚI HẠN PARETO: OPTIM 1 OBJ CỦA F ===
# -> Cực tiểu chiều 0: 0.0484795840781995
# -> Cực tiểu chiều 1: 0.04752539402914545
# -> Điểm lý tưởng z*: [0.0485 0.0475]
#
# === BẮT ĐẦU PHASE 2: SCALARIZATION (MULTI-RAY) - ALGORITHM 1-A ===
# Running Ray 1/20: [1. 0.]
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Running Ray 2/20: [0.9966 0.0826]
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Running Ray 3/20: [0.9864 0.1646]
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Running Ray 4/20: [0.9694 0.2455]
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Running Ray 5/20: [0.9458 0.3247]
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Running Ray 6/20: [0.9158 0.4017]
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Running Ray 7/20: [0.8795 0.4759]
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Running Ray 8/20: [0.8372 0.5469]
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Running Ray 9/20: [0.7891 0.6142]
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Running Ray 10/20: [0.7357 0.6773]
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Running Ray 11/20: [0.6773 0.7357]
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Running Ray 12/20: [0.6142 0.7891]
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Running Ray 13/20: [0.5469 0.8372]
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Running Ray 14/20: [0.4759 0.8795]
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Running Ray 15/20: [0.4017 0.9158]
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Running Ray 16/20: [0.3247 0.9458]
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Running Ray 17/20: [0.2455 0.9694]
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Running Ray 18/20: [0.1646 0.9864]
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Running Ray 19/20: [0.0826 0.9966]
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Running Ray 20/20: [0. 1.]
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
#
# === HOÀN THÀNH ===
# Tìm thấy 20 điểm Pareto.
#          f_0       f_1
# 0   0.050186  0.602142
# 1   0.084774  0.502455
# 2   0.115282  0.436219
# 3   0.135341  0.399566
# 4   0.158922  0.361621
# 5   0.175648  0.337440
# 6   0.192933  0.314450
# 7   0.209534  0.294037
# 8   0.225835  0.275393
# 9   0.244314  0.255751
# 10  0.261118  0.239123
# 11  0.278679  0.222878
# 12  0.297446  0.206674
# 13  0.315563  0.192063
# 14  0.338624  0.174796
# 15  0.365510  0.156361
# 16  0.400996  0.134511
# 17  0.437864  0.114438
# 18  0.501708  0.085081
# 19  0.600596  0.050633

# %%
visualize_pareto_front(
    pf_targets=results_dynamic["pareto_f"], 
    pf_cloud=pf_cloud,   
#     pf_targets=results["pareto_f"],
    title="Objective Space Visualization",
    figsize=(12, 8)
)

# %% [markdown]
# # Optim

# %%
from functions_hv_python3 import HyperVolume

def calculate_hv_score(pareto_f, prob, ref_point):
    """Tính Hypervolume, loại bỏ điểm vi phạm ràng buộc Q+"""
    valid_points = []
    tol = 1e-3
    for point in pareto_f:
        # Kiểm tra feasibility với Q+
        point_proj = prob.proj_Qplus(point)
        dist_Q = np.linalg.norm(point - point_proj)
        
        # Kiểm tra nằm trong vùng Reference
        is_dominated_by_ref = np.all(point < ref_point)
        
        if dist_Q < tol and is_dominated_by_ref:
            valid_points.append(point.tolist())
            
    if len(valid_points) < 2: return 0.0
    
    hv = HyperVolume(ref_point)
    return hv.compute(valid_points)

def generate_valid_params():
    """
    Sinh các tổ hợp tham số thỏa mãn điều kiện lý thuyết hội tụ:
    1. 0.5 < expo_lambda <= 1
    2. expo_alpha > 0
    3. expo_lambda + expo_alpha <= 1 (Để đảm bảo tổng hệ số tiến về 0 đúng tốc độ) - Tuỳ chọn chặt
       Hoặc điều kiện lỏng hơn: 0 < expo_beta, expo_gamma < expo_lambda
    """
    
    # Không gian tìm kiếm thô
    grid = {
        'expo_lambda': [0.55, 0.65],
        'expo_alpha':  [0.3, 0.45], 
        'expo_beta':   [0.3, 0.4],
        'expo_gamma':  [0.5],
        'init_params': [1.0, 2.0]
    }
    
    keys, values = zip(*grid.items())
    raw_combinations = [dict(zip(keys, v)) for v in itertools.product(*values)]
    
    valid_combinations = []
    for p in raw_combinations:
        # --- KIỂM TRA ĐIỀU KIỆN ---
        cond1 = 0.5 < p['expo_lambda'] <= 1.0
        cond2 = p['expo_lambda'] + p['expo_alpha'] <= 1
        cond3 = p['expo_beta'] < p['expo_lambda']
        cond4 = p['expo_gamma'] < p['expo_lambda']
        
        if cond1 and cond2 and cond3:
            valid_combinations.append(p)
            
    return valid_combinations

# %%
base_cfg = load_config()
base_cfg['phase2']['max_iter'] = 500 
base_cfg['phase2']['mu'] = 0.0001

# 1. Chạy Phase 1 (Tìm điểm khả thi ban đầu)
print("-> Đang tìm điểm Feasible (Phase 1)...")
x_feasible, _, _, _ = solve_CQ_feasible(
    prob.objective_func, prob.jacobian, prob.proj_C, prob.proj_Qplus,
    base_cfg['initialization']['x_init'],
    gamma=base_cfg['phase1']['gamma'] , max_iter=base_cfg['phase1']['max_iter']
)

print("-> Đang tìm các điểm cực trị để xác định Z* và Ref Point...")
z_vals = []
nadir_vals = []

for dim in range(2):
    # Tìm MIN
    x_min, _ = optim_Universal(prob, x_feasible, target_dim=dim, mode="min", max_iter=500, mu=0.001)
    val_min = prob.objective_func(x_min)[dim]
    z_vals.append(val_min)
    
    # Tìm MAX 
    x_max, _ = optim_Universal(prob, x_feasible, target_dim=dim, mode="max", max_iter=500, mu=0.001)
    val_max = prob.objective_func(x_max)[dim]
    nadir_vals.append(val_max)
    print(f"   Dim {dim}: Min={val_min:.4f}, Max={val_max:.4f}")
z_star = np.array(z_vals) - 0.05
ref_point = np.array(nadir_vals) + np.abs(np.array(nadir_vals)) * 0.1 + 0.5 
print(f"-> Z* (Ideal): {z_star}")
print(f"-> Ref Point (HV): {ref_point}")
# Out:
# -> Đang tìm điểm Feasible (Phase 1)...
# Khởi tạo: x0: [-10. -10.]
# Chiếu lên C được: x: [0. 0.]
# 100%|██████████| 500/500 [00:03<00:00, 125.95it/s]
# +-----+----------------------+---------+----------------------+----------------------+----------+----------+
# |  k  | x_new                | gamma_k | y                    | z_proj               |   e_x    |   e_f    |
# +-----+----------------------+---------+----------------------+----------------------+----------+----------+
# |  0  | [0., 0.]             | 0.5000  | [0., 1.]             | [0. , 0.6]           | 0.056569 | 0.400000 |
# |  10 | [0.110734, 0.110735] | 0.0454  | [0.00049 , 0.956197] | [0.00049, 0.6    ]   | 0.004477 | 0.356197 |
# |  20 | [0.133709, 0.133709] | 0.0238  | [0.000715, 0.947231] | [0.000715, 0.6     ] | 0.002275 | 0.347231 |
# |  30 | [0.147023, 0.147023] | 0.0161  | [0.000865, 0.942055] | [0.000865, 0.6     ] | 0.001514 | 0.342055 |
# |  40 | [0.15638, 0.15638]   | 0.0122  | [0.000978, 0.938426] | [0.000978, 0.6     ] | 0.001130 | 0.338426 |
# |  50 | [0.16358, 0.16358]   | 0.0098  | [0.00107 , 0.935638] | [0.00107, 0.6    ]   | 0.000900 | 0.335638 |
# |  60 | [0.169422, 0.169422] | 0.0082  | [0.001148, 0.933379] | [0.001148, 0.6     ] | 0.000746 | 0.333379 |
# |  70 | [0.174332, 0.174332] | 0.0070  | [0.001216, 0.931483] | [0.001216, 0.6     ] | 0.000637 | 0.331483 |
# |  80 | [0.178563, 0.178563] | 0.0062  | [0.001275, 0.92985 ] | [0.001275, 0.6     ] | 0.000555 | 0.329850 |
# |  90 | [0.182277, 0.182277] | 0.0055  | [0.001329, 0.928418] | [0.001329, 0.6     ] | 0.000492 | 0.328418 |
# | 100 | [0.185585, 0.185585] | 0.0049  | [0.001378, 0.927144] | [0.001378, 0.6     ] | 0.000441 | 0.327144 |
# | 110 | [0.188566, 0.188566] | 0.0045  | [0.001422, 0.925996] | [0.001422, 0.6     ] | 0.000399 | 0.325996 |
# | 120 | [0.191278, 0.191278] | 0.0041  | [0.001463, 0.924952] | [0.001463, 0.6     ] | 0.000365 | 0.324952 |
# | 130 | [0.193764, 0.193764] | 0.0038  | [0.001502, 0.923996] | [0.001502, 0.6     ] | 0.000336 | 0.323996 |
# | 140 | [0.196059, 0.196059] | 0.0035  | [0.001538, 0.923114] | [0.001538, 0.6     ] | 0.000311 | 0.323114 |
# | 150 | [0.19819, 0.19819]   | 0.0033  | [0.001571, 0.922295] | [0.001571, 0.6     ] | 0.000290 | 0.322295 |
# | 160 | [0.200177, 0.200178] | 0.0031  | [0.001603, 0.921532] | [0.001603, 0.6     ] | 0.000271 | 0.321532 |
# | 170 | [0.20204, 0.20204]   | 0.0029  | [0.001633, 0.920817] | [0.001633, 0.6     ] | 0.000254 | 0.320817 |
# | 180 | [0.203792, 0.203792] | 0.0028  | [0.001661, 0.920145] | [0.001661, 0.600001] | 0.000240 | 0.320144 |
# | 190 | [0.205445, 0.205445] | 0.0026  | [0.001688, 0.91951 ] | [0.001688, 0.6     ] | 0.000227 | 0.319510 |
# | 200 | [0.20701, 0.20701]   | 0.0025  | [0.001714, 0.91891 ] | [0.001714, 0.6     ] | 0.000215 | 0.318910 |
# | 210 | [0.208496, 0.208496] | 0.0024  | [0.001739, 0.918341] | [0.001739, 0.6     ] | 0.000204 | 0.318341 |
# | 220 | [0.209909, 0.209909] | 0.0023  | [0.001762, 0.917799] | [0.001762, 0.6     ] | 0.000195 | 0.317799 |
# | 230 | [0.211258, 0.211258] | 0.0022  | [0.001785, 0.917282] | [0.001785, 0.6     ] | 0.000186 | 0.317282 |
# | 240 | [0.212547, 0.212547] | 0.0021  | [0.001807, 0.916788] | [0.001807, 0.6     ] | 0.000178 | 0.316788 |
# | 250 | [0.213781, 0.213781] | 0.0020  | [0.001828, 0.916316] | [0.001828, 0.600001] | 0.000171 | 0.316315 |
# | 260 | [0.214964, 0.214964] | 0.0019  | [0.001848, 0.915863] | [0.001848, 0.6     ] | 0.000164 | 0.315862 |
# | 270 | [0.216101, 0.216102] | 0.0018  | [0.001868, 0.915427] | [0.001868, 0.6     ] | 0.000157 | 0.315427 |
# | 280 | [0.217196, 0.217196] | 0.0018  | [0.001887, 0.915009] | [0.001887, 0.6     ] | 0.000152 | 0.315009 |
# | 290 | [0.21825, 0.21825]   | 0.0017  | [0.001905, 0.914605] | [0.001905, 0.6     ] | 0.000146 | 0.314605 |
# | 300 | [0.219267, 0.219267] | 0.0017  | [0.001923, 0.914216] | [0.001923, 0.6     ] | 0.000141 | 0.314216 |
# | 310 | [0.220249, 0.220249] | 0.0016  | [0.00194 , 0.913841] | [0.00194, 0.6    ]   | 0.000136 | 0.313841 |
# | 320 | [0.221199, 0.221199] | 0.0016  | [0.001957, 0.913478] | [0.001957, 0.6     ] | 0.000132 | 0.313478 |
# | 330 | [0.222118, 0.222118] | 0.0015  | [0.001973, 0.913126] | [0.001973, 0.6     ] | 0.000128 | 0.313126 |
# | 340 | [0.223009, 0.223009] | 0.0015  | [0.001989, 0.912786] | [0.001989, 0.6     ] | 0.000124 | 0.312785 |
# | 350 | [0.223873, 0.223873] | 0.0014  | [0.002005, 0.912455] | [0.002005, 0.6     ] | 0.000120 | 0.312455 |
# | 360 | [0.224712, 0.224712] | 0.0014  | [0.00202 , 0.912135] | [0.00202, 0.6    ]   | 0.000117 | 0.312135 |
# | 370 | [0.225527, 0.225527] | 0.0013  | [0.002034, 0.911824] | [0.002034, 0.6     ] | 0.000113 | 0.311824 |
# | 380 | [0.226319, 0.226319] | 0.0013  | [0.002049, 0.911521] | [0.002049, 0.6     ] | 0.000110 | 0.311521 |
# | 390 | [0.227089, 0.227089] | 0.0013  | [0.002063, 0.911227] | [0.002063, 0.6     ] | 0.000107 | 0.311227 |
# | 400 | [0.22784, 0.22784]   | 0.0012  | [0.002076, 0.910941] | [0.002076, 0.6     ] | 0.000105 | 0.310940 |
# | 410 | [0.228571, 0.228571] | 0.0012  | [0.00209 , 0.910661] | [0.00209, 0.6    ]   | 0.000102 | 0.310661 |
# | 420 | [0.229284, 0.229284] | 0.0012  | [0.002103, 0.910389] | [0.002103, 0.6     ] | 0.000099 | 0.310389 |
# | 430 | [0.229979, 0.229979] | 0.0012  | [0.002116, 0.910124] | [0.002116, 0.6     ] | 0.000097 | 0.310124 |
# | 440 | [0.230658, 0.230658] | 0.0011  | [0.002128, 0.909865] | [0.002128, 0.6     ] | 0.000095 | 0.309865 |
# | 450 | [0.23132, 0.23132]   | 0.0011  | [0.00214 , 0.909612] | [0.00214, 0.6    ]   | 0.000093 | 0.309612 |
# | 460 | [0.231968, 0.231968] | 0.0011  | [0.002152, 0.909365] | [0.002152, 0.6     ] | 0.000090 | 0.309365 |
# | 470 | [0.232601, 0.232601] | 0.0011  | [0.002164, 0.909124] | [0.002164, 0.600001] | 0.000088 | 0.309123 |
# | 480 | [0.23322, 0.23322]   | 0.0010  | [0.002176, 0.908888] | [0.002176, 0.6     ] | 0.000087 | 0.308888 |
# | 490 | [0.233826, 0.233826] | 0.0010  | [0.002187, 0.908657] | [0.002187, 0.6     ] | 0.000085 | 0.308656 |
# +-----+----------------------+---------+----------------------+----------------------+----------+----------+
# -> Đang tìm các điểm cực trị để xác định Z* và Ref Point...
#    Dim 0: Min=0.0374, Max=0.8115
#    Dim 1: Min=0.0374, Max=0.8115
# -> Z* (Ideal): [-0.0126 -0.0126]
# -> Ref Point (HV): [1.3927 1.3927]

# %%
# ==============================================================================
# 3. GRID SEARCH (PHASE 2 - ALGORITHM 1-A)
# ==============================================================================
# Lấy tập params hợp lệ
param_combinations = generate_valid_params()
print(f"\n=== BẮT ĐẦU GRID SEARCH TRÊN {len(param_combinations)} CẤU HÌNH HỢP LỆ ===")

# Dùng tập rays thưa để test nhanh (Ví dụ 10 tia)
test_rays_subset = base_cfg['data']['test_ray']

results_log = []
best_hv = -1.0
best_params = None

for idx, params in enumerate(param_combinations):
    # In tiến độ gọn
    if idx % 5 == 0: print(f"Processing {idx}/{len(param_combinations)}...")
        
    pareto_f_temp = []
    
    # Chạy Alg 1-A với cấu hình hiện tại
    for r in test_rays_subset:
        x_final, _ = optim_Scalarization(
            prob=prob,
            x_feasible=x_feasible,  
            r=r, 
            z_star=z_star,
            # Các tham số tĩnh
            max_iter=base_cfg['phase2']['max_iter'],
            mu=base_cfg['phase2']['mu'],
            verbose=False,
            # --- CÁC THAM SỐ ĐANG TỐI ƯU ---
            init_params=params['init_params'],
            expo_alpha=params['expo_alpha'],
            expo_lambda=params['expo_lambda'],
            expo_beta=params['expo_beta'],
            expo_gamma=params['expo_gamma'],
        )
        pareto_f_temp.append(prob.objective_func(x_final))
    
    # Tính HV
    hv_score = calculate_hv_score(np.array(pareto_f_temp), prob, ref_point)
    
    # Lưu log
    log_entry = params.copy()
    log_entry['HV'] = hv_score
    results_log.append(log_entry)
    
    # Cập nhật Best
    if hv_score > best_hv:
        best_hv = hv_score
        best_params = params
        print(f"   [New Best] Config {idx}: HV = {best_hv:.6f}")
# Out:
# === BẮT ĐẦU GRID SEARCH TRÊN 12 CẤU HÌNH HỢP LỆ ===
# Processing 0/12...
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.002075
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.001689
#    [New Best] Config 0: HV = 1.674278
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000123
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000124
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.004762
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.007739
#    [New Best] Config 1: HV = 1.677606
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.001721
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.001687
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000190
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000124
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.016211
# Params: alpha=k^-0.3, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.009874
#    [New Best] Config 3: HV = 1.678159
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.004263
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.003964
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000021
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000001
# Processing 5/12...
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000043
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000006
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000003
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.004356
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.005002
#    [New Best] Config 6: HV = 1.694880
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000008
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000028
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.005529
# Params: alpha=k^-0.45, lambda=k^-0.55, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.010686
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.003660
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000963
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000054
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.001515
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.005095
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000309
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.3, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.001709
# Processing 10/12...
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.003618
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000374
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.004112
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.005085
#    [New Best] Config 10: HV = 1.696038
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000126
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000008
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000

# %%
# np.save(f"test/{case}/pf_dynamic_true.npy", results_dynamic["pareto_f"])

# %%
pareto_f_temp = []
for r in test_rays_subset:
        x_final, _ = optim_Scalarization(
            prob=prob,
            x_feasible=x_feasible,  
            r=r, 
            z_star=z_star,
            # Các tham số tĩnh
            max_iter=base_cfg['phase2']['max_iter'],
            mu=base_cfg['phase2']['mu'],
            verbose=False,
            # --- CÁC THAM SỐ ĐANG TỐI ƯU ---
            init_params=1.0,
            expo_alpha=0.3,
            expo_lambda=0.65,
            expo_beta=0.4,
            expo_gamma=0.5,
        )
        pareto_f_temp.append(prob.objective_func(x_final))
    
    # Tính HV
hv_score = calculate_hv_score(np.array(pareto_f_temp), prob, ref_point)
hv_score
# Out:
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.003579
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000375
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000004
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.004721
# Params: alpha=k^-0.3, lambda=k^-0.65, beta=k^0.4, gamma=k^0.5
# -> Reach max_iter. Final Gap C: 0.000000, Gap Q: 0.005054
# np.float64(1.6962153202734984)

# %%
calculate_hv_score(results_dynamic["pareto_f"], prob, ref_point)
# Out:
# np.float64(1.669164626830761)

# %%
visualize_pareto_front(
    pf_targets=np.array(pareto_f_temp), 
    pf_cloud=pf_cloud,   
#     pf_targets=results["pareto_f"],
    title="Objective Space Visualization",
    figsize=(12, 8)
)
