# %%
from project import Projection
from Problem import Problem
from Phase1 import solve_CQ_feasible
from Phase2_1_obj import optim_Universal
from Phase2_dynamic import optim_Scalarization
from main_dynamic import load_config
from utils import visualize_pareto_front, generate_pareto_grid

# %%
import autograd.numpy as np
from scipy.optimize import Bounds
import matplotlib.pyplot as plt
import pandas as pd
import math
import itertools
from tqdm import tqdm

# %%
case = "_Ex_7_2"

# %% [markdown]
# # Prob

# %% [markdown]
# * for exact

# %%
def f(x):
    """Hàm mục tiêu F: R^2 -> R^2"""
    return np.array([
        (x[0]**2 + x[1]**2) / 50.0,
        ((x[0] - 5)**2 + (x[1] - 5)**2) / 50.0
    ])

def jacobian_f(x):
    """
    Ma trận Jacobian của F(x) kích thước (m x n)
    m = số hàm mục tiêu (2), n = số biến (2)
    """
    # df1/dx0 = 2*x0/50, df1/dx1 = 2*x1/50
    # df2/dx0 = 2*(x0-5)/50, df2/dx1 = 2*(x1-5)/50
    return np.array([
        [x[0]/25.0, x[1]/25.0],
        [(x[0] - 5)/25.0, (x[1] - 5)/25.0]
    ])

# --- Các ràng buộc tập X (Hộp [0, 5]x[0, 5]) ---
def constraints_X(x):
    # Trả về mảng các giá trị >= 0
    return np.array([
        x[0],           # x0 >= 0
        5.0 - x[0],     # x0 <= 5
        x[1],           # x1 >= 0
        5.0 - x[1]      # x1 <= 5
    ])

# --- Các ràng buộc tập Q ---
def q1(y): return 0.2**2 - (y[0] - 0.4)**2 - (y[1] - 0.4)**2
def q_plus(y):
    center = 0.4
    radius_sq = 0.2**2  
    dx = np.maximum(0, y[0] - center)
    dy = np.maximum(0, y[1] - center)
    return radius_sq - (dx**2 + dy**2)

dim_x = 2
dim_y = 2

def S_weighted_chebyshev(x, r, z):
    vals = f(x)
    weighted_diffs = r * np.abs(vals - z)
    return np.max(weighted_diffs)

def get_subgradient(x, r, z):
    vals = f(x)
    diffs = vals - z
    weighted_abs_diffs = r * np.abs(diffs)
    
    # Tìm chỉ số k mà tại đó giá trị đạt Max
    k = np.argmax(weighted_abs_diffs)
    
    J = jacobian_f(x)
    gradient_fk = J[k] # Hàng thứ k của Jacobian (là một vector n-chiều)
    
    sign = 1.0 if diffs[k] >= 0 else -1.0
    grad = r[k] * sign * gradient_fk
    return grad

# %% [markdown]
# * for dynamic

# %%
#--------------- C --------------------#
bounds_x = Bounds([0,0],[5, 5])
#--------------- Q --------------------#
def q1(y):    return 0.2**2 - (y[0] - 0.4)**2 - (y[1] - 0.4)**2
# Hàm dùng cho Projection 
cons_C = ()
cons_Q = ({'type': 'ineq', 'fun' : q1,},)
cons_Qplus = ({'type': 'ineq', 'fun': q_plus},)
# Setup Projections
proj_C_handler = Projection(cons=cons_C, bounds=bounds_x, dim=dim_x, proj_type='euclid')
proj_Q_handler = Projection(cons=cons_Q, bounds=None, dim=dim_y, proj_type='qplus')
# Setup Problem
prob = Problem(
    f=[f], jac_f=[jacobian_f], C=[], Q=[],
    dim_x=dim_x, dim_y=dim_y,
    proj_C=proj_C_handler.project,
    proj_Qplus=proj_Q_handler.project
)

# %% [markdown]
# * config

# %%
base_cfg = load_config()
test_rays = base_cfg['data']['test_ray']

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Cloud

# %%
def generate_pareto_grid(f_func, c_funcs, q_plus_func, resolution=400):
    """
    Sinh dữ liệu Pareto cho bài toán 2D bằng cách quét lưới tọa độ.
    f_func: Hàm mục tiêu f(x)
    c_funcs: Danh sách các hàm ràng buộc c(x) >= 0 (miền C)
    q_plus_func: Hàm ràng buộc q_plus(y) >= 0 (miền Q+)
    """
    print(f"--- Đang quét lưới {resolution}x{resolution} điểm ---")
    
    # 1. Xác định phạm vi quét dựa trên các ràng buộc hình tròn c1, c2

    x0_range = np.linspace(0, 5, resolution)
    x1_range = np.linspace(0, 5, resolution)
    X0, X1 = np.meshgrid(x0_range, x1_range)
    
    # Làm phẳng để tính toán vector
    points_X = np.vstack([X0.ravel(), X1.ravel()]).T
    
    # 2. Kiểm tra ràng buộc miền C: c1(x) >= 0 và c2(x) >= 0
    # (Sử dụng các hàm c1, c2 đã định nghĩa của bạn)
    mask_C = np.ones(len(points_X), dtype=bool)
    for c_func in c_funcs:
        mask_C &= (c_func(points_X.T) >= 0)
    
    feasible_X = points_X[mask_C]
    print(f"-> Tìm thấy {len(feasible_X)} điểm thỏa mãn miền C.")
    
    if len(feasible_X) == 0:
        return None, None

    # 3. Tính giá trị mục tiêu f(x) và kiểm tra miền Q+
    f_vals = np.array([f_func(x) for x in feasible_X])  # shape (N, 2)
    
    # Kiểm tra q_plus(f(x)) >= 0
    # Lưu ý: Hàm q_plus của bạn nhận 1 vector y, ta cần áp dụng cho toàn bộ f_vals
    mask_Qplus = np.array([q_plus_func(y) >= 0 for y in f_vals])
    
    pf_cloud_data = f_vals[mask_Qplus]
    print(f"-> Lọc còn {len(pf_cloud_data)} điểm thỏa mãn Q+ (Cloud).")

    if len(pf_cloud_data) == 0:
        return None, None

    # 4. Lọc Pareto Front từ Cloud (Tìm các điểm không bị trội)
    # Sắp xếp theo f1 tăng dần
    sorted_indices = np.argsort(pf_cloud_data[:, 0])
    y_sorted = pf_cloud_data[sorted_indices]
    
    pareto_list = []
    pareto_list.append(y_sorted[0])
    current_min_f2 = y_sorted[0][1]
    
    for i in range(1, len(y_sorted)):
        if y_sorted[i][1] < current_min_f2:
            pareto_list.append(y_sorted[i])
            current_min_f2 = y_sorted[i][1]
    
    pf_targets_data = np.array(pareto_list)
    print(f"-> Kết quả: {len(pf_targets_data)} điểm Pareto.")
    
    return pf_cloud_data, pf_targets_data

# %%
def non_c(x):
    return 1
pf_cloud, pf_targets = generate_pareto_grid(
    f_func=f, 
    c_funcs=[non_c], 
    q_plus_func=q_plus, 
    resolution=500
)
# Out:
# --- Đang quét lưới 500x500 điểm ---
# -> Tìm thấy 250000 điểm thỏa mãn miền C.
# -> Lọc còn 192206 điểm thỏa mãn Q+ (Cloud).
# -> Kết quả: 549 điểm Pareto.

# %% [markdown]
# # Exact

# %%
from scipy.optimize import minimize
def project_step(x_temp, y_temp, dim_x, dim_y):
    """
    Chiếu điểm (x, y) vào tập:
    { (x, y) | x \in X, y \in Q, f(x) <= y }
    """
    z_start = np.concatenate([x_temp, y_temp])
    
    def proj_obj(z): 
        return 0.5 * np.sum((z - z_start)**2)
    
    def proj_jac(z): 
        return z - z_start

    # Danh sách ràng buộc: scipy yêu cầu dạng 'ineq' (tức là >= 0)
    cons = [
        # Ràng buộc x \in X
        {'type': 'ineq', 'fun': lambda z: constraints_X(z[:dim_x])},
        # Ràng buộc y \in Q
        {'type': 'ineq', 'fun': lambda z: q1(z[dim_x:])},
        # Ràng buộc f(x) <= y  <=>  y - f(x) >= 0
        {'type': 'ineq', 'fun': lambda z: z[dim_x:] - f(z[:dim_x])}
    ]

    res = minimize(
        fun=proj_obj, x0=z_start, jac=proj_jac,
        constraints=cons, method='SLSQP',
        options={'disp': False}
    )
    
    if not res.success:
        return x_temp, y_temp
    return res.x[:dim_x], res.x[dim_x:]

# ==========================================
# 3. THUẬT TOÁN PROJECTED SUBGRADIENT DESCENT
# ==========================================

def solve_weighted_chebyshev(r_pref, z_ref, x_init, y_init, dim_x=1, dim_y=2, learning_rate=0.01, max_iters=5000, tol=1e-5):
    
    # Khởi tạo điểm bắt đầu
    x = x_init    
    y = y_init
    
    # Biến lưu giá trị hàm mục tiêu của bước trước (Khởi tạo là vô cùng)
    prev_obj_val = float('inf')
    converge = False
    
    print(f"Bắt đầu giải với r={r_pref}, z*={z_ref}")
    print(f"{'Iter':<5} | {'x':<10} | {'y vector':<15} | {'Objective':<10} | {'Active Idx'}")
    for k in range(max_iters):
        # --- BƯỚC 1: Tính Subgradient ---
        grad_x = get_subgradient(x, r_pref, z_ref)
        
        # --- BƯỚC 2: Cập nhật biến x ---
        x_temp = x - learning_rate * grad_x
        y_temp = y 
        
        # --- BƯỚC 3: Phép chiếu (Projection) ---
        x_next, y_next = project_step(x_temp, y_temp, dim_x, dim_y)
        
        # --- Tính giá trị hàm mục tiêu hiện tại ---
        obj_val = S_weighted_chebyshev(x_next, r_pref, z_ref)
        
        # --- Logging ---
        diffs = r_pref * np.abs(f(x_next) - z_ref)
        active_idx = np.argmax(diffs)
        
        if k % 2000 == 0: # In thường xuyên hơn một chút để dễ quan sát
            print(f"{k:<5} | {x_next[0]:.4f}     | [{y_next[0]:.2f}, {y_next[1]:.2f}] | {obj_val:.6f}     | f_{active_idx+1}")

        # --- BƯỚC 4: Kiểm tra điều kiện dừng (MỚI) ---
        # So sánh độ sụt giảm của hàm mục tiêu
        loss_change = abs(prev_obj_val - obj_val)
        
        if loss_change < tol:
            print(f"\n--> Hội tụ theo hàm mục tiêu tại bước {k}!")
            converge = True
            break
            
        # Cập nhật giá trị cũ cho vòng lặp sau
        prev_obj_val = obj_val
        x = x_next
        y = y_next

    return x, y, converge
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\i'
# <>:5: SyntaxWarning: invalid escape sequence '\i'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16908\184801281.py:5: SyntaxWarning: invalid escape sequence '\i'
#   { (x, y) | x \in X, y \in Q, f(x) <= y }

# %% [markdown]
# ## z_star

# %%
# 1. Chạy Phase 1 (Tìm điểm khả thi ban đầu)
print("-> Đang tìm điểm Feasible (Phase 1)...")
x_feasible, _, _, _ = solve_CQ_feasible(
    prob.objective_func, prob.jacobian, prob.proj_C, prob.proj_Qplus,
    base_cfg['initialization']['x_init'],
    gamma=base_cfg['phase1']['gamma'] , max_iter=base_cfg['phase1']['max_iter']
)

print("-> Đang tìm các điểm cực trị để xác định Z* và Ref Point...")
z_vals = []
nadir_vals = []

for dim in range(2):
    # Tìm MIN
    x_min, _ = optim_Universal(prob, x_feasible, target_dim=dim, mode="min", max_iter=500, mu=0.001)
    val_min = prob.objective_func(x_min)[dim]
    z_vals.append(val_min)
    
    # Tìm MAX 
    x_max, _ = optim_Universal(prob, x_feasible, target_dim=dim, mode="max", max_iter=500, mu=0.001)
    val_max = prob.objective_func(x_max)[dim]
    nadir_vals.append(val_max)
    print(f"   Dim {dim}: Min={val_min:.4f}, Max={val_max:.4f}")
z_star = np.array(z_vals)
ref_point = np.array(nadir_vals) + np.abs(np.array(nadir_vals)) * 0.1 + 0.5 
print(f"-> Z* (Ideal): {z_star}")
print(f"-> Ref Point (HV): {ref_point}")
# Out:
# -> Đang tìm điểm Feasible (Phase 1)...
# Khởi tạo: x0: [2.5 2.5]
# Chiếu lên C được: x: [2.5 2.5]
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Hội tụ tại vòng lặp 0
# +---+------------+---------+--------------+--------------+----------+----------+
# | k | x_new      | gamma_k | y            | z_proj       |   e_x    |   e_f    |
# +---+------------+---------+--------------+--------------+----------+----------+
# | 0 | [2.5, 2.5] | 12.0000 | [0.25, 0.25] | [0.25, 0.25] | 0.000000 | 0.000000 |
# +---+------------+---------+--------------+--------------+----------+----------+
# -> Đang tìm các điểm cực trị để xác định Z* và Ref Point...
#    Dim 0: Min=0.0374, Max=0.8115
#    Dim 1: Min=0.0374, Max=0.8115
# -> Z* (Ideal): [0.0374 0.0374]
# -> Ref Point (HV): [1.3927 1.3927]

# %% [markdown]
# ## Exact loop

# %%
pareto_f_temp = []
learning_rate = 0.009
max_iters = 20000
x_init = np.array([2.5, 2.5])
y_init = np.array([1.0, 1.5])
converge = 0
for r in test_rays:
    x, y, conv = solve_weighted_chebyshev(
        r_pref=r, z_ref=z_star, 
        dim_x=dim_x, dim_y=dim_y,
        x_init=x_init, y_init=y_init,
        learning_rate=learning_rate,
        max_iters=max_iters)
    if conv:
        converge += 1
    pareto_f_temp.append(f(x))
print(f"Converge rate = {100*converge/len(test_rays)}%")
# Out:
# Bắt đầu giải với r=[1. 0.], z*=[0.0374 0.0374]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.4991     | [0.50, 0.58] | 0.212440     | f_1
# 2000  | 1.2163     | [0.50, 0.58] | 0.021794     | f_1
#
# --> Hội tụ theo hàm mục tiêu tại bước 2297!
# Bắt đầu giải với r=[0.9966 0.0826], z*=[0.0374 0.0374]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.4991     | [0.50, 0.58] | 0.211715     | f_1
#
# --> Hội tụ theo hàm mục tiêu tại bước 1633!
# Bắt đầu giải với r=[0.9864 0.1646], z*=[0.0374 0.0374]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.4991     | [0.50, 0.58] | 0.209545     | f_1
#
# --> Hội tụ theo hàm mục tiêu tại bước 1198!
# Bắt đầu giải với r=[0.9694 0.2455], z*=[0.0374 0.0374]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.4991     | [0.50, 0.58] | 0.205945     | f_1
#
# --> Hội tụ theo hàm mục tiêu tại bước 926!
# Bắt đầu giải với r=[0.9458 0.3247], z*=[0.0374 0.0374]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.4991     | [0.50, 0.58] | 0.200939     | f_1
#
# --> Hội tụ theo hàm mục tiêu tại bước 728!
# Bắt đầu giải với r=[0.9158 0.4017], z*=[0.0374 0.0374]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.4992     | [0.50, 0.58] | 0.194561     | f_1
#
# --> Hội tụ theo hàm mục tiêu tại bước 579!
# Bắt đầu giải với r=[0.8795 0.4759], z*=[0.0374 0.0374]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.4992     | [0.50, 0.58] | 0.186855     | f_1
#
# --> Hội tụ theo hàm mục tiêu tại bước 436!
# Bắt đầu giải với r=[0.8372 0.5469], z*=[0.0374 0.0374]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.4992     | [0.50, 0.58] | 0.177872     | f_1
#
# --> Hội tụ theo hàm mục tiêu tại bước 325!
# Bắt đầu giải với r=[0.7891 0.6142], z*=[0.0374 0.0374]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.4993     | [0.50, 0.58] | 0.167675     | f_1
#
# --> Hội tụ theo hàm mục tiêu tại bước 204!
# Bắt đầu giải với r=[0.7357 0.6773], z*=[0.0374 0.0374]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.4993     | [0.50, 0.58] | 0.156332     | f_1
#
# --> Hội tụ theo hàm mục tiêu tại bước 87!
# Bắt đầu giải với r=[0.6773 0.7357], z*=[0.0374 0.0374]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.5007     | [0.50, 0.58] | 0.156332     | f_2
#
# --> Hội tụ theo hàm mục tiêu tại bước 87!
# Bắt đầu giải với r=[0.6142 0.7891], z*=[0.0374 0.0374]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.5007     | [0.50, 0.58] | 0.167675     | f_2
#
# --> Hội tụ theo hàm mục tiêu tại bước 204!
# Bắt đầu giải với r=[0.5469 0.8372], z*=[0.0374 0.0374]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.5008     | [0.50, 0.58] | 0.177872     | f_2
#
# --> Hội tụ theo hàm mục tiêu tại bước 325!
# Bắt đầu giải với r=[0.4759 0.8795], z*=[0.0374 0.0374]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.5008     | [0.50, 0.58] | 0.186855     | f_2
#
# --> Hội tụ theo hàm mục tiêu tại bước 436!
# Bắt đầu giải với r=[0.4017 0.9158], z*=[0.0374 0.0374]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.5008     | [0.50, 0.58] | 0.194561     | f_2
#
# --> Hội tụ theo hàm mục tiêu tại bước 579!
# Bắt đầu giải với r=[0.3247 0.9458], z*=[0.0374 0.0374]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.5009     | [0.50, 0.58] | 0.200939     | f_2
#
# --> Hội tụ theo hàm mục tiêu tại bước 728!
# Bắt đầu giải với r=[0.2455 0.9694], z*=[0.0374 0.0374]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.5009     | [0.50, 0.58] | 0.205945     | f_2
#
# --> Hội tụ theo hàm mục tiêu tại bước 926!
# Bắt đầu giải với r=[0.1646 0.9864], z*=[0.0374 0.0374]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.5009     | [0.50, 0.58] | 0.209545     | f_2
#
# --> Hội tụ theo hàm mục tiêu tại bước 1198!
# Bắt đầu giải với r=[0.0826 0.9966], z*=[0.0374 0.0374]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.5009     | [0.50, 0.58] | 0.211715     | f_2
#
# --> Hội tụ theo hàm mục tiêu tại bước 1643!
# Bắt đầu giải với r=[0. 1.], z*=[0.0374 0.0374]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.5009     | [0.50, 0.58] | 0.212440     | f_2
# 2000  | 3.7653     | [0.57, 0.51] | 0.023603     | f_2
#
# --> Hội tụ theo hàm mục tiêu tại bước 2350!
# Converge rate = 100.0%

# %%
visualize_pareto_front(
    pf_targets=np.array(pareto_f_temp), 
    pf_cloud=pf_cloud,   
    title=f"z*: {z_star}, lr: {learning_rate}, max_iters: {max_iters}",
    figsize=(12, 8)
)

# %%
np.save(f"test/{case}/pf_true.npy", np.array(pareto_f_temp))

# %% [markdown]
# ` exact OK (chọn x_init nên trung tâm của miền)`

# %% [markdown]
# # Optim

# %%
from functions_hv_python3 import HyperVolume

def get_metrics(pareto_f, pf_true, prob, ref_point):
    """Tính toán đồng thời MED và HV"""
    pareto_f = np.array(pareto_f)
    
    # --- 1. Tính MED (Mean Error Distance) ---
    # Vì dùng chung tập test_ray nên ta tính khoảng cách cặp 1-1
    med = np.mean(np.linalg.norm(pareto_f - pf_true, axis=1))
    
    # --- 2. Tính HV (HyperVolume) ---
    valid_points = []
    tol = 1e-3
    for point in pareto_f:
        point_proj = prob.proj_Qplus(point)
        dist_Q = np.linalg.norm(point - point_proj)
        is_dominated_by_ref = np.all(point < ref_point)
        
        if dist_Q < tol and is_dominated_by_ref:
            valid_points.append(point.tolist())
            
    hv = 0.0
    if len(valid_points) >= 2:
        hv_obj = HyperVolume(ref_point)
        hv = hv_obj.compute(valid_points)
        
    return med, hv

def generate_valid_params():
    """
    Sinh các tổ hợp tham số thỏa mãn điều kiện lý thuyết hội tụ:
    1. 0.5 < expo_lambda <= 1
    2. expo_alpha > 0
    3. expo_lambda + expo_alpha <= 1 (Để đảm bảo tổng hệ số tiến về 0 đúng tốc độ) - Tuỳ chọn chặt
       Hoặc điều kiện lỏng hơn: 0 < expo_beta, expo_gamma < expo_lambda
    """
    
    # Không gian tìm kiếm thô
    grid = {
        'expo_lambda': [0.51, 0.65, 0.8],
        'expo_alpha':  [0.1, 0.25, 0.4], 
        'expo_beta':   [0.3, 0.5],
        'expo_gamma':  [0.3, 0.5],
        'init_params': [1.0, 2.0],
        'mu': [0.0001, 0.01],
        'max_iter' : [1000]
    }
    
    keys, values = zip(*grid.items())
    raw_combinations = [dict(zip(keys, v)) for v in itertools.product(*values)]
    
    valid_combinations = []
    for p in raw_combinations:
        # --- KIỂM TRA ĐIỀU KIỆN ---
        cond1 = 0.5 < p['expo_lambda'] <= 1.0
        cond2 = p['expo_lambda'] + p['expo_alpha'] <= 1
        cond3 = p['expo_beta'] < p['expo_lambda']
        cond4 = p['expo_gamma'] < p['expo_lambda']
        
        if cond1 and cond2 and cond3:
            valid_combinations.append(p)
            
    return valid_combinations

# %%
CHOSEN_INDICATOR = "MED"  
pf_true = np.load(f"test/{case}/pf_true.npy")

# %%
param_combinations = generate_valid_params()
results_log = []

print(f"=== GRID SEARCH: ƯU TIÊN {CHOSEN_INDICATOR} ===")
print(f"Số lượng cấu hình: {len(param_combinations)} | Số tia: {len(test_rays)}")

for idx, params in tqdm(enumerate(param_combinations)):
    pareto_f_temp = []
    
    # Chạy Algorithm 1-A cho từng tia với bộ params hiện tại
    for r in test_rays:
        x_final, _ = optim_Scalarization(
            prob=prob,
            x_feasible=x_feasible,  
            r=r, 
            z_star=z_star,
            verbose=False,
            **params 
        )
        pareto_f_temp.append(prob.objective_func(x_final))
    
    # Tính toán kết quả
    med, hv = get_metrics(pareto_f_temp, pf_true, prob, ref_point)
    
    log_entry = {
        'params': params,
        'MED': med,
        'HV': hv,
        'id': idx
    }
    results_log.append(log_entry)
    
    print(f"[{idx:02d}] MED: {med:.6e} | HV: {hv:.6f}")
# Out:
# === GRID SEARCH: ƯU TIÊN MED ===
# Số lượng cấu hình: 96 | Số tia: 20
# 0it [00:00, ?it/s]
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.001774, Gap C: 0.000000, Gap Q: 0.023674
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.000498, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.002709, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.001312, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.003098, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.000630, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.002252, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.002496, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.003134, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.003031, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.002890, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.002712, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.002496, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.003214, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.000630, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.003098, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.001312, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.000928, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.002332, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# 1it [01:44, 104.74s/it]
# !! Max_iter. Delta: 0.001774, Gap C: 0.000000, Gap Q: 0.023543
# [00] MED: 4.125442e-03 | HV: 1.654299
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.000002, Gap C: 0.000000, Gap Q: 0.017222
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# -> Thuật toán hội tụ sớm tại k=279.
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.002709, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.001312, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.003098, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.000630, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.003214, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.003193, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.003134, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.003031, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.003031, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.002712, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.002496, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.003214, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.000630, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.001659, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.001312, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.002709, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# -> Thuật toán hội tụ sớm tại k=489.
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# 2it [03:23, 101.25s/it]
# !! Max_iter. Delta: 0.000002, Gap C: 0.000000, Gap Q: 0.017223
# [01] MED: 4.700831e-03 | HV: 1.656981
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.003514, Gap C: 0.000000, Gap Q: 0.030126
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.004702, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.003183, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.002629, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.003325, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.006394, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.006453, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.006415, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.006289, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.006088, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.005803, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.006289, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.006415, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.004516, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.003953, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.006225, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.002629, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.003183, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.004702, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# 3it [05:08, 102.96s/it]
# !! Max_iter. Delta: 0.003520, Gap C: 0.000000, Gap Q: 0.029511
# [02] MED: 4.125653e-03 | HV: 1.646715
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.003539, Gap C: 0.000000, Gap Q: 0.014554
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.004702, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.003183, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.002629, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.003325, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.003953, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.004516, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.005011, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.005439, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.005803, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.006088, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.006289, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.006415, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.004516, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.003953, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.003325, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.002629, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.003183, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.004702, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# 4it [06:54, 104.18s/it]
# !! Max_iter. Delta: 0.003539, Gap C: 0.000000, Gap Q: 0.014563
# [03] MED: 5.268724e-03 | HV: 1.646715
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.001842, Gap C: 0.000000, Gap Q: 0.010789
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.000498, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.000928, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.001312, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.003098, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.000630, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.003214, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.003193, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.003134, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.003031, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.003031, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.003134, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.002496, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.003214, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.000630, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.003098, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.001312, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.000928, Gap C: 0.000000, Gap Q: 0.000001
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.002332, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# 5it [08:41, 105.00s/it]
# !! Max_iter. Delta: 0.001857, Gap C: 0.000000, Gap Q: 0.007964
# [04] MED: 2.659955e-03 | HV: 1.654236
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.001852, Gap C: 0.000000, Gap Q: 0.002469
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# -> Thuật toán hội tụ sớm tại k=391.
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.000928, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.002947, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.003098, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.000630, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.002252, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.003193, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.002712, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.002890, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.002890, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.002712, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.002496, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.003214, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.000630, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.003098, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.001312, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.000928, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# -> Thuật toán hội tụ sớm tại k=391.
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# 6it [10:21, 103.40s/it]
# !! Max_iter. Delta: 0.001849, Gap C: 0.000000, Gap Q: 0.002970
# [05] MED: 3.426564e-03 | HV: 1.653573
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.003678, Gap C: 0.000000, Gap Q: 0.001559
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.004702, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.003183, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.002629, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.006225, Gap C: 0.000000, Gap Q: 0.000059
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.006394, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.006453, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.005011, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.005439, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.006088, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.005803, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.005439, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.005011, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.004516, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.003953, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.006225, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.002629, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.003183, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.004702, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# 7it [12:06, 104.07s/it]
# !! Max_iter. Delta: 0.003753, Gap C: 0.000000, Gap Q: 0.000000
# [06] MED: 3.547794e-03 | HV: 1.646715
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.003720, Gap C: 0.000000, Gap Q: 0.010679
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.004702, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.003183, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.002629, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.006225, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.006394, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.006453, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.005011, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.005439, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.005803, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.005803, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.005439, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.005011, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.004516, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.003953, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.006225, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.002629, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.003183, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# !! Max_iter. Delta: 0.004702, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.3, gamma=k^0.5
# 8it [13:52, 104.47s/it]
# !! Max_iter. Delta: 0.003667, Gap C: 0.000000, Gap Q: 0.015672
# [07] MED: 2.466664e-03 | HV: 1.671106
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.001776, Gap C: 0.000000, Gap Q: 0.023278
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000498, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000928, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.002947, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.001659, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000630, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.003214, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.003193, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.002712, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.002890, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.002890, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.002712, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.002496, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.002252, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000630, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.003098, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.001312, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000928, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000498, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# 9it [15:36, 104.35s/it]
# !! Max_iter. Delta: 0.001757, Gap C: 0.000000, Gap Q: 0.023187
# [08] MED: 4.093331e-03 | HV: 1.654270
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000002, Gap C: 0.000000, Gap Q: 0.017223
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# -> Thuật toán hội tụ sớm tại k=391.
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.002709, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.001312, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.003098, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000630, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.002252, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.003193, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.002712, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.003031, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.003031, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.003134, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.002496, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.003214, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000630, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.001659, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.001312, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000928, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# -> Thuật toán hội tụ sớm tại k=391.
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# 10it [17:14, 102.42s/it]
# !! Max_iter. Delta: 0.000002, Gap C: 0.000000, Gap Q: 0.017222
# [09] MED: 4.266604e-03 | HV: 1.653625
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.003519, Gap C: 0.000000, Gap Q: 0.029674
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.001001, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.003183, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.002629, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.006225, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.006394, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.006453, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.006415, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.006289, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.005803, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.006088, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.006289, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.005011, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.006453, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.003953, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.006225, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.002629, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.003183, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.001001, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# 11it [18:58, 103.11s/it]
# !! Max_iter. Delta: 0.003517, Gap C: 0.000000, Gap Q: 0.029822
# [10] MED: 4.118410e-03 | HV: 1.646715
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.003539, Gap C: 0.000000, Gap Q: 0.014527
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.004702, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.003183, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.002629, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.006225, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.006394, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.006453, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.006415, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.005439, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.006088, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.005803, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.005439, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.006415, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.004516, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.003953, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.006225, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.005924, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.003183, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.001001, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.3
# 12it [20:43, 103.50s/it]
# !! Max_iter. Delta: 0.003539, Gap C: 0.000000, Gap Q: 0.014528
# [11] MED: 5.270882e-03 | HV: 1.654019
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.001857, Gap C: 0.000000, Gap Q: 0.001423
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000498, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.002709, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.001312, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.003098, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000630, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.002252, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.003193, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.003134, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.002890, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.002890, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.003134, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.002496, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.002252, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000630, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.001659, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.001312, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000928, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000498, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# 13it [22:27, 103.79s/it]
# !! Max_iter. Delta: 0.001856, Gap C: 0.000000, Gap Q: 0.001695
# [12] MED: 3.201583e-03 | HV: 1.654279
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.001856, Gap C: 0.000000, Gap Q: 0.001641
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# -> Thuật toán hội tụ sớm tại k=391.
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000928, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.001312, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.003098, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000630, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.002252, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.003193, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.002712, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.003031, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.003031, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.003134, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.002496, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.003214, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000630, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.003098, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.002947, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000928, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# -> Thuật toán hội tụ sớm tại k=419.
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# 14it [24:05, 102.07s/it]
# !! Max_iter. Delta: 0.001854, Gap C: 0.000000, Gap Q: 0.001971
# [13] MED: 3.695803e-03 | HV: 1.656223
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.003754, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.001001, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.003183, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.002629, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.006225, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.006394, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.004516, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.005011, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.005439, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.005803, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.006088, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.005439, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.006415, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.004516, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.003953, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.006225, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.005924, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.003183, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.004702, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# 15it [25:50, 102.72s/it]
# !! Max_iter. Delta: 0.003758, Gap C: 0.000000, Gap Q: 0.000000
# [14] MED: 3.159496e-03 | HV: 1.654019
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.003666, Gap C: 0.000000, Gap Q: 0.015770
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.001001, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.003183, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.002629, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.003325, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.006394, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.004516, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.006415, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.006289, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.005803, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.005803, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.005439, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.005011, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.006453, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.003953, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.006225, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.005924, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.003183, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.001001, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.51, beta=k^0.5, gamma=k^0.5
# 16it [27:34, 103.16s/it]
# !! Max_iter. Delta: 0.003716, Gap C: 0.000000, Gap Q: 0.011057
# [15] MED: 2.456078e-03 | HV: 1.678485
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.001835, Gap C: 0.000000, Gap Q: 0.012097
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.000498, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.002709, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.001312, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.003098, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.000630, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.003214, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.003193, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.002712, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.003031, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.003031, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.002712, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.002496, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.003214, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.000630, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.001659, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.001312, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.002709, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.002332, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# 17it [29:18, 103.49s/it]
# !! Max_iter. Delta: 0.001833, Gap C: 0.000000, Gap Q: 0.005996
# [16] MED: 3.300019e-03 | HV: 1.654342
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.000001, Gap C: 0.000000, Gap Q: 0.006366
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# -> Thuật toán hội tụ sớm tại k=106.
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# -> Thuật toán hội tụ sớm tại k=426.
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# -> Thuật toán hội tụ sớm tại k=528.
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.003046, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.000630, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.003214, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.003193, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.002712, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.003031, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.002890, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.002712, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.002496, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.002252, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.000630, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.003048, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# -> Thuật toán hội tụ sớm tại k=528.
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# -> Thuật toán hội tụ sớm tại k=426.
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# -> Thuật toán hội tụ sớm tại k=106.
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# 18it [30:42, 97.61s/it]
# !! Max_iter. Delta: 0.000001, Gap C: 0.000000, Gap Q: 0.006368
# [17] MED: 3.746186e-03 | HV: 1.657866
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.003721, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.001001, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.003183, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.002629, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.003325, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.006394, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.006453, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.005011, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.005439, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.005803, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.005803, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.006289, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.006415, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.006453, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.003953, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# !! Max_iter. Delta: 0.006225, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.25, lambda=k^-0.51, beta=k^0.3, gamma=k^0.3
# ...
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000265, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000416, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000177, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000125, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# -> Thuật toán hội tụ sớm tại k=519.
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# 90it [2:26:53, 100.07s/it]
# !! Max_iter. Delta: 0.000002, Gap C: 0.000000, Gap Q: 0.017256
# [89] MED: 2.424793e-03 | HV: 1.654323
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000482, Gap C: 0.000000, Gap Q: 0.016836
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000134, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000728, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000352, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000833, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000530, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000606, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000860, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000843, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000778, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000815, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000843, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000860, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000864, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000530, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000447, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000352, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000250, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000626, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# 91it [2:28:36, 100.90s/it]
# !! Max_iter. Delta: 0.000483, Gap C: 0.000000, Gap Q: 0.018409
# [90] MED: 2.688047e-03 | HV: 1.654441
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000002, Gap C: 0.000000, Gap Q: 0.017225
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000134, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000728, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000791, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000833, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000530, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000864, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000860, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000730, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000815, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000815, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000843, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000860, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000606, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000530, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000833, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000352, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000250, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# !! Max_iter. Delta: 0.000134, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.3
# 92it [2:30:18, 101.42s/it]
# !! Max_iter. Delta: 0.000002, Gap C: 0.000000, Gap Q: 0.017225
# [91] MED: 2.647408e-03 | HV: 1.653442
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000251, Gap C: 0.000000, Gap Q: 0.005138
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000067, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000364, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000177, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000416, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000265, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000302, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000429, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000421, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000389, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000407, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000421, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000429, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000302, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000265, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000223, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000177, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000125, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000067, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# 93it [2:32:01, 101.76s/it]
# !! Max_iter. Delta: 0.000250, Gap C: 0.000000, Gap Q: 0.004428
# [92] MED: 1.101628e-03 | HV: 1.654460
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000004, Gap C: 0.000000, Gap Q: 0.004529
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# -> Thuật toán hội tụ sớm tại k=274.
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000364, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000177, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000223, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000265, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000431, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000335, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000421, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000407, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000389, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000421, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000429, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000302, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000427, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000416, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000177, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000125, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# -> Thuật toán hội tụ sớm tại k=275.
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# 94it [2:33:36, 99.68s/it]
# !! Max_iter. Delta: 0.000001, Gap C: 0.000000, Gap Q: 0.004539
# [93] MED: 1.191664e-03 | HV: 1.654928
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000501, Gap C: 0.000000, Gap Q: 0.004166
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000626, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000728, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000791, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000833, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000530, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000864, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000673, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000843, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000778, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000778, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000843, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000673, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000606, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000855, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000447, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000352, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000250, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000134, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# 95it [2:35:18, 100.46s/it]
# !! Max_iter. Delta: 0.000502, Gap C: 0.000000, Gap Q: 0.003365
# [94] MED: 1.454179e-03 | HV: 1.654445
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000501, Gap C: 0.000000, Gap Q: 0.003828
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000134, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000728, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000352, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000833, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000855, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000864, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000673, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000843, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000778, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000778, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000843, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000860, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000864, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000530, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000833, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000791, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000250, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000134, Gap C: 0.000000, Gap Q: 0.000000
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# 96it [2:37:00, 98.13s/it]
# !! Max_iter. Delta: 0.000501, Gap C: 0.000000, Gap Q: 0.003827
# [95] MED: 1.453743e-03 | HV: 1.654440

# %%
if CHOSEN_INDICATOR == "MED":
    best_entry = min(results_log, key=lambda x: x['MED'])
elif CHOSEN_INDICATOR == "HV":
    best_entry = max(results_log, key=lambda x: x['HV'])
else:
    raise ValueError("Indicator phải là 'MED' hoặc 'HV'")

print("\n" + "="*60)
print(f"CẤU HÌNH TỐI ƯU NHẤT THEO {CHOSEN_INDICATOR}:")
print(f"ID: {best_entry['id']}")
print(f"MED: {best_entry['MED']:.8f}")
print(f"HV:  {best_entry['HV']:.8f}")
print(f"Params: {best_entry['params']}")
print("="*60)

# Lưu kết quả tốt nhất để sử dụng cho các bước sau
best_params = best_entry['params']
# Out:
# ============================================================
# CẤU HÌNH TỐI ƯU NHẤT THEO MED:
# ID: 92
# MED: 0.00110163
# HV:  1.65446006
# Params: {'expo_lambda': 0.8, 'expo_alpha': 0.1, 'expo_beta': 0.5, 'expo_gamma': 0.5, 'init_params': 1.0, 'mu': 0.0001, 'max_iter': 1000}
# ============================================================

# %%
results_log
# Out:
# [{'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.3,
#    'init_params': 1.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.00412544248032148),
#   'HV': np.float64(1.6542985910587134),
#   'id': 0},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.3,
#    'init_params': 1.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.004700831249803294),
#   'HV': np.float64(1.6569806074845443),
#   'id': 1},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.3,
#    'init_params': 2.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.0041256528425830195),
#   'HV': np.float64(1.6467153219625636),
#   'id': 2},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.3,
#    'init_params': 2.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.0052687244086302015),
#   'HV': np.float64(1.646715321880821),
#   'id': 3},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.5,
#    'init_params': 1.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.00265995524178717),
#   'HV': np.float64(1.6542360654366153),
#   'id': 4},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.5,
#    'init_params': 1.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.003426563777670906),
#   'HV': np.float64(1.6535727376347717),
#   'id': 5},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.5,
#    'init_params': 2.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.003547794236683492),
#   'HV': np.float64(1.646715321932204),
#   'id': 6},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.5,
#    'init_params': 2.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.002466664281000796),
#   'HV': np.float64(1.671106484744701),
#   'id': 7},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.3,
#    'init_params': 1.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.004093331318903298),
#   'HV': np.float64(1.6542699868274189),
#   'id': 8},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.3,
#    'init_params': 1.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.004266603983078555),
#   'HV': np.float64(1.6536245176675433),
#   'id': 9},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.3,
#    'init_params': 2.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.004118410494711679),
#   'HV': np.float64(1.64671532196473),
#   'id': 10},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.3,
#    'init_params': 2.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.005270882465112586),
#   'HV': np.float64(1.6540185715803664),
#   'id': 11},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.5,
#    'init_params': 1.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.003201583162186654),
#   'HV': np.float64(1.6542789970256258),
#   'id': 12},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.5,
#    'init_params': 1.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.0036958027474517747),
#   'HV': np.float64(1.6562230596202305),
#   'id': 13},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.5,
#    'init_params': 2.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.0031594962747541373),
#   'HV': np.float64(1.6540185715367315),
#   'id': 14},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.5,
#    'init_params': 2.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.0024560782957811196),
#   'HV': np.float64(1.6784850627468746),
#   'id': 15},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.25,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.3,
#    'init_params': 1.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.0033000194871075235),
#   'HV': np.float64(1.654341534142572),
#   'id': 16},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.25,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.3,
#    'init_params': 1.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.0037461863751602612),
#   'HV': np.float64(1.6578660201225377),
#   'id': 17},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.25,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.3,
#    'init_params': 2.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.0031247535365039234),
#   'HV': np.float64(1.6467153235915046),
#   'id': 18},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.25,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.3,
#    'init_params': 2.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.004576794056919387),
#   'HV': np.float64(1.6643179735172122),
#   'id': 19},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.25,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.5,
#    'init_params': 1.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.0025440184131081205),
#   'HV': np.float64(1.6542790037367754),
#   'id': 20},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.25,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.5,
#    'init_params': 1.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.003082072515186527),
#   'HV': np.float64(1.6762483237392076),
#   'id': 21},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.25,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.5,
#    'init_params': 2.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.002851291695715258),
#   'HV': np.float64(1.669515176232173),
#   'id': 22},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.25,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.5,
#    'init_params': 2.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.0028844681028300577),
#   'HV': np.float64(1.678560467334175),
#   'id': 23},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.25,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.3,
#    'init_params': 1.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.0032887178760084247),
#   'HV': np.float64(1.6544343144005276),
#   'id': 24},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.25,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.3,
#    'init_params': 1.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.0033915072720448205),
#   'HV': np.float64(1.6577781160666567),
#   'id': 25},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.25,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.3,
#    'init_params': 2.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.002515575380850567),
#   'HV': np.float64(1.6781055507271199),
#   'id': 26},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.25,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.3,
#    'init_params': 2.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.00377351892337604),
#   'HV': np.float64(1.6605822559794394),
#   'id': 27},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.25,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.5,
#    'init_params': 1.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.002528256318860525),
#   'HV': np.float64(1.6544131570515836),
#   'id': 28},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.25,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.5,
#    'init_params': 1.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.003708815532148412),
#   'HV': np.float64(1.6786358408362343),
#   'id': 29},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.25,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.5,
#    'init_params': 2.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.0025135569153287023),
#   'HV': np.float64(1.671455052316852),
#   'id': 30},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.25,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.5,
#    'init_params': 2.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.0019660368871728486),
#   'HV': np.float64(1.6920158642754366),
#   'id': 31},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.4,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.3,
#    'init_params': 1.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.0022064232389903448),
#   'HV': np.float64(1.6961095031974127),
#   'id': 32},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.4,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.3,
#    'init_params': 1.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.006018485399221811),
#   'HV': np.float64(1.6602948586092756),
#   'id': 33},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.4,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.3,
#    'init_params': 2.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.0030306525552296097),
#   'HV': np.float64(1.6924375566289651),
#   'id': 34},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.4,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.3,
#    'init_params': 2.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.005844573720387425),
#   'HV': np.float64(1.679500118787898),
#   'id': 35},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.4,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.5,
#    'init_params': 1.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.002859236034984606),
#   'HV': np.float64(1.6543219448014324),
#   'id': 36},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.4,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.5,
#    'init_params': 1.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.0051542396382125),
#   'HV': np.float64(1.6587036162147744),
#   'id': 37},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.4,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.5,
#    'init_params': 2.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.0025395898065602575),
#   'HV': np.float64(1.646715322066828),
#   'id': 38},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.4,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.5,
#    'init_params': 2.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.00551506054169805),
#   'HV': np.float64(1.692549712808088),
#   'id': 39},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.4,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.3,
#    'init_params': 1.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.0022111711462536716),
#   'HV': np.float64(1.6959828114261475),
#   'id': 40},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.4,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.3,
#    'init_params': 1.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.00629905743279634),
#   'HV': np.float64(1.6638178986854517),
#   'id': 41},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.4,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.3,
#    'init_params': 2.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.0028970319384827086),
#   'HV': np.float64(1.6927248212778983),
#   'id': 42},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.4,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.3,
#    'init_params': 2.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.004382513353520854),
#   'HV': np.float64(1.6792492691906271),
#   'id': 43},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.4,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.5,
#    'init_params': 1.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.002694035370932743),
#   'HV': np.float64(1.6543845530713979),
#   'id': 44},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.4,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.5,
#    'init_params': 1.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.005728342511308737),
#   'HV': np.float64(1.677781506921511),
#   'id': 45},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.4,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.5,
#    'init_params': 2.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.003023757336402613),
#   'HV': np.float64(1.677741132783531),
#   'id': 46},
#  {'params': {'expo_lambda': 0.51,
#    'expo_alpha': 0.4,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.5,
#    'init_params': 2.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.005578941388202061),
#   'HV': np.float64(1.6942075306431463),
#   'id': 47},
#  {'params': {'expo_lambda': 0.65,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.3,
#    'init_params': 1.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.0030271403702840497),
#   'HV': np.float64(1.6544549296353583),
#   'id': 48},
#  {'params': {'expo_lambda': 0.65,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.3,
#    'init_params': 1.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.0032070476315779724),
#   'HV': np.float64(1.6555476800182238),
#   'id': 49},
#  {'params': {'expo_lambda': 0.65,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.3,
#    'init_params': 2.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.0032663692833288216),
#   'HV': np.float64(1.6544092228181844),
#   'id': 50},
#  {'params': {'expo_lambda': 0.65,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.3,
#    'init_params': 2.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.0030945056349016447),
#   'HV': np.float64(1.6572060826763306),
#   'id': 51},
#  {'params': {'expo_lambda': 0.65,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.5,
#    'init_params': 1.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.0016395468840071984),
#   'HV': np.float64(1.6544316324214665),
#   'id': 52},
#  {'params': {'expo_lambda': 0.65,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.5,
#    'init_params': 1.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.0018929910980579633),
#   'HV': np.float64(1.655509048507964),
#   'id': 53},
#  {'params': {'expo_lambda': 0.65,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.5,
#    'init_params': 2.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.0019918593237981423),
#   'HV': np.float64(1.6572185173967768),
#   'id': 54},
#  {'params': {'expo_lambda': 0.65,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.5,
#    'init_params': 2.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.0015240524631717392),
#   'HV': np.float64(1.6543968007941643),
#   'id': 55},
#  {'params': {'expo_lambda': 0.65,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.3,
#    'init_params': 1.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.003146158831478272),
#   'HV': np.float64(1.6544572129112858),
#   'id': 56},
#  {'params': {'expo_lambda': 0.65,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.3,
#    'init_params': 1.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.003400483093347564),
#   'HV': np.float64(1.6570388214228302),
#   'id': 57},
#  {'params': {'expo_lambda': 0.65,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.3,
#    'init_params': 2.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.0033069197896384377),
#   'HV': np.float64(1.654396808581291),
#   'id': 58},
#  {'params': {'expo_lambda': 0.65,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.3,
#    'init_params': 2.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.0031039158359307873),
#   'HV': np.float64(1.6515998759260184),
#   'id': 59},
#  {'params': {'expo_lambda': 0.65,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.5,
#    'init_params': 1.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.0017226367966590168),
#   'HV': np.float64(1.6544143761104784),
#   'id': 60},
#  {'params': {'expo_lambda': 0.65,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.5,
#    'init_params': 1.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.002072851952165162),
#   'HV': np.float64(1.6570388090467407),
#   'id': 61},
#  {'params': {'expo_lambda': 0.65,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.5,
#    'init_params': 2.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.002074405490532698),
#   'HV': np.float64(1.651599868842832),
#   'id': 62},
#  {'params': {'expo_lambda': 0.65,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.5,
#    'init_params': 2.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.0016259756007515687),
#   'HV': np.float64(1.6572061434756837),
#   'id': 63},
#  {'params': {'expo_lambda': 0.65,
#    'expo_alpha': 0.25,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.3,
#    'init_params': 1.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.001976327613851585),
#   'HV': np.float64(1.6544692617861272),
#   'id': 64},
#  {'params': {'expo_lambda': 0.65,
#    'expo_alpha': 0.25,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.3,
#    'init_params': 1.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.0023855303213418137),
#   'HV': np.float64(1.65664175898743),
#   'id': 65},
#  {'params': {'expo_lambda': 0.65,
#    'expo_alpha': 0.25,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.3,
#    'init_params': 2.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.0021964264206477827),
#   'HV': np.float64(1.6515875131968372),
#   'id': 66},
#  {'params': {'expo_lambda': 0.65,
#    'expo_alpha': 0.25,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.3,
#    'init_params': 2.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.001963318476286564),
#   'HV': np.float64(1.6571199277702728),
#   'id': 67},
#  {'params': {'expo_lambda': 0.65,
#    'expo_alpha': 0.25,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.5,
#    'init_params': 1.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.0014240973744082893),
#   'HV': np.float64(1.654437677368977),
#   'id': 68},
#  {'params': {'expo_lambda': 0.65,
#    'expo_alpha': 0.25,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.5,
#    'init_params': 1.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.001802863866617839),
#   'HV': np.float64(1.6561352934296003),
#   'id': 69},
#  {'params': {'expo_lambda': 0.65,
#    'expo_alpha': 0.25,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.5,
#    'init_params': 2.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.0012828693296842299),
#   'HV': np.float64(1.695307987433082),
#   'id': 70},
#  {'params': {'expo_lambda': 0.65,
#    'expo_alpha': 0.25,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.5,
#    'init_params': 2.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.0016847365901172143),
#   'HV': np.float64(1.6778316011148606),
#   'id': 71},
#  {'params': {'expo_lambda': 0.65,
#    'expo_alpha': 0.25,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.3,
#    'init_params': 1.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.001860694017072248),
#   'HV': np.float64(1.6544576201229004),
#   'id': 72},
#  {'params': {'expo_lambda': 0.65,
#    'expo_alpha': 0.25,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.3,
#    'init_params': 1.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.0026036372194354596),
#   'HV': np.float64(1.6577570850679524),
#   'id': 73},
#  {'params': {'expo_lambda': 0.65,
#    'expo_alpha': 0.25,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.3,
#    'init_params': 2.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.0021404248656319174),
#   'HV': np.float64(1.654409251006089),
#   'id': 74},
#  {'params': {'expo_lambda': 0.65,
#    'expo_alpha': 0.25,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.3,
#    'init_params': 2.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.0019137757584879165),
#   'HV': np.float64(1.6567846111005502),
#   'id': 75},
#  {'params': {'expo_lambda': 0.65,
#    'expo_alpha': 0.25,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.5,
#    'init_params': 1.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.0015134123968296906),
#   'HV': np.float64(1.654469253177625),
#   'id': 76},
#  {'params': {'expo_lambda': 0.65,
#    'expo_alpha': 0.25,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.5,
#    'init_params': 1.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.0017215400440226826),
#   'HV': np.float64(1.6556882460280535),
#   'id': 77},
#  {'params': {'expo_lambda': 0.65,
#    'expo_alpha': 0.25,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.5,
#    'init_params': 2.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.0012516261317515693),
#   'HV': np.float64(1.6957895016689781),
#   'id': 78},
#  {'params': {'expo_lambda': 0.65,
#    'expo_alpha': 0.25,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.5,
#    'init_params': 2.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.0017350019482612945),
#   'HV': np.float64(1.6566237707360223),
#   'id': 79},
#  {'params': {'expo_lambda': 0.8,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.3,
#    'init_params': 1.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.0024562512510235756),
#   'HV': np.float64(1.6544739123134689),
#   'id': 80},
#  {'params': {'expo_lambda': 0.8,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.3,
#    'init_params': 1.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.0024982897299533993),
#   'HV': np.float64(1.6549530167123225),
#   'id': 81},
#  {'params': {'expo_lambda': 0.8,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.3,
#    'init_params': 2.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.0027200634257481425),
#   'HV': np.float64(1.6534454530050682),
#   'id': 82},
#  {'params': {'expo_lambda': 0.8,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.3,
#    'init_params': 2.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.0026780187356225107),
#   'HV': np.float64(1.6544436256328512),
#   'id': 83},
#  {'params': {'expo_lambda': 0.8,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.5,
#    'init_params': 1.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.001114241967366118),
#   'HV': np.float64(1.6544407719952519),
#   'id': 84},
#  {'params': {'expo_lambda': 0.8,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.5,
#    'init_params': 1.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.0012241746922587384),
#   'HV': np.float64(1.6553279956430398),
#   'id': 85},
#  {'params': {'expo_lambda': 0.8,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.5,
#    'init_params': 2.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.001450555492162741),
#   'HV': np.float64(1.6534463901951415),
#   'id': 86},
#  {'params': {'expo_lambda': 0.8,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.3,
#    'expo_gamma': 0.5,
#    'init_params': 2.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.0014374394098679735),
#   'HV': np.float64(1.6534420233654004),
#   'id': 87},
#  {'params': {'expo_lambda': 0.8,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.3,
#    'init_params': 1.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.0024748992712695156),
#   'HV': np.float64(1.6544600594746925),
#   'id': 88},
#  {'params': {'expo_lambda': 0.8,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.3,
#    'init_params': 1.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.00242479279989934),
#   'HV': np.float64(1.6543227138625936),
#   'id': 89},
#  {'params': {'expo_lambda': 0.8,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.3,
#    'init_params': 2.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.002688046799270019),
#   'HV': np.float64(1.6544405509154652),
#   'id': 90},
#  {'params': {'expo_lambda': 0.8,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.3,
#    'init_params': 2.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.0026474076677699006),
#   'HV': np.float64(1.6534421980199991),
#   'id': 91},
#  {'params': {'expo_lambda': 0.8,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.5,
#    'init_params': 1.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.0011016284820898027),
#   'HV': np.float64(1.6544600594585788),
#   'id': 92},
#  {'params': {'expo_lambda': 0.8,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.5,
#    'init_params': 1.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.0011916635516992144),
#   'HV': np.float64(1.6549281054674962),
#   'id': 93},
#  {'params': {'expo_lambda': 0.8,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.5,
#    'init_params': 2.0,
#    'mu': 0.0001,
#    'max_iter': 1000},
#   'MED': np.float64(0.0014541790324659443),
#   'HV': np.float64(1.6544449882170955),
#   'id': 94},
#  {'params': {'expo_lambda': 0.8,
#    'expo_alpha': 0.1,
#    'expo_beta': 0.5,
#    'expo_gamma': 0.5,
#    'init_params': 2.0,
#    'mu': 0.01,
#    'max_iter': 1000},
#   'MED': np.float64(0.0014537428618041366),
#   'HV': np.float64(1.654439912576183),
#   'id': 95}]

# %%
import pandas as pd
df = pd.json_normalize(results_log, sep='_')
df.columns = df.columns.str.replace('params_', '')
df.to_csv(f"exp/{case}.csv", index=False)

# %%
df.sort_values(by="MED")
# Out:
#          MED        HV  id  expo_lambda  expo_alpha  expo_beta  expo_gamma  \
# 92  0.001102  1.654460  92         0.80        0.10        0.5         0.5
# 84  0.001114  1.654441  84         0.80        0.10        0.3         0.5
# 93  0.001192  1.654928  93         0.80        0.10        0.5         0.5
# 85  0.001224  1.655328  85         0.80        0.10        0.3         0.5
# 78  0.001252  1.695790  78         0.65        0.25        0.5         0.5
# ..       ...       ...  ..          ...         ...        ...         ...
# 47  0.005579  1.694208  47         0.51        0.40        0.5         0.5
# 45  0.005728  1.677782  45         0.51        0.40        0.5         0.5
# 35  0.005845  1.679500  35         0.51        0.40        0.3         0.3
# 33  0.006018  1.660295  33         0.51        0.40        0.3         0.3
# 41  0.006299  1.663818  41         0.51        0.40        0.5         0.3
#
#     init_params      mu  max_iter
# 92          1.0  0.0001      1000
# 84          1.0  0.0001      1000
# 93          1.0  0.0100      1000
# 85          1.0  0.0100      1000
# 78          2.0  0.0001      1000
# ..          ...     ...       ...
# 47          2.0  0.0100      1000
# 45          1.0  0.0100      1000
# 35          2.0  0.0100      1000
# 33          1.0  0.0100      1000
# 41          1.0  0.0100      1000
#
# [96 rows x 10 columns]

# %%
pareto_f_temp = []
for r in test_rays:
        x_final, _ = optim_Scalarization(
            prob=prob,
            x_feasible=x_feasible,  
            r=r, 
            z_star=z_star,
            # Các tham số tĩnh
            verbose=True,
            # --- CÁC THAM SỐ ĐANG TỐI ƯU ---
            max_iter=best_params['max_iter'],
            mu=best_params['mu'],
            init_params=best_params['init_params'],
            expo_alpha=best_params['expo_alpha'],
            expo_lambda=best_params['expo_lambda'],
            expo_beta=best_params['expo_beta'],
            expo_gamma=best_params['expo_gamma'],
        )
        pareto_f_temp.append(prob.objective_func(x_final))
    
    # Tính HV
# Out:
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000251, Gap C: 0.000000, Gap Q: 0.004317
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha |  Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 |  1.00000 |  1.00000 | 1.00000 | 7.07107 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 15.84298 | 15.84298 | 0.01203 | 6.67237 | 0.57240 | 0.00000 | 0.00968 |
# | 500 | 0.53705 | 22.38303 | 22.38303 | 0.00692 | 3.60817 | 0.56917 | 0.00000 | 0.00643 |
# | 750 | 0.51575 | 27.40438 | 27.40438 | 0.00501 | 2.20900 | 0.56775 | 0.00000 | 0.00500 |
# | 999 | 0.50119 | 31.62278 | 31.62278 | 0.00398 | 2.58622 | 0.56707 | 0.00000 | 0.00432 |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [1.1103 1.1103]
# -> S(F(x)) approx distance: 0.56794
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000067, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha |  Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 |  1.00000 |  1.00000 | 1.00000 | 7.09530 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 15.84298 | 15.84298 | 0.01203 | 1.24007 | 0.48516 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 22.38303 | 22.38303 | 0.00692 | 0.76443 | 0.48515 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 27.40438 | 27.40438 | 0.00501 | 0.57580 | 0.48515 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 31.62278 | 31.62278 | 0.00398 | 0.47085 | 0.48593 | 0.00000 | 0.00000 |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [1.3914 1.3914]
# -> S(F(x)) approx distance: 0.48515
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000364, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha |  Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 |  1.00000 |  1.00000 | 1.00000 | 7.16884 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 15.84298 | 15.84298 | 0.01203 | 0.66528 | 0.42370 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 22.38303 | 22.38303 | 0.00692 | 0.14093 | 0.42042 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 27.40438 | 27.40438 | 0.00501 | 0.10624 | 0.42075 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 31.62278 | 31.62278 | 0.00398 | 0.08713 | 0.42162 | 0.00000 | 0.00000 |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [1.631 1.631]
# -> S(F(x)) approx distance: 0.42230
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000396, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha |  Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 |  1.00000 |  1.00000 | 1.00000 | 7.29427 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 15.84298 | 15.84298 | 0.01203 | 0.20965 | 0.37960 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 22.38303 | 22.38303 | 0.00692 | 0.12949 | 0.38036 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 27.40438 | 27.40438 | 0.00501 | 0.21885 | 0.38215 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 31.62278 | 31.62278 | 0.00398 | 0.17930 | 0.38140 | 0.00000 | 0.00000 |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [1.8126 1.8126]
# -> S(F(x)) approx distance: 0.38080
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000416, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha |  Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 |  1.00000 |  1.00000 | 1.00000 | 7.47615 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 15.84298 | 15.84298 | 0.01203 | 0.37220 | 0.35524 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 22.38303 | 22.38303 | 0.00692 | 0.12315 | 0.35281 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 27.40438 | 27.40438 | 0.00501 | 0.17310 | 0.35433 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 31.62278 | 31.62278 | 0.00398 | 0.07610 | 0.35369 | 0.00000 | 0.00000 |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [1.948 1.948]
# -> S(F(x)) approx distance: 0.35420
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000427, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha |  Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 |  1.00000 |  1.00000 | 1.00000 | 7.72142 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 15.84298 | 15.84298 | 0.01203 | 0.19486 | 0.33395 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 22.38303 | 22.38303 | 0.00692 | 0.12012 | 0.33396 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 27.40438 | 27.40438 | 0.00501 | 0.09048 | 0.33396 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 31.62278 | 31.62278 | 0.00398 | 0.07394 | 0.33354 | 0.00000 | 0.00000 |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [2.0708 2.0708]
# -> S(F(x)) approx distance: 0.33396
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000302, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha |  Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 |  1.00000 |  1.00000 | 1.00000 | 8.04011 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 15.84298 | 15.84298 | 0.01203 | 0.27506 | 0.31988 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 22.38303 | 22.38303 | 0.00692 | 0.11896 | 0.31988 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 27.40438 | 27.40438 | 0.00501 | 0.12772 | 0.31988 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 31.62278 | 31.62278 | 0.00398 | 0.10442 | 0.32021 | 0.00000 | 0.00000 |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [2.1773 2.1773]
# -> S(F(x)) approx distance: 0.31988
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000335, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha |  Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 |  1.00000 |  1.00000 | 1.00000 | 8.44643 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 15.84298 | 15.84298 | 0.01203 | 0.19403 | 0.31015 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 22.38303 | 22.38303 | 0.00692 | 0.15283 | 0.31016 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 27.40438 | 27.40438 | 0.00501 | 0.11512 | 0.31016 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 31.62278 | 31.62278 | 0.00398 | 0.09412 | 0.31039 | 0.00000 | 0.00000 |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [2.275 2.275]
# -> S(F(x)) approx distance: 0.31016
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000421, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha |  Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 |  1.00000 |  1.00000 | 1.00000 | 8.96047 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 15.84298 | 15.84298 | 0.01203 | 0.22792 | 0.30437 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 22.38303 | 22.38303 | 0.00692 | 0.14060 | 0.30427 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 27.40438 | 27.40438 | 0.00501 | 0.09172 | 0.30385 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 31.62278 | 31.62278 | 0.00398 | 0.07517 | 0.30403 | 0.00000 | 0.00000 |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [2.3642 2.3642]
# -> S(F(x)) approx distance: 0.30417
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000407, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha |  Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 |  1.00000 |  1.00000 | 1.00000 | 9.61103 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 15.84298 | 15.84298 | 0.01203 | 0.21376 | 0.30121 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 22.38303 | 22.38303 | 0.00692 | 0.13195 | 0.30114 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 27.40438 | 27.40438 | 0.00501 | 0.09945 | 0.30112 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 31.62278 | 31.62278 | 0.00398 | 0.08150 | 0.30106 | 0.00000 | 0.00000 |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [2.4588 2.4588]
# -> S(F(x)) approx distance: 0.30101
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000389, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha |  Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 |  1.00000 |  1.00000 | 1.00000 | 9.61103 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 15.84298 | 15.84298 | 0.01203 | 0.21376 | 0.30121 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 22.38303 | 22.38303 | 0.00692 | 0.12581 | 0.30098 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 27.40438 | 27.40438 | 0.00501 | 0.09945 | 0.30112 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 31.62278 | 31.62278 | 0.00398 | 0.07771 | 0.30106 | 0.00000 | 0.00000 |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [2.5468 2.5468]
# -> S(F(x)) approx distance: 0.30111
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000421, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha |  Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 |  1.00000 |  1.00000 | 1.00000 | 8.96047 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 15.84298 | 15.84298 | 0.01203 | 0.22792 | 0.30437 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 22.38303 | 22.38303 | 0.00692 | 0.14060 | 0.30427 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 27.40438 | 27.40438 | 0.00501 | 0.09172 | 0.30385 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 31.62278 | 31.62278 | 0.00398 | 0.07517 | 0.30403 | 0.00000 | 0.00000 |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [2.6358 2.6358]
# -> S(F(x)) approx distance: 0.30417
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000429, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha |  Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 |  1.00000 |  1.00000 | 1.00000 | 8.44643 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 15.84298 | 15.84298 | 0.01203 | 0.19403 | 0.31015 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 22.38303 | 22.38303 | 0.00692 | 0.11961 | 0.31016 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 27.40438 | 27.40438 | 0.00501 | 0.09009 | 0.31016 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 31.62278 | 31.62278 | 0.00398 | 0.07364 | 0.30992 | 0.00000 | 0.00000 |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [2.725 2.725]
# -> S(F(x)) approx distance: 0.31016
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000431, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha |  Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 |  1.00000 |  1.00000 | 1.00000 | 8.04011 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 15.84298 | 15.84298 | 0.01203 | 0.19298 | 0.31988 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 22.38303 | 22.38303 | 0.00692 | 0.11896 | 0.31988 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 27.40438 | 27.40438 | 0.00501 | 0.08961 | 0.31988 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 31.62278 | 31.62278 | 0.00398 | 0.07324 | 0.31956 | 0.00000 | 0.00000 |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [2.8227 2.8227]
# -> S(F(x)) approx distance: 0.31988
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000265, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha |  Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 |  1.00000 |  1.00000 | 1.00000 | 7.72142 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 15.84298 | 15.84298 | 0.01203 | 0.31405 | 0.33396 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 22.38303 | 22.38303 | 0.00692 | 0.12012 | 0.33396 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 27.40438 | 27.40438 | 0.00501 | 0.09048 | 0.33396 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 31.62278 | 31.62278 | 0.00398 | 0.11922 | 0.33437 | 0.00000 | 0.00000 |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [2.9292 2.9292]
# -> S(F(x)) approx distance: 0.33396
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000223, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha |  Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 |  1.00000 |  1.00000 | 1.00000 | 7.47615 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 15.84298 | 15.84298 | 0.01203 | 0.37219 | 0.35524 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 22.38303 | 22.38303 | 0.00692 | 0.22971 | 0.35458 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 27.40438 | 27.40438 | 0.00501 | 0.17310 | 0.35433 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 31.62278 | 31.62278 | 0.00398 | 0.14183 | 0.35369 | 0.00000 | 0.00000 |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [3.0464 3.0464]
# -> S(F(x)) approx distance: 0.35319
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000396, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha |  Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 |  1.00000 |  1.00000 | 1.00000 | 7.29427 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 15.84298 | 15.84298 | 0.01203 | 0.47059 | 0.38321 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 22.38303 | 22.38303 | 0.00692 | 0.12949 | 0.38036 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 27.40438 | 27.40438 | 0.00501 | 0.21885 | 0.38215 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 31.62278 | 31.62278 | 0.00398 | 0.17930 | 0.38140 | 0.00000 | 0.00000 |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [3.1874 3.1874]
# -> S(F(x)) approx distance: 0.38080
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000125, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha |  Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 |  1.00000 |  1.00000 | 1.00000 | 7.16884 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 15.84298 | 15.84298 | 0.01203 | 0.22811 | 0.41954 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 22.38303 | 22.38303 | 0.00692 | 0.14093 | 0.42042 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 27.40438 | 27.40438 | 0.00501 | 0.30936 | 0.42248 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 31.62278 | 31.62278 | 0.00398 | 0.25344 | 0.42162 | 0.00000 | 0.00000 |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [3.3634 3.3634]
# -> S(F(x)) approx distance: 0.42093
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000313, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha |  Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 |  1.00000 |  1.00000 | 1.00000 | 7.09530 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 15.84298 | 15.84298 | 0.01203 | 1.24005 | 0.48516 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 22.38303 | 22.38303 | 0.00692 | 0.76440 | 0.48515 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 27.40438 | 27.40438 | 0.00501 | 0.57579 | 0.48515 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 31.62278 | 31.62278 | 0.00398 | 0.10106 | 0.48437 | 0.00000 | 0.00000 |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [3.6086 3.6086]
# -> S(F(x)) approx distance: 0.48515
# Params: alpha=k^-0.1, lambda=k^-0.8, beta=k^0.5, gamma=k^0.5
# !! Max_iter. Delta: 0.000251, Gap C: 0.000000, Gap Q: 0.005116
# +-----+---------+----------+----------+---------+----------+---------+---------+---------+
# |   k |   Alpha |  Beta(C) | Gamma(Q) |  Lambda |     Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+----------+----------+---------+----------+---------+---------+---------+
# |   0 | 1.00000 |  1.00000 |  1.00000 | 1.00000 |  7.07107 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 15.84298 | 15.84298 | 0.01203 |  8.76691 | 0.57252 | 0.00000 | 0.00980 |
# | 500 | 0.53705 | 22.38303 | 22.38303 | 0.00692 | 13.61433 | 0.56944 | 0.00000 | 0.00671 |
# | 750 | 0.51575 | 27.40438 | 27.40438 | 0.00501 |  6.59193 | 0.56779 | 0.00000 | 0.00550 |
# | 999 | 0.50119 | 31.62278 | 31.62278 | 0.00398 |  0.96823 | 0.56786 | 0.00000 | 0.00512 |
# +-----+---------+----------+----------+---------+----------+---------+---------+---------+
# -> Kết quả cuối cùng: [3.8866 3.8866]
# -> S(F(x)) approx distance: 0.56699

# %%
med, hv = get_metrics(pareto_f_temp, pf_true, prob, ref_point)
med, hv
# Out:
# (np.float64(0.0011067046035960644), np.float64(1.6544458155907442))

# %%
np.save(f"test/{case}/pf_dynamic_true.npy", pareto_f_temp)

# %%
visualize_pareto_front(
    pf_pred=np.array(pareto_f_temp), 
    pf_cloud=pf_cloud,   
    pf_targets=pf_true,
    title="Objective Space Visualization",
    figsize=(12, 8)
)
