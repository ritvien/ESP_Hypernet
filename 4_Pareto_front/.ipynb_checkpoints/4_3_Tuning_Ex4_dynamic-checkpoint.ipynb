# %%
import os
import yaml
import autograd.numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import itertools
from tqdm import tqdm

from scipy.optimize import Bounds
from autograd import jacobian

# %%
from Phase1 import solve_CQ_feasible
from Phase2_dynamic import optim_Scalarization
from Phase2_1_obj import optim_Universal
from Problem import Problem
from project import Projection
from utils import visualize_pareto_front

# %% [markdown]
# # Problem

# %%
def f(x):
    return np.array([
        4*x[0]**2 + 4*x[1]**2,
        (x[0] - 5)**2 + (x[1] - 5)**2
    ])

def c1(x):
    return -(x[0] - 5)**2 - x[1]**2 + 25

def c2(x):
    return -(x[0] - 8)**2 - (x[1] + 3)**2 + 17.7

def q1(y): # Đây là hàm ràng buộc cho Q, không phải Q+
    return 50**2 - (y[0] - 50)**2 - (y[1] - 50)**2

def q_plus(y): 
    radius_sq = 50**2  
    dx = np.maximum(0, y[0] - center)
    dy = np.maximum(0, y[1] - center)
    return radius_sq - (dx**2 + dy**2)

cons_C = (
    {'type': 'ineq', 'fun': c1},     
    {'type': 'ineq', 'fun': c2},     
)

dim_x = 2
bounds_x = Bounds([-15,-15],[30, 30])

cons_Q = (
    {'type': 'ineq', 'fun': q1},    
)

cons_Qplus = ( 
    {'type': 'ineq', 'fun': q_plus},
)
dim_y = 2

proj_C_handler = Projection(cons=cons_C, bounds=bounds_x, dim=dim_x, proj_type='euclid')
proj_Q_handler = Projection(cons=cons_Q, bounds=None, dim=dim_y, proj_type='qplus') 

# Setup Problem
prob = Problem(
    f=[f], jac_f=[jacobian(f)], C=[], Q=[], 
    dim_x=dim_x, dim_y=dim_y,
    proj_C=proj_C_handler.project,
    proj_Qplus=proj_Q_handler.project
)

x_init = np.array([-10., -10.])

# %%
GROUND_TRUTH_FILE = "test/ex4/pf_true.npy"
if os.path.exists(GROUND_TRUTH_FILE):
    pf_true = np.load(GROUND_TRUTH_FILE)
    print(f"✅ Đã tải ground truth Pareto front từ: {GROUND_TRUTH_FILE}")
else:
    print(f"❌ KHÔNG tìm thấy file ground truth tại: {GROUND_TRUTH_FILE}")
# Out:
# ✅ Đã tải ground truth Pareto front từ: test/ex4/pf_true.npy

# %% [markdown]
# # Define

# %%
def load_config(config_path='config.yaml'):
    with open(config_path, 'r') as f:
        cfg = yaml.safe_load(f)
    cfg['initialization']['x_init'] = np.array(cfg['initialization']['x_init'])
    cfg['data']['test_ray'] = np.array(cfg['data']['test_ray'])
    return cfg

# ==============================================================================
# HÀM 1: CHUẨN BỊ DỮ LIỆU CỐ ĐỊNH (Chạy 1 lần duy nhất bên ngoài vòng lặp)
# ==============================================================================
def prepare_fixed_data(prob, config_path='config.yaml'):
    """
    Thực hiện Phase 1 và tìm Z_star một lần duy nhất.
    Trả về các dữ liệu cần thiết để chạy Phase 2 nhiều lần.
    """
    cfg = load_config(config_path)
    
    print("=== [PREPARE] BẮT ĐẦU PHASE 1: TÌM ĐIỂM KHẢ THI ===")
    x_feasible, _, _, _ = solve_CQ_feasible(
        f=prob.objective_func,
        jac_f=prob.jacobian,
        proj_C=prob.proj_C,
        proj_Qplus=prob.proj_Qplus,
        x0=cfg['initialization']['x_init'],
        gamma=cfg['phase1']['gamma'], 
        max_iter=cfg['phase1']['max_iter'],
        tol=cfg['phase1']['tol']
    )
    print(f"-> Điểm khả thi cố định: {x_feasible}")
    
    print("=== [PREPARE] TÌM Z_STAR (IDEAL POINT) ===")
    limit_Q = []
    # Dùng tham số mặc định trong config để tìm z_star
    # (Hoặc bạn có thể hard-code một bộ tham số "mạnh" để đảm bảo z_star tốt nhất)
    for dim in range(2):
        x_final, _ = optim_Universal(
                prob=prob,
                x_feasible=x_feasible,  
                r=None,
                target_dim=dim,
                mode="min",
                max_iter=cfg['phase2']['max_iter'],
                mu=cfg['phase2']['mu'],
                expo_alpha=cfg['phase2']['expo_alpha'],
                expo_lambda=cfg['phase2']['expo_lambda'],
                init_params=cfg['phase2']['init_params'],
            )
        val = prob.objective_func(x_final)[dim]
        limit_Q.append(val)
        print(f"-> Z_star chiều {dim}: {val}")
        
    z_star = np.array(limit_Q)
    test_rays = cfg['data']['test_ray']
    
    # Trả về gói dữ liệu để dùng cho hàm tuning
    fixed_data = {
        "x_feasible": x_feasible,
        "z_star": z_star,
        "test_rays": test_rays,
        "base_max_iter": cfg['phase2']['max_iter'],
        "base_init_params": cfg['phase2']['init_params']
    }
    return fixed_data

# ==============================================================================
# HÀM 2: CHẠY TUNING (Gọi liên tục trong vòng lặp Grid Search)
# ==============================================================================
def run_phase2_tuning(prob, fixed_data, params):
    """
    Chỉ chạy Phase 2 Scalarization với bộ tham số `params` được truyền vào.
    Không đọc file config, không chạy lại Phase 1.
    
    Args:
        prob: Đối tượng bài toán
        fixed_data: Kết quả từ hàm prepare_fixed_data
        params: Dictionary chứa {'mu', 'expo_lambda', 'expo_alpha', ...}
    """
    # Trích xuất dữ liệu cố định
    x_feasible = fixed_data["x_feasible"]
    z_star = fixed_data["z_star"]
    test_rays = fixed_data["test_rays"]
    
    # Các tham số mặc định (nếu không có trong params thì lấy mặc định)
    max_iter = params.get('max_iter', fixed_data["base_max_iter"])
    init_params = params.get('init_params', fixed_data["base_init_params"])
    
    # Các tham số Tuning
    mu = params['mu']
    expo_lambda = params['expo_lambda']
    expo_alpha = params['expo_alpha']
    expo_beta = params['expo_beta']
    
    pareto_front_f = [] 
    
    # Chạy vòng lặp qua các tia (Rays)
    for r in test_rays:
        x_final, _ = optim_Scalarization(
            prob=prob,
            x_feasible=x_feasible,  
            r=r, 
            z_star=z_star,
            max_iter=max_iter,
            mu=mu,
            expo_alpha=expo_alpha,
            expo_lambda=expo_lambda,
            init_params=init_params,
            expo_beta=expo_beta,
            verbose=False
        )
        
        pareto_front_f.append(prob.objective_func(x_final))

    return np.array(pareto_front_f)

# %%
def update_yaml_params(config_path, params_dict):
    """Ghi đè tham số mới vào file config.yaml"""
    with open(config_path, 'r') as f:
        config = yaml.safe_load(f)
    
    # Cập nhật tham số phase 2
    for key, value in params_dict.items():
        if key in config['phase2']:
            config['phase2'][key] = float(value)
            
    with open(config_path, 'w') as f:
        yaml.dump(config, f)

# --- 3. HÀM TÍNH LỖI (MSE / IGD) ---
def calculate_mse_igd(pf_pred, pf_true):
    if len(pf_pred) == 0: return np.inf
    total_dist_sq = 0
    # Với mỗi điểm ground truth, tìm điểm dự đoán gần nhất
    for p_true in pf_true:
        dists_sq = np.sum((pf_pred - p_true)**2, axis=1)
        total_dist_sq += np.min(dists_sq)
    return total_dist_sq / len(pf_true)

# %% [markdown]
# # Search loop

# %%
# --- 5. THIẾT LẬP GRID SEARCH ---
fixed_data = prepare_fixed_data(prob)

param_grid = {
    'mu': [0.1, 1.0, 5.0],
    'expo_lambda': [0.6, 0.75, 0.85], 
    'expo_alpha': [0.15, 0.25, 0.35],  
    'expo_beta': [0.6, 0.8, 1]
}

valid_params_list = []
keys = list(param_grid.keys())
for values in itertools.product(*param_grid.values()):
    p = dict(zip(keys, values))
    if p['expo_lambda'] + p['expo_alpha'] <= 1.0:
        valid_params_list.append(p)

print(f"Số lượng cấu hình cần chạy: {len(valid_params_list)}")
# Out:
# === [PREPARE] BẮT ĐẦU PHASE 1: TÌM ĐIỂM KHẢ THI ===
# Khởi tạo: x0: [-10. -10.]
# Chiếu lên C được: x: [ 4.0789 -4.5249]
# 100%|██████████| 300/300 [00:01<00:00, 176.89it/s]
# +-----+------------------------+---------+--------------------------+------------------------+----------+-----------+
# |  k  | x_new                  | gamma_k | y                        | z_proj                 |   e_x    |    e_f    |
# +-----+------------------------+---------+--------------------------+------------------------+----------+-----------+
# |  0  | [ 4.078929, -4.524861] | 0.0006  | [148.44813 ,  91.571358] | [96.061748, 69.450331] | 1.337432 | 56.865392 |
# |  10 | [ 3.795914, -3.160196] | 0.0000  | [97.583211, 68.03862 ]   | [96.753194, 67.723963] | 0.001352 |  0.887659 |
# |  20 | [ 3.795597, -3.151645] | 0.0000  | [97.357703, 67.899908]   | [96.770593, 67.677998] | 0.000489 |  0.627648 |
# |  30 | [ 3.795463, -3.147885] | 0.0000  | [97.258891, 67.838944]   | [96.77832 , 67.657542] | 0.000276 |  0.513668 |
# |  40 | [ 3.795384, -3.145617] | 0.0000  | [97.199384, 67.802176]   | [96.783003, 67.64513 ] | 0.000180 |  0.445013 |
# |  50 | [ 3.79533 , -3.144058] | 0.0000  | [97.158536, 67.776913]   | [96.786231, 67.636569] | 0.000129 |  0.397879 |
# |  60 | [ 3.795291, -3.142906] | 0.0000  | [97.128368, 67.758242]   | [96.788622, 67.630224] | 0.000097 |  0.363064 |
# |  70 | [ 3.795261, -3.142021] | 0.0000  | [97.105195, 67.743894]   | [96.790463, 67.625339] | 0.000079 |  0.336321 |
# |  80 | [ 3.795237, -3.141301] | 0.0000  | [97.086385, 67.732242]   | [96.79196 , 67.621365] | 0.000064 |  0.314611 |
# |  90 | [ 3.795217, -3.140706] | 0.0000  | [97.070807, 67.72259 ]   | [96.793201, 67.618069] | 0.000054 |  0.296631 |
# | 100 | [ 3.7952  , -3.140199] | 0.0000  | [97.057567, 67.714383]   | [96.794257, 67.615263] | 0.000046 |  0.281348 |
# | 110 | [ 3.795185, -3.13976 ] | 0.0000  | [97.04609 , 67.707269]   | [96.795174, 67.612829] | 0.000042 |  0.268100 |
# | 120 | [ 3.795173, -3.139382] | 0.0000  | [97.036224, 67.70115 ]   | [96.795962, 67.610733] | 0.000040 |  0.256711 |
# | 130 | [ 3.795161, -3.139041] | 0.0000  | [97.027324, 67.695631]   | [96.796674, 67.608841] | 0.000034 |  0.246439 |
# | 140 | [ 3.795152, -3.138752] | 0.0000  | [97.019769, 67.690945]   | [96.797279, 67.607234] | 0.000024 |  0.237717 |
# | 150 | [ 3.795143, -3.138488] | 0.0000  | [97.012879, 67.68667 ]   | [96.797831, 67.605767] | 0.000025 |  0.229763 |
# | 160 | [ 3.795135, -3.138248] | 0.0000  | [97.006621, 67.682787]   | [96.798332, 67.604434] | 0.000022 |  0.222539 |
# | 170 | [ 3.795128, -3.138031] | 0.0000  | [97.000933, 67.679258]   | [96.798788, 67.603221] | 0.000025 |  0.215972 |
# | 180 | [ 3.795122, -3.137831] | 0.0000  | [96.995724, 67.676025]   | [96.799206, 67.602111] | 0.000019 |  0.209959 |
# | 190 | [ 3.795115, -3.137644] | 0.0000  | [96.990832, 67.672989]   | [96.799599, 67.601067] | 0.000018 |  0.204311 |
# | 200 | [ 3.79511 , -3.137473] | 0.0000  | [96.986383, 67.670228]   | [96.799956, 67.600118] | 0.000017 |  0.199175 |
# | 210 | [ 3.795289, -3.137504] | 0.0000  | [96.992582, 67.670297]   | [96.800698, 67.598144] | 0.000024 |  0.205001 |
# | 220 | [ 3.795153, -3.137352] | 0.0000  | [96.984657, 67.668146]   | [96.800426, 67.598867] | 0.000020 |  0.196826 |
# | 230 | [ 3.795101, -3.137207] | 0.0000  | [96.979447, 67.665922]   | [96.800513, 67.598636] | 0.000014 |  0.191167 |
# | 240 | [ 3.795097, -3.137079] | 0.0000  | [96.97611, 67.66385]     | [96.800781, 67.597923] | 0.000013 |  0.187314 |
# | 250 | [ 3.795093, -3.136952] | 0.0000  | [96.97279 , 67.661789]   | [96.801048, 67.597214] | 0.000011 |  0.183481 |
# | 260 | [ 3.795089, -3.136838] | 0.0000  | [96.969825, 67.659948]   | [96.801286, 67.59658 ] | 0.000011 |  0.180057 |
# | 270 | [ 3.795085, -3.136725] | 0.0000  | [96.966859, 67.658106]   | [96.801525, 67.595945] | 0.000009 |  0.176634 |
# | 280 | [ 3.795082, -3.13662 ] | 0.0000  | [96.964134, 67.656414]   | [96.801749, 67.595348] | 0.000010 |  0.173488 |
# | 290 | [ 3.795079, -3.136514] | 0.0000  | [96.961375, 67.654701]   | [96.801966, 67.594773] | 0.000010 |  0.170302 |
# +-----+------------------------+---------+--------------------------+------------------------+----------+-----------+
# -> Điểm khả thi cố định: [ 3.7951 -3.1364]
# === [PREPARE] TÌM Z_STAR (IDEAL POINT) ===
# -> Z_star chiều 0: 75.23365940198717
# -> Z_star chiều 1: 25.502073366366705
# Số lượng cấu hình cần chạy: 54

# %%
# 3. VÒNG LẶP TUNING (Sử dụng hàm run_phase2_tuning)
best_mse = float('inf')
best_params = None
results = []

for params in tqdm(valid_params_list):
    pf_pred = run_phase2_tuning(prob, fixed_data, params)

    # Tính MSE
    mse = calculate_mse_igd(pf_pred, pf_true) # Hàm tính lỗi đã viết ở trên

    results.append({**params, 'mse': mse})

    if mse < best_mse:
        best_mse = mse
        best_params = params
        print(f"New Best: {mse:.5f} | {params}")


print(f"\n🏆 BEST MSE: {best_mse}")
print(f"🏆 BEST PARAMS: {best_params}")
# Out:
#   2%|▏         | 1/54 [00:34<30:27, 34.48s/it]
# New Best: 2.44396 | {'mu': 0.1, 'expo_lambda': 0.6, 'expo_alpha': 0.15, 'expo_beta': 0.6}
#   4%|▎         | 2/54 [01:11<31:17, 36.11s/it]
# New Best: 0.46782 | {'mu': 0.1, 'expo_lambda': 0.6, 'expo_alpha': 0.15, 'expo_beta': 0.8}
#   6%|▌         | 3/54 [01:55<33:36, 39.53s/it]
# New Best: 0.29499 | {'mu': 0.1, 'expo_lambda': 0.6, 'expo_alpha': 0.15, 'expo_beta': 1}
#  11%|█         | 6/54 [03:56<32:50, 41.06s/it]
# New Best: 0.18144 | {'mu': 0.1, 'expo_lambda': 0.6, 'expo_alpha': 0.25, 'expo_beta': 1}
#  17%|█▋        | 9/54 [06:03<32:07, 42.83s/it]
# New Best: 0.16592 | {'mu': 0.1, 'expo_lambda': 0.6, 'expo_alpha': 0.35, 'expo_beta': 1}
#  22%|██▏       | 12/54 [07:51<27:04, 38.68s/it]
# New Best: 0.07933 | {'mu': 0.1, 'expo_lambda': 0.75, 'expo_alpha': 0.15, 'expo_beta': 1}
#  28%|██▊       | 15/54 [09:43<24:44, 38.06s/it]
# New Best: 0.06354 | {'mu': 0.1, 'expo_lambda': 0.75, 'expo_alpha': 0.25, 'expo_beta': 1}
# 100%|██████████| 54/54 [34:00<00:00, 37.78s/it]
# 🏆 BEST MSE: 0.06354248550817498
# 🏆 BEST PARAMS: {'mu': 0.1, 'expo_lambda': 0.75, 'expo_alpha': 0.25, 'expo_beta': 1}

# %%
df_results = pd.DataFrame(results)
df_results = df_results.sort_values(by='mse')
df_results.head()
# Out:
#      mu  expo_lambda  expo_alpha  expo_beta       mse
# 14  0.1         0.75        0.25        1.0  0.063542
# 44  5.0         0.60        0.35        1.0  0.067262
# 32  1.0         0.75        0.25        1.0  0.072722
# 29  1.0         0.75        0.15        1.0  0.075584
# 11  0.1         0.75        0.15        1.0  0.079330

# %%
# Cập nhật lại config file với tham số tốt nhất lần cuối
update_yaml_params('config.yaml', best_params)
