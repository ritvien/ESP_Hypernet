# %%
n_rays = 10
case = "_Ex_7_1"

# %%
params = {
    "initialization": {
        "x_init": [0.5],
        "y_init": [0.8, 0.5]
    },
    "exact":{
        "learning_rate": 0.001,
        "max_iters": 20000,
        "tol": 1e-5
    },
    "phase1": {
        "gamma": 12,
        "expo_gamma": 0.01,
        "max_iter": 10000,
        "tol": 1e-4
    },
    "phase2": {
        "expo_alpha": 0.45,
        "expo_beta": 0.4,
        "expo_lambda": 0.55,
        "init_params": 1.0,
        "max_iter": 2000,
        "mu": 1e-4,
        "verbose": False,
        "expo_gamma": 0.5
    }
}

# %% [markdown]
# # Gen rays

# %%
import autograd.numpy as np
import math

# %%
def generate_chebyshev_rays(num_rays=10):
    rays = []
    angles = np.linspace(0, np.pi/2, num_rays)
    for theta in angles:
        r1, r2 = math.cos(theta), math.sin(theta)
        if abs(r1) < 1e-9: r1 = 0.0
        if abs(r2) < 1e-9: r2 = 0.0
        rays.append([r1, r2])       
    return np.array(rays)

# %%
test_rays = generate_chebyshev_rays(n_rays)

# %% [markdown]
# # Giải chính xác bằng phương pháp chiếu

# %% [markdown]
# ## Bài toán

# %%
# ==========================================
# HÀM MỤC TIÊU
# ==========================================
def f(x):    return np.array([x[0],(x[0] - 1)**2])
def f1(x):    return x[0]
def f2(x):    return (x[0] - 1)**2
def jacobian_f(x):
    return np.array([[1.0],[2.0 * (x[0] - 1)]])
# --- Hàm mục tiêu Weighted Chebyshev ---
def S_weighted_chebyshev(x, r, z):
    vals = f(x)
    weighted_diffs = r * np.abs(vals - z)
    return np.max(weighted_diffs)
# --- Tính Subgradient ---
def get_subgradient(x, r, z):
    """
    Tính đạo hàm của hàm max(r_i * |f_i - z_i|)
    """
    vals = f(x)
    diffs = vals - z
    weighted_abs_diffs = r * np.abs(diffs)
    k = np.argmax(weighted_abs_diffs)
    J = jacobian_f(x)
    gradient_fk = J[k] 
    sign = 1.0 if diffs[k] >= 0 else -1.0
    grad = r[k] * sign * gradient_fk
    return grad
# ==========================================
# CÁC RÀNG BUỘC & PHÉP CHIẾU
# ==========================================
# Ràng buộc tập X
def c1(x): return x[0]
def c2(x): return -x[0] + 1
# Ràng buộc tập Q
def q1(y): return 0.2**2 - (y[0] - 0.4)**2 - (y[1] - 0.4)**2
def q_plus(y):
    center = .4
    radius_sq = 0.2**2  
    dx = np.maximum(0, y[0] - center)
    dy = np.maximum(0, y[1] - center)
    return radius_sq - (dx**2 + dy**2)
dim_x = 1
dim_y = 2

# %% [markdown]
# ## Phép chiếu lên X'

# %%
from Problem import Problem
from project import Projection
from scipy.optimize import minimize

# %%
cons_C = ({'type': 'ineq', 'fun' : c1,},
          {'type': 'ineq', 'fun' : c2,})
cons_Q = ({'type': 'ineq', 'fun' : q1,},)
cons_Qplus = ({'type': 'ineq', 'fun': q_plus},)
# Setup Projections
proj_C_handler = Projection(cons=cons_C, bounds=None, dim=dim_x, proj_type='euclid')
proj_Q_handler = Projection(cons=cons_Q, bounds=None, dim=dim_y, proj_type='qplus')
# Setup Problem
prob = Problem(
    f=[f], jac_f=[jacobian_f],
    dim_x=dim_x, dim_y=dim_y,
    proj_C=proj_C_handler.project,
    proj_Qplus=proj_Q_handler.project
)

# %%
def project_step(x_temp, y_temp, dim_x, dim_y):
    """
    Chiếu điểm (x, y) vào tập:
    { (x, y) | x in X, y in Q, f(x) <= y }
    """
    z_start = np.concatenate([x_temp, y_temp])
    def proj_obj(z): 
        return 0.5 * np.sum((z - z_start)**2)
    def proj_jac(z): 
        return z - z_start
    cons = [
        # Ràng buộc x in X
        {'type': 'ineq', 'fun': lambda z: c1(z[:dim_x])},
        {'type': 'ineq', 'fun': lambda z: c2(z[:dim_x])},
        # Ràng buộc y in Q
        {'type': 'ineq', 'fun': lambda z: q1(z[dim_x:])},
        # Ràng buộc f(x) <= y  <=>  y - f(x) >= 0
        {'type': 'ineq', 'fun': lambda z: z[dim_x:] - f(z[:dim_x])}
    ]

    res = minimize(
        fun=proj_obj, x0=z_start, jac=proj_jac,
        constraints=cons, method='SLSQP',
        options={'disp': False}
    )
    
    if not res.success:
        return x_temp, y_temp
    return res.x[:dim_x], res.x[dim_x:]

# %% [markdown]
# ## Core

# %%
def solve_weighted_chebyshev(r_pref, z_ref, params , dim_x=1, dim_y=2):
    x = params["initialization"]["x_init"]    
    y = params["initialization"]["y_init"]
    learning_rate = params["exact"]["learning_rate"]
    max_iters = params["exact"]["max_iters"]
    tol = params["exact"]["tol"]
    prev_obj_val = float('inf')
    converge = False
    
    print(f"r={r_pref}")
    print(f"{'Iter':<5} | {'x':<10} | {'y vector':<15} | {'Objective':<10} | {'Active Idx'}")
    for k in range(max_iters):
        # --- BƯỚC 1: Tính Subgradient ---
        grad_x = get_subgradient(x, r_pref, z_ref)
        
        # --- BƯỚC 2: Cập nhật biến x ---
        x_temp = x - learning_rate * grad_x
        y_temp = y 
        
        # --- BƯỚC 3: Phép chiếu (Projection) ---
        x_next, y_next = project_step(x_temp, y_temp, dim_x, dim_y)
        
        # --- Tính giá trị hàm mục tiêu hiện tại ---
        obj_val = S_weighted_chebyshev(x_next, r_pref, z_ref)
        
        # --- Logging ---
        diffs = r_pref * np.abs(f(x_next) - z_ref)
        active_idx = np.argmax(diffs)
        
        if k % 2000 == 0:
            print(f"{k:<5} | {x_next[0]:.4f}     | [{y_next[0]:.2f}, {y_next[1]:.2f}] | {obj_val:.6f}     | f_{active_idx+1}")

        # --- BƯỚC 4: Kiểm tra điều kiện dừng ---
        loss_change = abs(prev_obj_val - obj_val)
        
        if loss_change < tol:
            print(f"--> Hội tụ tại bước {k}!\n")
            converge = True
            break
            
        prev_obj_val = obj_val
        x = x_next
        y = y_next

    return x, y, converge

# %% [markdown]
# ## Tìm điểm tham chiếu

# %%
from Phase1 import solve_CQ_feasible
from Phase2_1_obj import optim_Universal

# %%
def relevant_point(prob, params):
    x_feasible, _, _, _ = solve_CQ_feasible(
        prob.objective_func, prob.jacobian, prob.proj_C, prob.proj_Qplus,
        x0=params['initialization']['x_init'],
        gamma=params['phase1']['gamma'] , max_iter=params['phase1']['max_iter']
    )

    z_vals = []
    nadir_vals = []

    for dim in range(2):
        # Tìm MIN
        x_min, _ = optim_Universal(prob, x_feasible, target_dim=dim, mode="min", max_iter=500, mu=0.001)
        val_min = prob.objective_func(x_min)[dim]
        z_vals.append(val_min)

        # Tìm MAX 
        x_max, _ = optim_Universal(prob, x_feasible, target_dim=dim, mode="max", max_iter=500, mu=0.001)
        val_max = prob.objective_func(x_max)[dim]
        nadir_vals.append(val_max)
        print(f"   Dim {dim}: Min={val_min:.4f}, Max={val_max:.4f}")
    z_star = np.array(z_vals)
    ref_point = np.array(nadir_vals) + np.abs(np.array(nadir_vals)) * 0.1 + 0.5 
    print(f"-> Z* (Ideal): {z_star}")
    print(f"-> Ref Point (HV): {ref_point}")
    print(f"-> x (Feasible): {x_feasible}")
    return z_star, ref_point, x_feasible

# %% [markdown]
# ## Giải chính xác

# %%
z_star, ref_point, x_feasible = relevant_point(prob, params)
# Out:
# Khởi tạo: x0: [0.5]
# Chiếu lên C được: x: [0.5]
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Hội tụ tại vòng lặp 0
# +---+-------+---------+--------------+--------------+----------+----------+
# | k | x_new | gamma_k | y            | z_proj       |   e_x    |   e_f    |
# +---+-------+---------+--------------+--------------+----------+----------+
# | 0 | [0.5] | 12.0000 | [0.5 , 0.25] | [0.5 , 0.25] | 0.000000 | 0.000000 |
# +---+-------+---------+--------------+--------------+----------+----------+
#    Dim 0: Min=0.1494, Max=0.8189
#    Dim 1: Min=0.0795, Max=0.8102
# -> Z* (Ideal): [0.1494 0.0795]
# -> Ref Point (HV): [1.4008 1.3912]
# -> x (Feasible): [0.5]

# %%
pf_true = []
converge = 0
for r in test_rays:
    x, y, conv = solve_weighted_chebyshev(
        r_pref=r,
        z_ref=z_star, 
        dim_x=dim_x, 
        dim_y=dim_y,
        params=params)
    if conv:
        converge += 1
    pf_true.append(f(x))
print(f"Converge rate = {100*converge/len(test_rays)}%")
# Out:
# r=[1. 0.]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.4990     | [0.59, 0.45] | 0.349600     | f_1
# --> Hội tụ tại bước 961!
#
# r=[0.9848 0.1736]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.4990     | [0.59, 0.45] | 0.344304     | f_1
# --> Hội tụ tại bước 636!
#
# r=[0.9397 0.342 ]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.4991     | [0.59, 0.45] | 0.328573     | f_1
# --> Hội tụ tại bước 303!
#
# r=[0.866 0.5  ]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.4991     | [0.59, 0.45] | 0.302878     | f_1
# --> Hội tụ tại bước 185!
#
# r=[0.766  0.6428]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.4992     | [0.59, 0.45] | 0.267988     | f_1
# --> Hội tụ tại bước 147!
#
# r=[0.6428 0.766 ]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.4994     | [0.59, 0.45] | 0.224948     | f_1
# --> Hội tụ tại bước 104!
#
# r=[0.5   0.866]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.4995     | [0.59, 0.45] | 0.175050     | f_1
# --> Hội tụ tại bước 87!
#
# r=[0.342  0.9397]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.5009     | [0.59, 0.45] | 0.159315     | f_2
# 2000  | 0.5325     | [0.59, 0.45] | 0.131033     | f_1
# --> Hội tụ tại bước 3667!
#
# r=[0.1736 0.9848]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.5010     | [0.59, 0.45] | 0.166920     | f_2
# --> Hội tụ tại bước 276!
#
# r=[0. 1.]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.5010     | [0.59, 0.45] | 0.169479     | f_2
# --> Hội tụ tại bước 276!
#
# Converge rate = 100.0%

# %% [markdown]
# # Giải xấp xỉ dynamic

# %% [markdown]
# ## Tuning

# %%
from tuning_dynamic import tuning_dynamic

# %%
best_params, df = tuning_dynamic(
    prob, z_star, x_feasible, pf_true, ref_point, test_rays
)
# Out:
# === GRID SEARCH: ƯU TIÊN MED ===
# Số lượng cấu hình: 96 | Số tia: 10
# 0it [00:00, ?it/s]
# !! Max_iter. Delta: 0.029527, Gap C: 0.000001, Gap Q: 0.042603
# !! Max_iter. Delta: 0.029079, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014431, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.025548, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.023600, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.018957, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014742, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.010080, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.024060, Gap C: 0.000000, Gap Q: 0.000000
# 1it [00:23, 23.80s/it]
# !! Max_iter. Delta: 0.020648, Gap C: 0.000000, Gap Q: 0.035590
# [00] MED: 9.102502e-03 | HV: 1.312977
# !! Max_iter. Delta: 0.029527, Gap C: 0.000000, Gap Q: 0.038214
# !! Max_iter. Delta: 0.029079, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014431, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.025548, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.023600, Gap C: 0.000002, Gap Q: 0.000000
# !! Max_iter. Delta: 0.018957, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014742, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.010080, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.024060, Gap C: 0.000000, Gap Q: 0.000000
# 2it [00:47, 23.91s/it]
# !! Max_iter. Delta: 0.020199, Gap C: 0.000000, Gap Q: 0.072714
# [01] MED: 1.672653e-02 | HV: 1.305074
# !! Max_iter. Delta: 0.059054, Gap C: 0.000001, Gap Q: 0.010662
# !! Max_iter. Delta: 0.016199, Gap C: 0.000000, Gap Q: 0.074389
# !! Max_iter. Delta: 0.029502, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.040216, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.045238, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.037959, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.029485, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020198, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.049805, Gap C: 0.000000, Gap Q: 0.000000
# 3it [01:11, 23.66s/it]
# !! Max_iter. Delta: 0.044573, Gap C: 0.000000, Gap Q: 0.000003
# [02] MED: 2.019244e-02 | HV: 1.305109
# !! Max_iter. Delta: 0.055280, Gap C: 0.000000, Gap Q: 0.129955
# !! Max_iter. Delta: 0.016199, Gap C: 0.000000, Gap Q: 0.074389
# !! Max_iter. Delta: 0.029502, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.040216, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.045238, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.037959, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.029485, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020198, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.049805, Gap C: 0.000000, Gap Q: 0.000001
# 4it [01:34, 23.55s/it]
# !! Max_iter. Delta: 0.038893, Gap C: 0.000001, Gap Q: 0.100225
# [03] MED: 1.020726e-02 | HV: 1.305109
# !! Max_iter. Delta: 0.029527, Gap C: 0.000000, Gap Q: 0.013420
# !! Max_iter. Delta: 0.029079, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014431, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.025548, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.023600, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.018957, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014742, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.010080, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.024060, Gap C: 0.000000, Gap Q: 0.000000
# 5it [01:57, 23.27s/it]
# !! Max_iter. Delta: 0.023658, Gap C: 0.000000, Gap Q: 0.000000
# [04] MED: 6.179425e-03 | HV: 1.305754
# !! Max_iter. Delta: 0.029527, Gap C: 0.000000, Gap Q: 0.016066
# !! Max_iter. Delta: 0.029079, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014431, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.025548, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.023600, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.018957, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014742, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.010080, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.024060, Gap C: 0.000000, Gap Q: 0.000000
# 6it [02:20, 23.11s/it]
# !! Max_iter. Delta: 0.022394, Gap C: 0.000000, Gap Q: 0.006017
# [05] MED: 8.549481e-03 | HV: 1.305636
# !! Max_iter. Delta: 0.059054, Gap C: 0.000000, Gap Q: 0.012933
# !! Max_iter. Delta: 0.016199, Gap C: 0.000000, Gap Q: 0.074389
# !! Max_iter. Delta: 0.029502, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.040216, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.045238, Gap C: 0.000003, Gap Q: 0.000000
# !! Max_iter. Delta: 0.037959, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.029485, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020198, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.049805, Gap C: 0.000000, Gap Q: 0.000000
# 7it [02:43, 23.11s/it]
# !! Max_iter. Delta: 0.042377, Gap C: 0.000000, Gap Q: 0.070731
# [06] MED: 1.122234e-02 | HV: 1.306421
# !! Max_iter. Delta: 0.059054, Gap C: 0.000000, Gap Q: 0.000002
# !! Max_iter. Delta: 0.016199, Gap C: 0.000000, Gap Q: 0.074389
# !! Max_iter. Delta: 0.029502, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.040216, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.045238, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.037959, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.029485, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020198, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.049805, Gap C: 0.000000, Gap Q: 0.000000
# 8it [03:06, 23.06s/it]
# !! Max_iter. Delta: 0.044347, Gap C: 0.000000, Gap Q: 0.000000
# [07] MED: 1.879886e-02 | HV: 1.305109
# !! Max_iter. Delta: 0.029527, Gap C: 0.000000, Gap Q: 0.042812
# !! Max_iter. Delta: 0.029079, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014431, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.025548, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.023600, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.018957, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014742, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.010080, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.024060, Gap C: 0.000000, Gap Q: 0.000000
# 9it [03:29, 23.06s/it]
# !! Max_iter. Delta: 0.020648, Gap C: 0.000000, Gap Q: 0.035590
# [08] MED: 9.078534e-03 | HV: 1.313079
# !! Max_iter. Delta: 0.029527, Gap C: 0.000000, Gap Q: 0.037354
# !! Max_iter. Delta: 0.029079, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014431, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.025548, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.023600, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.018957, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014742, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.010080, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.024060, Gap C: 0.000000, Gap Q: 0.000000
# 10it [03:52, 23.07s/it]
# !! Max_iter. Delta: 0.019709, Gap C: 0.000000, Gap Q: 0.072572
# [09] MED: 1.660477e-02 | HV: 1.305074
# !! Max_iter. Delta: 0.059054, Gap C: 0.000000, Gap Q: 0.005564
# !! Max_iter. Delta: 0.016199, Gap C: 0.000000, Gap Q: 0.074389
# !! Max_iter. Delta: 0.029502, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.040216, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.045238, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.037959, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.029485, Gap C: 0.000002, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020198, Gap C: 0.000000, Gap Q: 0.000001
# !! Max_iter. Delta: 0.049805, Gap C: 0.000000, Gap Q: 0.000000
# 11it [04:15, 23.10s/it]
# !! Max_iter. Delta: 0.044351, Gap C: 0.000000, Gap Q: 0.054015
# [10] MED: 1.328762e-02 | HV: 1.349254
# !! Max_iter. Delta: 0.059054, Gap C: 0.000000, Gap Q: 0.117769
# !! Max_iter. Delta: 0.016199, Gap C: 0.000000, Gap Q: 0.074389
# !! Max_iter. Delta: 0.029502, Gap C: 0.000000, Gap Q: 0.000001
# !! Max_iter. Delta: 0.040216, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.045238, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.037959, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.029485, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020198, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.049805, Gap C: 0.000000, Gap Q: 0.000000
# 12it [04:38, 23.23s/it]
# !! Max_iter. Delta: 0.038956, Gap C: 0.000000, Gap Q: 0.099691
# [11] MED: 8.800287e-03 | HV: 1.305109
# !! Max_iter. Delta: 0.029527, Gap C: 0.000001, Gap Q: 0.034039
# !! Max_iter. Delta: 0.029079, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014431, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.025548, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.023600, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.018957, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014742, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.010080, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.024060, Gap C: 0.000000, Gap Q: 0.000000
# 13it [05:02, 23.27s/it]
# !! Max_iter. Delta: 0.023658, Gap C: 0.000000, Gap Q: 0.000000
# [12] MED: 3.803936e-03 | HV: 1.308754
# !! Max_iter. Delta: 0.029527, Gap C: 0.000000, Gap Q: 0.012342
# !! Max_iter. Delta: 0.029079, Gap C: 0.000002, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014431, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.025548, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.023600, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.018957, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014742, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.010080, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.024060, Gap C: 0.000000, Gap Q: 0.000000
# 14it [05:25, 23.17s/it]
# !! Max_iter. Delta: 0.022404, Gap C: 0.000000, Gap Q: 0.005850
# [13] MED: 8.958576e-03 | HV: 1.305799
# !! Max_iter. Delta: 0.059054, Gap C: 0.000000, Gap Q: 0.016070
# !! Max_iter. Delta: 0.016199, Gap C: 0.000000, Gap Q: 0.074389
# !! Max_iter. Delta: 0.029502, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.040216, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.045238, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.037959, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.029485, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020198, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.049805, Gap C: 0.000000, Gap Q: 0.000000
# 15it [05:48, 23.19s/it]
# !! Max_iter. Delta: 0.042300, Gap C: 0.000000, Gap Q: 0.012325
# [14] MED: 1.509520e-02 | HV: 1.322800
# !! Max_iter. Delta: 0.059054, Gap C: 0.000000, Gap Q: 0.000002
# !! Max_iter. Delta: 0.016199, Gap C: 0.000001, Gap Q: 0.074389
# !! Max_iter. Delta: 0.029502, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.040216, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.045238, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.037959, Gap C: 0.000000, Gap Q: 0.000001
# !! Max_iter. Delta: 0.029485, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020198, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.049805, Gap C: 0.000000, Gap Q: 0.000000
# 16it [06:11, 23.10s/it]
# !! Max_iter. Delta: 0.044407, Gap C: 0.000000, Gap Q: 0.000000
# [15] MED: 1.878031e-02 | HV: 1.305109
# !! Max_iter. Delta: 0.029527, Gap C: 0.000000, Gap Q: 0.013240
# !! Max_iter. Delta: 0.029079, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014431, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.025548, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.023600, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.018957, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014742, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.010080, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.024060, Gap C: 0.000001, Gap Q: 0.000000
# 17it [06:34, 23.07s/it]
# !! Max_iter. Delta: 0.022982, Gap C: 0.000000, Gap Q: 0.000000
# [16] MED: 1.151000e-02 | HV: 1.305074
# !! Max_iter. Delta: 0.029527, Gap C: 0.000000, Gap Q: 0.015397
# !! Max_iter. Delta: 0.029079, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014431, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.025548, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.023600, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.018957, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014742, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.010080, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.024060, Gap C: 0.000000, Gap Q: 0.000000
# 18it [06:57, 22.97s/it]
# !! Max_iter. Delta: 0.021828, Gap C: 0.000000, Gap Q: 0.015604
# [17] MED: 9.807179e-03 | HV: 1.305667
# !! Max_iter. Delta: 0.059054, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.016199, Gap C: 0.000000, Gap Q: 0.074389
# !! Max_iter. Delta: 0.029502, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.040216, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.045238, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.037959, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.029485, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020198, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.049805, Gap C: 0.000000, Gap Q: 0.000000
# 19it [07:20, 23.01s/it]
# !! Max_iter. Delta: 0.043583, Gap C: 0.000000, Gap Q: 0.060518
# [18] MED: 4.149137e-03 | HV: 1.305109
# !! Max_iter. Delta: 0.059054, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.016199, Gap C: 0.000000, Gap Q: 0.074389
# !! Max_iter. Delta: 0.029502, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.040216, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.045238, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.037959, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.029485, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020198, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.049805, Gap C: 0.000000, Gap Q: 0.000000
# 20it [07:43, 22.97s/it]
# !! Max_iter. Delta: 0.048536, Gap C: 0.000000, Gap Q: 0.018578
# [19] MED: 7.832752e-03 | HV: 1.325993
# !! Max_iter. Delta: 0.029527, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.029079, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014431, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.025548, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.023600, Gap C: 0.000002, Gap Q: 0.000000
# !! Max_iter. Delta: 0.018957, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014742, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.010080, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.024060, Gap C: 0.000000, Gap Q: 0.000000
# 21it [08:05, 22.90s/it]
# !! Max_iter. Delta: 0.022556, Gap C: 0.000000, Gap Q: 0.003291
# [20] MED: 6.087931e-03 | HV: 1.305074
# !! Max_iter. Delta: 0.029527, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.029079, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014431, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.025548, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.023600, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.018957, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014742, Gap C: 0.000000, Gap Q: 0.000011
# !! Max_iter. Delta: 0.010080, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.024060, Gap C: 0.000000, Gap Q: 0.000000
# 22it [08:28, 22.86s/it]
# !! Max_iter. Delta: 0.023822, Gap C: 0.000000, Gap Q: 0.000000
# [21] MED: 7.515255e-03 | HV: 1.305074
# !! Max_iter. Delta: 0.059054, Gap C: 0.000000, Gap Q: 0.019203
# !! Max_iter. Delta: 0.016199, Gap C: 0.000001, Gap Q: 0.074389
# !! Max_iter. Delta: 0.029502, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.040216, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.045238, Gap C: 0.000003, Gap Q: 0.000000
# !! Max_iter. Delta: 0.037959, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.029485, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020198, Gap C: 0.000000, Gap Q: 0.000002
# !! Max_iter. Delta: 0.049805, Gap C: 0.000001, Gap Q: 0.000000
# 23it [08:51, 22.86s/it]
# !! Max_iter. Delta: 0.047199, Gap C: 0.000000, Gap Q: 0.029904
# [22] MED: 1.240703e-02 | HV: 1.335268
# !! Max_iter. Delta: 0.059054, Gap C: 0.000000, Gap Q: 0.041612
# !! Max_iter. Delta: 0.016199, Gap C: 0.000000, Gap Q: 0.074388
# !! Max_iter. Delta: 0.029502, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.040216, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.045238, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.037959, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.029485, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020198, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.049805, Gap C: 0.000000, Gap Q: 0.000000
# 24it [09:14, 22.93s/it]
# !! Max_iter. Delta: 0.044807, Gap C: 0.000000, Gap Q: 0.050158
# [23] MED: 7.256251e-03 | HV: 1.348174
# !! Max_iter. Delta: 0.029527, Gap C: 0.000002, Gap Q: 0.048782
# !! Max_iter. Delta: 0.029079, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014431, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.025548, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.023600, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.018957, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014742, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.010080, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.024060, Gap C: 0.000000, Gap Q: 0.000000
# 25it [09:37, 22.87s/it]
# !! Max_iter. Delta: 0.022982, Gap C: 0.000000, Gap Q: 0.000000
# [24] MED: 4.630590e-03 | HV: 1.305074
# !! Max_iter. Delta: 0.029527, Gap C: 0.000000, Gap Q: 0.060145
# !! Max_iter. Delta: 0.029079, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014431, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.025548, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.023600, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.018957, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014742, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.010080, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.024060, Gap C: 0.000001, Gap Q: 0.000000
# 26it [10:00, 22.89s/it]
# !! Max_iter. Delta: 0.021815, Gap C: 0.000000, Gap Q: 0.015833
# [25] MED: 8.376766e-03 | HV: 1.305074
# !! Max_iter. Delta: 0.059054, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.016199, Gap C: 0.000000, Gap Q: 0.074389
# !! Max_iter. Delta: 0.029502, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.040216, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.045238, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.037959, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.029485, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020198, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.049805, Gap C: 0.000000, Gap Q: 0.000000
# 27it [10:23, 23.01s/it]
# !! Max_iter. Delta: 0.041869, Gap C: 0.000000, Gap Q: 0.015975
# [26] MED: 1.891125e-02 | HV: 1.305109
# !! Max_iter. Delta: 0.059054, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.016199, Gap C: 0.000000, Gap Q: 0.074389
# !! Max_iter. Delta: 0.029502, Gap C: 0.000001, Gap Q: 0.000005
# !! Max_iter. Delta: 0.040216, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.045238, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.037959, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.029485, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020198, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.049805, Gap C: 0.000000, Gap Q: 0.000000
# 28it [10:46, 22.94s/it]
# !! Max_iter. Delta: 0.048549, Gap C: 0.000000, Gap Q: 0.018474
# [27] MED: 7.862824e-03 | HV: 1.325917
# !! Max_iter. Delta: 0.029527, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.029079, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014431, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.025548, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.023600, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.018957, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014742, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.010080, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.024060, Gap C: 0.000000, Gap Q: 0.000000
# 29it [11:08, 22.84s/it]
# !! Max_iter. Delta: 0.023716, Gap C: 0.000000, Gap Q: 0.000001
# [28] MED: 3.688690e-03 | HV: 1.305074
# !! Max_iter. Delta: 0.029527, Gap C: 0.000000, Gap Q: 0.041181
# !! Max_iter. Delta: 0.029079, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014431, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.025548, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.023600, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.018957, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014742, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.010080, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.024060, Gap C: 0.000000, Gap Q: 0.000000
# 30it [11:31, 22.81s/it]
# !! Max_iter. Delta: 0.023839, Gap C: 0.000000, Gap Q: 0.000000
# [29] MED: 2.597001e-03 | HV: 1.312284
# !! Max_iter. Delta: 0.059054, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.016199, Gap C: 0.000000, Gap Q: 0.074387
# !! Max_iter. Delta: 0.029502, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.040216, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.045238, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.037959, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.029485, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020198, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.049805, Gap C: 0.000000, Gap Q: 0.000000
# 31it [11:54, 22.84s/it]
# !! Max_iter. Delta: 0.043425, Gap C: 0.000000, Gap Q: 0.061853
# [30] MED: 6.542449e-03 | HV: 1.305109
# !! Max_iter. Delta: 0.059054, Gap C: 0.000000, Gap Q: 0.041406
# !! Max_iter. Delta: 0.016199, Gap C: 0.000000, Gap Q: 0.074389
# !! Max_iter. Delta: 0.029502, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.040216, Gap C: 0.000000, Gap Q: 0.000038
# !! Max_iter. Delta: 0.045238, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.037959, Gap C: 0.000002, Gap Q: 0.000000
# !! Max_iter. Delta: 0.029485, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020198, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.049805, Gap C: 0.000000, Gap Q: 0.000000
# 32it [12:17, 22.91s/it]
# !! Max_iter. Delta: 0.043618, Gap C: 0.000000, Gap Q: 0.060226
# [31] MED: 6.695793e-03 | HV: 1.306363
# !! Max_iter. Delta: 0.029527, Gap C: 0.000000, Gap Q: 0.005126
# !! Max_iter. Delta: 0.029079, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014431, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.025548, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.023600, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.018957, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014742, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.010080, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.024060, Gap C: 0.000002, Gap Q: 0.000000
# 33it [12:40, 22.93s/it]
# !! Max_iter. Delta: 0.022567, Gap C: 0.000000, Gap Q: 0.003094
# [32] MED: 9.451417e-03 | HV: 1.306065
# !! Max_iter. Delta: 0.029527, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.029079, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014431, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.025548, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.023600, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.018957, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014742, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.010080, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.024060, Gap C: 0.000000, Gap Q: 0.000000
# 34it [13:03, 22.94s/it]
# !! Max_iter. Delta: 0.022495, Gap C: 0.000000, Gap Q: 0.004314
# [33] MED: 1.062515e-02 | HV: 1.305074
# !! Max_iter. Delta: 0.059054, Gap C: 0.000000, Gap Q: 0.000784
# !! Max_iter. Delta: 0.016199, Gap C: 0.000000, Gap Q: 0.074388
# !! Max_iter. Delta: 0.029502, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.040216, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.045238, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.037959, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.029485, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020198, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.049805, Gap C: 0.000000, Gap Q: 0.000000
# 35it [13:26, 22.95s/it]
# !! Max_iter. Delta: 0.046482, Gap C: 0.000000, Gap Q: 0.035972
# [34] MED: 1.499783e-02 | HV: 1.337934
# !! Max_iter. Delta: 0.059054, Gap C: 0.000000, Gap Q: 0.050492
# !! Max_iter. Delta: 0.016199, Gap C: 0.000000, Gap Q: 0.074389
# !! Max_iter. Delta: 0.029502, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.040216, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.045238, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.037959, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.029485, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020198, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.049805, Gap C: 0.000000, Gap Q: 0.000000
# 36it [13:49, 23.01s/it]
# !! Max_iter. Delta: 0.044253, Gap C: 0.000000, Gap Q: 0.054847
# [35] MED: 5.660955e-03 | HV: 1.350784
# !! Max_iter. Delta: 0.029527, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.029079, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014431, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.025548, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.023600, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.018957, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014742, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.010080, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005127, Gap C: 0.000001, Gap Q: 0.030578
# 37it [14:12, 22.91s/it]
# !! Max_iter. Delta: 0.024290, Gap C: 0.000000, Gap Q: 0.003441
# [36] MED: 5.011350e-03 | HV: 1.335923
# !! Max_iter. Delta: 0.029527, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.029079, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014431, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.025548, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.023600, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.018957, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014742, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.010080, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.016572, Gap C: 0.000001, Gap Q: 0.008463
# 38it [14:34, 22.81s/it]
# !! Max_iter. Delta: 0.023713, Gap C: 0.000001, Gap Q: 0.000000
# [37] MED: 8.675103e-03 | HV: 1.339232
# !! Max_iter. Delta: 0.059054, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.016199, Gap C: 0.000000, Gap Q: 0.074389
# !! Max_iter. Delta: 0.029502, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.040216, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.045238, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.037959, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.029485, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020198, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.049805, Gap C: 0.000000, Gap Q: 0.000000
# 39it [14:57, 22.85s/it]
# !! Max_iter. Delta: 0.045781, Gap C: 0.000000, Gap Q: 0.041905
# [38] MED: 1.248079e-02 | HV: 1.341774
# !! Max_iter. Delta: 0.059054, Gap C: 0.000000, Gap Q: 0.068907
# !! Max_iter. Delta: 0.016199, Gap C: 0.000001, Gap Q: 0.074389
# !! Max_iter. Delta: 0.029502, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.040216, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.045238, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.037959, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.029485, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020198, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006910, Gap C: 0.000000, Gap Q: 0.056631
# 40it [15:20, 22.84s/it]
# !! Max_iter. Delta: 0.049811, Gap C: 0.000001, Gap Q: 0.007788
# [39] MED: 9.559470e-03 | HV: 1.351845
# !! Max_iter. Delta: 0.029527, Gap C: 0.000000, Gap Q: 0.006535
# !! Max_iter. Delta: 0.029079, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014431, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.025548, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.023600, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.018957, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014742, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.010080, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.024060, Gap C: 0.000000, Gap Q: 0.000000
# 41it [15:43, 22.79s/it]
# !! Max_iter. Delta: 0.023284, Gap C: 0.000000, Gap Q: 0.020489
# [40] MED: 5.935992e-03 | HV: 1.347760
# !! Max_iter. Delta: 0.029527, Gap C: 0.000000, Gap Q: 0.000643
# !! Max_iter. Delta: 0.029079, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014431, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.025548, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.023600, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.018957, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014742, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.010080, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.024060, Gap C: 0.000000, Gap Q: 0.000000
# 42it [16:06, 22.84s/it]
# !! Max_iter. Delta: 0.022555, Gap C: 0.000000, Gap Q: 0.003302
# [41] MED: 1.087369e-02 | HV: 1.305074
# !! Max_iter. Delta: 0.059054, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.016199, Gap C: 0.000000, Gap Q: 0.074389
# !! Max_iter. Delta: 0.029502, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.040216, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.045238, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.037959, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.029485, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020198, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.049805, Gap C: 0.000001, Gap Q: 0.000000
# 43it [16:29, 22.91s/it]
# !! Max_iter. Delta: 0.044765, Gap C: 0.000002, Gap Q: 0.050511
# [42] MED: 1.208460e-02 | HV: 1.347140
# !! Max_iter. Delta: 0.059054, Gap C: 0.000000, Gap Q: 0.041320
# !! Max_iter. Delta: 0.016199, Gap C: 0.000000, Gap Q: 0.074389
# !! Max_iter. Delta: 0.029502, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.040216, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.045238, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.037959, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.029485, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020198, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.049805, Gap C: 0.000000, Gap Q: 0.000000
# 44it [16:52, 22.93s/it]
# !! Max_iter. Delta: 0.043155, Gap C: 0.000001, Gap Q: 0.064139
# [43] MED: 7.204907e-03 | HV: 1.306365
# !! Max_iter. Delta: 0.029527, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.029079, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014431, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.025548, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.023600, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.018957, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014742, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.010080, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005127, Gap C: 0.000000, Gap Q: 0.030579
# 45it [17:15, 22.86s/it]
# !! Max_iter. Delta: 0.023278, Gap C: 0.000000, Gap Q: 0.020588
# [44] MED: 3.026023e-03 | HV: 1.346876
# !! Max_iter. Delta: 0.029527, Gap C: 0.000000, Gap Q: 0.044690
# !! Max_iter. Delta: 0.029079, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014431, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.025548, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.023600, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.018957, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014742, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.010080, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.010995, Gap C: 0.000000, Gap Q: 0.014052
# 46it [17:37, 22.80s/it]
# !! Max_iter. Delta: 0.024363, Gap C: 0.000000, Gap Q: 0.000000
# [45] MED: 2.651346e-03 | HV: 1.342817
# !! Max_iter. Delta: 0.059054, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.016199, Gap C: 0.000000, Gap Q: 0.074389
# !! Max_iter. Delta: 0.029502, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.040216, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.045238, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.037959, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.029485, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020198, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.049805, Gap C: 0.000000, Gap Q: 0.000000
# 47it [18:00, 22.83s/it]
# !! Max_iter. Delta: 0.047945, Gap C: 0.000000, Gap Q: 0.023587
# [46] MED: 1.499950e-02 | HV: 1.329536
# !! Max_iter. Delta: 0.059054, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.016199, Gap C: 0.000000, Gap Q: 0.074387
# !! Max_iter. Delta: 0.029502, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.040216, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.045238, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.037959, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.029485, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020198, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.025677, Gap C: 0.000001, Gap Q: 0.023993
# 48it [18:23, 22.80s/it]
# !! Max_iter. Delta: 0.048248, Gap C: 0.000000, Gap Q: 0.021019
# [47] MED: 1.208673e-02 | HV: 1.329900
# !! Max_iter. Delta: 0.011227, Gap C: 0.000000, Gap Q: 0.044345
# !! Max_iter. Delta: 0.002985, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005425, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007377, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.008601, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007217, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005614, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003840, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.008939, Gap C: 0.000000, Gap Q: 0.000020
# 49it [18:46, 22.80s/it]
# !! Max_iter. Delta: 0.007953, Gap C: 0.000000, Gap Q: 0.051446
# [48] MED: 1.402052e-02 | HV: 1.296123
# !! Max_iter. Delta: 0.011227, Gap C: 0.000000, Gap Q: 0.056350
# !! Max_iter. Delta: 0.002985, Gap C: 0.000000, Gap Q: 0.000002
# !! Max_iter. Delta: 0.005425, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007377, Gap C: 0.000003, Gap Q: 0.000000
# !! Max_iter. Delta: 0.008601, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007217, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005614, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003840, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.008939, Gap C: 0.000000, Gap Q: 0.000000
# 50it [19:08, 22.79s/it]
# !! Max_iter. Delta: 0.007874, Gap C: 0.000000, Gap Q: 0.054940
# [49] MED: 1.584823e-02 | HV: 1.296123
# !! Max_iter. Delta: 0.022455, Gap C: 0.000000, Gap Q: 0.040742
# !! Max_iter. Delta: 0.022114, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.010919, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.019447, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.017202, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.019823, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020661, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020217, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.018142, Gap C: 0.000000, Gap Q: 0.001037
# 51it [19:31, 22.84s/it]
# !! Max_iter. Delta: 0.016083, Gap C: 0.000000, Gap Q: 0.053122
# [50] MED: 2.515318e-02 | HV: 1.320343
# !! Max_iter. Delta: 0.022455, Gap C: 0.000000, Gap Q: 0.072383
# !! Max_iter. Delta: 0.022114, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.010919, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.019447, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.017202, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.019823, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020661, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020217, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.018142, Gap C: 0.000000, Gap Q: 0.001037
# 52it [19:54, 22.90s/it]
# !! Max_iter. Delta: 0.015494, Gap C: 0.000000, Gap Q: 0.043762
# [51] MED: 3.313699e-02 | HV: 1.320343
# !! Max_iter. Delta: 0.011227, Gap C: 0.000000, Gap Q: 0.008015
# !! Max_iter. Delta: 0.002985, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005425, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007377, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.008601, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007217, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005614, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003840, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.008939, Gap C: 0.000000, Gap Q: 0.000000
# 53it [20:17, 22.88s/it]
# !! Max_iter. Delta: 0.008699, Gap C: 0.000000, Gap Q: 0.018211
# [52] MED: 9.763803e-03 | HV: 1.296123
# !! Max_iter. Delta: 0.011227, Gap C: 0.000001, Gap Q: 0.009548
# !! Max_iter. Delta: 0.002985, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005425, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007377, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.008601, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007217, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005614, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003840, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.008939, Gap C: 0.000000, Gap Q: 0.000000
# 54it [20:40, 22.89s/it]
# !! Max_iter. Delta: 0.008594, Gap C: 0.000000, Gap Q: 0.011647
# [53] MED: 1.195146e-02 | HV: 1.296123
# !! Max_iter. Delta: 0.022455, Gap C: 0.000000, Gap Q: 0.031326
# !! Max_iter. Delta: 0.022114, Gap C: 0.000003, Gap Q: 0.000000
# !! Max_iter. Delta: 0.010919, Gap C: 0.000002, Gap Q: 0.000000
# !! Max_iter. Delta: 0.019447, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.017202, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.019823, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020661, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020217, Gap C: 0.000002, Gap Q: 0.000000
# !! Max_iter. Delta: 0.018142, Gap C: 0.000000, Gap Q: 0.001035
# 55it [21:03, 22.86s/it]
# !! Max_iter. Delta: 0.017709, Gap C: 0.000001, Gap Q: 0.016907
# [54] MED: 2.083465e-02 | HV: 1.355593
# !! Max_iter. Delta: 0.022455, Gap C: 0.000000, Gap Q: 0.016874
# !! Max_iter. Delta: 0.022114, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.010919, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.019447, Gap C: 0.000002, Gap Q: 0.000000
# !! Max_iter. Delta: 0.017202, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.019823, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020661, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020217, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.018142, Gap C: 0.000000, Gap Q: 0.001037
# 56it [21:26, 22.86s/it]
# !! Max_iter. Delta: 0.017009, Gap C: 0.000000, Gap Q: 0.032486
# [55] MED: 2.348359e-02 | HV: 1.320990
# !! Max_iter. Delta: 0.011227, Gap C: 0.000004, Gap Q: 0.044347
# !! Max_iter. Delta: 0.002985, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005425, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007377, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.008601, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007217, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005614, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003840, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.008939, Gap C: 0.000000, Gap Q: 0.000001
# 57it [21:49, 22.86s/it]
# !! Max_iter. Delta: 0.007954, Gap C: 0.000000, Gap Q: 0.051408
# [56] MED: 1.401612e-02 | HV: 1.296123
# !! Max_iter. Delta: 0.011227, Gap C: 0.000001, Gap Q: 0.056763
# !! Max_iter. Delta: 0.002985, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005425, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007377, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.008601, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007217, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005614, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003840, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.008939, Gap C: 0.000000, Gap Q: 0.000000
# 58it [22:12, 22.85s/it]
# !! Max_iter. Delta: 0.007877, Gap C: 0.000000, Gap Q: 0.054829
# [57] MED: 1.588259e-02 | HV: 1.296123
# !! Max_iter. Delta: 0.022455, Gap C: 0.000000, Gap Q: 0.075326
# !! Max_iter. Delta: 0.022114, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.010919, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.019447, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.017202, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.019823, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020661, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020217, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.018142, Gap C: 0.000000, Gap Q: 0.001035
# 59it [22:35, 22.91s/it]
# !! Max_iter. Delta: 0.016083, Gap C: 0.000000, Gap Q: 0.053122
# [58] MED: 2.913453e-02 | HV: 1.320343
# !! Max_iter. Delta: 0.022455, Gap C: 0.000000, Gap Q: 0.053435
# !! Max_iter. Delta: 0.022114, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.010919, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.019447, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.017202, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.019823, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020661, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020217, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.018142, Gap C: 0.000000, Gap Q: 0.001037
# 60it [22:58, 22.95s/it]
# !! Max_iter. Delta: 0.015539, Gap C: 0.000000, Gap Q: 0.042777
# [59] MED: 3.083955e-02 | HV: 1.320343
# !! Max_iter. Delta: 0.011227, Gap C: 0.000000, Gap Q: 0.021184
# !! Max_iter. Delta: 0.002985, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005425, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007377, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.008601, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007217, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005614, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003840, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.008939, Gap C: 0.000000, Gap Q: 0.000000
# 61it [23:20, 22.91s/it]
# !! Max_iter. Delta: 0.008699, Gap C: 0.000000, Gap Q: 0.018211
# [60] MED: 7.152679e-03 | HV: 1.296123
# !! Max_iter. Delta: 0.011227, Gap C: 0.000000, Gap Q: 0.009260
# !! Max_iter. Delta: 0.002985, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005425, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007377, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.008601, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007217, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005614, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003840, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.008939, Gap C: 0.000000, Gap Q: 0.000109
# 62it [23:43, 22.90s/it]
# !! Max_iter. Delta: 0.008595, Gap C: 0.000002, Gap Q: 0.011630
# [61] MED: 1.191487e-02 | HV: 1.296123
# !! Max_iter. Delta: 0.022455, Gap C: 0.000000, Gap Q: 0.009405
# !! Max_iter. Delta: 0.022114, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.010919, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.019447, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.017202, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.019823, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020661, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020217, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.018142, Gap C: 0.000000, Gap Q: 0.001036
# 63it [24:06, 22.95s/it]
# !! Max_iter. Delta: 0.017545, Gap C: 0.000000, Gap Q: 0.020564
# [62] MED: 2.580794e-02 | HV: 1.320343
# !! Max_iter. Delta: 0.022455, Gap C: 0.000000, Gap Q: 0.031859
# !! Max_iter. Delta: 0.022114, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.010919, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.019447, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.017202, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.019823, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020661, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020217, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.018142, Gap C: 0.000000, Gap Q: 0.001037
# 64it [24:29, 22.94s/it]
# !! Max_iter. Delta: 0.016933, Gap C: 0.000000, Gap Q: 0.034180
# [63] MED: 2.195997e-02 | HV: 1.328512
# !! Max_iter. Delta: 0.011227, Gap C: 0.000000, Gap Q: 0.001833
# !! Max_iter. Delta: 0.002985, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005425, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007377, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.008601, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007217, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005614, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003840, Gap C: 0.000002, Gap Q: 0.000000
# !! Max_iter. Delta: 0.008939, Gap C: 0.000000, Gap Q: 0.000000
# 65it [24:52, 22.90s/it]
# !! Max_iter. Delta: 0.008513, Gap C: 0.000000, Gap Q: 0.026494
# [64] MED: 1.007102e-02 | HV: 1.296123
# !! Max_iter. Delta: 0.011227, Gap C: 0.000000, Gap Q: 0.013319
# !! Max_iter. Delta: 0.002985, Gap C: 0.000000, Gap Q: 0.000005
# !! Max_iter. Delta: 0.005425, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007377, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.008601, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007217, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005614, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003840, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.008939, Gap C: 0.000000, Gap Q: 0.000000
# 66it [25:15, 22.93s/it]
# !! Max_iter. Delta: 0.008501, Gap C: 0.000000, Gap Q: 0.027037
# [65] MED: 1.151772e-02 | HV: 1.296123
# !! Max_iter. Delta: 0.022455, Gap C: 0.000000, Gap Q: 0.015430
# !! Max_iter. Delta: 0.022114, Gap C: 0.000003, Gap Q: 0.000000
# !! Max_iter. Delta: 0.010919, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.019447, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.017202, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.019823, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020661, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020217, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.018142, Gap C: 0.000000, Gap Q: 0.001036
# 67it [25:38, 22.88s/it]
# !! Max_iter. Delta: 0.017445, Gap C: 0.000000, Gap Q: 0.022784
# [66] MED: 2.241476e-02 | HV: 1.351284
# !! Max_iter. Delta: 0.022455, Gap C: 0.000000, Gap Q: 0.000001
# !! Max_iter. Delta: 0.022114, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.010919, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.019447, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.017202, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.019823, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020661, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020217, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.018142, Gap C: 0.000000, Gap Q: 0.001036
# 68it [26:01, 22.85s/it]
# !! Max_iter. Delta: 0.016718, Gap C: 0.000000, Gap Q: 0.016510
# [67] MED: 2.896248e-02 | HV: 1.320343
# !! Max_iter. Delta: 0.011227, Gap C: 0.000000, Gap Q: 0.005713
# !! Max_iter. Delta: 0.002985, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005425, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007377, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.008601, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007217, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005614, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003840, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.008939, Gap C: 0.000000, Gap Q: 0.000000
# 69it [26:23, 22.83s/it]
# !! Max_iter. Delta: 0.009009, Gap C: 0.000000, Gap Q: 0.004418
# [68] MED: 8.624800e-03 | HV: 1.300029
# !! Max_iter. Delta: 0.011227, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002985, Gap C: 0.000000, Gap Q: 0.000085
# ...
# !! Max_iter. Delta: 0.008601, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007217, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005614, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003840, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.008939, Gap C: 0.000000, Gap Q: 0.000000
# 74it [28:17, 22.80s/it]
# !! Max_iter. Delta: 0.008499, Gap C: 0.000000, Gap Q: 0.027138
# [73] MED: 1.152074e-02 | HV: 1.296123
# !! Max_iter. Delta: 0.022455, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.022114, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.010919, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.019447, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.017202, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.019823, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020661, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020217, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.018142, Gap C: 0.000000, Gap Q: 0.001037
# 75it [28:40, 22.79s/it]
# !! Max_iter. Delta: 0.017686, Gap C: 0.000000, Gap Q: 0.000000
# [74] MED: 2.552528e-02 | HV: 1.320343
# !! Max_iter. Delta: 0.022455, Gap C: 0.000000, Gap Q: 0.038612
# !! Max_iter. Delta: 0.022114, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.010919, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.019447, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.017202, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.019823, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020661, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020217, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.018142, Gap C: 0.000000, Gap Q: 0.001037
# 76it [29:03, 22.81s/it]
# !! Max_iter. Delta: 0.016739, Gap C: 0.000000, Gap Q: 0.016041
# [75] MED: 2.587274e-02 | HV: 1.320343
# !! Max_iter. Delta: 0.011227, Gap C: 0.000000, Gap Q: 0.005595
# !! Max_iter. Delta: 0.002985, Gap C: 0.000000, Gap Q: 0.000001
# !! Max_iter. Delta: 0.005425, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007377, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.008601, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007217, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005614, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003840, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.008939, Gap C: 0.000000, Gap Q: 0.000000
# 77it [29:26, 22.79s/it]
# !! Max_iter. Delta: 0.008757, Gap C: 0.000000, Gap Q: 0.004416
# [76] MED: 8.638190e-03 | HV: 1.299970
# !! Max_iter. Delta: 0.011227, Gap C: 0.000000, Gap Q: 0.000548
# !! Max_iter. Delta: 0.002985, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005425, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007377, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.008601, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007217, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005614, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003840, Gap C: 0.000000, Gap Q: 0.000022
# !! Max_iter. Delta: 0.008939, Gap C: 0.000002, Gap Q: 0.000000
# 78it [29:48, 22.74s/it]
# !! Max_iter. Delta: 0.008961, Gap C: 0.000000, Gap Q: 0.006527
# [77] MED: 7.714582e-03 | HV: 1.349030
# !! Max_iter. Delta: 0.022455, Gap C: 0.000000, Gap Q: 0.019451
# !! Max_iter. Delta: 0.022114, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.010919, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.019447, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.017202, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.019823, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020661, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020217, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.018142, Gap C: 0.000000, Gap Q: 0.001960
# 79it [30:11, 22.74s/it]
# !! Max_iter. Delta: 0.018193, Gap C: 0.000000, Gap Q: 0.006130
# [78] MED: 2.360625e-02 | HV: 1.342780
# !! Max_iter. Delta: 0.022455, Gap C: 0.000000, Gap Q: 0.027821
# !! Max_iter. Delta: 0.022114, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.010919, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.019447, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.017202, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.019823, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020661, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.020217, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.018142, Gap C: 0.000001, Gap Q: 0.003232
# 80it [30:34, 22.74s/it]
# !! Max_iter. Delta: 0.018217, Gap C: 0.000000, Gap Q: 0.005585
# [79] MED: 2.270669e-02 | HV: 1.346633
# !! Max_iter. Delta: 0.003984, Gap C: 0.000000, Gap Q: 0.044249
# !! Max_iter. Delta: 0.003924, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003739, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003450, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003122, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002561, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001992, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003518, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000692, Gap C: 0.000000, Gap Q: 0.001051
# 81it [30:57, 22.82s/it]
# !! Max_iter. Delta: 0.002819, Gap C: 0.000001, Gap Q: 0.044241
# [80] MED: 1.419250e-02 | HV: 1.350316
# !! Max_iter. Delta: 0.003984, Gap C: 0.000001, Gap Q: 0.044947
# !! Max_iter. Delta: 0.003924, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003739, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003450, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003122, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002561, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001992, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003518, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000692, Gap C: 0.000000, Gap Q: 0.001598
# 82it [31:20, 22.84s/it]
# !! Max_iter. Delta: 0.002823, Gap C: 0.000001, Gap Q: 0.047688
# [81] MED: 1.372149e-02 | HV: 1.350316
# !! Max_iter. Delta: 0.007969, Gap C: 0.000000, Gap Q: 0.030615
# !! Max_iter. Delta: 0.002120, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007488, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005223, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006265, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005122, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007232, Gap C: 0.000002, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007066, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006324, Gap C: 0.000000, Gap Q: 0.001045
# 83it [31:43, 22.91s/it]
# !! Max_iter. Delta: 0.005656, Gap C: 0.000000, Gap Q: 0.049093
# [82] MED: 2.113561e-02 | HV: 1.304685
# !! Max_iter. Delta: 0.007969, Gap C: 0.000000, Gap Q: 0.051720
# !! Max_iter. Delta: 0.002120, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007488, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005223, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006265, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005122, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007232, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007066, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006324, Gap C: 0.000000, Gap Q: 0.001045
# 84it [32:06, 22.90s/it]
# !! Max_iter. Delta: 0.005607, Gap C: 0.000000, Gap Q: 0.044198
# [83] MED: 2.196710e-02 | HV: 1.304685
# !! Max_iter. Delta: 0.003984, Gap C: 0.000000, Gap Q: 0.004066
# !! Max_iter. Delta: 0.003924, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003739, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003450, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003122, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002561, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001992, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003518, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000692, Gap C: 0.000001, Gap Q: 0.001051
# 85it [32:29, 22.95s/it]
# !! Max_iter. Delta: 0.003089, Gap C: 0.000000, Gap Q: 0.010356
# [84] MED: 6.716045e-03 | HV: 1.350316
# !! Max_iter. Delta: 0.003984, Gap C: 0.000000, Gap Q: 0.009695
# !! Max_iter. Delta: 0.003924, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003739, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003450, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003122, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002561, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001992, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003518, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000692, Gap C: 0.000000, Gap Q: 0.001051
# 86it [32:52, 22.97s/it]
# !! Max_iter. Delta: 0.003076, Gap C: 0.000000, Gap Q: 0.015971
# [85] MED: 7.090666e-03 | HV: 1.350316
# !! Max_iter. Delta: 0.007969, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002120, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007488, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005223, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006265, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005122, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007232, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007066, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006324, Gap C: 0.000000, Gap Q: 0.001045
# 87it [33:15, 22.99s/it]
# !! Max_iter. Delta: 0.006209, Gap C: 0.000000, Gap Q: 0.006415
# [86] MED: 1.394588e-02 | HV: 1.304685
# !! Max_iter. Delta: 0.007969, Gap C: 0.000000, Gap Q: 0.003623
# !! Max_iter. Delta: 0.002120, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007488, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005223, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006265, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005122, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007232, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007066, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006324, Gap C: 0.000000, Gap Q: 0.001044
# 88it [33:38, 23.02s/it]
# !! Max_iter. Delta: 0.006124, Gap C: 0.000000, Gap Q: 0.011740
# [87] MED: 1.524863e-02 | HV: 1.304685
# !! Max_iter. Delta: 0.003984, Gap C: 0.000000, Gap Q: 0.037969
# !! Max_iter. Delta: 0.003924, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003739, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003450, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003122, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002561, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001992, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003518, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000692, Gap C: 0.000000, Gap Q: 0.001051
# 89it [34:01, 23.01s/it]
# !! Max_iter. Delta: 0.002845, Gap C: 0.000001, Gap Q: 0.045008
# [88] MED: 1.407323e-02 | HV: 1.350316
# !! Max_iter. Delta: 0.003984, Gap C: 0.000000, Gap Q: 0.044989
# !! Max_iter. Delta: 0.003924, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003739, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003450, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003122, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002561, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001992, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003518, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000692, Gap C: 0.000000, Gap Q: 0.002237
# 90it [34:24, 22.97s/it]
# !! Max_iter. Delta: 0.002823, Gap C: 0.000000, Gap Q: 0.047662
# [89] MED: 1.372320e-02 | HV: 1.350316
# !! Max_iter. Delta: 0.007969, Gap C: 0.000000, Gap Q: 0.030615
# !! Max_iter. Delta: 0.002120, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007488, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005223, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006265, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005122, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007232, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007066, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006324, Gap C: 0.000000, Gap Q: 0.001045
# 91it [34:47, 22.98s/it]
# !! Max_iter. Delta: 0.005656, Gap C: 0.000000, Gap Q: 0.049094
# [90] MED: 2.113561e-02 | HV: 1.304685
# !! Max_iter. Delta: 0.007969, Gap C: 0.000000, Gap Q: 0.051765
# !! Max_iter. Delta: 0.002120, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007488, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005223, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006265, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005122, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007232, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007066, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006324, Gap C: 0.000000, Gap Q: 0.001045
# 92it [35:10, 22.95s/it]
# !! Max_iter. Delta: 0.005607, Gap C: 0.000000, Gap Q: 0.044187
# [91] MED: 2.197103e-02 | HV: 1.304685
# !! Max_iter. Delta: 0.003984, Gap C: 0.000000, Gap Q: 0.016009
# !! Max_iter. Delta: 0.003924, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003739, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003450, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003122, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002561, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001992, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003518, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000692, Gap C: 0.000000, Gap Q: 0.001051
# 93it [35:33, 22.97s/it]
# !! Max_iter. Delta: 0.003089, Gap C: 0.000001, Gap Q: 0.010355
# [92] MED: 6.657378e-03 | HV: 1.350316
# !! Max_iter. Delta: 0.003984, Gap C: 0.000000, Gap Q: 0.009676
# !! Max_iter. Delta: 0.003924, Gap C: 0.000000, Gap Q: 0.000001
# !! Max_iter. Delta: 0.003739, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003450, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003122, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002561, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001992, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003518, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000692, Gap C: 0.000000, Gap Q: 0.002543
# 94it [35:56, 22.97s/it]
# !! Max_iter. Delta: 0.003076, Gap C: 0.000000, Gap Q: 0.015963
# [93] MED: 7.087510e-03 | HV: 1.350316
# !! Max_iter. Delta: 0.007969, Gap C: 0.000001, Gap Q: 0.012831
# !! Max_iter. Delta: 0.002120, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007488, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005223, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006265, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005122, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007232, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007066, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006324, Gap C: 0.000000, Gap Q: 0.001045
# 95it [36:19, 23.03s/it]
# !! Max_iter. Delta: 0.006209, Gap C: 0.000000, Gap Q: 0.006416
# [94] MED: 1.272116e-02 | HV: 1.321007
# !! Max_iter. Delta: 0.007969, Gap C: 0.000000, Gap Q: 0.009903
# !! Max_iter. Delta: 0.002120, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007488, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005223, Gap C: 0.000002, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006265, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005122, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007232, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007066, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006324, Gap C: 0.000000, Gap Q: 0.001044
# 96it [36:42, 22.94s/it]
# !! Max_iter. Delta: 0.006118, Gap C: 0.000000, Gap Q: 0.012113
# [95] MED: 1.604738e-02 | HV: 1.304685
#
# ============================================================
# CẤU HÌNH TỐI ƯU NHẤT THEO MED:
# ID: 29
# MED: 0.002597, HV 1.312284499627925
# Params: {'expo_lambda': 0.51, 'expo_alpha': 0.25, 'expo_beta': 0.5, 'expo_gamma': 0.5, 'init_params': 1.0, 'mu': 0.01, 'max_iter': 1000}
# ============================================================

# %% [markdown]
# ## Best

# %%
from Phase2_dynamic import optim_Scalarization
from evaluate import get_metrics

# %%
pf_true_dynamic = []
for r in test_rays:
        x_final, _ = optim_Scalarization(
            prob=prob,
            x_feasible=x_feasible,  
            r=r, 
            z_star=z_star,
            # Các tham số tĩnh
            verbose=True,
            # --- CÁC THAM SỐ ĐANG TỐI ƯU ---
            max_iter=best_params['max_iter'],
            mu=best_params['mu'],
            init_params=best_params['init_params'],
            expo_alpha=best_params['expo_alpha'],
            expo_lambda=best_params['expo_lambda'],
            expo_beta=best_params['expo_beta'],
            expo_gamma=best_params['expo_gamma'],
        )
        pf_true_dynamic.append(prob.objective_func(x_final))
    
med, hv = get_metrics(pf_true_dynamic, pf_true, prob, ref_point)
# Out:
# !! Max_iter. Delta: 0.029527, Gap C: 0.000000, Gap Q: 0.037040
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha |  Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 |  1.00000 |  1.00000 | 1.00000 | 1.00000 | 0.38985 | 0.00000 | 0.00000 |
# | 250 | 0.25124 | 15.84298 | 15.84298 | 0.05973 | 0.23773 | 0.49780 | 0.00000 | 0.00000 |
# | 500 | 0.21137 | 22.38303 | 22.38303 | 0.04198 | 0.19861 | 0.50941 | 0.00000 | 0.00000 |
# | 750 | 0.19102 | 27.40438 | 27.40438 | 0.03415 | 0.17878 | 0.51465 | 0.00000 | 0.00000 |
# | 999 | 0.17783 | 31.62278 | 31.62278 | 0.02951 | 0.01744 | 0.55998 | 0.00000 | 0.03704 |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [0.2314]
# -> S(F(x)) approx distance: 0.51781
# !! Max_iter. Delta: 0.029079, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha |  Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 |  1.00000 |  1.00000 | 1.00000 | 1.01543 | 0.38985 | 0.00000 | 0.00000 |
# | 250 | 0.25124 | 15.84298 | 15.84298 | 0.05973 | 0.89806 | 0.50915 | 0.00000 | 0.00000 |
# | 500 | 0.21137 | 22.38303 | 22.38303 | 0.04198 | 0.75027 | 0.50920 | 0.00000 | 0.00000 |
# | 750 | 0.19102 | 27.40438 | 27.40438 | 0.03415 | 0.67541 | 0.50914 | 0.00000 | 0.00000 |
# | 999 | 0.17783 | 31.62278 | 31.62278 | 0.02951 | 0.16852 | 0.47223 | 0.00000 | 0.00000 |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [0.2378]
# -> S(F(x)) approx distance: 0.50912
# !! Max_iter. Delta: 0.014431, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha |  Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 |  1.00000 |  1.00000 | 1.00000 | 1.06418 | 0.38985 | 0.00000 | 0.00000 |
# | 250 | 0.25124 | 15.84298 | 15.84298 | 0.05973 | 0.49584 | 0.43812 | 0.00000 | 0.00000 |
# | 500 | 0.21137 | 22.38303 | 22.38303 | 0.04198 | 0.21138 | 0.43800 | 0.00000 | 0.00000 |
# | 750 | 0.19102 | 27.40438 | 27.40438 | 0.03415 | 0.19026 | 0.43798 | 0.00000 | 0.00000 |
# | 999 | 0.17783 | 31.62278 | 31.62278 | 0.02951 | 0.33219 | 0.46950 | 0.00000 | 0.00000 |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [0.2992]
# -> S(F(x)) approx distance: 0.43800
# !! Max_iter. Delta: 0.025548, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha |  Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 |  1.00000 |  1.00000 | 1.00000 | 1.15460 | 0.38985 | 0.00000 | 0.00007 |
# | 250 | 0.25124 | 15.84298 | 15.84298 | 0.05973 | 0.36485 | 0.39833 | 0.00000 | 0.00000 |
# | 500 | 0.21137 | 22.38303 | 22.38303 | 0.04198 | 0.30489 | 0.39825 | 0.00000 | 0.00000 |
# | 750 | 0.19102 | 27.40438 | 27.40438 | 0.03415 | 0.20644 | 0.39824 | 0.00000 | 0.00000 |
# | 999 | 0.17783 | 31.62278 | 31.62278 | 0.02951 | 0.19163 | 0.38304 | 0.00000 | 0.00000 |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [0.3485]
# -> S(F(x)) approx distance: 0.39825
# !! Max_iter. Delta: 0.023600, Gap C: 0.000001, Gap Q: 0.000000
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha |  Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 |  1.00000 |  1.00000 | 1.00000 | 1.30541 | 0.38985 | 0.00000 | 0.00000 |
# | 250 | 0.25124 | 15.84298 | 15.84298 | 0.05973 | 0.31033 | 0.37804 | 0.00000 | 0.00000 |
# | 500 | 0.21137 | 22.38303 | 22.38303 | 0.04198 | 0.25929 | 0.37808 | 0.00000 | 0.00000 |
# | 750 | 0.19102 | 27.40438 | 27.40438 | 0.03415 | 0.22888 | 0.37809 | 0.00000 | 0.00000 |
# | 999 | 0.17783 | 31.62278 | 31.62278 | 0.02951 | 0.20261 | 0.39000 | 0.00000 | 0.00000 |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [0.3924]
# -> S(F(x)) approx distance: 0.37808
# !! Max_iter. Delta: 0.018957, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha |  Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 |  1.00000 |  1.00000 | 1.00000 | 1.55572 | 0.38985 | 0.00000 | 0.00000 |
# | 250 | 0.25124 | 15.84298 | 15.84298 | 0.05973 | 0.27459 | 0.37286 | 0.00000 | 0.00000 |
# | 500 | 0.21137 | 22.38303 | 22.38303 | 0.04198 | 0.30902 | 0.37286 | 0.00000 | 0.00000 |
# | 750 | 0.19102 | 27.40438 | 27.40438 | 0.03415 | 0.27814 | 0.37286 | 0.00000 | 0.00000 |
# | 999 | 0.17783 | 31.62278 | 31.62278 | 0.02951 | 0.25820 | 0.37715 | 0.00000 | 0.00000 |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [0.435]
# -> S(F(x)) approx distance: 0.37286
# !! Max_iter. Delta: 0.014742, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha |  Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 |  1.00000 |  1.00000 | 1.00000 | 2.00000 | 0.38985 | 0.00000 | 0.00000 |
# | 250 | 0.25124 | 15.84298 | 15.84298 | 0.05973 | 0.47546 | 0.38177 | 0.00000 | 0.00000 |
# | 500 | 0.21137 | 22.38303 | 22.38303 | 0.04198 | 0.22053 | 0.38174 | 0.00000 | 0.00000 |
# | 750 | 0.19102 | 27.40438 | 27.40438 | 0.03415 | 0.35757 | 0.38176 | 0.00000 | 0.00000 |
# | 999 | 0.17783 | 31.62278 | 31.62278 | 0.02951 | 0.33191 | 0.39449 | 0.00000 | 0.00000 |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [0.48]
# -> S(F(x)) approx distance: 0.38175
# !! Max_iter. Delta: 0.010080, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha |  Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 |  1.00000 |  1.00000 | 1.00000 | 1.06418 | 0.38985 | 0.00000 | 0.00000 |
# | 250 | 0.25124 | 15.84298 | 15.84298 | 0.05973 | 0.27032 | 0.40728 | 0.00000 | 0.00000 |
# | 500 | 0.21137 | 22.38303 | 22.38303 | 0.04198 | 0.22592 | 0.40736 | 0.00000 | 0.00000 |
# | 750 | 0.19102 | 27.40438 | 27.40438 | 0.03415 | 0.20334 | 0.40734 | 0.00000 | 0.00000 |
# | 999 | 0.17783 | 31.62278 | 31.62278 | 0.02951 | 0.48522 | 0.42740 | 0.00000 | 0.00000 |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [0.5322]
# -> S(F(x)) approx distance: 0.40736
# !! Max_iter. Delta: 0.024060, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha |  Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 |  1.00000 |  1.00000 | 1.00000 | 1.01543 | 0.38985 | 0.00000 | 0.00000 |
# | 250 | 0.25124 | 15.84298 | 15.84298 | 0.05973 | 0.99091 | 0.45862 | 0.00000 | 0.00105 |
# | 500 | 0.21137 | 22.38303 | 22.38303 | 0.04198 | 0.29249 | 0.45858 | 0.00000 | 0.00101 |
# | 750 | 0.19102 | 27.40438 | 27.40438 | 0.03415 | 0.41234 | 0.45862 | 0.00000 | 0.00246 |
# | 999 | 0.17783 | 31.62278 | 31.62278 | 0.02951 | 0.19665 | 0.43476 | 0.00000 | 0.00000 |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [0.601]
# -> S(F(x)) approx distance: 0.45861
# !! Max_iter. Delta: 0.023839, Gap C: 0.000000, Gap Q: 0.000017
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha |  Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 |  1.00000 |  1.00000 | 1.00000 | 1.00000 | 0.38985 | 0.00000 | 0.00000 |
# | 250 | 0.25124 | 15.84298 | 15.84298 | 0.05973 | 0.26272 | 0.48059 | 0.00000 | 0.02620 |
# | 500 | 0.21137 | 22.38303 | 22.38303 | 0.04198 | 0.18597 | 0.47268 | 0.00000 | 0.01731 |
# | 750 | 0.19102 | 27.40438 | 27.40438 | 0.03415 | 0.15572 | 0.46924 | 0.00000 | 0.01339 |
# | 999 | 0.17783 | 31.62278 | 31.62278 | 0.02951 | 0.19903 | 0.44259 | 0.00000 | 0.00002 |
# +-----+---------+----------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [0.6111]
# -> S(F(x)) approx distance: 0.46721

# %% [markdown]
# ## Viz

# %%
from utils import visualize_pareto_front, generate_pareto_grid

# %%
def non_c(x):
    return 1
pf_cloud, pf_targets = generate_pareto_grid(
    f_func=f, 
    c_funcs=[non_c], 
    q_plus_func=q_plus, 
    resolution=500
)
# Out:
# --- Đang quét lưới 500x500 điểm ---
# -> Tìm thấy 250000 điểm thỏa mãn miền C.
# -> Lọc còn 93500 điểm thỏa mãn Q+ (Cloud).
# -> Kết quả: 187 điểm Pareto.

# %%
visualize_pareto_front(
    pf_pred=np.array(pf_true_dynamic), 
    pf_cloud=pf_cloud,   
    pf_targets=np.array(pf_true),
    title="Dynamic approximate exact",
    figsize=(8, 6)
)

# %% [markdown]
# # Hypernet

# %%
from training_hypernet import train_hypernet

# %%
prob = Problem(
    f=[f1, f2], jac_f=[jacobian_f],
    dim_x=dim_x, dim_y=dim_y,
    proj_C=proj_C_handler.project,
    proj_Qplus=proj_Q_handler.project
)

# %% [markdown]
# ## Tuning

# %%
from tuning_hypernet import run_hypernet_tuning

# %%
param_grid = {
    'lr': [1e-3, 5e-4],
    'num_epochs': [500, 1000, 2000],
    
    'num_partitions': [20],
    
    # Tham số thuật toán 2-A: Tăng dần penalty
    'beta_C_0': [10],
    'beta_Q_0': [5],
    'rho_C': [1.03], 
    'rho_Q': [1.01, 1.03],
    
    # Cố định Max để tránh grid quá lớn 
    'beta_C_max': [1000.0],
    'beta_Q_max': [100.0, 500.0, 1000.0]
}

# %%
device = 'cpu'

# %%
results = run_hypernet_tuning(
    prob=prob,
    dim_x=dim_x,
    z_star=z_star,
    ref_point=ref_point,
    test_rays=test_rays,
    pf_true=pf_true_dynamic,
    param_grid=param_grid,
    indicator="MED", 
    device=device,
    save_dir=f"model/{case}",
    train_func=train_hypernet
)
# Out:
# ============================================================
# 🔹 TUNING MODEL: MLP | PRIORITY: MED
# ============================================================
#
# >>> [Config 1/36] Params: {'lr': 0.001, 'num_epochs': 500, 'num_partitions': 20, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 100.0}
#       ⏱️ Time: 27.5s | 📏 MED: 0.005517 | 📈 HV: 1.343933
#       🏆 NEW BEST FOUND! Saved to: model/_Ex_7_1/best_MLP_MED.pth
#
# >>> [Config 2/36] Params: {'lr': 0.001, 'num_epochs': 500, 'num_partitions': 20, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 500.0}
#       ⏱️ Time: 26.3s | 📏 MED: 0.009702 | 📈 HV: 1.328190
#
# >>> [Config 3/36] Params: {'lr': 0.001, 'num_epochs': 500, 'num_partitions': 20, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 1000.0}
#       ⏱️ Time: 26.7s | 📏 MED: 0.009633 | 📈 HV: 1.337342
#
# >>> [Config 4/36] Params: {'lr': 0.001, 'num_epochs': 500, 'num_partitions': 20, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 100.0}
#       ⏱️ Time: 26.8s | 📏 MED: 0.005496 | 📈 HV: 1.344516
#       🏆 NEW BEST FOUND! Saved to: model/_Ex_7_1/best_MLP_MED.pth
#
# >>> [Config 5/36] Params: {'lr': 0.001, 'num_epochs': 500, 'num_partitions': 20, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 500.0}
#       ⏱️ Time: 26.6s | 📏 MED: 0.007189 | 📈 HV: 1.351301
#
# >>> [Config 6/36] Params: {'lr': 0.001, 'num_epochs': 500, 'num_partitions': 20, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 1000.0}
#       ⏱️ Time: 26.3s | 📏 MED: 0.008822 | 📈 HV: 1.336375
#
# >>> [Config 7/36] Params: {'lr': 0.001, 'num_epochs': 1000, 'num_partitions': 20, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 100.0}
#       ⏱️ Time: 53.3s | 📏 MED: 0.005588 | 📈 HV: 1.343690
#
# >>> [Config 8/36] Params: {'lr': 0.001, 'num_epochs': 1000, 'num_partitions': 20, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 500.0}
#       ⏱️ Time: 53.8s | 📏 MED: 0.003362 | 📈 HV: 1.353027
#       🏆 NEW BEST FOUND! Saved to: model/_Ex_7_1/best_MLP_MED.pth
#
# >>> [Config 9/36] Params: {'lr': 0.001, 'num_epochs': 1000, 'num_partitions': 20, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 1000.0}
#       ⏱️ Time: 53.2s | 📏 MED: 0.007363 | 📈 HV: 1.334135
#
# >>> [Config 10/36] Params: {'lr': 0.001, 'num_epochs': 1000, 'num_partitions': 20, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 100.0}
#       ⏱️ Time: 53.3s | 📏 MED: 0.006900 | 📈 HV: 1.339875
#
# >>> [Config 11/36] Params: {'lr': 0.001, 'num_epochs': 1000, 'num_partitions': 20, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 500.0}
#       ⏱️ Time: 52.9s | 📏 MED: 0.008518 | 📈 HV: 1.334537
#
# >>> [Config 12/36] Params: {'lr': 0.001, 'num_epochs': 1000, 'num_partitions': 20, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 1000.0}
#       ⏱️ Time: 53.2s | 📏 MED: 0.005574 | 📈 HV: 1.342629
#
# >>> [Config 13/36] Params: {'lr': 0.001, 'num_epochs': 2000, 'num_partitions': 20, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 100.0}
#       ⏱️ Time: 108.0s | 📏 MED: 0.003691 | 📈 HV: 1.349787
#
# >>> [Config 14/36] Params: {'lr': 0.001, 'num_epochs': 2000, 'num_partitions': 20, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 500.0}
#       ⏱️ Time: 106.4s | 📏 MED: 0.005664 | 📈 HV: 1.340395
#
# >>> [Config 15/36] Params: {'lr': 0.001, 'num_epochs': 2000, 'num_partitions': 20, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 1000.0}
#       ⏱️ Time: 106.3s | 📏 MED: 0.006174 | 📈 HV: 1.338674
#
# >>> [Config 16/36] Params: {'lr': 0.001, 'num_epochs': 2000, 'num_partitions': 20, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 100.0}
#       ⏱️ Time: 107.9s | 📏 MED: 0.005692 | 📈 HV: 1.342353
#
# >>> [Config 17/36] Params: {'lr': 0.001, 'num_epochs': 2000, 'num_partitions': 20, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 500.0}
#       ⏱️ Time: 111.8s | 📏 MED: 0.003731 | 📈 HV: 1.350569
#
# >>> [Config 18/36] Params: {'lr': 0.001, 'num_epochs': 2000, 'num_partitions': 20, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 1000.0}
