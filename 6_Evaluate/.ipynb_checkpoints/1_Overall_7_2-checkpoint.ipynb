# %%
n_rays = 50
case = "_Ex_7_2"

# %%
params = {
    "initialization": {
        "x_init": [2.5, 2.5],
        "y_init": [1.0, 1.5]
    },
    "exact":{
        "learning_rate": 0.009,
        "max_iters": 20000,
        "tol": 1e-5
    },
    "phase1": {
        "gamma": 12,
        "expo_gamma": 0.01,
        "max_iter": 10000,
        "tol": 1e-4
    },
    "phase2": {
        "expo_alpha": 0.45,
        "expo_beta": 0.4,
        "expo_lambda": 0.55,
        "init_params": 1.0,
        "max_iter": 2000,
        "mu": 1e-4,
        "verbose": False,
        "expo_gamma": 0.5
    }
}

# %%
import autograd.numpy as np
import torch

def set_seed(seed=702):
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)

set_seed(702)

# %% [markdown]
# # Gen rays

# %%
import autograd.numpy as np
import math

# %%
def generate_chebyshev_rays(num_rays=10):
    rays = []
    angles = np.linspace(0, np.pi/2, num_rays)
    for theta in angles:
        r1, r2 = math.cos(theta), math.sin(theta)
        if abs(r1) < 1e-9: r1 = 0.0
        if abs(r2) < 1e-9: r2 = 0.0
        rays.append([r1, r2])       
    return np.array(rays)

# %%
test_rays = generate_chebyshev_rays(n_rays)

# %% [markdown]
# # Giải chính xác bằng phương pháp chiếu

# %% [markdown]
# ## Bài toán

# %%
from scipy.optimize import Bounds

# %%
# ==========================================
# HÀM MỤC TIÊU
# ==========================================
def f1(x):    return (x[0]**2 + x[1]**2)/50
def f2(x):    return ((x[0] - 5)**2 + (x[1] - 5)**2)/50
def f(x):    return np.array([
    (x[0]**2 + x[1]**2)/50,
    ((x[0] - 5)**2 + (x[1] - 5)**2)/50])
def jacobian_f(x):
    return np.array([
        [x[0]/25.0, x[1]/25.0],
        [(x[0] - 5)/25.0, (x[1] - 5)/25.0]
    ])
# --- Hàm mục tiêu Weighted Chebyshev ---
def S_weighted_chebyshev(x, r, z):
    vals = f(x)
    weighted_diffs = r * np.abs(vals - z)
    return np.max(weighted_diffs)

def get_subgradient(x, r, z):
    vals = f(x)
    diffs = vals - z
    weighted_abs_diffs = r * np.abs(diffs)
    k = np.argmax(weighted_abs_diffs)
    
    J = jacobian_f(x)
    gradient_fk = J[k] 
    
    sign = 1.0 if diffs[k] >= 0 else -1.0
    grad = r[k] * sign * gradient_fk
    return grad
# ==========================================
# CÁC RÀNG BUỘC & PHÉP CHIẾU
# ==========================================
# Ràng buộc tập X
bounds_x = Bounds([0,0],[5, 5])
def constraints_X(x):
    # Trả về mảng các giá trị >= 0
    return np.array([
        x[0],           # x0 >= 0
        5.0 - x[0],     # x0 <= 5
        x[1],           # x1 >= 0
        5.0 - x[1]      # x1 <= 5
    ])

# --- Các ràng buộc tập Q ---
def q1(y): return 0.2**2 - (y[0] - 0.4)**2 - (y[1] - 0.4)**2
def q_plus(y):
    center = 0.4
    radius_sq = 0.2**2  
    dx = np.maximum(0, y[0] - center)
    dy = np.maximum(0, y[1] - center)
    return radius_sq - (dx**2 + dy**2)

dim_x = 2
dim_y = 2

# %% [markdown]
# ## Phép chiếu lên X'

# %%
from Problem import Problem
from project import Projection
from scipy.optimize import minimize

# %%
cons_C = ()
cons_Q = ({'type': 'ineq', 'fun' : q1,},)
cons_Qplus = ({'type': 'ineq', 'fun': q_plus},)
# Setup Projections
proj_C_handler = Projection(cons=cons_C, bounds=bounds_x, dim=dim_x, proj_type='euclid')
proj_Q_handler = Projection(cons=cons_Q, bounds=None, dim=dim_y, proj_type='qplus')
# Setup Problem
prob = Problem(
    f=[f], jac_f=[jacobian_f],
    dim_x=dim_x, dim_y=dim_y,
    proj_C=proj_C_handler.project,
    proj_Qplus=proj_Q_handler.project
)

# %%
def project_step(x_temp, y_temp, dim_x, dim_y):
    """
    Chiếu điểm (x, y) vào tập:
    { (x, y) | x in X, y in Q, f(x) <= y }
    """
    z_start = np.concatenate([x_temp, y_temp])
    
    def proj_obj(z): 
        return 0.5 * np.sum((z - z_start)**2)
    
    def proj_jac(z): 
        return z - z_start

    # Danh sách ràng buộc: scipy yêu cầu dạng 'ineq' (tức là >= 0)
    cons = [
        # Ràng buộc x \in X
        {'type': 'ineq', 'fun': lambda z: constraints_X(z[:dim_x])},
        # Ràng buộc y \in Q
        {'type': 'ineq', 'fun': lambda z: q1(z[dim_x:])},
        # Ràng buộc f(x) <= y  <=>  y - f(x) >= 0
        {'type': 'ineq', 'fun': lambda z: z[dim_x:] - f(z[:dim_x])}
    ]

    res = minimize(
        fun=proj_obj, x0=z_start, jac=proj_jac,
        constraints=cons, method='SLSQP',
        options={'disp': False}
    )
    
    if not res.success:
        return x_temp, y_temp
    return res.x[:dim_x], res.x[dim_x:]

# %% [markdown]
# ## Core

# %%
def solve_weighted_chebyshev(r_pref, z_ref, params , dim_x=1, dim_y=2):
    x = params["initialization"]["x_init"]    
    y = params["initialization"]["y_init"]
    learning_rate = params["exact"]["learning_rate"]
    max_iters = params["exact"]["max_iters"]
    tol = params["exact"]["tol"]
    prev_obj_val = float('inf')
    converge = False
    
    print(f"r={r_pref}")
    print(f"{'Iter':<5} | {'x':<10} | {'y vector':<15} | {'Objective':<10} | {'Active Idx'}")
    for k in range(max_iters):
        # --- BƯỚC 1: Tính Subgradient ---
        grad_x = get_subgradient(x, r_pref, z_ref)
        
        # --- BƯỚC 2: Cập nhật biến x ---
        x_temp = x - learning_rate * grad_x
        y_temp = y 
        
        # --- BƯỚC 3: Phép chiếu (Projection) ---
        x_next, y_next = project_step(x_temp, y_temp, dim_x, dim_y)
        
        # --- Tính giá trị hàm mục tiêu hiện tại ---
        obj_val = S_weighted_chebyshev(x_next, r_pref, z_ref)
        
        # --- Logging ---
        diffs = r_pref * np.abs(f(x_next) - z_ref)
        active_idx = np.argmax(diffs)
        
        if k % 2000 == 0:
            print(f"{k:<5} | {x_next[0]:.4f}     | [{y_next[0]:.2f}, {y_next[1]:.2f}] | {obj_val:.6f}     | f_{active_idx+1}")

        # --- BƯỚC 4: Kiểm tra điều kiện dừng ---
        loss_change = abs(prev_obj_val - obj_val)
        
        if loss_change < tol:
            print(f"--> Hội tụ tại bước {k}!\n")
            converge = True
            break
            
        prev_obj_val = obj_val
        x = x_next
        y = y_next

    return x, y, converge

# %% [markdown]
# ## Tìm điểm tham chiếu

# %%
from Phase1 import solve_CQ_feasible
from Phase2_1_obj import optim_Universal

# %%
def relevant_point(prob, params):
    x_feasible, _, _, _ = solve_CQ_feasible(
        prob.objective_func, prob.jacobian, prob.proj_C, prob.proj_Qplus,
        x0=params['initialization']['x_init'],
        gamma=params['phase1']['gamma'] , max_iter=params['phase1']['max_iter']
    )

    z_vals = []
    nadir_vals = []

    for dim in range(2):
        # Tìm MIN
        x_min, _ = optim_Universal(prob, x_feasible, target_dim=dim, mode="min", max_iter=500, mu=0.001)
        val_min = prob.objective_func(x_min)[dim]
        z_vals.append(val_min)

        # Tìm MAX 
        x_max, _ = optim_Universal(prob, x_feasible, target_dim=dim, mode="max", max_iter=500, mu=0.001)
        val_max = prob.objective_func(x_max)[dim]
        nadir_vals.append(val_max)
        print(f"   Dim {dim}: Min={val_min:.4f}, Max={val_max:.4f}")
    z_star = np.array(z_vals)
    ref_point = np.array(nadir_vals) + np.abs(np.array(nadir_vals)) * 0.1 + 0.5 
    print(f"-> Z* (Ideal): {z_star}")
    print(f"-> Ref Point (HV): {ref_point}")
    print(f"-> x (Feasible): {x_feasible}")
    return z_star, ref_point, x_feasible

# %% [markdown]
# ## Giải chính xác

# %%
z_star, ref_point, x_feasible = relevant_point(prob, params)
# Out:
# Khởi tạo: x0: [2.5, 2.5]
# Chiếu lên C được: x: [2.5 2.5]
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Hội tụ tại vòng lặp 0
# +---+------------+---------+--------------+--------------+----------+----------+
# | k | x_new      | gamma_k | y            | z_proj       |   e_x    |   e_f    |
# +---+------------+---------+--------------+--------------+----------+----------+
# | 0 | [2.5, 2.5] | 12.0000 | [0.25, 0.25] | [0.25, 0.25] | 0.000000 | 0.000000 |
# +---+------------+---------+--------------+--------------+----------+----------+
#    Dim 0: Min=0.0374, Max=0.8115
#    Dim 1: Min=0.0374, Max=0.8115
# -> Z* (Ideal): [0.0374 0.0374]
# -> Ref Point (HV): [1.3927 1.3927]
# -> x (Feasible): [2.5 2.5]

# %%
pf_true = []
converge = 0
for r in test_rays:
    x, y, conv = solve_weighted_chebyshev(
        r_pref=r,
        z_ref=z_star, 
        dim_x=dim_x, 
        dim_y=dim_y,
        params=params)
    if conv:
        converge += 1
    pf_true.append(f(x))
print(f"Converge rate = {100*converge/len(test_rays)}%")
# Out:
# r=[1. 0.]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.4991     | [0.50, 0.58] | 0.212440     | f_1
# 2000  | 1.2163     | [0.50, 0.58] | 0.021794     | f_1
# --> Hội tụ tại bước 2297!
#
# r=[0.9995 0.0321]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.4991     | [0.50, 0.58] | 0.212331     | f_1
# 2000  | 1.2167     | [0.50, 0.58] | 0.021827     | f_1
# --> Hội tụ tại bước 2125!
#
# r=[0.9979 0.0641]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.4991     | [0.50, 0.58] | 0.212004     | f_1
# --> Hội tụ tại bước 1777!
#
# r=[0.9954 0.096 ]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.4991     | [0.50, 0.58] | 0.211460     | f_1
# --> Hội tụ tại bước 1543!
#
# r=[0.9918 0.1279]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.4991     | [0.50, 0.58] | 0.210698     | f_1
# --> Hội tụ tại bước 1363!
#
# r=[0.9872 0.1596]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.4991     | [0.50, 0.58] | 0.209720     | f_1
# --> Hội tụ tại bước 1218!
#
# r=[0.9816 0.1912]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.4991     | [0.50, 0.58] | 0.208526     | f_1
# --> Hội tụ tại bước 1101!
#
# r=[0.9749 0.2225]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.4991     | [0.50, 0.58] | 0.207118     | f_1
# --> Hội tụ tại bước 996!
#
# r=[0.9673 0.2537]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.4991     | [0.50, 0.58] | 0.205498     | f_1
# --> Hội tụ tại bước 904!
#
# r=[0.9587 0.2845]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.4991     | [0.50, 0.58] | 0.203667     | f_1
# --> Hội tụ tại bước 834!
#
# r=[0.9491 0.3151]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.4991     | [0.50, 0.58] | 0.201626     | f_1
# --> Hội tụ tại bước 761!
#
# r=[0.9385 0.3454]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.4992     | [0.50, 0.58] | 0.199379     | f_1
# --> Hội tụ tại bước 684!
#
# r=[0.9269 0.3753]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.4992     | [0.50, 0.58] | 0.196927     | f_1
# --> Hội tụ tại bước 634!
#
# r=[0.9144 0.4048]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.4992     | [0.50, 0.58] | 0.194272     | f_1
# --> Hội tụ tại bước 565!
#
# r=[0.901  0.4339]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.4992     | [0.50, 0.58] | 0.191418     | f_1
# --> Hội tụ tại bước 516!
#
# r=[0.8866 0.4625]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.4992     | [0.50, 0.58] | 0.188368     | f_1
# --> Hội tụ tại bước 463!
#
# r=[0.8713 0.4907]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.4992     | [0.50, 0.58] | 0.185123     | f_1
# --> Hội tụ tại bước 411!
#
# r=[0.8551 0.5184]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.4992     | [0.50, 0.58] | 0.181689     | f_1
# --> Hội tụ tại bước 363!
#
# r=[0.8381 0.5455]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.4992     | [0.50, 0.58] | 0.178068     | f_1
# --> Hội tụ tại bước 315!
#
# r=[0.8202 0.5721]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.4993     | [0.50, 0.58] | 0.174264     | f_1
# --> Hội tụ tại bước 271!
#
# r=[0.8014 0.5981]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.4993     | [0.50, 0.58] | 0.170281     | f_1
# --> Hội tụ tại bước 228!
#
# r=[0.7818 0.6235]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.4993     | [0.50, 0.58] | 0.166123     | f_1
# --> Hội tụ tại bước 181!
#
# r=[0.7614 0.6482]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.4993     | [0.50, 0.58] | 0.161795     | f_1
# --> Hội tụ tại bước 135!
#
# r=[0.7403 0.6723]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.4993     | [0.50, 0.58] | 0.157300     | f_1
# --> Hội tụ tại bước 80!
#
# r=[0.7183 0.6957]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.4994     | [0.50, 0.58] | 0.152643     | f_1
# --> Hội tụ tại bước 26!
#
# r=[0.6957 0.7183]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.5006     | [0.50, 0.58] | 0.152643     | f_2
# --> Hội tụ tại bước 26!
#
# r=[0.6723 0.7403]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.5007     | [0.50, 0.58] | 0.157300     | f_2
# --> Hội tụ tại bước 80!
#
# r=[0.6482 0.7614]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.5007     | [0.50, 0.58] | 0.161795     | f_2
# --> Hội tụ tại bước 135!
#
# r=[0.6235 0.7818]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.5007     | [0.50, 0.58] | 0.166123     | f_2
# --> Hội tụ tại bước 181!
#
# r=[0.5981 0.8014]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.5007     | [0.50, 0.58] | 0.170281     | f_2
# --> Hội tụ tại bước 228!
#
# r=[0.5721 0.8202]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.5007     | [0.50, 0.58] | 0.174264     | f_2
# --> Hội tụ tại bước 271!
#
# r=[0.5455 0.8381]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.5008     | [0.50, 0.58] | 0.178068     | f_2
# --> Hội tụ tại bước 315!
#
# r=[0.5184 0.8551]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.5008     | [0.50, 0.58] | 0.181689     | f_2
# --> Hội tụ tại bước 363!
#
# r=[0.4907 0.8713]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.5008     | [0.50, 0.58] | 0.185123     | f_2
# --> Hội tụ tại bước 411!
#
# r=[0.4625 0.8866]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.5008     | [0.50, 0.58] | 0.188368     | f_2
# --> Hội tụ tại bước 463!
#
# r=[0.4339 0.901 ]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.5008     | [0.50, 0.58] | 0.191418     | f_2
# --> Hội tụ tại bước 516!
#
# r=[0.4048 0.9144]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.5008     | [0.50, 0.58] | 0.194272     | f_2
# --> Hội tụ tại bước 565!
#
# r=[0.3753 0.9269]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.5008     | [0.50, 0.58] | 0.196927     | f_2
# --> Hội tụ tại bước 634!
#
# r=[0.3454 0.9385]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.5008     | [0.50, 0.58] | 0.199379     | f_2
# --> Hội tụ tại bước 684!
#
# r=[0.3151 0.9491]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.5009     | [0.50, 0.58] | 0.201626     | f_2
# --> Hội tụ tại bước 761!
#
# r=[0.2845 0.9587]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.5009     | [0.50, 0.58] | 0.203667     | f_2
# --> Hội tụ tại bước 834!
#
# r=[0.2537 0.9673]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.5009     | [0.50, 0.58] | 0.205498     | f_2
# --> Hội tụ tại bước 904!
#
# r=[0.2225 0.9749]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.5009     | [0.50, 0.58] | 0.207118     | f_2
# --> Hội tụ tại bước 996!
#
# r=[0.1912 0.9816]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.5009     | [0.50, 0.58] | 0.208526     | f_2
# --> Hội tụ tại bước 1101!
#
# r=[0.1596 0.9872]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.5009     | [0.50, 0.58] | 0.209720     | f_2
# --> Hội tụ tại bước 1218!
#
# r=[0.1279 0.9918]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.5009     | [0.50, 0.58] | 0.210698     | f_2
# --> Hội tụ tại bước 1363!
#
# r=[0.096  0.9954]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.5009     | [0.50, 0.58] | 0.211460     | f_2
# --> Hội tụ tại bước 1547!
#
# r=[0.0641 0.9979]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.5009     | [0.50, 0.58] | 0.212004     | f_2
# --> Hội tụ tại bước 1797!
#
# r=[0.0321 0.9995]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.5009     | [0.50, 0.58] | 0.212331     | f_2
# 2000  | 3.7649     | [0.57, 0.51] | 0.023630     | f_2
# --> Hội tụ tại bước 2178!
#
# r=[0. 1.]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 2.5009     | [0.50, 0.58] | 0.212440     | f_2
# 2000  | 3.7653     | [0.57, 0.51] | 0.023603     | f_2
# --> Hội tụ tại bước 2350!
#
# Converge rate = 100.0%

# %% [markdown]
# # Giải xấp xỉ dynamic

# %% [markdown]
# ## Tuning

# %%
from tuning_dynamic import tuning_dynamic

# %%
best_params, df = tuning_dynamic(
    prob, z_star, x_feasible, pf_true, ref_point, test_rays
)
# Out:
# === GRID SEARCH: ƯU TIÊN MED ===
# Số lượng cấu hình: 96 | Số tia: 50
# 0it [00:00, ?it/s]
# !! Max_iter. Delta: 0.001780, Gap C: 0.000000, Gap Q: 0.022489
# !! Max_iter. Delta: 0.000204, Gap C: 0.000000, Gap Q: 0.000023
# !! Max_iter. Delta: 0.000395, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000571, Gap C: 0.000000, Gap Q: 0.000000
# -> Hội tụ sớm tại k=73.
# !! Max_iter. Delta: 0.002691, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002798, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001207, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002966, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003031, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001619, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001746, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001868, Gap C: 0.000000, Gap Q: 0.000000
# -> Hội tụ sớm tại k=294.
# !! Max_iter. Delta: 0.003200, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003212, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002305, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003209, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002491, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002581, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002663, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002740, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002811, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003038, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002934, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002934, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003038, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003084, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003122, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002663, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003178, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003194, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002402, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002305, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002203, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003200, Gap C: 0.000000, Gap Q: 0.000000
# -> Hội tụ sớm tại k=294.
# !! Max_iter. Delta: 0.001868, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003127, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001619, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003031, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002966, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002889, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002798, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000903, Gap C: 0.000000, Gap Q: 0.000000
# -> Hội tụ sớm tại k=73.
# !! Max_iter. Delta: 0.000571, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000395, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000204, Gap C: 0.000000, Gap Q: 0.000023
# 1it [01:54, 114.11s/it]
# !! Max_iter. Delta: 0.001777, Gap C: 0.000000, Gap Q: 0.023002
# [00] MED: 3.764711e-03 | HV: 1.694546
# !! Max_iter. Delta: 0.000002, Gap C: 0.000000, Gap Q: 0.017222
# -> Hội tụ sớm tại k=271.
# -> Hội tụ sớm tại k=649.
# -> Hội tụ sớm tại k=911.
# -> Hội tụ sớm tại k=73.
# !! Max_iter. Delta: 0.002691, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002798, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001207, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002966, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003031, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001619, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001746, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001868, Gap C: 0.000000, Gap Q: 0.000000
# -> Hội tụ sớm tại k=294.
# !! Max_iter. Delta: 0.003200, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003212, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002305, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003209, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002491, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002581, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002663, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002740, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002811, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003038, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002934, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002934, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003038, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003084, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003122, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002663, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003178, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003194, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002402, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002305, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002203, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003200, Gap C: 0.000000, Gap Q: 0.000000
# -> Hội tụ sớm tại k=294.
# !! Max_iter. Delta: 0.001868, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003127, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001619, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003031, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002966, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002889, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002798, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000903, Gap C: 0.000000, Gap Q: 0.000000
# -> Hội tụ sớm tại k=73.
# -> Hội tụ sớm tại k=911.
# -> Hội tụ sớm tại k=649.
# -> Hội tụ sớm tại k=271.
# 2it [03:43, 111.42s/it]
# !! Max_iter. Delta: 0.000002, Gap C: 0.000000, Gap Q: 0.017222
# [01] MED: 4.575803e-03 | HV: 1.697559
# !! Max_iter. Delta: 0.003553, Gap C: 0.000000, Gap Q: 0.026454
# !! Max_iter. Delta: 0.003984, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.004472, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001149, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001489, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005338, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002119, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002421, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005966, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006090, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003244, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006281, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006354, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006403, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006437, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006449, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.004622, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006447, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005002, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006384, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006328, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006264, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006189, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006101, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006005, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006005, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005771, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006189, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006264, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005341, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005182, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006417, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006447, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006452, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.004417, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006437, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003983, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006354, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006281, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006196, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002979, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002708, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005813, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002119, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005338, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001489, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.004851, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000792, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003984, Gap C: 0.000000, Gap Q: 0.000000
# 3it [05:46, 116.60s/it]
# !! Max_iter. Delta: 0.003553, Gap C: 0.000000, Gap Q: 0.026454
# [02] MED: 3.252324e-03 | HV: 1.700259
# !! Max_iter. Delta: 0.003539, Gap C: 0.000000, Gap Q: 0.014554
# -> Hội tụ sớm tại k=620.
# !! Max_iter. Delta: 0.004472, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001149, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001489, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005338, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002119, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002421, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005966, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006090, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003244, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006281, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006354, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006403, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006437, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006449, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.004622, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006447, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005002, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006384, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006328, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006264, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006189, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006101, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006005, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006005, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005771, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006189, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006264, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005341, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005182, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006417, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006447, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006452, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.004417, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006437, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003983, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006354, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006281, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006196, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002979, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002708, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005813, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002119, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005338, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001489, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.004851, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000792, Gap C: 0.000000, Gap Q: 0.000000
# -> Hội tụ sớm tại k=618.
# 4it [07:45, 117.60s/it]
# !! Max_iter. Delta: 0.003539, Gap C: 0.000000, Gap Q: 0.014549
# [03] MED: 3.932563e-03 | HV: 1.701113
# !! Max_iter. Delta: 0.001847, Gap C: 0.000000, Gap Q: 0.003386
# !! Max_iter. Delta: 0.000204, Gap C: 0.000000, Gap Q: 0.000023
# !! Max_iter. Delta: 0.000395, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000571, Gap C: 0.000000, Gap Q: 0.000000
# -> Hội tụ sớm tại k=73.
# !! Max_iter. Delta: 0.002691, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002798, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001207, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002966, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003031, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001619, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001746, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001868, Gap C: 0.000000, Gap Q: 0.000000
# -> Hội tụ sớm tại k=294.
# !! Max_iter. Delta: 0.003200, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003212, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002305, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003209, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002491, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002581, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002663, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002740, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002811, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003038, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002934, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002934, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003038, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003084, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003122, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002663, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003178, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003194, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002402, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002305, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002203, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003200, Gap C: 0.000000, Gap Q: 0.000000
# -> Hội tụ sớm tại k=294.
# !! Max_iter. Delta: 0.001868, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003127, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001619, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003031, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002966, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002889, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002798, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000903, Gap C: 0.000000, Gap Q: 0.000000
# -> Hội tụ sớm tại k=73.
# !! Max_iter. Delta: 0.000571, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000395, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000204, Gap C: 0.000000, Gap Q: 0.000023
# 5it [09:38, 115.86s/it]
# !! Max_iter. Delta: 0.001861, Gap C: 0.000000, Gap Q: 0.000805
# [04] MED: 3.449788e-03 | HV: 1.694546
# !! Max_iter. Delta: 0.001848, Gap C: 0.000000, Gap Q: 0.003119
# -> Hội tụ sớm tại k=133.
# -> Hội tụ sớm tại k=205.
# -> Hội tụ sớm tại k=911.
# -> Hội tụ sớm tại k=73.
# !! Max_iter. Delta: 0.002691, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002798, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001207, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002966, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003031, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001619, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001746, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001868, Gap C: 0.000000, Gap Q: 0.000000
# -> Hội tụ sớm tại k=294.
# !! Max_iter. Delta: 0.003200, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003212, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002305, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003209, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002491, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002581, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002663, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002740, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002811, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003038, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002934, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002934, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003038, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003084, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003122, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002663, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003178, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003194, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002402, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002305, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002203, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003200, Gap C: 0.000000, Gap Q: 0.000000
# -> Hội tụ sớm tại k=294.
# !! Max_iter. Delta: 0.001868, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003127, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001619, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003031, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002966, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002889, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002798, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000903, Gap C: 0.000000, Gap Q: 0.000000
# -> Hội tụ sớm tại k=73.
# -> Hội tụ sớm tại k=911.
# -> Hội tụ sớm tại k=205.
# -> Hội tụ sớm tại k=695.
# 6it [11:23, 112.19s/it]
# !! Max_iter. Delta: 0.001848, Gap C: 0.000000, Gap Q: 0.003118
# [05] MED: 4.715058e-03 | HV: 1.687884
# !! Max_iter. Delta: 0.003755, Gap C: 0.000000, Gap Q: 0.007457
# !! Max_iter. Delta: 0.003984, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.004472, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001149, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001489, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005338, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002119, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002421, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005966, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006090, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003244, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006281, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006354, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006403, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006437, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006449, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.004622, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006447, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005002, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006384, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006328, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006264, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006189, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006101, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006005, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006005, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005771, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006189, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006264, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005341, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005182, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006417, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006447, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006452, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.004417, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006437, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003983, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006354, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006281, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006196, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002979, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002708, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005813, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002119, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005338, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001489, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.004851, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000792, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003984, Gap C: 0.000000, Gap Q: 0.000000
# 7it [13:26, 115.91s/it]
# !! Max_iter. Delta: 0.003707, Gap C: 0.000000, Gap Q: 0.000000
# [06] MED: 2.985539e-03 | HV: 1.700315
# !! Max_iter. Delta: 0.003654, Gap C: 0.000000, Gap Q: 0.016860
# -> Hội tụ sớm tại k=666.
# !! Max_iter. Delta: 0.004472, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001149, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001489, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005338, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002119, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002421, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005966, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006090, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003244, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006281, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006354, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006403, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006437, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006449, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.004622, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006447, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005002, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006384, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006328, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006264, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006189, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006101, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006005, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006005, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005771, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006189, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006264, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005341, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005182, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006417, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006447, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006452, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.004417, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006437, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003983, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006354, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006281, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006196, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002979, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002708, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005813, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002119, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005338, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001489, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.004851, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000792, Gap C: 0.000000, Gap Q: 0.000000
# -> Hội tụ sớm tại k=674.
# 8it [15:23, 116.12s/it]
# !! Max_iter. Delta: 0.003654, Gap C: 0.000000, Gap Q: 0.016857
# [07] MED: 2.916025e-03 | HV: 1.700852
# !! Max_iter. Delta: 0.001780, Gap C: 0.000000, Gap Q: 0.022489
# !! Max_iter. Delta: 0.000204, Gap C: 0.000000, Gap Q: 0.000023
# !! Max_iter. Delta: 0.000395, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000571, Gap C: 0.000000, Gap Q: 0.000000
# -> Hội tụ sớm tại k=73.
# !! Max_iter. Delta: 0.002691, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002798, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001207, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002966, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003031, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001619, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001746, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001868, Gap C: 0.000000, Gap Q: 0.000000
# -> Hội tụ sớm tại k=294.
# !! Max_iter. Delta: 0.003200, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003212, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002305, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003209, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002491, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002581, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002663, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002740, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002811, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003038, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002934, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002934, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003038, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003084, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003122, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002663, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003178, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003194, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002402, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002305, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002203, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003200, Gap C: 0.000000, Gap Q: 0.000000
# -> Hội tụ sớm tại k=294.
# !! Max_iter. Delta: 0.001868, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003127, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001619, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003031, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002966, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002889, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002798, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000903, Gap C: 0.000000, Gap Q: 0.000000
# -> Hội tụ sớm tại k=73.
# !! Max_iter. Delta: 0.000571, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000395, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000204, Gap C: 0.000000, Gap Q: 0.000023
# 9it [17:13, 114.06s/it]
# !! Max_iter. Delta: 0.001777, Gap C: 0.000000, Gap Q: 0.023002
# [08] MED: 3.764711e-03 | HV: 1.694546
# !! Max_iter. Delta: 0.000002, Gap C: 0.000000, Gap Q: 0.017222
# -> Hội tụ sớm tại k=271.
# -> Hội tụ sớm tại k=649.
# -> Hội tụ sớm tại k=911.
# -> Hội tụ sớm tại k=73.
# !! Max_iter. Delta: 0.002691, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002798, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001207, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002966, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003031, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001619, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001746, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001868, Gap C: 0.000000, Gap Q: 0.000000
# -> Hội tụ sớm tại k=294.
# !! Max_iter. Delta: 0.003200, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003212, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002305, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003209, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002491, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002581, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002663, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002740, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002811, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003038, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002934, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002934, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003038, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003084, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003122, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002663, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003178, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003194, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002402, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002305, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002203, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003200, Gap C: 0.000000, Gap Q: 0.000000
# -> Hội tụ sớm tại k=294.
# !! Max_iter. Delta: 0.001868, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003127, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001619, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003031, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002966, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002889, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002798, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000903, Gap C: 0.000000, Gap Q: 0.000000
# -> Hội tụ sớm tại k=73.
# -> Hội tụ sớm tại k=911.
# -> Hội tụ sớm tại k=649.
# -> Hội tụ sớm tại k=271.
# 10it [18:53, 109.86s/it]
# !! Max_iter. Delta: 0.000002, Gap C: 0.000000, Gap Q: 0.017222
# [09] MED: 4.575803e-03 | HV: 1.697559
# !! Max_iter. Delta: 0.003553, Gap C: 0.000000, Gap Q: 0.026454
# !! Max_iter. Delta: 0.003984, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.004472, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001149, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001489, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005338, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002119, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002421, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005966, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006090, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003244, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006281, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006354, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006403, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006437, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006449, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.004622, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006447, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005002, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006384, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006328, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006264, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006189, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006101, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006005, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006005, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005771, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006189, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006264, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005341, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005182, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006417, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006447, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006452, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.004417, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006437, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003983, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006354, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006281, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006196, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002979, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002708, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005813, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002119, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005338, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001489, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.004851, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000792, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003984, Gap C: 0.000000, Gap Q: 0.000000
# 11it [20:47, 111.01s/it]
# !! Max_iter. Delta: 0.003553, Gap C: 0.000000, Gap Q: 0.026454
# [10] MED: 3.252324e-03 | HV: 1.700259
# !! Max_iter. Delta: 0.003539, Gap C: 0.000000, Gap Q: 0.014554
# -> Hội tụ sớm tại k=620.
# !! Max_iter. Delta: 0.004472, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001149, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001489, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005338, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002119, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002421, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005966, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006090, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003244, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006281, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006354, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006403, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006437, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006449, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.004622, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006447, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005002, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006384, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006328, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006264, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006189, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006101, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006005, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006005, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005771, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006189, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006264, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005341, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005182, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006417, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006447, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006452, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.004417, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006437, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003983, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006354, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006281, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006196, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002979, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002708, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005813, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002119, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005338, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001489, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.004851, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000792, Gap C: 0.000000, Gap Q: 0.000000
# -> Hội tụ sớm tại k=618.
# 12it [22:39, 111.48s/it]
# !! Max_iter. Delta: 0.003539, Gap C: 0.000000, Gap Q: 0.014549
# [11] MED: 3.932563e-03 | HV: 1.701113
# !! Max_iter. Delta: 0.001847, Gap C: 0.000000, Gap Q: 0.003386
# !! Max_iter. Delta: 0.000204, Gap C: 0.000000, Gap Q: 0.000023
# !! Max_iter. Delta: 0.000395, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000571, Gap C: 0.000000, Gap Q: 0.000000
# -> Hội tụ sớm tại k=73.
# !! Max_iter. Delta: 0.002691, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002798, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001207, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002966, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003031, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001619, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001746, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001868, Gap C: 0.000000, Gap Q: 0.000000
# -> Hội tụ sớm tại k=294.
# !! Max_iter. Delta: 0.003200, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003212, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002305, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003209, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002491, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002581, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002663, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002740, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002811, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003038, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002934, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002934, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003038, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003084, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003122, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002663, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003178, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003194, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002402, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002305, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002203, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003200, Gap C: 0.000000, Gap Q: 0.000000
# -> Hội tụ sớm tại k=294.
# !! Max_iter. Delta: 0.001868, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003127, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001619, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003031, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002966, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002889, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002798, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000903, Gap C: 0.000000, Gap Q: 0.000000
# -> Hội tụ sớm tại k=73.
# !! Max_iter. Delta: 0.000571, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000395, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000204, Gap C: 0.000000, Gap Q: 0.000023
# 13it [24:25, 109.87s/it]
# !! Max_iter. Delta: 0.001861, Gap C: 0.000000, Gap Q: 0.000805
# [12] MED: 3.449788e-03 | HV: 1.694546
# !! Max_iter. Delta: 0.001848, Gap C: 0.000000, Gap Q: 0.003119
# -> Hội tụ sớm tại k=133.
# -> Hội tụ sớm tại k=205.
# -> Hội tụ sớm tại k=911.
# -> Hội tụ sớm tại k=73.
# !! Max_iter. Delta: 0.002691, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002798, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001207, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002966, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003031, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001619, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001746, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001868, Gap C: 0.000000, Gap Q: 0.000000
# -> Hội tụ sớm tại k=294.
# !! Max_iter. Delta: 0.003200, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003212, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002305, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003209, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002491, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002581, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002663, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002740, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002811, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003038, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002934, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002934, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003038, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003084, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003122, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002663, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003178, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003194, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002402, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002305, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002203, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003200, Gap C: 0.000000, Gap Q: 0.000000
# -> Hội tụ sớm tại k=294.
# !! Max_iter. Delta: 0.001868, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003127, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001619, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003031, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002966, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002889, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002798, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000903, Gap C: 0.000000, Gap Q: 0.000000
# -> Hội tụ sớm tại k=73.
# -> Hội tụ sớm tại k=911.
# -> Hội tụ sớm tại k=205.
# -> Hội tụ sớm tại k=695.
# 14it [26:04, 106.38s/it]
# !! Max_iter. Delta: 0.001848, Gap C: 0.000000, Gap Q: 0.003118
# [13] MED: 4.715058e-03 | HV: 1.687884
# !! Max_iter. Delta: 0.003755, Gap C: 0.000000, Gap Q: 0.007457
# !! Max_iter. Delta: 0.003984, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.004472, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001149, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001489, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005338, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002119, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002421, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005966, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006090, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003244, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006281, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006354, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006403, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006437, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006449, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.004622, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006447, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005002, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006384, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006328, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006264, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006189, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006101, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006005, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006005, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005771, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006189, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006264, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005341, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005182, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006417, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006447, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006452, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.004417, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006437, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003983, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006354, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006281, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006196, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002979, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002708, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005813, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002119, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005338, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001489, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.004851, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000792, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003984, Gap C: 0.000000, Gap Q: 0.000000
# 15it [27:58, 108.68s/it]
# !! Max_iter. Delta: 0.003707, Gap C: 0.000000, Gap Q: 0.000000
# [14] MED: 2.985539e-03 | HV: 1.700315
# !! Max_iter. Delta: 0.003654, Gap C: 0.000000, Gap Q: 0.016860
# -> Hội tụ sớm tại k=666.
# !! Max_iter. Delta: 0.004472, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001149, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001489, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005338, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002119, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002421, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005966, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006090, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003244, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006281, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006354, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006403, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006437, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006449, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.004622, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006447, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005002, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006384, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006328, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006264, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006189, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006101, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006005, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006005, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005771, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006189, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006264, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005341, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005182, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006417, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.006447, Gap C: 0.000000, Gap Q: 0.000000
# ...
# -> Hội tụ sớm tại k=158.
# !! Max_iter. Delta: 0.000595, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000154, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000200, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000722, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000284, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000324, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000363, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000400, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000435, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000841, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000502, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000534, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000861, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000593, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000619, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000863, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000860, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000695, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000717, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000737, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000756, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000774, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000790, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000805, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000818, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000830, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000737, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000717, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000695, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000860, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000647, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000863, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000593, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000861, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000857, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000502, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000841, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000828, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000815, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000363, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000324, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000284, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000722, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000200, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000647, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000106, Gap C: 0.000000, Gap Q: 0.000000
# -> Hội tụ sớm tại k=158.
# 92it [2:37:45, 109.02s/it]
# !! Max_iter. Delta: 0.000002, Gap C: 0.000000, Gap Q: 0.017226
# [91] MED: 1.827475e-03 | HV: 1.698203
# !! Max_iter. Delta: 0.000251, Gap C: 0.000000, Gap Q: 0.005160
# !! Max_iter. Delta: 0.000264, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000053, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000077, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000100, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000361, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000376, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000162, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000182, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000407, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000218, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000235, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000251, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000267, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000430, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000296, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000431, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000323, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000429, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000347, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000423, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000420, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000378, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000409, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000402, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000395, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000387, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000415, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000420, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000423, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000347, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000429, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000323, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000431, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000432, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000430, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000267, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000251, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000235, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000218, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000407, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000398, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000162, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000142, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000361, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000343, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000323, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000297, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000028, Gap C: 0.000000, Gap Q: 0.000000
# 93it [2:39:37, 110.10s/it]
# !! Max_iter. Delta: 0.000251, Gap C: 0.000000, Gap Q: 0.005264
# [92] MED: 7.134958e-04 | HV: 1.695070
# !! Max_iter. Delta: 0.000001, Gap C: 0.000000, Gap Q: 0.004539
# -> Hội tụ sớm tại k=112.
# -> Hội tụ sớm tại k=184.
# -> Hội tụ sớm tại k=899.
# !! Max_iter. Delta: 0.000100, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000361, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000376, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000162, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000182, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000407, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000218, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000235, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000251, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000267, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000430, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000296, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000431, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000323, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000429, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000347, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000423, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000420, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000378, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000409, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000402, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000395, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000387, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000415, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000420, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000423, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000347, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000429, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000323, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000431, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000432, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000430, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000267, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000251, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000235, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000218, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000407, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000398, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000162, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000142, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000361, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000343, Gap C: 0.000000, Gap Q: 0.000000
# -> Hội tụ sớm tại k=899.
# -> Hội tụ sớm tại k=184.
# -> Hội tụ sớm tại k=112.
# 94it [2:41:21, 108.14s/it]
# !! Max_iter. Delta: 0.000001, Gap C: 0.000000, Gap Q: 0.004539
# [93] MED: 8.180665e-04 | HV: 1.696158
# !! Max_iter. Delta: 0.000501, Gap C: 0.000000, Gap Q: 0.005949
# !! Max_iter. Delta: 0.000055, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000595, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000154, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000200, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000722, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000284, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000324, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000363, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000400, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000435, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000841, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000502, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000534, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000861, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000593, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000619, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000863, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000860, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000695, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000717, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000737, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000756, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000774, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000790, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000805, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000818, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000830, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000737, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000717, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000695, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000860, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000647, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000863, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000593, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000861, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000857, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000502, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000841, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000828, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000815, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000363, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000324, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000284, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000722, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000200, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000647, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000106, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000529, Gap C: 0.000000, Gap Q: 0.000000
# 95it [2:43:14, 109.56s/it]
# !! Max_iter. Delta: 0.000501, Gap C: 0.000000, Gap Q: 0.005932
# [94] MED: 1.067383e-03 | HV: 1.695044
# !! Max_iter. Delta: 0.000501, Gap C: 0.000000, Gap Q: 0.003826
# -> Hội tụ sớm tại k=272.
# !! Max_iter. Delta: 0.000595, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000154, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000200, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000722, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000284, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000324, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000363, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000400, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000435, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000841, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000502, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000534, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000861, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000593, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000619, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000863, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000860, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000695, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000717, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000737, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000756, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000774, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000790, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000805, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000818, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000830, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000737, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000717, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000695, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000860, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000647, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000863, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000593, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000861, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000857, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000502, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000841, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000828, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000815, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000363, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000324, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000284, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000722, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000200, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000647, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000106, Gap C: 0.000000, Gap Q: 0.000000
# -> Hội tụ sớm tại k=272.
# 96it [2:45:03, 103.16s/it]
# !! Max_iter. Delta: 0.000501, Gap C: 0.000000, Gap Q: 0.003826
# [95] MED: 1.075843e-03 | HV: 1.695293
#
# ============================================================
# CẤU HÌNH TỐI ƯU NHẤT THEO MED:
# ID: 84
# MED: 0.000713, HV 1.6950697381589523
# Params: {'expo_lambda': 0.8, 'expo_alpha': 0.1, 'expo_beta': 0.3, 'expo_gamma': 0.5, 'init_params': 1.0, 'mu': 0.0001, 'max_iter': 1000}
# ============================================================

# %%
df.to_csv(f"exp/{case}/{n_rays}_tuning_dynamic.csv", index=False)

# %%
best_params
# Out:
# {'expo_lambda': 0.8,
#  'expo_alpha': 0.1,
#  'expo_beta': 0.3,
#  'expo_gamma': 0.5,
#  'init_params': 1.0,
#  'mu': 0.0001,
#  'max_iter': 1000}

# %%
best_params = {
    'expo_lambda': 0.8,
     'expo_alpha': 0.1,
     'expo_beta': 0.3,
     'expo_gamma': 0.5,
     'init_params': 1.0,
     'mu': 0.0001,
     'max_iter': 1000
}

# %% [markdown]
# ## Best

# %%
from Phase2_dynamic import optim_Scalarization
from evaluate import get_metrics

# %%
pf_true_dynamic = []
for r in test_rays:
        x_final, _ = optim_Scalarization(
            prob=prob,
            x_feasible=x_feasible,  
            r=r, 
            z_star=z_star,
            # Các tham số tĩnh
            verbose=True,
            # --- CÁC THAM SỐ ĐANG TỐI ƯU ---
            max_iter=best_params['max_iter'],
            mu=best_params['mu'],
            init_params=best_params['init_params'],
            expo_alpha=best_params['expo_alpha'],
            expo_lambda=best_params['expo_lambda'],
            expo_beta=best_params['expo_beta'],
            expo_gamma=best_params['expo_gamma'],
        )
        pf_true_dynamic.append(prob.objective_func(x_final))
    
med, hv = get_metrics(pf_true_dynamic, pf_true, prob, ref_point)
# Out:
# !! Max_iter. Delta: 0.000251, Gap C: 0.000000, Gap Q: 0.005160
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 7.07107 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 1.82451 | 0.57109 | 0.00000 | 0.00836 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 5.24434 | 0.56929 | 0.00000 | 0.00655 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 1.84002 | 0.56767 | 0.00000 | 0.00493 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.90000 | 0.56791 | 0.00000 | 0.00516 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [1.1132 1.1132]
# -> S(F(x)) approx distance: 0.56704
# !! Max_iter. Delta: 0.000264, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 7.07470 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 2.99791 | 0.55153 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.19360 | 0.54746 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 1.39475 | 0.55002 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 1.14349 | 0.54895 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [1.1751 1.1751]
# -> S(F(x)) approx distance: 0.54809
# !! Max_iter. Delta: 0.000053, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 7.08563 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.28041 | 0.50520 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.17286 | 0.50521 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.72783 | 0.50521 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.59518 | 0.50602 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [1.3205 1.3205]
# -> S(F(x)) approx distance: 0.50521
# !! Max_iter. Delta: 0.000077, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 7.10389 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.25814 | 0.47227 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.15913 | 0.47228 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.50168 | 0.47228 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.41023 | 0.47305 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [1.4381 1.4381]
# -> S(F(x)) approx distance: 0.47228
# !! Max_iter. Delta: 0.000100, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 7.12960 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.83433 | 0.44613 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.51431 | 0.44613 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.38740 | 0.44613 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.31678 | 0.44686 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [1.5365 1.5365]
# -> S(F(x)) approx distance: 0.44613
# !! Max_iter. Delta: 0.000361, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 7.16288 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.22967 | 0.42258 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.14189 | 0.42346 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.31787 | 0.42554 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.26041 | 0.42466 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [1.6242 1.6242]
# -> S(F(x)) approx distance: 0.42397
# !! Max_iter. Delta: 0.000376, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 7.20391 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.58366 | 0.40865 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.36018 | 0.40781 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.10283 | 0.40583 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.22236 | 0.40666 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [1.6993 1.6993]
# -> S(F(x)) approx distance: 0.40600
# !! Max_iter. Delta: 0.000162, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 7.25291 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.21385 | 0.38944 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.31586 | 0.39240 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.23802 | 0.39210 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.19500 | 0.39132 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [1.7667 1.7667]
# -> S(F(x)) approx distance: 0.39070
# !! Max_iter. Delta: 0.000182, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 7.31015 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.45768 | 0.37989 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.28245 | 0.37913 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.21285 | 0.37884 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.07952 | 0.37810 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [1.8226 1.8226]
# -> S(F(x)) approx distance: 0.37869
# !! Max_iter. Delta: 0.000407, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 7.37593 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.41542 | 0.36830 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.25637 | 0.36759 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.09492 | 0.36593 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.15829 | 0.36662 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [1.8849 1.8849]
# -> S(F(x)) approx distance: 0.36607
# !! Max_iter. Delta: 0.000218, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 7.45063 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.38153 | 0.35817 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.23547 | 0.35750 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.09327 | 0.35594 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.14538 | 0.35659 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [1.9377 1.9377]
# -> S(F(x)) approx distance: 0.35608
# !! Max_iter. Delta: 0.000235, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 7.53469 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.19759 | 0.34635 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.12202 | 0.34696 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.09198 | 0.34719 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.07540 | 0.34780 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [1.9815 1.9815]
# -> S(F(x)) approx distance: 0.34828
# !! Max_iter. Delta: 0.000251, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 7.62859 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.19565 | 0.33902 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.12071 | 0.33930 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.15382 | 0.34064 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.12603 | 0.34007 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [2.0338 2.0338]
# -> S(F(x)) approx distance: 0.33963
# !! Max_iter. Delta: 0.000267, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 7.73291 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.19472 | 0.33328 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.19242 | 0.33328 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.09041 | 0.33328 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.11850 | 0.33370 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [2.0754 2.0754]
# -> S(F(x)) approx distance: 0.33328
# !! Max_iter. Delta: 0.000430, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 7.84829 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.29550 | 0.32732 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.11938 | 0.32732 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.08993 | 0.32732 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.07349 | 0.32695 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [2.1178 2.1178]
# -> S(F(x)) approx distance: 0.32732
# !! Max_iter. Delta: 0.000296, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 7.97549 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.19309 | 0.32211 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.11903 | 0.32211 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.08966 | 0.32211 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.10673 | 0.32245 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [2.1585 2.1585]
# -> S(F(x)) approx distance: 0.32211
# !! Max_iter. Delta: 0.000431, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 8.11536 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.26873 | 0.31758 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.11895 | 0.31757 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.08960 | 0.31757 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.07323 | 0.31727 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [2.1978 2.1978]
# -> S(F(x)) approx distance: 0.31757
# !! Max_iter. Delta: 0.000323, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 8.26887 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.19327 | 0.31366 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.15898 | 0.31366 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.11975 | 0.31366 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.09790 | 0.31393 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [2.2359 2.2359]
# -> S(F(x)) approx distance: 0.31366
# !! Max_iter. Delta: 0.000429, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 8.43714 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.24840 | 0.31032 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.11958 | 0.31032 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.11534 | 0.31032 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.07362 | 0.31008 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [2.273 2.273]
# -> S(F(x)) approx distance: 0.31032
# !! Max_iter. Delta: 0.000347, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 8.62144 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.19510 | 0.30752 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.12027 | 0.30751 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.09059 | 0.30752 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.09112 | 0.30772 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [2.3093 2.3093]
# -> S(F(x)) approx distance: 0.30752
# !! Max_iter. Delta: 0.000423, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 8.82324 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.23269 | 0.30522 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.14344 | 0.30522 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.10805 | 0.30522 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.07463 | 0.30506 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [2.3449 2.3449]
# -> S(F(x)) approx distance: 0.30522
# !! Max_iter. Delta: 0.000420, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 9.04424 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.19789 | 0.30304 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.13918 | 0.30364 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.10489 | 0.30358 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.08596 | 0.30341 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [2.3827 2.3827]
# -> S(F(x)) approx distance: 0.30329
# !! Max_iter. Delta: 0.000378, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 9.28637 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.20029 | 0.30181 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.12365 | 0.30192 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.10224 | 0.30219 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.07638 | 0.30207 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [2.4117 2.4117]
# -> S(F(x)) approx distance: 0.30217
# !! Max_iter. Delta: 0.000409, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 9.55191 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.20314 | 0.30104 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.12541 | 0.30110 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.09990 | 0.30126 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.07746 | 0.30119 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [2.446 2.446]
# -> S(F(x)) approx distance: 0.30124
# !! Max_iter. Delta: 0.000402, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 9.84349 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.21032 | 0.30081 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.12984 | 0.30078 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.09785 | 0.30077 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.07873 | 0.30075 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [2.4801 2.4801]
# -> S(F(x)) approx distance: 0.30077
# !! Max_iter. Delta: 0.000395, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 9.84349 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.21032 | 0.30081 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.12984 | 0.30078 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.09785 | 0.30077 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.08019 | 0.30075 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [2.5142 2.5142]
# -> S(F(x)) approx distance: 0.30073
# !! Max_iter. Delta: 0.000387, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 9.55191 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.20314 | 0.30104 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.12541 | 0.30110 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.09990 | 0.30126 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.08187 | 0.30119 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [2.5484 2.5484]
# -> S(F(x)) approx distance: 0.30113
# !! Max_iter. Delta: 0.000415, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 9.28637 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.20029 | 0.30181 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.12365 | 0.30192 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.10224 | 0.30219 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.08378 | 0.30207 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [2.5827 2.5827]
# -> S(F(x)) approx distance: 0.30198
# !! Max_iter. Delta: 0.000420, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 9.04424 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.19789 | 0.30304 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.13918 | 0.30364 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.09208 | 0.30326 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.08596 | 0.30341 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [2.6173 2.6173]
# -> S(F(x)) approx distance: 0.30329
# !! Max_iter. Delta: 0.000423, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 8.82324 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.23269 | 0.30522 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.14344 | 0.30522 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.09131 | 0.30522 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.07463 | 0.30506 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [2.6551 2.6551]
# -> S(F(x)) approx distance: 0.30522
# !! Max_iter. Delta: 0.000347, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 8.62144 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.19510 | 0.30752 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.12027 | 0.30751 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.11146 | 0.30752 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.09112 | 0.30772 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [2.6907 2.6907]
# -> S(F(x)) approx distance: 0.30752
# !! Max_iter. Delta: 0.000429, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 8.43714 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.24840 | 0.31032 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.11958 | 0.31032 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.09007 | 0.31032 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.07362 | 0.31008 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [2.727 2.727]
# -> S(F(x)) approx distance: 0.31032
# !! Max_iter. Delta: 0.000323, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 8.26887 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.19327 | 0.31366 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.15898 | 0.31366 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.11975 | 0.31366 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.09790 | 0.31393 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [2.7641 2.7641]
# -> S(F(x)) approx distance: 0.31366
# !! Max_iter. Delta: 0.000431, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 8.11536 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.26873 | 0.31758 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.11895 | 0.31757 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.08960 | 0.31757 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.07323 | 0.31727 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [2.8022 2.8022]
# -> S(F(x)) approx distance: 0.31757
# !! Max_iter. Delta: 0.000432, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 7.97549 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.19309 | 0.32211 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.11903 | 0.32211 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.08966 | 0.32211 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.07328 | 0.32177 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [2.8415 2.8415]
# -> S(F(x)) approx distance: 0.32211
# !! Max_iter. Delta: 0.000430, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 7.84829 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.29550 | 0.32732 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.11938 | 0.32732 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.13721 | 0.32732 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.07349 | 0.32695 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [2.8822 2.8822]
# -> S(F(x)) approx distance: 0.32732
# !! Max_iter. Delta: 0.000267, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 7.73291 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.19472 | 0.33328 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.19242 | 0.33328 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.14494 | 0.33328 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.11850 | 0.33370 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [2.9246 2.9246]
# -> S(F(x)) approx distance: 0.33328
# !! Max_iter. Delta: 0.000251, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 7.62859 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.19565 | 0.33902 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.12071 | 0.33930 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.15382 | 0.34064 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.12603 | 0.34007 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [2.9662 2.9662]
# -> S(F(x)) approx distance: 0.33963
# !! Max_iter. Delta: 0.000235, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 7.53469 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.19759 | 0.34635 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.12202 | 0.34696 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.16455 | 0.34841 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.07540 | 0.34780 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [3.0185 3.0185]
# -> S(F(x)) approx distance: 0.34828
# !! Max_iter. Delta: 0.000218, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 7.45063 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.38153 | 0.35817 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.23547 | 0.35750 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.09327 | 0.35594 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.14538 | 0.35659 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [3.0623 3.0623]
# -> S(F(x)) approx distance: 0.35608
# !! Max_iter. Delta: 0.000407, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 7.37593 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.41542 | 0.36830 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.25637 | 0.36759 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.19320 | 0.36732 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.15829 | 0.36662 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [3.1151 3.1151]
# -> S(F(x)) approx distance: 0.36607
# !! Max_iter. Delta: 0.000398, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 7.31015 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.45768 | 0.37989 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.28245 | 0.37913 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.09699 | 0.37737 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.17438 | 0.37810 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [3.1718 3.1718]
# -> S(F(x)) approx distance: 0.37752
# !! Max_iter. Delta: 0.000162, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 7.25291 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.21385 | 0.38944 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.31586 | 0.39240 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.23802 | 0.39210 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.19500 | 0.39132 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [3.2333 3.2333]
# -> S(F(x)) approx distance: 0.39070
# !! Max_iter. Delta: 0.000142, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 7.20391 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.58366 | 0.40865 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.36018 | 0.40781 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.10283 | 0.40583 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.08433 | 0.40666 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [3.3064 3.3064]
# -> S(F(x)) approx distance: 0.40732
# !! Max_iter. Delta: 0.000361, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 7.16288 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.22967 | 0.42258 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.14189 | 0.42346 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.10697 | 0.42379 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.26041 | 0.42466 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [3.3758 3.3758]
# -> S(F(x)) approx distance: 0.42397
# !! Max_iter. Delta: 0.000343, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 7.12960 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.83433 | 0.44613 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.51431 | 0.44613 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.11260 | 0.44613 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.09198 | 0.44540 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [3.4635 3.4635]
# -> S(F(x)) approx distance: 0.44613
# !! Max_iter. Delta: 0.000323, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 7.10389 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.25814 | 0.47227 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.15913 | 0.47228 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.50168 | 0.47228 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.09790 | 0.47151 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [3.5619 3.5619]
# -> S(F(x)) approx distance: 0.47228
# !! Max_iter. Delta: 0.000297, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 7.08563 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 0.28041 | 0.50520 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.96626 | 0.50521 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.13021 | 0.50521 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.10633 | 0.50440 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [3.6795 3.6795]
# -> S(F(x)) approx distance: 0.50521
# !! Max_iter. Delta: 0.000028, Gap C: 0.000000, Gap Q: 0.000000
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 7.07470 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 2.99791 | 0.55153 | 0.00000 | 0.00000 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 0.19360 | 0.54746 | 0.00000 | 0.00000 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 0.14600 | 0.54787 | 0.00000 | 0.00000 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.11985 | 0.54895 | 0.00000 | 0.00000 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [3.8305 3.8305]
# -> S(F(x)) approx distance: 0.54980
# !! Max_iter. Delta: 0.000251, Gap C: 0.000000, Gap Q: 0.005264
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   k |   Alpha | Beta(C) | Gamma(Q) |  Lambda |    Step | S(F(x)) |   Gap C |  Gap Q+ |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# |   0 | 1.00000 | 1.00000 |  1.00000 | 1.00000 | 7.07107 | 0.30069 | 0.00000 | 0.00000 |
# | 250 | 0.57548 | 5.24689 | 15.84298 | 0.01203 | 1.82451 | 0.57109 | 0.00000 | 0.00836 |
# | 500 | 0.53705 | 6.45582 | 22.38303 | 0.00692 | 1.78307 | 0.56878 | 0.00000 | 0.00604 |
# | 750 | 0.51575 | 7.28940 | 27.40438 | 0.00501 | 2.25863 | 0.56776 | 0.00000 | 0.00501 |
# | 999 | 0.50119 | 7.94328 | 31.62278 | 0.00398 | 0.77185 | 0.56801 | 0.00000 | 0.00526 |
# +-----+---------+---------+----------+---------+---------+---------+---------+---------+
# -> Kết quả cuối cùng: [3.8871 3.8871]
# -> S(F(x)) approx distance: 0.56714

# %%
med, hv
# Out:
# (np.float64(0.0007134958458184718), np.float64(1.6950697381589523))

# %% [markdown]
# ## Viz

# %%
from utils import visualize_pareto_front, generate_pareto_grid

# %%
def generate_pareto_grid(f_func, c_funcs, q_plus_func, resolution=400):
    """
    Sinh dữ liệu Pareto cho bài toán 2D bằng cách quét lưới tọa độ.
    f_func: Hàm mục tiêu f(x)
    c_funcs: Danh sách các hàm ràng buộc c(x) >= 0 (miền C)
    q_plus_func: Hàm ràng buộc q_plus(y) >= 0 (miền Q+)
    """
    print(f"--- Đang quét lưới {resolution}x{resolution} điểm ---")
    
    # 1. Xác định phạm vi quét dựa trên các ràng buộc hình tròn c1, c2

    x0_range = np.linspace(0, 5, resolution)
    x1_range = np.linspace(0, 5, resolution)
    X0, X1 = np.meshgrid(x0_range, x1_range)
    
    # Làm phẳng để tính toán vector
    points_X = np.vstack([X0.ravel(), X1.ravel()]).T
    
    # 2. Kiểm tra ràng buộc miền C: c1(x) >= 0 và c2(x) >= 0
    # (Sử dụng các hàm c1, c2 đã định nghĩa của bạn)
    mask_C = np.ones(len(points_X), dtype=bool)
    for c_func in c_funcs:
        mask_C &= (c_func(points_X.T) >= 0)
    
    feasible_X = points_X[mask_C]
    print(f"-> Tìm thấy {len(feasible_X)} điểm thỏa mãn miền C.")
    
    if len(feasible_X) == 0:
        return None, None

    # 3. Tính giá trị mục tiêu f(x) và kiểm tra miền Q+
    f_vals = np.array([f_func(x) for x in feasible_X])  # shape (N, 2)
    
    # Kiểm tra q_plus(f(x)) >= 0
    # Lưu ý: Hàm q_plus của bạn nhận 1 vector y, ta cần áp dụng cho toàn bộ f_vals
    mask_Qplus = np.array([q_plus_func(y) >= 0 for y in f_vals])
    
    pf_cloud_data = f_vals[mask_Qplus]
    print(f"-> Lọc còn {len(pf_cloud_data)} điểm thỏa mãn Q+ (Cloud).")

    if len(pf_cloud_data) == 0:
        return None, None

    # 4. Lọc Pareto Front từ Cloud (Tìm các điểm không bị trội)
    # Sắp xếp theo f1 tăng dần
    sorted_indices = np.argsort(pf_cloud_data[:, 0])
    y_sorted = pf_cloud_data[sorted_indices]
    
    pareto_list = []
    pareto_list.append(y_sorted[0])
    current_min_f2 = y_sorted[0][1]
    
    for i in range(1, len(y_sorted)):
        if y_sorted[i][1] < current_min_f2:
            pareto_list.append(y_sorted[i])
            current_min_f2 = y_sorted[i][1]
    
    pf_targets_data = np.array(pareto_list)
    print(f"-> Kết quả: {len(pf_targets_data)} điểm Pareto.")
    
    return pf_cloud_data, pf_targets_data

# %%
def non_c(x):
    return 1
pf_cloud, pf_targets = generate_pareto_grid(
    f_func=f, 
    c_funcs=[non_c], 
    q_plus_func=q_plus, 
    resolution=500
)
# Out:
# --- Đang quét lưới 500x500 điểm ---
# -> Tìm thấy 250000 điểm thỏa mãn miền C.
# -> Lọc còn 192206 điểm thỏa mãn Q+ (Cloud).
# -> Kết quả: 549 điểm Pareto.

# %%
visualize_pareto_front(
    pf_pred=np.array(pf_true_dynamic), 
    pf_cloud=pf_cloud,   
    pf_targets=np.array(pf_true),
    title="Dynamic approximate exact",
    figsize=(8, 6)
)

# %% [markdown]
# # Hypernet

# %%
from training_hypernet import train_hypernet

# %%
prob_ = Problem(
    f=[f1, f2], jac_f=[jacobian_f],
    dim_x=dim_x, dim_y=dim_y,
    proj_C=proj_C_handler.project,
    proj_Qplus=proj_Q_handler.project
)

# %% [markdown]
# ## Tuning

# %%
from tuning_hypernet import run_hypernet_tuning

# %%
param_grid = {
    'lr': [1e-3],
    'num_epochs': [1000, 2000],
    
    'num_partitions': [n_rays],
    
    # Tham số thuật toán 2-A: Tăng dần penalty
    'beta_C_0': [10],
    'beta_Q_0': [1, 5],
    'rho_C': [1.01], 
    'rho_Q': [1.01, 1.001],
    
    # Cố định Max để tránh grid quá lớn 
    'beta_C_max': [1000.0],
    'beta_Q_max': [50.0, 100.0, 200.0]
}

# %%
device = 'cpu'

# %%
results = run_hypernet_tuning(
    prob=prob_,
    dim_x=dim_x,
    z_star=z_star,
    ref_point=ref_point,
    test_rays=test_rays,
    pf_true=pf_true,
    param_grid=param_grid,
    indicator="MED", 
    device=device,
    save_dir=f"model/{case}",
    train_func=train_hypernet
)
# Out:
# ============================================================
# 🔹 TUNING MODEL: MLP | PRIORITY: MED
# ============================================================
#
# >>> [Config 1/24] Params: {'lr': 0.001, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 1, 'rho_C': 1.01, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 50.0}
#       ⏱️ Time: 148.1s | 📏 MED: 0.003445 | 📈 HV: 1.693190
#       🏆 NEW BEST FOUND! Saved to: model/_Ex_7_2/best_MLP_MED.pth
#
# >>> [Config 2/24] Params: {'lr': 0.001, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 1, 'rho_C': 1.01, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 100.0}
#       ⏱️ Time: 145.2s | 📏 MED: 0.008428 | 📈 HV: 1.678370
#
# >>> [Config 3/24] Params: {'lr': 0.001, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 1, 'rho_C': 1.01, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 200.0}
#       ⏱️ Time: 146.3s | 📏 MED: 0.015082 | 📈 HV: 1.662164
#
# >>> [Config 4/24] Params: {'lr': 0.001, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 1, 'rho_C': 1.01, 'rho_Q': 1.001, 'beta_C_max': 1000.0, 'beta_Q_max': 50.0}
#       ⏱️ Time: 145.0s | 📏 MED: 0.007498 | 📈 HV: 1.681169
#
# >>> [Config 5/24] Params: {'lr': 0.001, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 1, 'rho_C': 1.01, 'rho_Q': 1.001, 'beta_C_max': 1000.0, 'beta_Q_max': 100.0}
#       ⏱️ Time: 143.3s | 📏 MED: 0.017388 | 📈 HV: 1.656642
#
# >>> [Config 6/24] Params: {'lr': 0.001, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 1, 'rho_C': 1.01, 'rho_Q': 1.001, 'beta_C_max': 1000.0, 'beta_Q_max': 200.0}
#       ⏱️ Time: 145.4s | 📏 MED: 0.007800 | 📈 HV: 1.684522
#
# >>> [Config 7/24] Params: {'lr': 0.001, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.01, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 50.0}
#       ⏱️ Time: 145.5s | 📏 MED: 0.023099 | 📈 HV: 1.643693
#
# >>> [Config 8/24] Params: {'lr': 0.001, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.01, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 100.0}
#       ⏱️ Time: 144.0s | 📏 MED: 0.011597 | 📈 HV: 1.671440
#
# >>> [Config 9/24] Params: {'lr': 0.001, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.01, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 200.0}
#       ⏱️ Time: 145.5s | 📏 MED: 0.005329 | 📈 HV: 1.692561
#
# >>> [Config 10/24] Params: {'lr': 0.001, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.01, 'rho_Q': 1.001, 'beta_C_max': 1000.0, 'beta_Q_max': 50.0}
#       ⏱️ Time: 146.5s | 📏 MED: 0.017976 | 📈 HV: 1.649548
#
# >>> [Config 11/24] Params: {'lr': 0.001, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.01, 'rho_Q': 1.001, 'beta_C_max': 1000.0, 'beta_Q_max': 100.0}
#       ⏱️ Time: 145.6s | 📏 MED: 0.007688 | 📈 HV: 1.682179
#
# >>> [Config 12/24] Params: {'lr': 0.001, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.01, 'rho_Q': 1.001, 'beta_C_max': 1000.0, 'beta_Q_max': 200.0}
#       ⏱️ Time: 146.7s | 📏 MED: 0.006694 | 📈 HV: 1.684637
#
# >>> [Config 13/24] Params: {'lr': 0.001, 'num_epochs': 2000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 1, 'rho_C': 1.01, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 50.0}
#       ⏱️ Time: 290.8s | 📏 MED: 0.005272 | 📈 HV: 1.693425
#
# >>> [Config 14/24] Params: {'lr': 0.001, 'num_epochs': 2000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 1, 'rho_C': 1.01, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 100.0}
#       ⏱️ Time: 285.6s | 📏 MED: 0.013962 | 📈 HV: 1.667296
#
# >>> [Config 15/24] Params: {'lr': 0.001, 'num_epochs': 2000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 1, 'rho_C': 1.01, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 200.0}
#       ⏱️ Time: 286.7s | 📏 MED: 0.011125 | 📈 HV: 1.674480
#
# >>> [Config 16/24] Params: {'lr': 0.001, 'num_epochs': 2000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 1, 'rho_C': 1.01, 'rho_Q': 1.001, 'beta_C_max': 1000.0, 'beta_Q_max': 50.0}
#       ⏱️ Time: 289.6s | 📏 MED: 0.005988 | 📈 HV: 1.686695
#
# >>> [Config 17/24] Params: {'lr': 0.001, 'num_epochs': 2000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 1, 'rho_C': 1.01, 'rho_Q': 1.001, 'beta_C_max': 1000.0, 'beta_Q_max': 100.0}
#       ⏱️ Time: 289.0s | 📏 MED: 0.008017 | 📈 HV: 1.683660
#
# >>> [Config 18/24] Params: {'lr': 0.001, 'num_epochs': 2000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 1, 'rho_C': 1.01, 'rho_Q': 1.001, 'beta_C_max': 1000.0, 'beta_Q_max': 200.0}
#       ⏱️ Time: 289.9s | 📏 MED: 0.007409 | 📈 HV: 1.681308
#
# >>> [Config 19/24] Params: {'lr': 0.001, 'num_epochs': 2000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.01, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 50.0}
#       ⏱️ Time: 284.9s | 📏 MED: 0.007266 | 📈 HV: 1.686190
#
# >>> [Config 20/24] Params: {'lr': 0.001, 'num_epochs': 2000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.01, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 100.0}
#       ⏱️ Time: 279.6s | 📏 MED: 0.003749 | 📈 HV: 1.696347
#
# >>> [Config 21/24] Params: {'lr': 0.001, 'num_epochs': 2000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.01, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 200.0}
#       ⏱️ Time: 279.9s | 📏 MED: 0.004211 | 📈 HV: 1.693632
#
# >>> [Config 22/24] Params: {'lr': 0.001, 'num_epochs': 2000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.01, 'rho_Q': 1.001, 'beta_C_max': 1000.0, 'beta_Q_max': 50.0}
#       ⏱️ Time: 279.9s | 📏 MED: 0.007015 | 📈 HV: 1.684601
#
# >>> [Config 23/24] Params: {'lr': 0.001, 'num_epochs': 2000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.01, 'rho_Q': 1.001, 'beta_C_max': 1000.0, 'beta_Q_max': 100.0}
#       ⏱️ Time: 288.5s | 📏 MED: 0.007148 | 📈 HV: 1.680927
#
# >>> [Config 24/24] Params: {'lr': 0.001, 'num_epochs': 2000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.01, 'rho_Q': 1.001, 'beta_C_max': 1000.0, 'beta_Q_max': 200.0}
#       ⏱️ Time: 294.0s | 📏 MED: 0.014382 | 📈 HV: 1.661682
#
# ✅ Hoàn thành MLP. Best MED: 3.444720e-03
#    Best Config: {'lr': 0.001, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 1, 'rho_C': 1.01, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 50.0}
#
# ============================================================
# 🔹 TUNING MODEL: trans | PRIORITY: MED
# ============================================================
#
# >>> [Config 1/24] Params: {'lr': 0.001, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 1, 'rho_C': 1.01, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 50.0}
#       ⏱️ Time: 174.8s | 📏 MED: 0.008810 | 📈 HV: 1.676780
#       🏆 NEW BEST FOUND! Saved to: model/_Ex_7_2/best_trans_MED.pth
#
# >>> [Config 2/24] Params: {'lr': 0.001, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 1, 'rho_C': 1.01, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 100.0}
#       ⏱️ Time: 175.7s | 📏 MED: 0.002858 | 📈 HV: 1.694996
#       🏆 NEW BEST FOUND! Saved to: model/_Ex_7_2/best_trans_MED.pth
#
# >>> [Config 3/24] Params: {'lr': 0.001, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 1, 'rho_C': 1.01, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 200.0}
#       ⏱️ Time: 175.5s | 📏 MED: 0.003946 | 📈 HV: 1.699252
#
# >>> [Config 4/24] Params: {'lr': 0.001, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 1, 'rho_C': 1.01, 'rho_Q': 1.001, 'beta_C_max': 1000.0, 'beta_Q_max': 50.0}
#       ⏱️ Time: 178.1s | 📏 MED: 0.003913 | 📈 HV: 1.695007
#
# >>> [Config 5/24] Params: {'lr': 0.001, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 1, 'rho_C': 1.01, 'rho_Q': 1.001, 'beta_C_max': 1000.0, 'beta_Q_max': 100.0}
#       ⏱️ Time: 177.4s | 📏 MED: 0.002739 | 📈 HV: 1.695942
#       🏆 NEW BEST FOUND! Saved to: model/_Ex_7_2/best_trans_MED.pth
#
# >>> [Config 6/24] Params: {'lr': 0.001, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 1, 'rho_C': 1.01, 'rho_Q': 1.001, 'beta_C_max': 1000.0, 'beta_Q_max': 200.0}
#       ⏱️ Time: 175.0s | 📏 MED: 0.006439 | 📈 HV: 1.685707
#
# >>> [Config 7/24] Params: {'lr': 0.001, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.01, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 50.0}

# %% [markdown]
# # Viz

# %%
import pandas as pd

# %%
df = pd.json_normalize(results, sep='_')
df.columns = df.columns.str.replace('params_', '')

# %%
df.sort_values("med")
# Out:
#     model       med        hv        time      lr  num_epochs  num_partitions  \
# 42  trans  0.003086  1.690350  446.615109  0.0010        1000              50
# 13    MLP  0.003296  1.693888  805.076371  0.0010        2000              50
# 47  trans  0.003365  1.689480  453.407133  0.0010        1000              50
# 52  trans  0.003785  1.692493  902.579770  0.0010        2000              50
# 48  trans  0.004267  1.687069  901.109759  0.0010        2000              50
# ..    ...       ...       ...         ...     ...         ...             ...
# 28    MLP  0.035404  1.606009  413.396231  0.0005        1000              50
# 19    MLP  0.041322  1.585093  208.361228  0.0005         500              50
# 21    MLP  0.041654  1.582100  208.505226  0.0005         500              50
# 22    MLP  0.102841  1.439336  208.529208  0.0005         500              50
# 23    MLP  0.175784  1.275646  208.657225  0.0005         500              50
#
#     beta_C_0  beta_Q_0  rho_C  rho_Q  beta_C_max  beta_Q_max
# 42        10         5   1.03   1.01      1000.0       100.0
# 13        10         5   1.03   1.01      1000.0       500.0
# 47        10         5   1.03   1.03      1000.0      1000.0
# 52        10         5   1.03   1.03      1000.0       500.0
# 48        10         5   1.03   1.01      1000.0       100.0
# ..       ...       ...    ...    ...         ...         ...
# 28        10         5   1.03   1.03      1000.0       500.0
# 19        10         5   1.03   1.01      1000.0       500.0
# 21        10         5   1.03   1.03      1000.0       100.0
# 22        10         5   1.03   1.03      1000.0       500.0
# 23        10         5   1.03   1.03      1000.0      1000.0
#
# [72 rows x 13 columns]

# %%
 df.groupby("beta_Q_max")[["med", "hv"]].agg(["mean", "min", "max"]).reset_index()
# Out:
#   beta_Q_max       med                            hv
#                   mean       min       max      mean       min       max
# 0      100.0  0.015903  0.003086  0.041654  1.659431  1.582100  1.699756
# 1      500.0  0.018349  0.003296  0.102841  1.654028  1.439336  1.700539
# 2     1000.0  0.021516  0.003365  0.175784  1.647645  1.275646  1.691537

# %%
 df.groupby("num_epochs")[["med", "hv"]].agg(["mean", "min", "max"]).reset_index()
# Out:
#   num_epochs       med                            hv
#                   mean       min       max      mean       min       max
# 0        500  0.028602  0.004293  0.175784  1.628070  1.275646  1.699756
# 1       1000  0.013202  0.003086  0.035404  1.668737  1.606009  1.700539
# 2       2000  0.013965  0.003296  0.034009  1.664297  1.599833  1.693888

# %%
 df.groupby("lr")[["med", "hv"]].agg(["mean", "min", "max"]).reset_index()
# Out:
#        lr       med                            hv
#                mean       min       max      mean       min       max
# 0  0.0005  0.027199  0.005076  0.175784  1.630870  1.275646  1.691257
# 1  0.0010  0.009979  0.003086  0.031690  1.676533  1.620793  1.700539

# %%
 df.groupby("rho_Q")[["med", "hv"]].agg(["mean", "min", "max"]).reset_index()
# Out:
#   rho_Q       med                            hv
#              mean       min       max      mean       min       max
# 0  1.01  0.014216  0.003086  0.041322  1.664953  1.585093  1.694324
# 1  1.03  0.022962  0.003365  0.175784  1.642450  1.275646  1.700539

# %%
df.to_csv(f"exp/{case}/{n_rays}.csv", index=False)

# %% [markdown]
# ## Infer

# %%
import os
import torch
import time
from hypernet_MLP import Hypernet_MLP
from hypernet_trans import Hypernet_trans
from utils import plot_trajectories

# %%
def infer(model, test_rays=test_rays):
    model.eval()
    pf_pred = [] 
    tmp_err = [] 
    t1 = time.time()
    print(f"Evaluating on {len(test_rays)} rays...")

    for r in test_rays:   
        # --- Dự đoán với Hypernetwork ---
        ray_t = torch.from_numpy(r).float().unsqueeze(0)
        with torch.no_grad(): 
            output_x = model(ray_t).flatten() 
            vals = [func(output_x).item() for func in prob_.f]
            obj_pred = np.array(vals)

        pf_pred.append(obj_pred)
    t2 = time.time()
    pf_pred = np.array(pf_pred)
    print("-" * 30)
    print(f"Inference Time: {t2-t1:.4f}s")
    return pf_pred

# %%
best_MLP = Hypernet_MLP(ray_hidden_dim=32, out_dim=dim_x, n_tasks=2)
best_trans = Hypernet_trans(ray_hidden_dim=32, out_dim=dim_x, n_tasks=2)
# 2. Đường dẫn file đã lưu
PATH_MLP = f"model/{case}/best_MLP_MED.pth"
PATH_trans = f"model/{case}/best_trans_MED.pth"
# 3. Load state dict
if os.path.exists(PATH_MLP):
    state_dict = torch.load(PATH_MLP, map_location=device)
    best_MLP.load_state_dict(state_dict)
    best_MLP.to(device)
    best_MLP.eval() 
    print("Successful MLP ✅")

if os.path.exists(PATH_trans):
    state_dict = torch.load(PATH_trans, map_location=device)
    best_trans.load_state_dict(state_dict)
    best_trans.to(device)
    best_trans.eval() 
    print("Successful Trans ✅")
# Out:
# Successful MLP ✅
# Successful Trans ✅

# %%
pf_pred = infer(best_trans)
med, hv = get_metrics(pf_pred, pf_true, prob_, ref_point)
med, hv
# Out:
# Evaluating on 50 rays...
# ------------------------------
# Inference Time: 0.0242s
# (np.float64(0.0030862847461095104), np.float64(1.69035003826803))

# %%
plot_trajectories(obs_true=np.array(pf_true),obs_predict=np.array(pf_pred),obs_pareto_front=pf_cloud , figsize=(16, 8))

# %%
pf_pred = infer(best_MLP)
med, hv = get_metrics(pf_pred, pf_true, prob, ref_point)
med, hv
# Out:
# Evaluating on 50 rays...
# ------------------------------
# Inference Time: 0.0060s
# (np.float64(0.003295732837755168), np.float64(1.693888255841661))

# %%
plot_trajectories(obs_true=np.array(pf_true),obs_predict=np.array(pf_pred),obs_pareto_front=pf_cloud , figsize=(16, 8))

# %% [markdown]
# # Summarize

# %%
def run_benchmark(
    name,               # Tên hiển thị trong CSV (vd: "Hypernet_MLP", "Solver_BestParams")
    method_type,        # "model" hoặc "solver"
    prob,               # Đối tượng bài toán
    test_rays,          # Tập tia kiểm tra
    pf_true_gt,         # Ground Truth chuẩn để tính MED
    ref_point,          # Điểm tham chiếu tính HV
    # --- Optional cho Model ---
    model=None,
    # --- Optional cho Solver ---
    solver_func=None,
    x_feasible=None,
    z_star=None,
    solver_params=None, # Dictionary chứa {mu, max_iter, ...}
    # --- Settings ---
    csv_path="results_summary.csv",
    n_runs=None         # Số lần chạy để tính trung bình time (Mặc định: Model=10, Solver=1)
):
    """
    Hàm benchmark tổng hợp cho cả AI Model và Numerical Solver.
    """
    num_rays = len(test_rays)
    
    # 1. Xác định số lần chạy mặc định nếu không truyền vào
    if n_runs is None:
        n_runs = 10 if method_type == "model" else 1
    
    # 2. KIỂM TRA TRÙNG LẶP TRONG CSV
    if os.path.exists(csv_path):
        try:
            df_check = pd.read_csv(csv_path)
            is_exist = not df_check[(df_check['model'] == name) & 
                                    (df_check['num_rays'] == num_rays)].empty
            if is_exist:
                print(f"⚠️  [EXIST] Kết quả '{name}' ({num_rays} rays) đã có.")
                user_resp = input("   Chạy lại? (y/n): ").strip().lower()
                if user_resp != 'y':
                    return df_check
        except: pass

    print(f"\n🚀 BENCHMARKING: {name}")
    print(f"   Type: {method_type} | Rays: {num_rays} | Repeats: {n_runs}")

    # 3. CHUẨN BỊ (Warm-up cho Model)
    device = None
    if method_type == "model" and model is not None:
        model.eval()
        device = next(model.parameters()).device
        # Warm-up 1 pass
        dummy_ray = torch.from_numpy(test_rays[0]).float().unsqueeze(0).to(device)
        with torch.no_grad(): _ = model(dummy_ray)

    # 4. ĐO THỜI GIAN VÀ CHẠY
    total_time = 0
    pf_pred_final = []

    for i in range(n_runs):
        t1 = time.time()
        current_pf_vals = []

        # --- CASE A: DEEP LEARNING MODEL ---
        if method_type == "model":
            for r in test_rays:
                ray_t = torch.from_numpy(r).float().unsqueeze(0).to(device)
                with torch.no_grad():
                    output_x = model(ray_t).flatten()
                    x_cpu = output_x.cpu().numpy()
                    vals = [func(x_cpu).item() for func in prob.f]
                    current_pf_vals.append(vals)
        
        # --- CASE B: NUMERICAL SOLVER ---
        elif method_type == "solver":
            for r in test_rays:
                # Gọi solver với tham số unpack từ dict
                x_final, _ = solver_func(
                    prob=prob,
                    x_feasible=x_feasible,
                    r=r,
                    z_star=z_star,
                    verbose=False, # Tắt log chi tiết khi benchmark
                    max_iter=solver_params['max_iter'],
                    mu=solver_params['mu'],
                    init_params=solver_params['init_params'],
                    expo_alpha=solver_params['expo_alpha'],
                    expo_lambda=solver_params['expo_lambda'],
                    expo_beta=solver_params['expo_beta'],
                    expo_gamma=solver_params['expo_gamma']
                )
                current_pf_vals.append(prob.objective_func(x_final))
        
        t2 = time.time()
        run_time = t2 - t1
        total_time += run_time
        
        # In tiến độ nếu chạy Solver (vì lâu)
        if method_type == "solver":
            print(f"   Run {i+1}/{n_runs}: {run_time:.4f}s")
        
        # Lưu kết quả của lần chạy cuối cùng
        if i == n_runs - 1:
            pf_pred_final = np.array(current_pf_vals)

    avg_time = total_time / n_runs
    print(f"   ⏱️ Avg Time: {avg_time:.4f}s")

    # 5. TÍNH METRICS & LƯU
    med, hv = get_metrics(pf_pred_final, pf_true_gt, prob, ref_point)
    print(f"   📊 MED: {med:.5f} | HV: {hv:.5f}")

    new_row = {
        "model": name,
        "num_rays": num_rays,
        "med": med,
        "hv": hv,
        "time": avg_time
    }
    
    if os.path.exists(csv_path):
        df = pd.read_csv(csv_path)
        df = pd.concat([df, pd.DataFrame([new_row])], ignore_index=True)
    else:
        df = pd.DataFrame([new_row])
        
    os.makedirs(os.path.dirname(csv_path), exist_ok=True)
    df.to_csv(csv_path, index=False)
    print(f"✅ Saved to {csv_path}")
    return df

# %%
csv_file = f"exp/{case}/{n_rays}_conclusion.csv"

# 1. Benchmark Hypernetwork MLP
run_benchmark(
    name="Hypernet_MLP",
    method_type="model",
    prob=prob_,
    test_rays=test_rays,
    pf_true_gt=pf_true,      # Ground Truth chuẩn
    ref_point=ref_point,
    model=best_MLP,          # Truyền model vào
    csv_path=csv_file
)

# 2. Benchmark Hypernetwork Transformer
run_benchmark(
    name="Hypernet_Trans",
    method_type="model",
    prob=prob_,
    test_rays=test_rays,
    pf_true_gt=pf_true,
    ref_point=ref_point,
    model=best_trans,        # Truyền model vào
    csv_path=csv_file
)

# 3. Benchmark Numerical Solver (Với tham số tốt nhất)
run_benchmark(
    name="Numerical_Solver",
    method_type="solver",
    prob=prob,
    test_rays=test_rays,
    pf_true_gt=pf_true,
    ref_point=ref_point,
    solver_func=optim_Scalarization,  # Truyền hàm giải
    x_feasible=x_feasible,            # Input cần thiết cho solver
    z_star=z_star,                    # Input cần thiết cho solver
    solver_params=best_params,        # Dictionary chứa {mu, expo_alpha...} từ GridSearch
    csv_path=csv_file,
    n_runs=1                          # Chạy 1 lần vì lâu
)
# Out:
# 🚀 BENCHMARKING: Hypernet_MLP
#    Type: model | Rays: 50 | Repeats: 10
#    ⏱️ Avg Time: 0.0026s
#    📊 MED: 0.00330 | HV: 1.69389
# ✅ Saved to exp/_Ex_7_2/50_conclusion.csv
#
# 🚀 BENCHMARKING: Hypernet_Trans
#    Type: model | Rays: 50 | Repeats: 10
#    ⏱️ Avg Time: 0.0145s
#    📊 MED: 0.00309 | HV: 1.69035
# ✅ Saved to exp/_Ex_7_2/50_conclusion.csv
#
# 🚀 BENCHMARKING: Numerical_Solver
#    Type: solver | Rays: 50 | Repeats: 1
# !! Max_iter. Delta: 0.000251, Gap C: 0.000000, Gap Q: 0.005160
# !! Max_iter. Delta: 0.000264, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000053, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000077, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000100, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000361, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000376, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000162, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000182, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000407, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000218, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000235, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000251, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000267, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000430, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000296, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000431, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000323, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000429, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000347, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000423, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000420, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000378, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000409, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000402, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000395, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000387, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000415, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000420, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000423, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000347, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000429, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000323, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000431, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000432, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000430, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000267, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000251, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000235, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000218, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000407, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000398, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000162, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000142, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000361, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000343, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000323, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000297, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000028, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000251, Gap C: 0.000000, Gap Q: 0.005264
#    Run 1/1: 123.7252s
#    ⏱️ Avg Time: 123.7252s
#    📊 MED: 0.00071 | HV: 1.69507
# ✅ Saved to exp/_Ex_7_2/50_conclusion.csv
#               model  num_rays       med        hv        time
# 0      Hypernet_MLP        50  0.003296  1.693888    0.002608
# 1    Hypernet_Trans        50  0.003086  1.690350    0.014490
# 2  Numerical_Solver        50  0.000713  1.695070  123.725183

# %%
pd.read_csv(csv_file)
# Out:
#               model  num_rays       med        hv        time
# 0      Hypernet_MLP        50  0.001573  1.390434    0.007625
# 1    Hypernet_Trans        50  0.001139  1.390369    0.030978
# 2  Numerical_Solver        50  0.004014  1.382445  145.921243
