# %%
n_rays = 50
case = "_Ex_7_1"

# %%
params = {
    "initialization": {
        "x_init": [0.5],
        "y_init": [0.8, 0.5]
    },
    "exact":{
        "learning_rate": 0.001,
        "max_iters": 20000,
        "tol": 1e-5
    },
    "phase1": {
        "gamma": 12,
        "expo_gamma": 0.01,
        "max_iter": 10000,
        "tol": 1e-4
    },
    "phase2": {
        "expo_alpha": 0.45,
        "expo_beta": 0.4,
        "expo_lambda": 0.55,
        "init_params": 1.0,
        "max_iter": 2000,
        "mu": 1e-4,
        "verbose": False,
        "expo_gamma": 0.5
    }
}

# %%
import autograd.numpy as np
import torch

# %%
def set_seed(seed=702):
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)

set_seed(702)

# %% [markdown]
# # Gen rays

# %%
import math

# %%
def generate_chebyshev_rays(num_rays=10):
    rays = []
    angles = np.linspace(0, np.pi/2, num_rays)
    for theta in angles:
        r1, r2 = math.cos(theta), math.sin(theta)
        if abs(r1) < 1e-9: r1 = 0.0
        if abs(r2) < 1e-9: r2 = 0.0
        rays.append([r1, r2])       
    return np.array(rays)

# %%
test_rays = generate_chebyshev_rays(n_rays)

# %% [markdown]
# # Giải chính xác bằng phương pháp chiếu

# %% [markdown]
# ## Bài toán

# %%
# ==========================================
# HÀM MỤC TIÊU
# ==========================================
def f(x):    return np.array([x[0],(x[0] - 1)**2])
def f1(x):    return x[0]
def f2(x):    return (x[0] - 1)**2
def jacobian_f(x):
    return np.array([[1.0],[2.0 * (x[0] - 1)]])
# --- Hàm mục tiêu Weighted Chebyshev ---
def S_weighted_chebyshev(x, r, z):
    vals = f(x)
    weighted_diffs = r * np.abs(vals - z)
    return np.max(weighted_diffs)
# --- Tính Subgradient ---
def get_subgradient(x, r, z):
    """
    Tính đạo hàm của hàm max(r_i * |f_i - z_i|)
    """
    vals = f(x)
    diffs = vals - z
    weighted_abs_diffs = r * np.abs(diffs)
    k = np.argmax(weighted_abs_diffs)
    J = jacobian_f(x)
    gradient_fk = J[k] 
    sign = 1.0 if diffs[k] >= 0 else -1.0
    grad = r[k] * sign * gradient_fk
    return grad
# ==========================================
# CÁC RÀNG BUỘC & PHÉP CHIẾU
# ==========================================
# Ràng buộc tập X
def c1(x): return x[0]
def c2(x): return -x[0] + 1
# Ràng buộc tập Q
def q1(y): return 0.2**2 - (y[0] - 0.4)**2 - (y[1] - 0.4)**2
def q_plus(y):
    center = .4
    radius_sq = 0.2**2  
    dx = np.maximum(0, y[0] - center)
    dy = np.maximum(0, y[1] - center)
    return radius_sq - (dx**2 + dy**2)
dim_x = 1
dim_y = 2

# %% [markdown]
# ## Phép chiếu lên X'

# %%
from Problem import Problem
from project import Projection
from scipy.optimize import minimize

# %%
cons_C = ({'type': 'ineq', 'fun' : c1,},
          {'type': 'ineq', 'fun' : c2,})
cons_Q = ({'type': 'ineq', 'fun' : q1,},)
cons_Qplus = ({'type': 'ineq', 'fun': q_plus},)
# Setup Projections
proj_C_handler = Projection(cons=cons_C, bounds=None, dim=dim_x, proj_type='euclid')
proj_Q_handler = Projection(cons=cons_Q, bounds=None, dim=dim_y, proj_type='qplus')
# Setup Problem
prob = Problem(
    f=[f], jac_f=[jacobian_f],
    dim_x=dim_x, dim_y=dim_y,
    proj_C=proj_C_handler.project,
    proj_Qplus=proj_Q_handler.project
)

# %%
def project_step(x_temp, y_temp, dim_x, dim_y):
    """
    Chiếu điểm (x, y) vào tập:
    { (x, y) | x in X, y in Q, f(x) <= y }
    """
    z_start = np.concatenate([x_temp, y_temp])
    def proj_obj(z): 
        return 0.5 * np.sum((z - z_start)**2)
    def proj_jac(z): 
        return z - z_start
    cons = [
        # Ràng buộc x in X
        {'type': 'ineq', 'fun': lambda z: c1(z[:dim_x])},
        {'type': 'ineq', 'fun': lambda z: c2(z[:dim_x])},
        # Ràng buộc y in Q
        {'type': 'ineq', 'fun': lambda z: q1(z[dim_x:])},
        # Ràng buộc f(x) <= y  <=>  y - f(x) >= 0
        {'type': 'ineq', 'fun': lambda z: z[dim_x:] - f(z[:dim_x])}
    ]

    res = minimize(
        fun=proj_obj, x0=z_start, jac=proj_jac,
        constraints=cons, method='SLSQP',
        options={'disp': False}
    )
    
    if not res.success:
        return x_temp, y_temp
    return res.x[:dim_x], res.x[dim_x:]

# %% [markdown]
# ## Core

# %%
def solve_weighted_chebyshev(r_pref, z_ref, params , dim_x=1, dim_y=2):
    x = params["initialization"]["x_init"]    
    y = params["initialization"]["y_init"]
    learning_rate = params["exact"]["learning_rate"]
    max_iters = params["exact"]["max_iters"]
    tol = params["exact"]["tol"]
    prev_obj_val = float('inf')
    converge = False
    
    print(f"r={r_pref}")
    print(f"{'Iter':<5} | {'x':<10} | {'y vector':<15} | {'Objective':<10} | {'Active Idx'}")
    for k in range(max_iters):
        # --- BƯỚC 1: Tính Subgradient ---
        grad_x = get_subgradient(x, r_pref, z_ref)
        
        # --- BƯỚC 2: Cập nhật biến x ---
        x_temp = x - learning_rate * grad_x
        y_temp = y 
        
        # --- BƯỚC 3: Phép chiếu (Projection) ---
        x_next, y_next = project_step(x_temp, y_temp, dim_x, dim_y)
        
        # --- Tính giá trị hàm mục tiêu hiện tại ---
        obj_val = S_weighted_chebyshev(x_next, r_pref, z_ref)
        
        # --- Logging ---
        diffs = r_pref * np.abs(f(x_next) - z_ref)
        active_idx = np.argmax(diffs)
        
        if k % 2000 == 0:
            print(f"{k:<5} | {x_next[0]:.4f}     | [{y_next[0]:.2f}, {y_next[1]:.2f}] | {obj_val:.6f}     | f_{active_idx+1}")

        # --- BƯỚC 4: Kiểm tra điều kiện dừng ---
        loss_change = abs(prev_obj_val - obj_val)
        
        if loss_change < tol:
            print(f"--> Hội tụ tại bước {k}!\n")
            converge = True
            break
            
        prev_obj_val = obj_val
        x = x_next
        y = y_next

    return x, y, converge

# %% [markdown]
# ## Tìm điểm tham chiếu

# %%
from Phase1 import solve_CQ_feasible
from Phase2_1_obj import optim_Universal

# %%
def relevant_point(prob, params):
    x_feasible, _, _, _ = solve_CQ_feasible(
        prob.objective_func, prob.jacobian, prob.proj_C, prob.proj_Qplus,
        x0=params['initialization']['x_init'],
        gamma=params['phase1']['gamma'] , max_iter=params['phase1']['max_iter']
    )

    z_vals = []
    nadir_vals = []

    for dim in range(2):
        # Tìm MIN
        x_min, _ = optim_Universal(prob, x_feasible, target_dim=dim, mode="min", max_iter=500, mu=0.001)
        val_min = prob.objective_func(x_min)[dim]
        z_vals.append(val_min)

        # Tìm MAX 
        x_max, _ = optim_Universal(prob, x_feasible, target_dim=dim, mode="max", max_iter=500, mu=0.001)
        val_max = prob.objective_func(x_max)[dim]
        nadir_vals.append(val_max)
        print(f"   Dim {dim}: Min={val_min:.4f}, Max={val_max:.4f}")
    z_star = np.array(z_vals)
    ref_point = np.array(nadir_vals) + np.abs(np.array(nadir_vals)) * 0.1 + 0.5 
    print(f"-> Z* (Ideal): {z_star}")
    print(f"-> Ref Point (HV): {ref_point}")
    print(f"-> x (Feasible): {x_feasible}")
    return z_star, ref_point, x_feasible

# %% [markdown]
# ## Giải chính xác

# %%
z_star, ref_point, x_feasible = relevant_point(prob, params)
# Out:
# Khởi tạo: x0: [0.5]
# Chiếu lên C được: x: [0.5]
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Hội tụ tại vòng lặp 0
# +---+-------+---------+--------------+--------------+----------+----------+
# | k | x_new | gamma_k | y            | z_proj       |   e_x    |   e_f    |
# +---+-------+---------+--------------+--------------+----------+----------+
# | 0 | [0.5] | 12.0000 | [0.5 , 0.25] | [0.5 , 0.25] | 0.000000 | 0.000000 |
# +---+-------+---------+--------------+--------------+----------+----------+
#    Dim 0: Min=0.1499, Max=0.8194
#    Dim 1: Min=0.0798, Max=0.8238
# -> Z* (Ideal): [0.1499 0.0798]
# -> Ref Point (HV): [1.4013 1.4062]
# -> x (Feasible): [0.5]

# %%
pf_true = []
converge = 0
for r in test_rays:
    x, y, conv = solve_weighted_chebyshev(
        r_pref=r,
        z_ref=z_star, 
        dim_x=dim_x, 
        dim_y=dim_y,
        params=params)
    if conv:
        converge += 1
    pf_true.append(f(x))
print(f"Converge rate = {100*converge/len(test_rays)}%")
# Out:
# r=[1. 0.]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.4990     | [0.59, 0.45] | 0.349078     | f_1
# --> Hội tụ tại bước 961!
#
# r=[0.9995 0.0321]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.4990     | [0.59, 0.45] | 0.348899     | f_1
# --> Hội tụ tại bước 961!
#
# r=[0.9979 0.0641]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.4990     | [0.59, 0.45] | 0.348363     | f_1
# --> Hội tụ tại bước 962!
#
# r=[0.9954 0.096 ]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.4990     | [0.59, 0.45] | 0.347470     | f_1
# --> Hội tụ tại bước 964!
#
# r=[0.9918 0.1279]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.4990     | [0.59, 0.45] | 0.346220     | f_1
# --> Hội tụ tại bước 966!
#
# r=[0.9872 0.1596]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.4990     | [0.59, 0.45] | 0.344616     | f_1
# --> Hội tụ tại bước 734!
#
# r=[0.9816 0.1912]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.4990     | [0.59, 0.45] | 0.342659     | f_1
# --> Hội tụ tại bước 575!
#
# r=[0.9749 0.2225]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.4990     | [0.59, 0.45] | 0.340351     | f_1
# --> Hội tụ tại bước 469!
#
# r=[0.9673 0.2537]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.4990     | [0.59, 0.45] | 0.337693     | f_1
# --> Hội tụ tại bước 403!
#
# r=[0.9587 0.2845]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.4990     | [0.59, 0.45] | 0.334690     | f_1
# --> Hội tụ tại bước 404!
#
# r=[0.9491 0.3151]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.4991     | [0.59, 0.45] | 0.331343     | f_1
# --> Hội tụ tại bước 346!
#
# r=[0.9385 0.3454]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.4991     | [0.59, 0.45] | 0.327657     | f_1
# --> Hội tụ tại bước 280!
#
# r=[0.9269 0.3753]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.4991     | [0.59, 0.45] | 0.323634     | f_1
# --> Hội tụ tại bước 303!
#
# r=[0.9144 0.4048]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.4991     | [0.59, 0.45] | 0.319280     | f_1
# --> Hội tụ tại bước 254!
#
# r=[0.901  0.4339]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.4991     | [0.59, 0.45] | 0.314598     | f_1
# --> Hội tụ tại bước 243!
#
# r=[0.8866 0.4625]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.4991     | [0.59, 0.45] | 0.309593     | f_1
# --> Hội tụ tại bước 194!
#
# r=[0.8713 0.4907]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.4991     | [0.59, 0.45] | 0.304271     | f_1
# --> Hội tụ tại bước 212!
#
# r=[0.8551 0.5184]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.4991     | [0.59, 0.45] | 0.298636     | f_1
# --> Hội tụ tại bước 194!
#
# r=[0.8381 0.5455]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.4992     | [0.59, 0.45] | 0.292694     | f_1
# --> Hội tụ tại bước 224!
#
# r=[0.8202 0.5721]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.4992     | [0.59, 0.45] | 0.286452     | f_1
# --> Hội tụ tại bước 162!
#
# r=[0.8014 0.5981]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.4992     | [0.59, 0.45] | 0.279915     | f_1
# --> Hội tụ tại bước 259!
#
# r=[0.7818 0.6235]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.4992     | [0.59, 0.45] | 0.273091     | f_1
# --> Hội tụ tại bước 212!
#
# r=[0.7614 0.6482]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.4992     | [0.59, 0.45] | 0.265986     | f_1
# --> Hội tụ tại bước 183!
#
# r=[0.7403 0.6723]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.4993     | [0.59, 0.45] | 0.258607     | f_1
# --> Hội tụ tại bước 211!
#
# r=[0.7183 0.6957]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.4993     | [0.59, 0.45] | 0.250962     | f_1
# --> Hội tụ tại bước 186!
#
# r=[0.6957 0.7183]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.4993     | [0.59, 0.45] | 0.243059     | f_1
# --> Hội tụ tại bước 131!
#
# r=[0.6723 0.7403]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.4993     | [0.59, 0.45] | 0.234906     | f_1
# --> Hội tụ tại bước 236!
#
# r=[0.6482 0.7614]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.4994     | [0.59, 0.45] | 0.226510     | f_1
# --> Hội tụ tại bước 164!
#
# r=[0.6235 0.7818]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.4994     | [0.59, 0.45] | 0.217881     | f_1
# --> Hội tụ tại bước 120!
#
# r=[0.5981 0.8014]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.4994     | [0.59, 0.45] | 0.209028     | f_1
# --> Hội tụ tại bước 151!
#
# r=[0.5721 0.8202]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.4994     | [0.59, 0.45] | 0.199958     | f_1
# --> Hội tụ tại bước 268!
#
# r=[0.5455 0.8381]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.4995     | [0.59, 0.45] | 0.190682     | f_1
# --> Hội tụ tại bước 144!
#
# r=[0.5184 0.8551]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.4995     | [0.59, 0.45] | 0.181209     | f_1
# --> Hội tụ tại bước 101!
#
# r=[0.4907 0.8713]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.4995     | [0.59, 0.45] | 0.171549     | f_1
# --> Hội tụ tại bước 88!
#
# r=[0.4625 0.8866]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.4995     | [0.59, 0.45] | 0.161711     | f_1
# --> Hội tụ tại bước 30!
#
# r=[0.4339 0.901 ]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.5009     | [0.59, 0.45] | 0.152547     | f_2
# --> Hội tụ tại bước 6!
#
# r=[0.4048 0.9144]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.5009     | [0.59, 0.45] | 0.154811     | f_2
# --> Hội tụ tại bước 105!
#
# r=[0.3753 0.9269]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.5009     | [0.59, 0.45] | 0.156916     | f_2
# --> Hội tụ tại bước 38!
#
# r=[0.3454 0.9385]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.5009     | [0.59, 0.45] | 0.158861     | f_2
# --> Hội tụ tại bước 51!
#
# r=[0.3151 0.9491]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.5009     | [0.59, 0.45] | 0.160643     | f_2
# --> Hội tụ tại bước 128!
#
# r=[0.2845 0.9587]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.5010     | [0.59, 0.45] | 0.162261     | f_2
# --> Hội tụ tại bước 67!
#
# r=[0.2537 0.9673]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.5010     | [0.59, 0.45] | 0.163713     | f_2
# --> Hội tụ tại bước 91!
#
# r=[0.2225 0.9749]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.5010     | [0.59, 0.45] | 0.164997     | f_2
# --> Hội tụ tại bước 117!
#
# r=[0.1912 0.9816]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.5010     | [0.59, 0.45] | 0.166113     | f_2
# --> Hội tụ tại bước 104!
#
# r=[0.1596 0.9872]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.5010     | [0.59, 0.45] | 0.167059     | f_2
# --> Hội tụ tại bước 276!
#
# r=[0.1279 0.9918]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.5010     | [0.59, 0.45] | 0.167834     | f_2
# --> Hội tụ tại bước 276!
#
# r=[0.096  0.9954]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.5010     | [0.59, 0.45] | 0.168438     | f_2
# --> Hội tụ tại bước 276!
#
# r=[0.0641 0.9979]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.5010     | [0.59, 0.45] | 0.168870     | f_2
# --> Hội tụ tại bước 276!
#
# r=[0.0321 0.9995]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.5010     | [0.59, 0.45] | 0.169129     | f_2
# --> Hội tụ tại bước 276!
#
# r=[0. 1.]
# Iter  | x          | y vector        | Objective  | Active Idx
# 0     | 0.5010     | [0.59, 0.45] | 0.169215     | f_2
# --> Hội tụ tại bước 276!
#
# Converge rate = 100.0%

# %% [markdown]
# # Giải xấp xỉ dynamic

# %% [markdown]
# ## Tuning

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import itertools
from tqdm import tqdm
from Phase2_dynamic import optim_Scalarization
from evaluate import get_metrics
import pandas as pd

def generate_valid_params():
    grid = {
        'expo_lambda': [0.54, 0.55, 0.56],
        'expo_alpha':  [0.4], 
        'expo_beta':   [0.3],
        'expo_gamma':  [0.5],
        'init_params': [0.5],
        'mu': [0.0001],
        'max_iter' : [10000]
    }
    keys, values = zip(*grid.items())
    raw_combinations = [dict(zip(keys, v)) for v in itertools.product(*values)]
    valid_combinations = []
    for p in raw_combinations:
        # --- KIỂM TRA ĐIỀU KIỆN ---
        cond1 = 0.5 < p['expo_lambda'] <= 1.0
        cond2 = p['expo_lambda'] + p['expo_alpha'] <= 1
        cond3 = p['expo_beta'] < p['expo_lambda']
        cond4 = p['expo_gamma'] < p['expo_lambda']
        if cond1 and cond2 and cond3 and cond4:
            valid_combinations.append(p)  
    return valid_combinations

def tuning_dynamic(prob, z_star, x_feasible, pf_true, ref_point, test_rays):
    param_combinations = generate_valid_params()
    results_log = []

    print(f"=== GRID SEARCH: ƯU TIÊN MED ===")
    print(f"Số lượng cấu hình: {len(param_combinations)} | Số tia: {len(test_rays)}")

    for idx, params in tqdm(enumerate(param_combinations)):
        pareto_f_temp = []
        for r in test_rays:
            x_final, _ = optim_Scalarization(
                prob=prob,
                x_feasible=x_feasible,  
                r=r, 
                z_star=z_star,
                verbose=False,
                **params 
            )
            pareto_f_temp.append(prob.objective_func(x_final))
        med, hv = get_metrics(pareto_f_temp, pf_true, prob, ref_point)

        log_entry = {
            'params': params,
            'MED': med,
            'HV': hv,
            'id': idx
        }
        results_log.append(log_entry)

        print(f"[{idx:02d}] MED: {med:.6e} | HV: {hv:.6f}")
    best_entry = min(results_log, key=lambda x: x['MED'])
    print("\n" + "="*60)
    print(f"CẤU HÌNH TỐI ƯU NHẤT THEO MED:")
    print(f"ID: {best_entry['id']}")
    print(f"MED: {best_entry['MED']:.6f}, HV {best_entry['HV']}")
    print(f"Params: {best_entry['params']}")
    print("="*60)
    df = pd.json_normalize(results_log, sep='_')
    df.columns = df.columns.str.replace('params_', '')
    
    return best_entry['params'], df

# %%
best_params, df = tuning_dynamic(
    prob, z_star, x_feasible, pf_true, ref_point, test_rays
)
# Out:
# === GRID SEARCH: ƯU TIÊN MED ===
# Số lượng cấu hình: 3 | Số tia: 50
# 0it [00:00, ?it/s]
# !! Max_iter. Delta: 0.003459, Gap C: 0.000000, Gap Q: 0.001598
# !! Max_iter. Delta: 0.003458, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003452, Gap C: 0.000000, Gap Q: 0.002589
# !! Max_iter. Delta: 0.003443, Gap C: 0.000000, Gap Q: 0.005182
# !! Max_iter. Delta: 0.003431, Gap C: 0.000000, Gap Q: 0.000016
# !! Max_iter. Delta: 0.000849, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001000, Gap C: 0.000000, Gap Q: 0.000004
# -> Hội tụ sớm tại k=7384.
# !! Max_iter. Delta: 0.003346, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001421, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003283, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001675, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001795, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003163, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002021, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002126, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002227, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002958, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002413, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002498, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002772, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002654, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002724, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002789, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002485, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002406, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002326, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002242, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002157, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002069, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003088, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001887, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001793, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001698, Gap C: 0.000000, Gap Q: 0.000000
# -> Hội tụ sớm tại k=802.
# -> Hội tụ sớm tại k=215.
# !! Max_iter. Delta: 0.003107, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003086, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003057, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003020, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000984, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000877, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000770, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002779, Gap C: 0.000001, Gap Q: 0.000005
# !! Max_iter. Delta: 0.002737, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002743, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002756, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002749, Gap C: 0.000001, Gap Q: 0.000077
# !! Max_iter. Delta: 0.002776, Gap C: 0.000001, Gap Q: 0.000265
# 1it [08:27, 507.90s/it]
# !! Max_iter. Delta: 0.002756, Gap C: 0.000001, Gap Q: 0.003443
# [00] MED: 2.121700e-03 | HV: 1.390071
# !! Max_iter. Delta: 0.003155, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003153, Gap C: 0.000000, Gap Q: 0.000380
# !! Max_iter. Delta: 0.003148, Gap C: 0.000000, Gap Q: 0.004147
# !! Max_iter. Delta: 0.003140, Gap C: 0.000000, Gap Q: 0.004191
# !! Max_iter. Delta: 0.003129, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003114, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000912, Gap C: 0.000000, Gap Q: 0.000003
# !! Max_iter. Delta: 0.002146, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.003052, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001295, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002994, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002961, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002924, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002885, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001842, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001938, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002030, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002117, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002644, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002587, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002528, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002420, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002402, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002336, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002266, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002646, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002121, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002730, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002764, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002793, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001805, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002833, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001635, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001548, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001459, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002845, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001956, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000755, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001089, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002753, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000897, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000800, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000702, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000603, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002481, Gap C: 0.000001, Gap Q: 0.000111
# !! Max_iter. Delta: 0.002511, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002520, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002509, Gap C: 0.000001, Gap Q: 0.000033
# !! Max_iter. Delta: 0.002530, Gap C: 0.000001, Gap Q: 0.000385
# 2it [17:12, 517.94s/it]
# !! Max_iter. Delta: 0.002533, Gap C: 0.000001, Gap Q: 0.000226
# [01] MED: 1.210538e-03 | HV: 1.390129
# !! Max_iter. Delta: 0.002877, Gap C: 0.000000, Gap Q: 0.002210
# !! Max_iter. Delta: 0.002876, Gap C: 0.000000, Gap Q: 0.001193
# !! Max_iter. Delta: 0.002871, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002864, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002854, Gap C: 0.000000, Gap Q: 0.004546
# !! Max_iter. Delta: 0.002840, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002824, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002805, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001069, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002758, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002731, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002700, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002667, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001588, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001680, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001768, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001851, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002461, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002006, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002077, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002144, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002206, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002265, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002130, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002368, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002413, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001934, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002489, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001794, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001721, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002567, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001569, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.001492, Gap C: 0.000000, Gap Q: 0.000000
# -> Hội tụ sớm tại k=230.
# !! Max_iter. Delta: 0.002600, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002594, Gap C: 0.000000, Gap Q: 0.000000
# -> Hội tụ sớm tại k=515.
# !! Max_iter. Delta: 0.002565, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000994, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002510, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002472, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000730, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.000640, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002309, Gap C: 0.000001, Gap Q: 0.000007
# !! Max_iter. Delta: 0.002264, Gap C: 0.000001, Gap Q: 0.002985
# !! Max_iter. Delta: 0.002289, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002295, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.002291, Gap C: 0.000001, Gap Q: 0.000029

# %%
df.sort_values("MED")
# Out:
#         MED        HV  id  expo_lambda  expo_alpha  expo_beta  expo_gamma  \
# 3  0.001460  1.390575   3         0.55         0.4        0.3         0.5
# 1  0.002146  1.389664   1         0.53         0.4        0.3         0.5
# 2  0.002288  1.385867   2         0.55         0.4        0.3         0.5
# 0  0.003242  1.384163   0         0.53         0.4        0.3         0.5
# 5  0.006842  1.390141   5         0.57         0.4        0.3         0.5
# 4  0.007048  1.383697   4         0.57         0.4        0.3         0.5
#
#    init_params      mu  max_iter
# 3          0.5  0.0001      5000
# 1          0.5  0.0001      5000
# 2          0.5  0.0001      2000
# 0          0.5  0.0001      2000
# 5          0.5  0.0001      5000
# 4          0.5  0.0001      2000

# %%
old_df = pd.read_csv(f"exp/{case}/{n_rays}_tuning_dynamic.csv")

# %%
df = pd.concat([df, old_df])

# %%
df.to_csv(f"exp/{case}/{n_rays}_tuning_dynamic.csv", index=False)

# %%
df.sort_values("MED")
# Out:
#           MED        HV  id  expo_lambda  expo_alpha  expo_beta  expo_gamma  \
# 3    0.001460  1.390575   3         0.55        0.40        0.3         0.5
# 1    0.002146  1.389664   1         0.53        0.40        0.3         0.5
# 2    0.002288  1.385867   2         0.55        0.40        0.3         0.5
# 0    0.003242  1.384163   0         0.53        0.40        0.3         0.5
# 8    0.004014  1.382445   8         0.51        0.40        0.3         0.5
# ..        ...       ...  ..          ...         ...        ...         ...
# 111  0.028912  1.375373  75         0.65        0.25        0.5         0.3
# 94   0.029627  1.375373  58         0.65        0.10        0.5         0.3
# 86   0.029651  1.375373  50         0.65        0.10        0.3         0.3
# 95   0.033582  1.375373  59         0.65        0.10        0.5         0.3
# 87   0.033643  1.375373  51         0.65        0.10        0.3         0.3
#
#      init_params      mu  max_iter
# 3            0.5  0.0001      5000
# 1            0.5  0.0001      5000
# 2            0.5  0.0001      2000
# 0            0.5  0.0001      2000
# 8            1.0  0.0001      1000
# ..           ...     ...       ...
# 111          2.0  0.0100      1000
# 94           2.0  0.0001      1000
# 86           2.0  0.0001      1000
# 95           2.0  0.0100      1000
# 87           2.0  0.0100      1000
#
# [138 rows x 10 columns]

# %%
df.groupby("expo_lambda")[["MED", "HV"]].agg(["mean", "min", "max"]).reset_index()
# Out:
#   expo_lambda       MED                            HV
#                    mean       min       max      mean       min       max
# 0        0.51  0.007061  0.001536  0.015139  1.382173  1.379220  1.390520
# 1        0.55  0.002678  0.001460  0.003852  1.388886  1.385867  1.390575
# 2        0.60  0.009387  0.008230  0.010639  1.384116  1.378848  1.389551
# 3        0.65  0.020878  0.011669  0.033643  1.382023  1.375373  1.387838
# 4        0.75  0.007684  0.006254  0.009285  1.384026  1.382280  1.389268
# 5        0.80  0.013907  0.007173  0.021266  1.381708  1.378851  1.388317
# 6        0.90  0.010320  0.010086  0.010519  1.380233  1.380232  1.380234

# %%
df.groupby("max_iter")[["MED", "HV"]].agg(["mean", "min", "max"]).reset_index()
# Out:
#   max_iter       MED                            HV
#                 mean       min       max      mean       min       max
# 0     1000  0.011816  0.004014  0.033643  1.381999  1.375373  1.390520
# 1     2000  0.003167  0.002136  0.004334  1.387476  1.384497  1.389669
# 2     5000  0.002814  0.001460  0.005195  1.388719  1.384217  1.390575

# %%
df.groupby("expo_beta")[["MED", "HV"]].agg(["mean", "min", "max"]).reset_index()
# Out:
#   expo_beta       MED                            HV
#                  mean       min       max      mean       min       max
# 0       0.3  0.010692  0.001460  0.033643  1.382735  1.375373  1.390575
# 1       0.5  0.011032  0.001507  0.033582  1.382582  1.375373  1.390410

# %%
df.groupby("mu")[["MED", "HV"]].agg(["mean", "min", "max"]).reset_index()
# Out:
#        mu       MED                           HV
#                mean      min       max      mean       min       max
# 0  0.0001  0.010538  0.00146  0.029651  1.382929  1.375373  1.390575
# 1  0.0100  0.011186  0.00331  0.033643  1.382388  1.375373  1.390520

# %%
best_params
# Out:
# {'expo_lambda': 0.51,
#  'expo_alpha': 0.4,
#  'expo_beta': 0.3,
#  'expo_gamma': 0.5,
#  'init_params': 1.0,
#  'mu': 0.0001,
#  'max_iter': 1000}

# %%
best_params = {'expo_lambda': 0.51,
 'expo_alpha': 0.4,
 'expo_beta': 0.3,
 'expo_gamma': 0.5,
 'init_params': 1.0,
 'mu': 0.0001,
 'max_iter': 1000}

# %% [markdown]
# ## Best

# %%
from Phase2_dynamic import optim_Scalarization
from evaluate import get_metrics

# %%
pf_true_dynamic = []
for r in test_rays:
        x_final, _ = optim_Scalarization(
            prob=prob,
            x_feasible=x_feasible,  
            r=r, 
            z_star=z_star,
            # Các tham số tĩnh
            verbose=False,
            # --- CÁC THAM SỐ ĐANG TỐI ƯU ---
            max_iter=best_params['max_iter'],
            mu=best_params['mu'],
            init_params=best_params['init_params'],
            expo_alpha=best_params['expo_alpha'],
            expo_lambda=best_params['expo_lambda'],
            expo_beta=best_params['expo_beta'],
            expo_gamma=best_params['expo_gamma'],
        )
        pf_true_dynamic.append(prob.objective_func(x_final))
    
med, hv = get_metrics(pf_true_dynamic, pf_true, prob, ref_point)
# Out:
# !! Max_iter. Delta: 0.029527, Gap C: 0.000000, Gap Q: 0.019787
# !! Max_iter. Delta: 0.029512, Gap C: 0.000000, Gap Q: 0.021931
# !! Max_iter. Delta: 0.029466, Gap C: 0.000000, Gap Q: 0.026439
# !! Max_iter. Delta: 0.029391, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.029285, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007375, Gap C: 0.000000, Gap Q: 0.035562
# !! Max_iter. Delta: 0.008686, Gap C: 0.000000, Gap Q: 0.015001
# !! Max_iter. Delta: 0.009931, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.011149, Gap C: 0.000000, Gap Q: 0.000010
# !! Max_iter. Delta: 0.012345, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.028002, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014544, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.015613, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.016618, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.026603, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.026156, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.025705, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.025250, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.021013, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.024194, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.023640, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.023133, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.022460, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.024300, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.021211, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.025329, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.019828, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.026144, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.026477, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.026737, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.016893, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.027171, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.027273, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014489, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.027360, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.024014, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.027202, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.027031, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.010198, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.009286, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.008401, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007490, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.025098, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005644, Gap C: 0.000001, Gap Q: 0.022105
# !! Max_iter. Delta: 0.023768, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.023880, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.024252, Gap C: 0.000001, Gap Q: 0.002187
# !! Max_iter. Delta: 0.024293, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.023479, Gap C: 0.000001, Gap Q: 0.000002
# !! Max_iter. Delta: 0.022910, Gap C: 0.000001, Gap Q: 0.026824

# %%
med, hv
# Out:
# (np.float64(0.004014192322563691), np.float64(1.382444915614446))

# %%
med, hv
# Out:
# (np.float64(0.004014192322563691), np.float64(1.382444915614446))

# %% [markdown]
# ## Viz

# %%
from utils import visualize_pareto_front, generate_pareto_grid

# %%
def non_c(x):
    return 1
pf_cloud, pf_targets = generate_pareto_grid(
    f_func=f, 
    c_funcs=[non_c], 
    q_plus_func=q_plus, 
    resolution=500
)
# Out:
# --- Đang quét lưới 500x500 điểm ---
# -> Tìm thấy 250000 điểm thỏa mãn miền C.
# -> Lọc còn 93500 điểm thỏa mãn Q+ (Cloud).
# -> Kết quả: 187 điểm Pareto.

# %%
visualize_pareto_front(
    pf_pred=np.array(pf_true_dynamic), 
    pf_cloud=pf_cloud,   
    pf_targets=np.array(pf_true),
    title="Dynamic approximate exact",
    figsize=(8, 6)
)

# %% [markdown]
# # Hypernet

# %%
from training_hypernet import train_hypernet

# %%
prob_ = Problem(
    f=[f1, f2], jac_f=[jacobian_f],
    dim_x=dim_x, dim_y=dim_y,
    proj_C=proj_C_handler.project,
    proj_Qplus=proj_Q_handler.project
)

# %% [markdown]
# ## Tuning

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from tuning_hypernet import run_hypernet_tuning

# %%
param_grid = {
    'lr': [1e-3, 5e-4],
    'num_epochs': [500, 1000, 2000],
    
    'num_partitions': [n_rays],
    
    # Tham số thuật toán 2-A: Tăng dần penalty
    'beta_C_0': [10],
    'beta_Q_0': [5],
    'rho_C': [1.03], 
    'rho_Q': [1.01, 1.03],
    
    # Cố định Max để tránh grid quá lớn 
    'beta_C_max': [1000.0],
    'beta_Q_max': [100.0, 500.0, 1000.0]
}

# %%
device = 'cpu'

# %%
results = run_hypernet_tuning(
    prob=prob_,
    dim_x=dim_x,
    z_star=z_star,
    ref_point=ref_point,
    test_rays=test_rays,
    pf_true=pf_true,
    param_grid=param_grid,
    indicator="MED", 
    device=device,
    save_dir=f"model/{case}",
    train_func=train_hypernet
)
# Out:
# ============================================================
# 🔹 TUNING MODEL: MLP | PRIORITY: MED
# ============================================================
#
# >>> [Config 1/36] Params: {'lr': 0.001, 'num_epochs': 500, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 100.0}
#       ⏱️ Time: 35.2s | 📏 MED: 0.003661 | 📈 HV: 1.388761
#       🏆 NEW BEST FOUND! Saved to: model/_Ex_7_1/best_MLP_MED.pth
#
# >>> [Config 2/36] Params: {'lr': 0.001, 'num_epochs': 500, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 500.0}
#       ⏱️ Time: 34.2s | 📏 MED: 0.003636 | 📈 HV: 1.387195
#       🏆 NEW BEST FOUND! Saved to: model/_Ex_7_1/best_MLP_MED.pth
#
# >>> [Config 3/36] Params: {'lr': 0.001, 'num_epochs': 500, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 1000.0}
#       ⏱️ Time: 34.3s | 📏 MED: 0.006398 | 📈 HV: 1.389974
#
# >>> [Config 4/36] Params: {'lr': 0.001, 'num_epochs': 500, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 100.0}
#       ⏱️ Time: 35.0s | 📏 MED: 0.002556 | 📈 HV: 1.384832
#       🏆 NEW BEST FOUND! Saved to: model/_Ex_7_1/best_MLP_MED.pth
#
# >>> [Config 5/36] Params: {'lr': 0.001, 'num_epochs': 500, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 500.0}
#       ⏱️ Time: 34.3s | 📏 MED: 0.006008 | 📈 HV: 1.387612
#
# >>> [Config 6/36] Params: {'lr': 0.001, 'num_epochs': 500, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 1000.0}
#       ⏱️ Time: 34.7s | 📏 MED: 0.005770 | 📈 HV: 1.388299
#
# >>> [Config 7/36] Params: {'lr': 0.001, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 100.0}
#       ⏱️ Time: 69.6s | 📏 MED: 0.003669 | 📈 HV: 1.385439
#
# >>> [Config 8/36] Params: {'lr': 0.001, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 500.0}
#       ⏱️ Time: 157.9s | 📏 MED: 0.004226 | 📈 HV: 1.390175
#
# >>> [Config 9/36] Params: {'lr': 0.001, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 1000.0}
#       ⏱️ Time: 186.0s | 📏 MED: 0.003438 | 📈 HV: 1.390263
#
# >>> [Config 10/36] Params: {'lr': 0.001, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 100.0}
#       ⏱️ Time: 185.5s | 📏 MED: 0.002629 | 📈 HV: 1.384138
#
# >>> [Config 11/36] Params: {'lr': 0.001, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 500.0}
#       ⏱️ Time: 188.1s | 📏 MED: 0.001573 | 📈 HV: 1.390433
#       🏆 NEW BEST FOUND! Saved to: model/_Ex_7_1/best_MLP_MED.pth
#
# >>> [Config 12/36] Params: {'lr': 0.001, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 1000.0}
#       ⏱️ Time: 181.0s | 📏 MED: 0.003006 | 📈 HV: 1.390472
#
# >>> [Config 13/36] Params: {'lr': 0.001, 'num_epochs': 2000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 100.0}
#       ⏱️ Time: 369.3s | 📏 MED: 0.003061 | 📈 HV: 1.382638
#
# >>> [Config 14/36] Params: {'lr': 0.001, 'num_epochs': 2000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 500.0}
#       ⏱️ Time: 364.6s | 📏 MED: 0.003896 | 📈 HV: 1.389353
#
# >>> [Config 15/36] Params: {'lr': 0.001, 'num_epochs': 2000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 1000.0}
#       ⏱️ Time: 367.6s | 📏 MED: 0.002488 | 📈 HV: 1.390407
#
# >>> [Config 16/36] Params: {'lr': 0.001, 'num_epochs': 2000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 100.0}
#       ⏱️ Time: 368.7s | 📏 MED: 0.003509 | 📈 HV: 1.384032
#
# >>> [Config 17/36] Params: {'lr': 0.001, 'num_epochs': 2000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 500.0}
#       ⏱️ Time: 361.7s | 📏 MED: 0.004275 | 📈 HV: 1.388624
#
# >>> [Config 18/36] Params: {'lr': 0.001, 'num_epochs': 2000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 1000.0}
#       ⏱️ Time: 363.2s | 📏 MED: 0.003900 | 📈 HV: 1.390158
#
# >>> [Config 19/36] Params: {'lr': 0.0005, 'num_epochs': 500, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 100.0}
#       ⏱️ Time: 93.2s | 📏 MED: 0.009012 | 📈 HV: 1.387135
#
# >>> [Config 20/36] Params: {'lr': 0.0005, 'num_epochs': 500, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 500.0}
#       ⏱️ Time: 94.4s | 📏 MED: 0.005123 | 📈 HV: 1.388183
#
# >>> [Config 21/36] Params: {'lr': 0.0005, 'num_epochs': 500, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 1000.0}
#       ⏱️ Time: 92.2s | 📏 MED: 0.003240 | 📈 HV: 1.387425
#
# >>> [Config 22/36] Params: {'lr': 0.0005, 'num_epochs': 500, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 100.0}
#       ⏱️ Time: 89.8s | 📏 MED: 0.004022 | 📈 HV: 1.390494
#
# >>> [Config 23/36] Params: {'lr': 0.0005, 'num_epochs': 500, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 500.0}
#       ⏱️ Time: 92.5s | 📏 MED: 0.003026 | 📈 HV: 1.387705
#
# >>> [Config 24/36] Params: {'lr': 0.0005, 'num_epochs': 500, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 1000.0}
#       ⏱️ Time: 92.3s | 📏 MED: 0.002566 | 📈 HV: 1.390210
#
# >>> [Config 25/36] Params: {'lr': 0.0005, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 100.0}
#       ⏱️ Time: 188.6s | 📏 MED: 0.002440 | 📈 HV: 1.382944
#
# >>> [Config 26/36] Params: {'lr': 0.0005, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 500.0}
#       ⏱️ Time: 185.2s | 📏 MED: 0.004404 | 📈 HV: 1.390153
#
# >>> [Config 27/36] Params: {'lr': 0.0005, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 1000.0}
#       ⏱️ Time: 188.2s | 📏 MED: 0.006023 | 📈 HV: 1.389571
#
# >>> [Config 28/36] Params: {'lr': 0.0005, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 100.0}
#       ⏱️ Time: 185.4s | 📏 MED: 0.004648 | 📈 HV: 1.390520
#
# >>> [Config 29/36] Params: {'lr': 0.0005, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 500.0}
#       ⏱️ Time: 179.3s | 📏 MED: 0.006210 | 📈 HV: 1.388153
#
# >>> [Config 30/36] Params: {'lr': 0.0005, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 1000.0}
#       ⏱️ Time: 185.4s | 📏 MED: 0.004807 | 📈 HV: 1.390448
#
# >>> [Config 31/36] Params: {'lr': 0.0005, 'num_epochs': 2000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 100.0}
#       ⏱️ Time: 376.5s | 📏 MED: 0.002307 | 📈 HV: 1.383977
#
# >>> [Config 32/36] Params: {'lr': 0.0005, 'num_epochs': 2000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 500.0}
#       ⏱️ Time: 392.2s | 📏 MED: 0.001926 | 📈 HV: 1.390549
#
# >>> [Config 33/36] Params: {'lr': 0.0005, 'num_epochs': 2000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 1000.0}
#       ⏱️ Time: 374.8s | 📏 MED: 0.002061 | 📈 HV: 1.390609
#
# >>> [Config 34/36] Params: {'lr': 0.0005, 'num_epochs': 2000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 100.0}
#       ⏱️ Time: 372.0s | 📏 MED: 0.002844 | 📈 HV: 1.387139
#
# >>> [Config 35/36] Params: {'lr': 0.0005, 'num_epochs': 2000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 500.0}
#       ⏱️ Time: 373.4s | 📏 MED: 0.003613 | 📈 HV: 1.388513
#
# >>> [Config 36/36] Params: {'lr': 0.0005, 'num_epochs': 2000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 1000.0}
#       ⏱️ Time: 382.1s | 📏 MED: 0.001810 | 📈 HV: 1.390169
#
# ✅ Hoàn thành MLP. Best MED: 1.572961e-03
#    Best Config: {'lr': 0.001, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 500.0}
#
# ============================================================
# 🔹 TUNING MODEL: trans | PRIORITY: MED
# ============================================================
#
# >>> [Config 1/36] Params: {'lr': 0.001, 'num_epochs': 500, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 100.0}
#       ⏱️ Time: 122.4s | 📏 MED: 0.006261 | 📈 HV: 1.385397
#       🏆 NEW BEST FOUND! Saved to: model/_Ex_7_1/best_trans_MED.pth
#
# >>> [Config 2/36] Params: {'lr': 0.001, 'num_epochs': 500, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 500.0}
#       ⏱️ Time: 122.3s | 📏 MED: 0.005574 | 📈 HV: 1.387316
#       🏆 NEW BEST FOUND! Saved to: model/_Ex_7_1/best_trans_MED.pth
#
# >>> [Config 3/36] Params: {'lr': 0.001, 'num_epochs': 500, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 1000.0}
#       ⏱️ Time: 121.3s | 📏 MED: 0.008214 | 📈 HV: 1.387999
#
# >>> [Config 4/36] Params: {'lr': 0.001, 'num_epochs': 500, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 100.0}
#       ⏱️ Time: 121.9s | 📏 MED: 0.006886 | 📈 HV: 1.387380
#
# >>> [Config 5/36] Params: {'lr': 0.001, 'num_epochs': 500, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 500.0}
#       ⏱️ Time: 120.7s | 📏 MED: 0.007707 | 📈 HV: 1.386815
#
# >>> [Config 6/36] Params: {'lr': 0.001, 'num_epochs': 500, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 1000.0}
#       ⏱️ Time: 119.5s | 📏 MED: 0.009813 | 📈 HV: 1.385042
#
# >>> [Config 7/36] Params: {'lr': 0.001, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 100.0}
#       ⏱️ Time: 249.4s | 📏 MED: 0.002731 | 📈 HV: 1.384473
#       🏆 NEW BEST FOUND! Saved to: model/_Ex_7_1/best_trans_MED.pth
#
# >>> [Config 8/36] Params: {'lr': 0.001, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 500.0}
#       ⏱️ Time: 245.0s | 📏 MED: 0.005912 | 📈 HV: 1.388064
#
# >>> [Config 9/36] Params: {'lr': 0.001, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 1000.0}
#       ⏱️ Time: 242.2s | 📏 MED: 0.004908 | 📈 HV: 1.389024
#
# >>> [Config 10/36] Params: {'lr': 0.001, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 100.0}
#       ⏱️ Time: 247.2s | 📏 MED: 0.003480 | 📈 HV: 1.384217
#
# >>> [Config 11/36] Params: {'lr': 0.001, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 500.0}
#       ⏱️ Time: 244.4s | 📏 MED: 0.004449 | 📈 HV: 1.389586
#
# >>> [Config 12/36] Params: {'lr': 0.001, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 1000.0}
#       ⏱️ Time: 248.0s | 📏 MED: 0.002148 | 📈 HV: 1.390150
#       🏆 NEW BEST FOUND! Saved to: model/_Ex_7_1/best_trans_MED.pth
#
# >>> [Config 13/36] Params: {'lr': 0.001, 'num_epochs': 2000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 100.0}
#       ⏱️ Time: 494.2s | 📏 MED: 0.003263 | 📈 HV: 1.388193
#
# >>> [Config 14/36] Params: {'lr': 0.001, 'num_epochs': 2000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 500.0}
#       ⏱️ Time: 508.7s | 📏 MED: 0.001139 | 📈 HV: 1.390369
#       🏆 NEW BEST FOUND! Saved to: model/_Ex_7_1/best_trans_MED.pth
#
# >>> [Config 15/36] Params: {'lr': 0.001, 'num_epochs': 2000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 1000.0}
#       ⏱️ Time: 484.7s | 📏 MED: 0.004840 | 📈 HV: 1.389675
#
# >>> [Config 16/36] Params: {'lr': 0.001, 'num_epochs': 2000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 100.0}
#       ⏱️ Time: 489.8s | 📏 MED: 0.003223 | 📈 HV: 1.383627
#
# >>> [Config 17/36] Params: {'lr': 0.001, 'num_epochs': 2000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 500.0}
#       ⏱️ Time: 478.5s | 📏 MED: 0.006864 | 📈 HV: 1.388262
#
# >>> [Config 18/36] Params: {'lr': 0.001, 'num_epochs': 2000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 1000.0}
#       ⏱️ Time: 490.7s | 📏 MED: 0.003037 | 📈 HV: 1.389014
#
# >>> [Config 19/36] Params: {'lr': 0.0005, 'num_epochs': 500, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 100.0}
#       ⏱️ Time: 119.3s | 📏 MED: 0.009292 | 📈 HV: 1.387205
#
# >>> [Config 20/36] Params: {'lr': 0.0005, 'num_epochs': 500, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 500.0}
#       ⏱️ Time: 121.3s | 📏 MED: 0.004061 | 📈 HV: 1.388175
#
# >>> [Config 21/36] Params: {'lr': 0.0005, 'num_epochs': 500, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 1000.0}
#       ⏱️ Time: 117.9s | 📏 MED: 0.005014 | 📈 HV: 1.387075
#
# >>> [Config 22/36] Params: {'lr': 0.0005, 'num_epochs': 500, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 100.0}
#       ⏱️ Time: 118.7s | 📏 MED: 0.005942 | 📈 HV: 1.389150
#
# >>> [Config 23/36] Params: {'lr': 0.0005, 'num_epochs': 500, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 500.0}
#       ⏱️ Time: 120.9s | 📏 MED: 0.004082 | 📈 HV: 1.387738
#
# >>> [Config 24/36] Params: {'lr': 0.0005, 'num_epochs': 500, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 1000.0}
#       ⏱️ Time: 118.8s | 📏 MED: 0.008233 | 📈 HV: 1.388690
#
# >>> [Config 25/36] Params: {'lr': 0.0005, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 100.0}
#       ⏱️ Time: 243.3s | 📏 MED: 0.003558 | 📈 HV: 1.382844
#
# >>> [Config 26/36] Params: {'lr': 0.0005, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 500.0}
#       ⏱️ Time: 237.4s | 📏 MED: 0.007074 | 📈 HV: 1.388169
#
# >>> [Config 27/36] Params: {'lr': 0.0005, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 1000.0}
#       ⏱️ Time: 241.2s | 📏 MED: 0.005326 | 📈 HV: 1.389907
#
# >>> [Config 28/36] Params: {'lr': 0.0005, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 100.0}
#       ⏱️ Time: 242.2s | 📏 MED: 0.003138 | 📈 HV: 1.387457
#
# >>> [Config 29/36] Params: {'lr': 0.0005, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 500.0}
#       ⏱️ Time: 228.2s | 📏 MED: 0.010283 | 📈 HV: 1.388603
#
# >>> [Config 30/36] Params: {'lr': 0.0005, 'num_epochs': 1000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 1000.0}
#       ⏱️ Time: 237.8s | 📏 MED: 0.005432 | 📈 HV: 1.388697
#
# >>> [Config 31/36] Params: {'lr': 0.0005, 'num_epochs': 2000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 100.0}
#       ⏱️ Time: 482.9s | 📏 MED: 0.003965 | 📈 HV: 1.387724
#
# >>> [Config 32/36] Params: {'lr': 0.0005, 'num_epochs': 2000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 500.0}
#       ⏱️ Time: 497.6s | 📏 MED: 0.002604 | 📈 HV: 1.390202
#
# >>> [Config 33/36] Params: {'lr': 0.0005, 'num_epochs': 2000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 1000.0}
#       ⏱️ Time: 476.6s | 📏 MED: 0.006558 | 📈 HV: 1.388657
#
# >>> [Config 34/36] Params: {'lr': 0.0005, 'num_epochs': 2000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 100.0}
#       ⏱️ Time: 484.7s | 📏 MED: 0.004099 | 📈 HV: 1.385728
#
# >>> [Config 35/36] Params: {'lr': 0.0005, 'num_epochs': 2000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 500.0}
#       ⏱️ Time: 496.2s | 📏 MED: 0.002566 | 📈 HV: 1.390365
#
# >>> [Config 36/36] Params: {'lr': 0.0005, 'num_epochs': 2000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.03, 'beta_C_max': 1000.0, 'beta_Q_max': 1000.0}
#       ⏱️ Time: 501.9s | 📏 MED: 0.002421 | 📈 HV: 1.390422
#
# ✅ Hoàn thành trans. Best MED: 1.139362e-03
#    Best Config: {'lr': 0.001, 'num_epochs': 2000, 'num_partitions': 50, 'beta_C_0': 10, 'beta_Q_0': 5, 'rho_C': 1.03, 'rho_Q': 1.01, 'beta_C_max': 1000.0, 'beta_Q_max': 500.0}

# %% [markdown]
# ## Viz

# %%
import pandas as pd

# %%
df = pd.json_normalize(results, sep='_')
df.columns = df.columns.str.replace('params_', '')

# %%
df.sort_values("med")
# Out:
#     model       med        hv        time      lr  num_epochs  num_partitions  \
# 49  trans  0.001139  1.390369  508.684750  0.0010        2000              50
# 10    MLP  0.001573  1.390433  188.111139  0.0010        1000              50
# 35    MLP  0.001810  1.390169  382.066045  0.0005        2000              50
# 31    MLP  0.001926  1.390549  392.215790  0.0005        2000              50
# 32    MLP  0.002061  1.390609  374.806595  0.0005        2000              50
# ..    ...       ...       ...         ...     ...         ...             ...
# 59  trans  0.008233  1.388690  118.827724  0.0005         500              50
# 18    MLP  0.009012  1.387135   93.231511  0.0005         500              50
# 54  trans  0.009292  1.387205  119.293987  0.0005         500              50
# 41  trans  0.009813  1.385042  119.455122  0.0010         500              50
# 64  trans  0.010283  1.388603  228.162555  0.0005        1000              50
#
#     beta_C_0  beta_Q_0  rho_C  rho_Q  beta_C_max  beta_Q_max
# 49        10         5   1.03   1.01      1000.0       500.0
# 10        10         5   1.03   1.03      1000.0       500.0
# 35        10         5   1.03   1.03      1000.0      1000.0
# 31        10         5   1.03   1.01      1000.0       500.0
# 32        10         5   1.03   1.01      1000.0      1000.0
# ..       ...       ...    ...    ...         ...         ...
# 59        10         5   1.03   1.03      1000.0      1000.0
# 18        10         5   1.03   1.01      1000.0       100.0
# 54        10         5   1.03   1.01      1000.0       100.0
# 41        10         5   1.03   1.03      1000.0      1000.0
# 64        10         5   1.03   1.03      1000.0       500.0
#
# [72 rows x 13 columns]

# %%
df.to_csv(f"exp/{case}/{n_rays}_Tuning_hnet.csv", index=False)

# %%
 df.groupby("beta_Q_max")[["med", "hv"]].agg(["mean", "min", "max"]).reset_index()
# Out:
#   beta_Q_max       med                            hv
#                   mean       min       max      mean       min       max
# 0      100.0  0.004175  0.002307  0.009292  1.386060  1.382638  1.390520
# 1      500.0  0.004593  0.001139  0.010283  1.388763  1.386815  1.390549
# 2     1000.0  0.004644  0.001810  0.009813  1.389265  1.385042  1.390609

# %%
 df.groupby("num_epochs")[["med", "hv"]].agg(["mean", "min", "max"]).reset_index()
# Out:
#   num_epochs       med                            hv
#                   mean       min       max      mean       min       max
# 0        500  0.005671  0.002556  0.009813  1.387742  1.384832  1.390494
# 1       1000  0.004396  0.001573  0.010283  1.388079  1.382844  1.390520
# 2       2000  0.003345  0.001139  0.006864  1.388267  1.382638  1.390609

# %%
 df.groupby("lr")[["med", "hv"]].agg(["mean", "min", "max"]).reset_index()
# Out:
#        lr       med                            hv
#                mean       min       max      mean       min       max
# 0  0.0005  0.004548  0.001810  0.010283  1.388353  1.382844  1.390609
# 1  0.0010  0.004393  0.001139  0.009813  1.387706  1.382638  1.390472

# %%
df
# Out:
#     model       med        hv        time      lr  num_epochs  num_partitions  \
# 0     MLP  0.003661  1.388761   35.188294  0.0010         500              50
# 1     MLP  0.003636  1.387195   34.231603  0.0010         500              50
# 2     MLP  0.006398  1.389974   34.325571  0.0010         500              50
# 3     MLP  0.002556  1.384832   35.019568  0.0010         500              50
# 4     MLP  0.006008  1.387612   34.254089  0.0010         500              50
# ..    ...       ...       ...         ...     ...         ...             ...
# 67  trans  0.002604  1.390202  497.589059  0.0005        2000              50
# 68  trans  0.006558  1.388657  476.601522  0.0005        2000              50
# 69  trans  0.004099  1.385728  484.653365  0.0005        2000              50
# 70  trans  0.002566  1.390365  496.236610  0.0005        2000              50
# 71  trans  0.002421  1.390422  501.944829  0.0005        2000              50
#
#     beta_C_0  beta_Q_0  rho_C  rho_Q  beta_C_max  beta_Q_max
# 0         10         5   1.03   1.01      1000.0       100.0
# 1         10         5   1.03   1.01      1000.0       500.0
# 2         10         5   1.03   1.01      1000.0      1000.0
# 3         10         5   1.03   1.03      1000.0       100.0
# 4         10         5   1.03   1.03      1000.0       500.0
# ..       ...       ...    ...    ...         ...         ...
# 67        10         5   1.03   1.01      1000.0       500.0
# 68        10         5   1.03   1.01      1000.0      1000.0
# 69        10         5   1.03   1.03      1000.0       100.0
# 70        10         5   1.03   1.03      1000.0       500.0
# 71        10         5   1.03   1.03      1000.0      1000.0
#
# [72 rows x 13 columns]

# %% [markdown]
# ## Infer

# %%
import os
import torch
import time
from hypernet_MLP import Hypernet_MLP
from hypernet_trans import Hypernet_trans
from utils import plot_trajectories

# %%
def infer(model, test_rays=test_rays):
    model.eval()
    pf_pred = [] 
    tmp_err = [] 
    t1 = time.time()
    print(f"Evaluating on {len(test_rays)} rays...")

    for r in test_rays:   
        # --- Dự đoán với Hypernetwork ---
        ray_t = torch.from_numpy(r).float().unsqueeze(0)
        with torch.no_grad(): 
            output_x = model(ray_t).flatten() 
            vals = [func(output_x).item() for func in prob_.f]
            obj_pred = np.array(vals)

        pf_pred.append(obj_pred)
    t2 = time.time()
    pf_pred = np.array(pf_pred)
    print("-" * 30)
    print(f"Inference Time: {t2-t1:.4f}s")
    return pf_pred

# %%
best_MLP = Hypernet_MLP(ray_hidden_dim=32, out_dim=dim_x, n_tasks=2)
best_trans = Hypernet_trans(ray_hidden_dim=32, out_dim=dim_x, n_tasks=2)
# 2. Đường dẫn file đã lưu
PATH_MLP = f"model/{case}/best_MLP_MED.pth"
PATH_trans = f"model/{case}/best_trans_MED.pth"
# 3. Load state dict
if os.path.exists(PATH_MLP):
    state_dict = torch.load(PATH_MLP, map_location=device)
    best_MLP.load_state_dict(state_dict)
    best_MLP.to(device)
    best_MLP.eval() 
    print("Successful MLP ✅")

if os.path.exists(PATH_trans):
    state_dict = torch.load(PATH_trans, map_location=device)
    best_trans.load_state_dict(state_dict)
    best_trans.to(device)
    best_trans.eval() 
    print("Successful Trans ✅")
# Out:
# Successful MLP ✅
# Successful Trans ✅

# %%
pf_pred = infer(best_trans)
med, hv = get_metrics(pf_pred, pf_true, prob_, ref_point)
med, hv
# Out:
# Evaluating on 50 rays...
# ------------------------------
# Inference Time: 0.0350s
# (np.float64(0.0011394396725037325), np.float64(1.3903687937400713))

# %%
plot_trajectories(obs_true=np.array(pf_true),obs_predict=np.array(pf_pred),obs_pareto_front=pf_cloud , figsize=(16, 8))

# %%
pf_pred = infer(best_MLP)
med, hv = get_metrics(pf_pred, pf_true, prob, ref_point)
med, hv
# Out:
# Evaluating on 50 rays...
# ------------------------------
# Inference Time: 0.0110s
# (np.float64(0.0015730136749247214), np.float64(1.3904335437964486))

# %%
plot_trajectories(obs_true=np.array(pf_true),obs_predict=np.array(pf_pred),obs_pareto_front=pf_cloud , figsize=(16, 8))

# %% [markdown]
# # Summarize

# %%
def run_benchmark(
    name,               # Tên hiển thị trong CSV (vd: "Hypernet_MLP", "Solver_BestParams")
    method_type,        # "model" hoặc "solver"
    prob,               # Đối tượng bài toán
    test_rays,          # Tập tia kiểm tra
    pf_true_gt,         # Ground Truth chuẩn để tính MED
    ref_point,          # Điểm tham chiếu tính HV
    # --- Optional cho Model ---
    model=None,
    # --- Optional cho Solver ---
    solver_func=None,
    x_feasible=None,
    z_star=None,
    solver_params=None, # Dictionary chứa {mu, max_iter, ...}
    # --- Settings ---
    csv_path="results_summary.csv",
    n_runs=None         # Số lần chạy để tính trung bình time (Mặc định: Model=10, Solver=1)
):
    """
    Hàm benchmark tổng hợp cho cả AI Model và Numerical Solver.
    """
    num_rays = len(test_rays)
    
    # 1. Xác định số lần chạy mặc định nếu không truyền vào
    if n_runs is None:
        n_runs = 10 if method_type == "model" else 1
    
    # 2. KIỂM TRA TRÙNG LẶP TRONG CSV
    if os.path.exists(csv_path):
        try:
            df_check = pd.read_csv(csv_path)
            is_exist = not df_check[(df_check['model'] == name) & 
                                    (df_check['num_rays'] == num_rays)].empty
            if is_exist:
                print(f"⚠️  [EXIST] Kết quả '{name}' ({num_rays} rays) đã có.")
                user_resp = input("   Chạy lại? (y/n): ").strip().lower()
                if user_resp != 'y':
                    return df_check
        except: pass

    print(f"\n🚀 BENCHMARKING: {name}")
    print(f"   Type: {method_type} | Rays: {num_rays} | Repeats: {n_runs}")

    # 3. CHUẨN BỊ (Warm-up cho Model)
    device = None
    if method_type == "model" and model is not None:
        model.eval()
        device = next(model.parameters()).device
        # Warm-up 1 pass
        dummy_ray = torch.from_numpy(test_rays[0]).float().unsqueeze(0).to(device)
        with torch.no_grad(): _ = model(dummy_ray)

    # 4. ĐO THỜI GIAN VÀ CHẠY
    total_time = 0
    pf_pred_final = []

    for i in range(n_runs):
        t1 = time.time()
        current_pf_vals = []

        # --- CASE A: DEEP LEARNING MODEL ---
        if method_type == "model":
            for r in test_rays:
                ray_t = torch.from_numpy(r).float().unsqueeze(0).to(device)
                with torch.no_grad():
                    output_x = model(ray_t).flatten()
                    x_cpu = output_x.cpu().numpy()
                    vals = [func(x_cpu).item() for func in prob.f]
                    current_pf_vals.append(vals)
        
        # --- CASE B: NUMERICAL SOLVER ---
        elif method_type == "solver":
            for r in test_rays:
                # Gọi solver với tham số unpack từ dict
                x_final, _ = solver_func(
                    prob=prob,
                    x_feasible=x_feasible,
                    r=r,
                    z_star=z_star,
                    verbose=False, # Tắt log chi tiết khi benchmark
                    max_iter=solver_params['max_iter'],
                    mu=solver_params['mu'],
                    init_params=solver_params['init_params'],
                    expo_alpha=solver_params['expo_alpha'],
                    expo_lambda=solver_params['expo_lambda'],
                    expo_beta=solver_params['expo_beta'],
                    expo_gamma=solver_params['expo_gamma']
                )
                current_pf_vals.append(prob.objective_func(x_final))
        
        t2 = time.time()
        run_time = t2 - t1
        total_time += run_time
        
        # In tiến độ nếu chạy Solver (vì lâu)
        if method_type == "solver":
            print(f"   Run {i+1}/{n_runs}: {run_time:.4f}s")
        
        # Lưu kết quả của lần chạy cuối cùng
        if i == n_runs - 1:
            pf_pred_final = np.array(current_pf_vals)

    avg_time = total_time / n_runs
    print(f"   ⏱️ Avg Time: {avg_time:.4f}s")

    # 5. TÍNH METRICS & LƯU
    med, hv = get_metrics(pf_pred_final, pf_true_gt, prob, ref_point)
    print(f"   📊 MED: {med:.5f} | HV: {hv:.5f}")

    new_row = {
        "model": name,
        "num_rays": num_rays,
        "med": med,
        "hv": hv,
        "time": avg_time
    }
    
    if os.path.exists(csv_path):
        df = pd.read_csv(csv_path)
        df = pd.concat([df, pd.DataFrame([new_row])], ignore_index=True)
    else:
        df = pd.DataFrame([new_row])
        
    os.makedirs(os.path.dirname(csv_path), exist_ok=True)
    df.to_csv(csv_path, index=False)
    print(f"✅ Saved to {csv_path}")
    return df

# %%
csv_file = f"exp/{case}/{n_rays}_conclusion.csv"

# 1. Benchmark Hypernetwork MLP
run_benchmark(
    name="Hypernet_MLP",
    method_type="model",
    prob=prob_,
    test_rays=test_rays,
    pf_true_gt=pf_true,      # Ground Truth chuẩn
    ref_point=ref_point,
    model=best_MLP,          # Truyền model vào
    csv_path=csv_file
)

# 2. Benchmark Hypernetwork Transformer
run_benchmark(
    name="Hypernet_Trans",
    method_type="model",
    prob=prob_,
    test_rays=test_rays,
    pf_true_gt=pf_true,
    ref_point=ref_point,
    model=best_trans,        # Truyền model vào
    csv_path=csv_file
)

# 3. Benchmark Numerical Solver (Với tham số tốt nhất)
run_benchmark(
    name="Numerical_Solver",
    method_type="solver",
    prob=prob,
    test_rays=test_rays,
    pf_true_gt=pf_true,
    ref_point=ref_point,
    solver_func=optim_Scalarization,  # Truyền hàm giải
    x_feasible=x_feasible,            # Input cần thiết cho solver
    z_star=z_star,                    # Input cần thiết cho solver
    solver_params=best_params,        # Dictionary chứa {mu, expo_alpha...} từ GridSearch
    csv_path=csv_file,
    n_runs=1                          # Chạy 1 lần vì lâu
)
# Out:
# 🚀 BENCHMARKING: Hypernet_MLP
#    Type: model | Rays: 50 | Repeats: 10
#    ⏱️ Avg Time: 0.0076s
#    📊 MED: 0.00157 | HV: 1.39043
# ✅ Saved to exp/_Ex_7_1/results_summary.csv
#
# 🚀 BENCHMARKING: Hypernet_Trans
#    Type: model | Rays: 50 | Repeats: 10
#    ⏱️ Avg Time: 0.0310s
#    📊 MED: 0.00114 | HV: 1.39037
# ✅ Saved to exp/_Ex_7_1/results_summary.csv
#
# 🚀 BENCHMARKING: Numerical_Solver
#    Type: solver | Rays: 50 | Repeats: 1
# !! Max_iter. Delta: 0.029527, Gap C: 0.000000, Gap Q: 0.019787
# !! Max_iter. Delta: 0.029512, Gap C: 0.000000, Gap Q: 0.021931
# !! Max_iter. Delta: 0.029466, Gap C: 0.000000, Gap Q: 0.026439
# !! Max_iter. Delta: 0.029391, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.029285, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007375, Gap C: 0.000000, Gap Q: 0.035562
# !! Max_iter. Delta: 0.008686, Gap C: 0.000000, Gap Q: 0.015001
# !! Max_iter. Delta: 0.009931, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.011149, Gap C: 0.000000, Gap Q: 0.000010
# !! Max_iter. Delta: 0.012345, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.028002, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014544, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.015613, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.016618, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.026603, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.026156, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.025705, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.025250, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.021013, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.024194, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.023640, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.023133, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.022460, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.024300, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.021211, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.025329, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.019828, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.026144, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.026477, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.026737, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.016893, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.027171, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.027273, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.014489, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.027360, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.024014, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.027202, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.027031, Gap C: 0.000000, Gap Q: 0.000000
# !! Max_iter. Delta: 0.010198, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.009286, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.008401, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.007490, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.025098, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.005644, Gap C: 0.000001, Gap Q: 0.022105
# !! Max_iter. Delta: 0.023768, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.023880, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.024252, Gap C: 0.000001, Gap Q: 0.002187
# !! Max_iter. Delta: 0.024293, Gap C: 0.000001, Gap Q: 0.000000
# !! Max_iter. Delta: 0.023479, Gap C: 0.000001, Gap Q: 0.000002
# !! Max_iter. Delta: 0.022910, Gap C: 0.000001, Gap Q: 0.026824
#    Run 1/1: 145.9212s
#    ⏱️ Avg Time: 145.9212s
#    📊 MED: 0.00401 | HV: 1.38244
# ✅ Saved to exp/_Ex_7_1/results_summary.csv
#               model  num_rays       med        hv        time
# 0      Hypernet_MLP        50  0.001573  1.390434    0.007625
# 1    Hypernet_Trans        50  0.001139  1.390369    0.030978
# 2  Numerical_Solver        50  0.004014  1.382445  145.921243

# %%
pd.read_csv(csv_file)
# Out:
#               model  num_rays       med        hv        time
# 0      Hypernet_MLP        50  0.001573  1.390434    0.007625
# 1    Hypernet_Trans        50  0.001139  1.390369    0.030978
# 2  Numerical_Solver        50  0.004014  1.382445  145.921243
